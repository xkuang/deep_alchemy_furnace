# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#GPU" data-toc-modified-id="GPU-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>GPU</a></div><div class="lev1 toc-item"><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Preprocessing</a></div><div class="lev2 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load Data</a></div><div class="lev3 toc-item"><a href="#Load-Train-Data" data-toc-modified-id="Load-Train-Data-211"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Load Train Data</a></div><div class="lev3 toc-item"><a href="#Train-Data-Sample" data-toc-modified-id="Train-Data-Sample-212"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Train Data Sample</a></div><div class="lev3 toc-item"><a href="#Load-Test-Data" data-toc-modified-id="Load-Test-Data-213"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Load Test Data</a></div><div class="lev3 toc-item"><a href="#Test-Data-Sample" data-toc-modified-id="Test-Data-Sample-214"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Test Data Sample</a></div><div class="lev3 toc-item"><a href="#Relation-Types" data-toc-modified-id="Relation-Types-215"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Relation Types</a></div><div class="lev2 toc-item"><a href="#Participle" data-toc-modified-id="Participle-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Participle</a></div><div class="lev2 toc-item"><a href="#Make-Adjacency-List" data-toc-modified-id="Make-Adjacency-List-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Make Adjacency List</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Train-Data" data-toc-modified-id="Make-Adjacency-List-of-Train-Data-231"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Make Adjacency List of Train Data</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Test-Data" data-toc-modified-id="Make-Adjacency-List-of-Test-Data-232"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Make Adjacency List of Test Data</a></div><div class="lev1 toc-item"><a href="#Word-to-Vector" data-toc-modified-id="Word-to-Vector-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Word to Vector</a></div><div class="lev2 toc-item"><a href="#Tokenize-Text" data-toc-modified-id="Tokenize-Text-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Tokenize Text</a></div><div class="lev2 toc-item"><a href="#Create-Word-Embeddings-with-GloVe" data-toc-modified-id="Create-Word-Embeddings-with-GloVe-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create Word Embeddings with GloVe</a></div><div class="lev3 toc-item"><a href="#Read-GloVe" data-toc-modified-id="Read-GloVe-321"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Read GloVe</a></div><div class="lev3 toc-item"><a href="#Use-Glove-to-Initialize-Embedding-Matrix" data-toc-modified-id="Use-Glove-to-Initialize-Embedding-Matrix-322"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Use Glove to Initialize Embedding Matrix</a></div><div class="lev1 toc-item"><a href="#Build-Dateset" data-toc-modified-id="Build-Dateset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Build Dateset</a></div><div class="lev1 toc-item"><a href="#Save-Dataset" data-toc-modified-id="Save-Dataset-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Save Dataset</a></div><div class="lev1 toc-item"><a href="#Checkpoint" data-toc-modified-id="Checkpoint-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Checkpoint</a></div><div class="lev1 toc-item"><a href="#Build-Model" data-toc-modified-id="Build-Model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Build Model</a></div><div class="lev2 toc-item"><a href="#Set-Hyperparameters" data-toc-modified-id="Set-Hyperparameters-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Set Hyperparameters</a></div><div class="lev2 toc-item"><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Import Libraries</a></div><div class="lev2 toc-item"><a href="#Build-Graph" data-toc-modified-id="Build-Graph-73"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Build Graph</a></div><div class="lev2 toc-item"><a href="#Model-Visualization" data-toc-modified-id="Model-Visualization-74"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Model Visualization</a></div><div class="lev2 toc-item"><a href="#Train" data-toc-modified-id="Train-75"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Train</a></div><div class="lev1 toc-item"><a href="#Evaluate" data-toc-modified-id="Evaluate-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Evaluate</a></div>

# %% [markdown]
# # GPU

# %%
import tensorflow as tf 
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Default GPU Device:

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Load Train Data

# %%
import json

# %%
sentText = []
relationMentions = []
relationLabels = []
entityMentions = []
entityLabels = []
em1Text = []
em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/train.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    # Exclude "None" label
    if not all(i['label'] == 'None' for i in item['relationMentions']):
        sentText.append(item['sentText'])
        relationMentions.append(item['relationMentions'])
        entityMentions.append(item['entityMentions'])
    
relationLabels = [[i['label'].split('/')[-1] for i in rM] for rM in relationMentions]
entityLabels = [[i['text'] for i in eM] for eM in entityMentions]
em1Text = [[i['em1Text'] for i in rM] for rM in relationMentions]
em2Text = [[i['em2Text'] for i in rM] for rM in relationMentions]

# %%
# Clean words
replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
em1Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em1Text]
em2Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em2Text]

# %% [markdown]
# ### Train Data Sample

# %%
sentText[0]
# Out:
# 'But that spasm of irritation by a master intimidator was minor compared with what Bobby Fischer , the erratic former world chess champion , dished out in March at a news conference in Reykjavik , Iceland .'

# %%
relationMentions[0]
# Out:
# [{'em1Text': 'Bobby Fischer',
#   'em2Text': 'Iceland',
#   'label': '/people/person/nationality'},
#  {'em1Text': 'Iceland',
#   'em2Text': 'Reykjavik',
#   'label': '/location/country/capital'},
#  {'em1Text': 'Iceland',
#   'em2Text': 'Reykjavik',
#   'label': '/location/location/contains'},
#  {'em1Text': 'Bobby Fischer',
#   'em2Text': 'Reykjavik',
#   'label': '/people/deceased_person/place_of_death'}]

# %%
relationLabels[0]
# Out:
# ['nationality', 'capital', 'contains', 'place_of_death']

# %%
entityMentions[0]
# Out:
# [{'label': 'PERSON', 'start': 0, 'text': 'Bobby Fischer'},
#  {'label': 'LOCATION', 'start': 1, 'text': 'Reykjavik'},
#  {'label': 'LOCATION', 'start': 2, 'text': 'Iceland'}]

# %%
entityLabels[0]
# Out:
# ['Bobby Fischer', 'Reykjavik', 'Iceland']

# %%
em1Text[0]
# Out:
# ['Bobby Fischer', 'Iceland', 'Iceland', 'Bobby Fischer']

# %%
em2Text[0]
# Out:
# ['Iceland', 'Reykjavik', 'Reykjavik', 'Reykjavik']

# %% [markdown]
# ### Load Test Data

# %%
t_sentText = []
t_relationMentions = []
t_relationLabels = []
t_entityMentions = []
t_entityLabels = []
t_em1Text = []
t_em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/test.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    t_sentText.append(item['sentText'])
    t_relationMentions.append(item['relationMentions'])
    t_entityMentions.append(item['entityMentions'])
    
t_relationLabels = [[i['label'].split('/')[-1] for i in rM] for rM in t_relationMentions]
t_entityLabels = [[i['text'] for i in eM] for eM in t_entityMentions]
t_em1Text = [[i['em1Text'] for i in rM] for rM in t_relationMentions]
t_em2Text = [[i['em2Text'] for i in rM] for rM in t_relationMentions]

# %%
# Clean words
t_replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
t_em1Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em1Text]
t_em2Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em2Text]
t_entityLabels = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_entityLabels]

# %% [markdown]
# ### Test Data Sample

# %%
t_sentText[254]
# Out:
# '"His idea -- one that has rarely , if ever , been tried on a large scale by a major museum -- is to collect significant pieces of midcentury residential architecture , including houses by Rudolf M. Schindler , Richard Neutra , Frank Lloyd Wright and his son Lloyd Wright , and to treat them as both museum objects and as residences for curators ."\r\n'

# %%
t_relationMentions[254]
# Out:
# [{'em1Text': 'Richard Neutra', 'em2Text': 'Lloyd Wright', 'label': 'None'},
#  {'em1Text': 'Lloyd Wright', 'em2Text': 'Richard Neutra', 'label': 'None'},
#  {'em1Text': 'Frank Lloyd Wright',
#   'em2Text': 'Lloyd Wright',
#   'label': '/people/person/children'},
#  {'em1Text': 'Lloyd Wright', 'em2Text': 'Frank Lloyd Wright', 'label': 'None'},
#  {'em1Text': 'Richard Neutra',
#   'em2Text': 'Frank Lloyd Wright',
#   'label': 'None'},
#  {'em1Text': 'Frank Lloyd Wright',
#   'em2Text': 'Richard Neutra',
#   'label': 'None'}]

# %%
t_relationLabels[254]
# Out:
# ['None', 'None', 'children', 'None', 'None', 'None']

# %%
t_entityMentions[254]
# Out:
# [{'label': 'PERSON', 'start': 1, 'text': 'Richard Neutra'},
#  {'label': 'PERSON', 'start': 2, 'text': 'Frank Lloyd Wright'},
#  {'label': 'PERSON', 'start': 3, 'text': 'Lloyd Wright'}]

# %%
t_entityLabels[254]
# Out:
# ['Richard Neutra', 'Frank Lloyd Wright', 'Lloyd Wright']

# %%
t_em1Text[254]
# Out:
# ['Richard Neutra',
#  'Lloyd Wright',
#  'Frank Lloyd Wright',
#  'Lloyd Wright',
#  'Richard Neutra',
#  'Frank Lloyd Wright']

# %%
t_em2Text[254]
# Out:
# ['Lloyd Wright',
#  'Richard Neutra',
#  'Lloyd Wright',
#  'Frank Lloyd Wright',
#  'Frank Lloyd Wright',
#  'Richard Neutra']

# %% [markdown]
# ###  Relation Types

# %%
relationTypes = list(set([r for rl in relationLabels for r in rl]))
relationTypes
# Out:
# ['contains',
#  'company',
#  'nationality',
#  'geographic_distribution',
#  'founders',
#  'industry',
#  'place_of_birth',
#  'teams',
#  'capital',
#  'ethnicity',
#  'major_shareholder_of',
#  'children',
#  'advisors',
#  'religion',
#  'place_lived',
#  'profession',
#  'place_founded',
#  'neighborhood_of',
#  'people',
#  'administrative_divisions',
#  'location',
#  'place_of_death',
#  'country',
#  'major_shareholders']

# %%
t_relationTypes = list(set([r for rl in t_relationLabels for r in rl if r != 'None']))
t_relationTypes
# Out:
# ['capital',
#  'contains',
#  'nationality',
#  'founders',
#  'neighborhood_of',
#  'administrative_divisions',
#  'place_of_birth',
#  'children',
#  'company',
#  'place_of_death',
#  'country',
#  'place_lived']

# %% [markdown]
# ## Participle

# %%
from nltk import regexp_tokenize

# %%
def cut(s):
    """
    Participle
    """
    pattern = r'''
              (?x)                   # set flag to allow verbose regexps 
              (?:[A-Z]\.)+           # abbreviations, e.g. U.S.A. 
              |\d+(?:\.\d+)?%?       # numbers, incl. currency and percentages 
              |\w+(?:[-']\w+)*       # words w/ optional internal hyphens/apostrophe  
           '''  
    return regexp_tokenize(s, pattern=pattern)

# %%
sentWords = [cut(s) for s in sentText]
entlabWords = [[cut(s) for s in eL] for eL in entityLabels]
em1Words = [[cut(s) for s in eL] for eL in em1Text]
em2Words = [[cut(s) for s in eL] for eL in em2Text]
t_sentWords = [cut(s) for s in t_sentText]
t_entlabWords = [[cut(s) for s in eL] for eL in t_entityLabels]
t_em1Words = [[cut(s) for s in eL] for eL in t_em1Text]
t_em2Words = [[cut(s) for s in eL] for eL in t_em2Text]

# %%
MAX_SENT_LEN = 120
MAX_ADJL_LEN = 20

# %%
len([i for i, j in enumerate(sentWords) if len(j) > 120])
#max(len(j) for i, j in enumerate(t_sentWords) if len(j) > 80)
# Out:
# 31

# %% [markdown]
# ## Make Adjacency List

# %% [markdown]
# ### Make Adjacency List of Train Data

# %%
from collections import Counter

# %%
i_entityLabels
# Out:
# [[[14, 15], [31], [32]],
#  [[9, 10], [12], [26, 27], [33, 34, 35]],
#  [[9], [12, 13]],
#  [[13, 14, 15], [18, 19]],
#  [[12], [13]],
#  [[11], [12]],
#  [[0], [1]],
#  [[24, 25, 26], [31], [41]],
#  [[12], [30, 31, 32]],
#  [[9, 10], [11, 12], [23, 24], [25]],
#  [[7], [8], [38, 39]],
#  [[16, 17], [25], [40, 41]],
#  [[2], [10, 11]],
#  [[5], [18]],
#  [[8, 9], [23, 24]],
#  [[1], [6, 7], [9, 10]],
#  [[2], [5, 6], [8], [9], [14, 15]],
#  [[9, 10], [12], [30, 31], [45]],
#  [[10], [31], [32]],
#  [[2], [27, 28, 29, 30]],
#  [[3], [17, 18]],
#  [[6, 7], [13]],
#  [[12, 13], [16], [18], [19, 20]],
#  [[2], [3, 4]],
#  [[0], [2, 3]],
#  [[18], [36, 37]],
#  [[12], [29]],
#  [[19], [32, 33], [39], [42, 43]],
#  [[16, 17, 18], [25]],
#  [[2, 3], [8], [13, 14], [15], [26], [39]],
#  [[21, 22], [28]],
#  [[15, 16], [24], [25], [28, 29]],
#  [[9], [40, 41, 42]],
#  [[18], [33], [18, 37]],
#  [[29], [38, 39], [60, 61], [70]],
#  [[3], [22], [45]],
#  [[2], [5, 6], [22], [37]],
#  [[0], [16, 17], [19]],
#  [[3, 4], [6]],
#  [[0], [16]],
#  [[6, 7], [9, 10], [12], [20, 21]],
#  [[9, 10], [17, 18]],
#  [[0], [39]],
#  [[7], [10], [16]],
#  [[7, 8], [20]],
#  [[18, 19], [40], [41]],
#  [[19, 20], [23, 24]],
#  [[0], [2], [9], [11, 12]],
#  [[21, 22], [33]],
#  [[0, 1], [3, 4], [20]],
#  [[1, 2], [5, 6], [8, 9], [12]],
#  [[9], [18], [19]],
#  [[7], [12, 13], [18, 19], [21, 22], [27, 28, 29], [31], [37], [41], [54]],
#  [[1], [7], [20]],
#  [[4, 5], [11]],
#  [[9], [9], [55]],
#  [[10], [12], [17, 18], [26], [12], [10], [86, 87]],
#  [[10, 11], [17], [21, 22], [28, 29]],
#  [[10], [14], [16], [16]],
#  [[1], [3, 4], [11], [12, 13], [18]],
#  [[0, 1], [3]],
#  [[1], [11, 12], [14], [18], [18], [14]],
#  [[18], [46], [49, 50]],
#  [[7, 8], [15]],
#  [[1], [13], [13], [33], [53]],
#  [[6, 7], [17, 18, 19, 20], [22, 23, 24], [33, 34], [40]],
#  [[2], [7, 8], [36, 37]],
#  [[1, 2], [4], [7, 8]],
#  [[20], [26, 27, 28]],
#  [[0], [5, 6], [8], [24]],
#  [[10, 11], [18, 19], [21]],
#  [[14, 15], [16]],
#  [[8], [24]],
#  [[15], [18, 19]],
#  [[24], [34]],
#  [[4, 5, 6], [20, 21], [34], [36, 37]],
#  [[4, 5, 6], [9], [17]],
#  [[7, 8, 9, 10], [17, 18]],
#  [[8, 9, 10], [12, 13]],
#  [[7, 8, 9], [7, 8], [7, 42]],
#  [[0, 1], [8, 9]],
#  [[9, 10], [12]],
#  [[3, 4], [5], [16]],
#  [[4], [8]],
#  [[14], [25], [14]],
#  [[3, 4, 5], [29], [32]],
#  [[2], [14], [20, 21, 22], [2]],
#  [[7], [19]],
#  [[24], [44]],
#  [[1], [5]],
#  [[0], [20]],
#  [[7, 8, 9], [14, 15], [20, 21], [20, 26], [34]],
#  [[9], [10]],
#  [[0, 1], [12]],
#  [[7, 8], [26]],
#  [[11, 12], [14]],
#  [[0, 1, 2], [21, 22]],
#  [[3], [9], [3], [29], [39, 40], [3]],
#  [[25, 26], [28]],
#  [[10], [21, 22], [41, 42], [45, 46]],
#  [[10], [11]],
#  [[2, 3], [5], [12, 13]],
#  [[1], [16], [23, 24]],
#  [[6], [12, 13]],
#  [[1], [2, 3], [10, 11]],
#  [[23, 24], [26, 27, 28], [30]],
#  [[8], [28]],
#  [[14, 15], [33], [35]],
#  [[16, 17], [30]],
#  [[6, 7], [20, 21]],
#  [[5], [18], [34]],
#  [[0], [12]],
#  [[24, 25], [27]],
#  [[3, 4], [8, 9, 10]],
#  [[5], [26, 27], [28], [30], [35]],
#  [[14, 15, 16], [17]],
#  [[22, 23], [26, 27]],
#  [[6], [9, 10], [12], [6]],
#  [[1, 2], [4], [27]],
#  [[6, 7], [9]],
#  [[18], [19, 20]],
#  [[3, 4], [6], [7, 8]],
#  [[15, 16], [17, 18]],
#  [[5], [18, 19]],
#  [[4, 5], [8, 9], [41, 42]],
#  [[6, 7], [14, 15]],
#  [[0, 1], [3, 4]],
#  [[1], [9, 10, 11]],
#  [[0], [15]],
#  [[1], [7], [12, 13]],
#  [[0], [9, 10]],
#  [[0], [12, 13], [16], [18]],
#  [[0], [9, 10], [0], [25, 26]],
#  [[1, 2], [4], [14, 15]],
#  [[11, 12], [14], [28, 29], [37], [14]],
#  [[0], [13], [16], [65, 66]],
#  [[3], [12, 13], [33, 34]],
#  [[2], [7], [12], [13], [14], [15], [17], [18]],
#  [[5, 6], [8], [18], [23, 24]],
#  [[10], [19]],
#  [[9], [14]],
#  [[1], [5, 6], [18, 19], [27], [37, 38]],
#  [[17, 18], [20], [25, 26], [28]],
#  [[8], [12, 13]],
#  [[8, 9], [15], [22, 23], [35]],
#  [[18], [34, 35], [39], [51, 52], [53], [18]],
#  [[15, 16], [22, 23, 24], [27]],
#  [[10, 11], [13, 14, 15], [40, 41], [44]],
#  [[23, 24], [27]],
#  [[14, 15, 16], [17], [23], [24]],
#  [[1, 2, 3], [8, 9], [12]],
#  [[4], [31, 32, 33, 34], [35], [45, 46]],
#  [[37], [39], [41], [47]],
#  [[4, 5], [11], [12]],
#  [[0], [17, 18], [25], [29]],
#  [[0, 1, 2], [6]],
#  [[6, 7], [10]],
#  [[1], [5], [14, 15], [31, 32], [35], [41, 42], [45]],
#  [[18, 19], [20]],
#  [[0, 1], [11], [0, 1, 19]],
#  [[8], [17], [18]],
#  [[3, 4], [33, 34]],
#  [[2, 3, 4], [5], [10], [11], [12, 13], [15]],
#  [[9], [11], [21, 22]],
#  [[0], [3, 4], [7, 8], [38, 39]],
#  [[17, 18, 19, 20, 21], [23], [24]],
#  [[0], [4, 5]],
#  [[5, 6], [11, 12]],
#  [[10], [29, 30, 31, 32], [34]],
#  [[1], [15]],
#  [[12], [25, 26, 27]],
#  [[4], [5], [5]],
#  [[11], [20, 21], [33]],
#  [[9], [23]],
#  [[17], [18, 19]],
#  [[10, 11, 12], [14, 15], [22], [37, 38], [58, 59]],
#  [[6], [9], [11], [0, 14, 15, 16], [24], [9], [14, 15], [11]],
#  [[0], [20]],
#  [[21, 22], [24, 25], [32, 33, 34], [42, 43], [52, 53, 54], [24]],
#  [[6], [7]],
#  [[19], [20]],
#  [[9, 10], [14, 15], [25, 26], [34, 35]],
#  [[16], [27]],
#  [[0], [7]],
#  [[2], [3, 4], [8], [16, 17], [17, 21, 22]],
#  [[1], [15]],
#  [[1], [15]],
#  [[7, 8], [18], [39], [51, 52]],
#  [[8], [19, 20], [23]],
#  [[12], [13], [27], [28], [30, 31], [12], [39, 40]],
#  [[0], [30], [37]],
#  [[7], [28]],
#  [[3], [9]],
#  [[1], [11]],
#  [[11], [22]],
#  [[10], [18], [21], [25]],
#  [[3], [18]],
#  [[1], [4], [14], [15], [17]],
#  [[32], [41, 42], [51]],
#  [[1, 2], [11], [14], [19, 20]],
#  [[7, 8], [13, 14, 15], [27, 28, 29]],
#  [[9], [12], [18], [28], [39], [57, 58]],
#  [[11], [19]],
#  [[4], [12, 13], [15], [38], [46]],
#  [[3], [5], [23]],
#  [[9], [27]],
#  [[19, 20], [26]],
#  [[1, 2], [5], [16, 17], [22, 23]],
#  [[3, 4], [21]],
#  [[6], [7], [9], [10], [35, 36], [38, 39]],
#  [[0], [1]],
#  [[1], [12], [13]],
#  [[12], [23, 24]],
#  [[7], [11, 12, 13], [28]],
#  [[5], [19], [19], [35, 36, 37]],
#  [[1, 2], [8, 9], [11], [14]],
#  [[4], [28]],
#  [[11, 12], [16, 17], [20], [28, 29]],
#  [[17, 18], [20]],
#  [[3, 4, 5], [24]],
#  [[17], [21, 22]],
#  [[4], [15]],
#  [[0], [9, 10], [11, 12], [13], [15], [20], [21], [23]],
#  [[0, 1], [9]],
#  [[2, 3], [4, 5]],
#  [[5], [16, 17], [20, 21]],
#  [[9], [15, 16]],
#  [[1], [4], [8], [17, 18]],
#  [[0], [16, 17], [29, 30], [16, 17]],
#  [[4], [14, 15, 16]],
#  [[0], [7, 8]],
#  [[16, 17], [33, 34]],
#  [[17], [18]],
#  [[10], [19, 20]],
#  [[2, 3], [9, 10], [13]],
#  [[0, 1], [5], [12, 13]],
#  [[32], [34], [35], [37, 38, 39]],
#  [[3], [13], [3], [32]],
#  [[2], [13], [23]],
#  [[1], [16]],
#  [[7, 8], [10], [15], [16], [18]],
#  [[4, 5], [6, 7]],
#  [[6, 7], [11, 12]],
#  [[19, 20, 21], [23], [24, 25]],
#  [[4, 5], [9, 10], [11]],
#  [[11, 12], [16, 17], [19, 20], [28]],
#  [[7, 8], [10]],
#  [[17], [18]],
#  [[1], [14], [25]],
#  [[17], [18], [22], [23], [29], [30], [38], [39], [52, 53], [30]],
#  [[4], [7], [10], [11], [12], [13], [15], [16], [21]],
#  [[17], [19], [44, 45], [54, 55]],
#  [[5], [7, 8], [11], [13], [22]],
#  [[0, 1], [11, 12]],
#  [[9, 10], [25, 26], [9]],
#  [[16, 17], [28]],
#  [[1, 2], [6], [9]],
#  [[0], [15], [23]],
#  [[7], [11, 12]],
#  [[13], [14]],
#  [[0, 1], [6], [7]],
#  [[13], [15, 16]],
#  [[14, 15], [32, 33], [35]],
#  [[29], [37], [39], [60]],
#  [[18], [26], [30], [34, 35], [46]],
#  [[7], [39]],
#  [[0], [12, 13], [12]],
#  [[9], [10], [14, 15], [17]],
#  [[10], [15]],
#  [[2, 3], [5]],
#  [[2, 3], [5]],
#  [[2], [5], [9], [21, 22, 23], [29], [2, 34]],
#  [[7], [19], [0, 32]],
#  [[3], [6, 7], [8, 9], [16, 17], [23, 24]],
#  [[0], [9, 10], [15]],
#  [[0], [10, 11], [28, 29]],
#  [[0], [4, 5]],
#  [[6], [21], [40]],
#  [[42, 43], [45, 46]],
#  [[23, 24, 25, 26], [28]],
#  [[9, 10, 11, 12], [14]],
#  [[10], [12], [23, 24]],
#  [[10], [11], [19], [11]],
#  [[6], [9], [11]],
#  [[2, 3], [12, 13]],
#  [[6], [7]],
#  [[8, 9], [10]],
#  [[1], [2], [17]],
#  [[7], [18, 19, 20]],
#  [[28, 29], [30]],
#  [[11, 12], [14], [32], [38, 39], [11]],
#  [[12], [14], [16], [18], [22]],
#  [[0, 1], [6], [11, 12], [14], [15], [17], [20, 21]],
#  [[2], [3], [4], [5], [7], [24]],
#  [[1], [2], [3, 4], [6, 7]],
#  [[11], [15], [31, 32, 33]],
#  [[7, 8], [12, 13], [16], [7, 21, 22]],
#  [[1], [2], [3, 4], [6], [17, 18], [21], [22, 23], [24], [25], [27]],
#  [[13], [30, 31], [33], [41, 42]],
#  [[28], [29], [36, 37], [45, 46]],
#  [[3, 4, 5], [8]],
#  [[0], [5, 6], [16], [20], [34, 35]],
#  [[6], [16]],
#  [[0], [8], [0], [27]],
#  [[12], [18], [19]],
#  [[16, 17], [23], [26]],
#  [[9], [17], [18]],
#  [[1], [13], [14], [13, 24, 25, 26]],
#  [[10, 11], [24, 25], [28], [38], [54], [54], [75, 76], [17, 90]],
#  [[0, 1], [9, 10, 11], [19, 20], [26, 27]],
#  [[5, 6], [5, 6, 14]],
#  [[13, 14], [34, 35], [43, 44]],
#  [[19], [26]],
#  [[3, 4], [19]],
#  [[20], [22]],
#  [[0], [28, 29]],
#  [[2, 3], [8], [19], [22]],
#  [[19, 20, 21, 22, 23], [25]],
#  [[7, 8], [10], [15, 16], [10]],
#  [[1, 2, 3], [7], [9], [23, 24]],
#  [[11], [15], [20], [25]],
#  [[7, 8], [11]],
#  [[10], [19, 20, 21, 22], [20], [25]],
#  [[1], [11], [13]],
#  [[1], [11], [14], [27], [36]],
#  [[3], [8], [22], [23]],
#  [[7], [18]],
#  [[9], [12, 13], [15, 16], [20]],
#  [[0, 1], [13], [0, 1], [39, 40], [45], [13]],
#  [[9], [10, 11], [13, 14, 15]],
#  [[1], [3], [15]],
#  [[4, 5], [12], [35], [37]],
#  [[7, 8, 9], [23, 24], [31]],
#  [[12], [21, 22], [29, 30, 31]],
#  [[11], [12, 13], [47, 48, 49]],
#  [[7, 8, 9], [10]],
#  [[3, 4], [16, 17, 18], [32, 33], [35]],
#  [[6], [11]],
#  [[12, 13], [14, 15], [20], [22], [25, 26], [27, 28], [27, 31], [38, 39]],
#  [[3, 4], [5, 6], [5, 8], [13, 14], [17, 18], [23]],
#  [[0, 1], [50], [70]],
#  [[0, 1], [2]],
#  [[5, 6], [12, 13]],
#  [[19], [22], [24]],
#  [[18, 19], [23, 24, 25]],
#  [[13], [14]],
#  [[10], [11]],
#  [[14], [15]],
#  [[4], [8], [15], [39]],
#  [[18], [26, 27], [28], [33, 34]],
#  [[0], [12], [14], [15]],
#  [[6, 7], [9]],
#  [[6, 7, 8], [10, 11], [16, 17]],
#  [[30, 31], [30, 31, 38]],
#  [[11, 12], [16], [24, 25]],
#  [[18, 19], [22]],
#  [[22, 23, 24, 25], [26]],
#  [[6, 7, 8], [10]],
#  [[11, 12, 13, 14, 15], [17]],
#  [[2, 3], [6]],
#  [[16], [17]],
#  [[18, 19], [21, 22], [25, 26], [27], [28], [33]],
#  [[7], [14], [20], [33], [36], [41, 42], [44, 45]],
#  [[0, 1], [17], [17]],
#  [[20], [26, 27], [37, 38], [40, 41]],
#  [[14], [18, 19], [22], [30], [34, 35]],
#  [[3], [20]],
#  [[14], [18, 19]],
#  [[5, 6], [12], [18], [21], [27], [38], [39]],
#  [[0, 1], [6, 7, 8, 9]],
#  [[10], [19], [10]],
#  [[4], [7, 8], [13, 14], [19]],
#  [[8, 9], [17, 18]],
#  [[0, 1], [2, 3], [38, 39], [44]],
#  [[18, 19, 20, 21], [23, 24]],
#  [[25, 26], [30]],
#  [[22, 23, 24], [26, 27]],
#  [[20], [27], [28]],
#  [[2], [3]],
#  [[10], [12, 13]],
#  [[11], [13, 14], [24, 25], [27, 28]],
#  [[10], [11, 12], [11, 12]],
#  [[0], [21, 22]],
#  [[8], [14], [19]],
#  [[9], [15, 16]],
#  [[0], [3, 4], [17], [26, 27]],
#  [[9], [32, 33], [38, 39], [32, 43], [47]],
#  [[3], [8]],
#  [[0, 1], [14, 15, 16], [24]],
#  [[10, 11], [14], [20]],
#  [[2, 3, 4], [17], [25, 26]],
#  [[5, 6], [28, 29], [32, 33], [35]],
#  [[4], [5]],
#  [[7, 8], [27], [28], [44]],
#  [[5, 6], [33], [5], [5]],
#  [[12], [22], [25]],
#  [[1], [8], [16, 17]],
#  [[0, 1, 2], [13]],
#  [[4, 5], [13], [24]],
#  [[17, 18], [20], [26, 27]],
#  [[6, 7, 8], [11], [14]],
#  [[0], [3, 4]],
#  [[4, 5], [7, 8], [10], [12, 13]],
#  [[11, 12], [21, 22, 23, 24]],
#  [[13, 14, 15], [20], [22], [13, 14], [46], [57]],
#  [[5], [8]],
#  [[3], [9, 10]],
#  [[4], [17]],
#  [[7, 8, 9, 10], [23], [34, 35]],
#  [[2, 3], [17, 18, 19]],
#  [[8, 9], [11], [15], [18, 19], [21], [24, 25]],
#  [[10, 11], [17], [19], [21], [28], [30, 31, 32]],
#  [[0], [5], [22]],
#  [[4], [12], [13]],
#  [[0, 1], [3, 4], [11]],
#  [[1], [14], [16, 17], [18], [27], [28], [33], [34, 35], [14]],
#  [[7, 8], [9]],
#  [[7], [35, 36]],
#  [[8, 9], [12], [14, 15, 16], [8, 9]],
#  [[6, 7], [9, 10]],
#  [[4], [11, 12], [14]],
#  [[8], [10], [32], [45, 46], [8]],
#  [[5], [6, 7, 8], [6]],
#  [[9], [13], [14], [16], [9], [26], [28]],
#  [[11], [22, 23]],
#  [[10, 11], [13], [10, 16], [18, 19]],
#  [[9, 10], [12], [17]],
#  [[24], [27, 28], [24], [37]],
#  [[7], [11, 12], [19]],
#  [[5], [27, 28]],
#  [[0], [2], [12, 13], [14], [16, 17]],
#  [[7, 8], [10], [34]],
#  [[18, 19], [31]],
#  [[21], [35]],
#  [[23], [29]],
#  [[18], [28]],
#  [[23, 24], [34, 35]],
#  [[5], [17], [19], [32], [34, 35], [40], [42]],
#  [[0], [33, 34]],
#  [[19, 20], [23]],
#  [[15], [17, 18], [20]],
#  [[1, 2, 3], [5]],
#  [[0, 1], [3, 4, 5, 6]],
#  [[7, 8], [15], [17], [27], [41, 42]],
#  [[14, 15], [16, 17, 18], [20], [26], [31], [38]],
#  [[18], [34], [39], [44], [45], [46], [48]],
#  [[14, 15], [18], [26, 27]],
#  [[11], [14, 15], [25]],
#  [[42], [38, 48], [50]],
#  [[8], [28, 29]],
#  [[3], [10], [19, 20, 21], [30], [32, 33]],
#  [[15, 16], [18]],
#  [[1, 2], [12, 13]],
#  [[8, 9], [12, 13], [26]],
#  [[7], [27]],
#  [[2, 3], [11, 12, 13], [17, 18], [39]],
#  [[6, 7], [17], [27], [29, 30]],
#  [[8], [9, 10, 11], [8], [28]],
#  [[0, 1], [4]],
#  [[10, 11], [14]],
#  [[4], [6, 7], [11, 12], [13, 14], [6, 7], [24], [32], [33, 34], [38]],
#  [[1, 2], [4], [10]],
#  [[3], [13], [21], [22], [23], [24]],
#  [[8], [10, 11], [15, 16], [0]],
#  [[3, 4], [13], [18, 19]],
#  [[13, 14], [20]],
#  [[21], [24], [31]],
#  [[8, 9], [26, 27], [30]],
#  [[0], [2], [10], [20, 21], [6, 29]],
#  [[0], [2], [9, 10], [12], [14, 15], [17], [36]],
#  [[8, 9], [12], [19, 20]],
#  [[8], [9, 10], [19, 20, 21]],
#  [[3, 4], [16, 17], [22, 23]],
#  [[6], [15], [17], [17]],
#  [[11], [32]],
#  [[6, 7], [17], [33, 34], [35, 36], [37, 38]],
#  [[20], [44]],
#  [[22, 23], [25], [22, 43], [45]],
#  [[12, 13, 14, 15], [17]],
#  [[4], [5]],
#  [[1], [2], [3, 4], [6, 7]],
#  [[11], [15], [31, 32, 33]],
#  [[7, 8], [12, 13], [16], [7, 21, 22]],
#  [[1], [2], [3, 4], [6], [17, 18], [21], [22, 23], [24], [25], [27]],
#  [[13], [30, 31], [33], [41, 42]],
#  [[5], [27]],
#  [[19, 20], [25, 26]],
#  [[3, 4], [6, 7]],
#  [[0, 1], [3]],
#  [[17, 18], [20, 21, 22], [30, 31]],
#  [[0, 1, 2], [13, 14, 15]],
#  [[9, 10], [13, 14]],
#  [[2, 3], [9], [13, 14]],
#  [[9, 10], [12], [15], [17, 18]],
#  [[39], [41, 42]],
#  [[19, 20], [23]],
#  [[19, 20, 21, 22], [26]],
#  [[15, 16], [17]],
#  [[3], [4, 5], [7, 8], [10, 11], [13]],
#  [[38], [43, 44], [49]],
#  [[12, 13], [14]],
#  [[12], [3, 21]],
#  [[2], [9, 10]],
#  [[16], [17]],
#  [[12], [19]],
#  [[10, 11], [17, 18], [27, 28, 29, 30], [39, 40, 41]],
#  [[27], [30], [39, 40]],
#  [[20, 21], [28, 29]],
#  [[10, 11], [12], [14], [18, 19]],
#  [[7], [15], [7]],
#  [[18], [24]],
#  [[0], [8, 9, 10], [24, 25]],
#  [[0, 1, 2], [14]],
#  [[30], [30], [51, 52, 53], [60]],
#  [[14], [15]],
#  [[7], [23, 24, 25]],
#  [[10, 11], [14], [24], [27]],
#  [[0, 1], [3, 4]],
#  [[20, 21, 22], [29, 30, 31, 32, 33, 34, 35, 36]],
#  [[6, 7], [31]],
#  [[9, 10], [13, 14], [20]],
#  [[4], [6], [17]],
#  [[0, 1], [9], [9, 22]],
#  [[10, 11], [12]],
#  [[16], [17]],
#  [[5], [16, 17]],
#  [[5], [7], [9, 10], [12], [19], [21], [9, 10], [25], [27, 28], [31], [33]],
#  [[2], [4], [12, 13], [20, 21, 22, 23], [25, 26], [34, 35]],
#  [[3], [12, 13], [3]],
#  [[15], [16]],
#  [[5], [6]],
#  [[5, 6], [29, 30]],
#  [[1], [7], [18, 19], [21], [24, 25]],
#  [[8, 9], [12], [12], [8], [35, 36]],
#  [[21], [27, 28]],
#  [[1], [1], [13], [28]],
#  [[39], [40]],
#  [[5, 6], [3]],
#  [[4], [22], [34, 35], [22]],
#  [[2], [2], [39]],
#  [[8], [23, 24], [30]],
#  [[20, 21], [30], [63]],
#  [[6], [7]],
#  [[4], [18]],
#  [[16, 17], [18], [19], [24]],
#  [[0, 1], [11]],
#  [[1], [4], [10]],
#  [[7, 8], [10]],
#  [[2], [9], [18, 19], [21]],
#  [[8], [11], [17], [18, 19], [34, 35], [41, 42]],
#  [[4, 5], [44, 45, 46], [47]],
#  [[9, 10], [30, 31], [33, 34]],
#  [[0], [6], [17], [19]],
#  [[8], [9]],
#  [[10, 11], [12]],
#  [[25, 26, 27, 28], [25]],
#  [[4, 5], [6, 7, 8], [18]],
#  [[0, 1], [5]],
#  [[4, 5], [10]],
#  [[15, 16], [18, 19]],
#  [[8, 9], [31, 32], [38]],
#  [[1], [2, 3], [19, 20], [26]],
#  [[7, 8], [15]],
#  [[2], [7, 8]],
#  [[19], [24], [25]],
#  [[3, 4], [11, 12], [13]],
#  [[24, 25], [28]],
#  [[6], [10], [13], [17], [17]],
#  [[2], [6]],
#  [[0, 1], [7], [0]],
#  [[0, 1], [18], [21], [23, 24], [30]],
#  [[0, 1], [7, 8], [7]],
#  [[11], [23], [26, 27], [29, 30]],
#  [[4], [45, 46]],
#  [[8, 9], [16], [24]],
#  [[12, 13], [14, 15], [17, 18], [21]],
#  [[2, 3], [10], [17], [24], [26]],
#  [[10], [19, 20]],
#  [[1], [2, 3]],
#  [[6, 7], [8]],
#  [[52], [53]],
#  [[16], [17], [19], [21], [28]],
#  [[4], [14], [33], [47], [48], [59, 60], [65, 66]],
#  [[32], [33]],
#  [[15, 16, 17], [18]],
#  [[10, 11], [17, 18, 19]],
#  [[3, 4], [7], [20], [14, 34]],
#  [[5], [7, 8], [11], [24]],
#  [[3], [5, 6], [3]],
#  [[1, 2], [6, 7], [10], [24], [10]],
#  [[28], [29], [38]],
#  [[5], [6, 7], [9]],
#  [[1, 2], [4], [21], [4]],
#  [[7], [26], [28]],
#  [[12], [29]],
#  [[9], [22], [27], [9]],
#  [[4], [12], [16]],
#  [[3], [39, 40, 41]],
#  [[17, 18], [22, 41]],
#  [[0, 1], [10, 11]],
#  [[3, 4, 5], [13, 14], [23, 24, 25]],
#  [[6], [17, 18], [19], [21], [34, 35]],
#  [[1], [8, 9], [10, 13], [15, 16], [23, 24]],
#  [[10], [11], [11]],
#  [[4, 5], [10], [16, 17]],
#  [[8, 9], [11, 12], [16]],
#  [[15, 16], [31]],
#  [[11, 12], [13]],
#  [[8, 9], [10]],
#  [[13, 14], [22, 23]],
#  [[1, 2], [8, 9], [1, 13]],
#  [[2, 3], [18, 19], [22, 23, 24]],
#  [[15, 16], [19], [22]],
#  [[4, 5], [10], [21, 22], [31], [21]],
#  [[6, 7, 8, 9], [25], [26], [38], [48, 49], [56]],
#  [[17], [19]],
#  [[0, 1], [26]],
#  [[9], [10]],
#  [[11, 12], [21, 22], [26]],
#  [[0, 1], [3], [20, 21], [23], [39, 40], [42]],
#  [[26], [27]],
#  [[0], [11]],
#  [[2], [14], [23, 24], [14]],
#  [[18, 19], [21, 22], [24, 25], [27, 28]],
#  [[1], [21], [24]],
#  [[1], [3, 4], [6], [12], [22]],
#  [[10], [11], [19], [28, 29]],
#  [[17, 18], [23, 24]],
#  [[0, 1, 2], [28], [29]],
#  [[14, 15, 16], [14, 15], [46, 47]],
#  [[12], [16]],
#  [[0, 1, 2], [9, 10], [24]],
#  [[2], [12], [13]],
#  [[13, 14], [17, 18], [26]],
#  [[20, 21], [26, 27]],
#  [[20, 21, 22, 23], [29], [11], [41]],
#  [[7, 8], [13], [19], [22, 23], [28, 29], [23], [53, 54], [68]],
#  [[8, 9], [42]],
#  [[6, 7], [25]],
#  [[0, 1],
#   [9, 10],
#   [13, 14, 15, 16, 17],
#   [8, 11, 33, 34],
#   [35, 36],
#   [42, 43, 44],
#   [47, 48, 49, 50]],
#  [[3], [4]],
#  [[0], [7], [8]],
#  [[11], [11], [29], [30]],
#  [[3], [4]],
#  [[1, 2], [3], [4]],
#  [[3], [4]],
#  [[0], [1]],
#  [[2, 3], [9], [14], [21, 22], [28]],
#  [[24, 25], [48, 49, 50], [52], [60, 61, 62]],
#  [[4], [4], [18]],
#  [[2], [2], [14, 15], [7], [25, 26], [7], [7]],
#  [[7, 8], [20]],
#  [[22], [23]],
#  [[21], [22]],
#  [[7], [13]],
#  [[0], [1]],
#  [[11, 12, 13], [18, 19, 20]],
#  [[12, 13], [14], [27]],
#  [[12], [43, 44], [45, 46]],
#  [[1], [18], [22], [18, 41]],
#  [[15], [20], [36], [38], [46, 47]],
#  [[12], [20], [22], [26]],
#  [[6], [9], [6], [36]],
#  [[12, 13], [29, 30], [39, 40], [45], [46]],
#  [[2, 3], [0, 10], [19]],
#  [[8, 9, 10], [14, 15, 16], [18]],
#  [[3, 4], [12], [14], [15, 16], [18, 19], [15], [22, 23], [24], [44]],
#  [[0, 1], [16, 17], [27]],
#  [[3, 4], [12], [22]],
#  [[7], [9, 10], [31], [32], [34]],
#  [[10], [27]],
#  [[9, 10], [12]],
#  [[1], [5], [7]],
#  [[9], [13, 14], [23], [25], [27, 28], [30], [35, 36]],
#  [[11], [12], [12], [28, 29]],
#  [[1], [8], [12], [15, 16], [29], [30]],
#  [[4], [21], [22]],
#  [[25, 26, 27, 28], [30, 31], [25]],
#  [[17], [18]],
#  [[10], [11, 12], [13, 14]],
#  [[16], [28]],
#  [[9], [27], [9]],
#  [[1], [9, 10], [13], [15, 16], [20], [36], [38]],
#  [[7, 8], [10], [12]],
#  [[1, 2], [6], [33]],
#  [[8], [9], [13]],
#  [[22, 23], [24, 25], [38]],
#  [[1], [2], [16]],
#  [[9, 10], [16, 17], [23, 24]],
#  [[1, 2], [8], [19], [32]],
#  [[10], [12], [32]],
#  [[14], [30, 31]],
#  [[8], [17], [22], [24, 25], [27, 28], [32, 33], [38, 39]],
#  [[2, 3], [11], [19], [19]],
#  [[5], [6], [28, 29], [40]],
#  [[8], [11, 12], [11, 12], [32, 33, 34]],
#  [[20, 21], [23, 24], [29, 30, 31, 32]],
#  [[0, 1], [5], [20]],
#  [[10], [20], [39]],
#  [[18], [30], [45]],
#  [[14], [14], [38, 39], [52]],
#  [[14], [19]],
#  [[13, 14, 15], [17, 18], [21, 22]],
#  [[0], [5, 6], [11, 12], [25], [25, 33], [42, 43]],
#  [[11], [15], [15, 27, 28, 29]],
#  [[29, 30], [38], [39]],
#  [[6], [22]],
#  [[7], [22, 23]],
#  [[0, 1], [7], [12, 13], [29, 30]],
#  [[4, 5], [13], [26]],
#  [[12, 13], [19]],
#  [[13, 14], [16]],
#  [[4, 5], [14]],
#  [[1, 2], [23]],
#  [[4], [12, 13], [23], [4], [23]],
#  [[5, 6], [25]],
#  [[6], [7, 8], [11]],
#  [[0, 1, 2], [17], [18]],
#  [[0], [0], [28, 29], [31]],
#  [[7, 8], [10], [21], [22], [23], [34]],
#  [[3, 4], [11], [12], [21]],
#  [[2, 3], [16]],
#  [[3], [7, 8], [16, 17]],
#  [[18, 19], [21], [24]],
#  [[15], [22], [22], [45], [22]],
#  [[10], [22], [27, 28], [33, 34], [38, 39], [41], [52], [54, 55]],
#  [[12], [33]],
#  [[6], [13, 14], [18], [48], [50, 51]],
#  [[6, 7], [8], [24]],
#  [[8, 9], [18, 19], [34], [44]],
#  [[30], [31]],
#  [[11, 12, 13], [23]],
#  [[23, 24], [25]],
#  [[1, 2], [5], [12]],
#  [[15], [17], [20], [21], [23], [25]],
#  [[9], [12], [45]],
#  [[12], [13]],
#  [[0], [7, 8], [10, 11, 12], [20, 21], [23], [29, 30], [32]],
#  [[11, 12], [16]],
#  [[27, 28], [29]],
#  [[13, 14, 15], [46, 47], [48]],
#  [[1, 2], [7, 8], [10]],
#  [[2], [13]],
#  [[4], [11], [16]],
#  [[11], [12]],
#  [[11, 12, 13], [20]],
#  [[13], [42, 43], [44], [45], [46], [48], [58, 59], [61, 62]],
#  [[1], [15]],
#  [[0], [32]],
#  [[16], [21]],
#  [[0], [25], [27]],
#  [[5, 6], [28], [41], [57]],
#  [[9, 10], [12], [22], [31]],
#  [[25, 26], [30], [32, 33], [35]],
#  [[20, 21, 22], [31, 32], [44, 45]],
#  [[25], [29, 30], [25]],
#  [[7], [17], [19, 20], [34]],
#  [[7, 8, 9], [19], [29, 30]],
#  [[4, 5], [7, 8], [21, 22]],
#  [[1, 2], [23, 24]],
#  [[0, 1], [7]],
#  [[8], [9], [18], [21], [29], [34, 35], [37, 38]],
#  [[9], [12, 13]],
#  [[1], [14], [26, 27]],
#  [[2], [12]],
#  [[2, 3], [6, 7], [11], [30]],
#  [[1, 2], [4]],
#  [[10], [11, 12]],
#  [[12, 13], [22], [27]],
#  [[4], [17], [4], [52]],
#  [[36], [38], [44]],
#  [[20], [51], [53]],
#  [[7], [9], [17]],
#  [[14, 15, 16], [26, 27], [29], [37]],
#  [[14, 15], [22], [28, 29], [35], [40, 41], [43, 44]],
#  [[10], [18], [28, 29], [31]],
#  [[0, 1], [3], [5]],
#  [[1, 2], [4]],
#  [[8, 9, 10], [15, 16, 17, 18], [20, 21]],
#  [[7, 8], [9], [15, 16]],
#  [[2], [8]],
#  [[6], [10]],
#  [[1], [37]],
#  [[4, 5], [7]],
#  [[0], [3], [4]],
#  [[6], [7]],
#  [[4], [15], [21, 22, 23], [29]],
#  [[10, 11], [13], [15], [29, 30], [32, 33], [47, 48]],
#  [[6, 7, 8], [10], [27, 28], [30]],
#  [[12], [33]],
#  [[5], [11], [15, 16], [17]],
#  [[11], [13, 14], [25], [31, 32]],
#  [[4], [16]],
#  [[3], [14, 15], [17], [25, 26]],
#  [[7], [20, 21], [23, 24, 25], [30]],
#  [[11, 12], [11, 20], [26]],
#  [[24], [34, 35], [20]],
#  [[10], [12, 13]],
#  [[30, 31, 32, 33], [35]],
#  [[30, 31, 32, 33], [35]],
#  [[0, 1], [13], [20, 21]],
#  [[34, 35], [46]],
#  [[15, 16], [18], [25, 26]],
#  [[8, 9], [28, 29], [31]],
#  [[10, 11], [13]],
#  [[6, 7], [10]],
#  [[1], [29], [36, 37]],
#  [[18, 19], [25]],
#  [[1], [16, 17], [26]],
#  [[10, 11], [28, 29], [10, 11]],
#  [[2, 3], [9], [21, 22]],
#  [[0, 1], [10, 11]],
#  [[15, 16], [18, 19]],
#  [[0, 1], [26, 27, 28, 29], [40]],
#  [[23], [25, 26], [32, 33]],
#  [[7, 8, 9, 10, 11, 12], [14]],
#  [[10, 11], [13]],
#  [[0], [13, 14], [18, 19]],
#  [[0, 1, 2, 3], [7, 8]],
#  [[16, 17], [18, 19]],
#  [[8], [17, 18], [21]],
#  [[7], [8, 9], [22]],
#  [[33], [35, 36, 37]],
#  [[3], [9, 10], [11]],
#  [[12], [29]],
#  [[7, 8], [17], [25]],
#  [[16], [17]],
#  [[14], [38, 39]],
#  [[33, 34], [51]],
#  [[14], [15]],
#  [[2, 3, 4], [2, 3], [30, 31]],
#  [[3], [6, 7]],
#  [[0], [4], [5, 6], [7, 8], [9], [11, 12], [16], [21], [28], [29], [31]],
#  [[28], [45], [55]],
#  [[2], [6]],
#  [[17], [30], [17]],
#  [[6], [26]],
#  [[16], [23]],
#  [[0, 1], [7, 8, 9]],
#  [[41, 42], [41, 42, 52]],
#  [[25, 26], [33, 34], [36, 37]],
#  [[8], [16, 17], [28, 29], [34]],
#  [[3], [7, 8], [12, 13, 14]],
#  [[26, 27], [26, 27, 34], [26, 40]],
#  [[19], [21], [22, 23], [25, 26], [30, 31]],
#  [[0, 1, 2], [6, 7, 8, 9, 10, 11, 12, 13]],
#  [[1], [5, 6], [16, 17]],
#  [[8, 9], [14], [30, 31]],
#  [[5], [24, 25], [5]],
#  [[10, 11], [44, 45]],
#  [[5], [8], [9], [23]],
#  [[6], [7]],
#  [[4], [6, 7], [22, 23]],
#  [[15, 16], [24]],
#  [[12], [20]],
#  [[16, 17, 18], [20]],
#  [[0, 1], [5]],
#  [[9], [14, 15], [24], [30], [40, 41]],
#  [[8, 9], [35, 36]],
#  [[12], [19, 20]],
#  [[0, 1], [2], [14, 15]],
#  [[1], [13, 14], [24]],
#  [[8, 9], [12, 13], [22], [35, 36]],
#  [[18, 19, 20], [30, 31, 32], [30, 31], [30, 57, 58]],
#  [[12, 13, 14], [18]],
#  [[4], [6], [4], [11]],
#  [[18], [23]],
#  [[7], [13, 14]],
#  [[0, 1], [9], [23], [29]],
#  [[6], [8], [12, 13]],
#  [[1, 2], [10, 11], [22, 23]],
#  [[15, 16], [18, 19]],
#  [[22, 23], [26], [27], [28], [29]],
#  [[1], [14], [33, 34, 35]],
#  [[1], [21], [22, 23]],
#  [[6], [10, 11, 12], [10, 11, 12], [41, 42], [48, 49, 50], [55, 56]],
#  [[13, 14], [18, 19], [25, 26], [31]],
#  [[14, 15], [24], [14, 27]],
#  [[4], [9, 10], [22, 23], [9, 10]],
#  [[0], [15, 16], [32, 33], [36], [16, 40]],
#  [[3], [5, 6], [19, 20, 21], [28, 29]],
#  [[16], [20, 21], [28, 29, 30]],
#  [[0, 1], [5], [17, 18, 19]],
#  [[4], [18], [24]],
#  [[11, 12], [14]],
#  [[14], [21, 22]],
#  [[6, 7], [23, 24], [28, 29], [28, 40], [48]],
#  [[5, 6], [13, 14], [17, 18], [25, 26], [30, 31], [12]],
#  [[8], [14, 15], [17, 18]],
#  [[0, 1], [4], [6, 7]],
#  [[2], [4], [5], [7], [17]],
#  [[5], [26, 27], [37], [48]],
#  [[5, 6], [21, 22]],
#  [[3, 4, 5], [8], [23], [24], [26]],
#  [[6], [13], [6, 27]],
#  [[7, 8], [21]],
#  [[2], [6, 7]],
#  [[1], [5, 6], [19, 20], [29], [36], [38]],
#  [[2, 3], [10], [31], [37]],
#  [[11, 12], [16, 17], [1, 20]],
#  [[7, 8, 9, 10], [31, 32, 33], [43]],
#  [[10, 11], [14, 15], [17], [23, 24], [26, 27], [40, 41, 42]],
#  [[10], [18]],
#  [[8, 9, 10], [14, 15]],
#  [[19], [21], [28, 29]],
#  [[0, 1, 2], [8], [8], [30, 31]],
#  [[14, 15], [24], [26]],
#  [[3], [4], [15]],
#  [[23], [34], [36], [38, 39]],
#  [[14, 15], [17], [20, 21], [39]],
#  [[8], [17]],
#  [[22], [31]],
#  [[7], [18]],
#  [[12], [27], [46]],
#  [[0, 1], [7], [12], [17], [34, 35]],
#  [[5, 6, 7], [11, 12], [14], [33, 34]],
#  [[3, 4], [11, 12], [20, 21]],
#  [[10], [24]],
#  [[10], [23]],
#  [[1], [13]],
#  [[14], [17, 18]],
#  [[25, 26], [33], [36]],
#  [[5], [11], [15, 16], [20, 21], [33]],
#  [[8], [10, 11], [8]],
#  [[7], [11]],
#  [[6, 7], [32], [33]],
#  [[7, 8], [10]],
#  [[16, 17], [19]],
#  [[8], [23, 24], [26, 27], [30, 31], [33]],
#  [[5], [14, 15], [18]],
#  [[5], [16], [19]],
#  [[1], [5]],
#  [[9, 10], [12]],
#  [[8], [13], [22, 23], [13]],
#  [[1], [5, 6, 7], [11], [12, 13], [14]],
#  [[1, 2], [8], [11, 12], [22], [24]],
#  [[13], [16]],
#  [[16, 17], [19], [21, 22], [24], [27], [36, 37]],
#  [[6, 7], [12]],
#  [[9], [19, 20], [32], [42]],
#  [[2, 3], [5], [8]],
#  [[7, 8], [9]],
#  [[0, 1, 2], [23]],
#  [[12, 13], [15], [22, 23], [25]],
#  [[8, 9], [15, 16, 17]],
#  [[0, 1], [11], [12]],
#  [[4, 5], [8, 9], [26], [28]],
#  [[12], [13, 14], [25, 26], [29], [37], [54, 55]],
#  [[0], [16]],
#  [[14], [24], [25]],
#  [[1], [19]],
#  [[4, 5], [7]],
#  [[11, 12], [15], [24]],
#  [[1, 2], [4], [7], [7]],
#  [[9], [13, 14], [17, 18], [21], [24], [28], [30]],
#  [[15, 16], [26, 27]],
#  [[0, 1], [3]],
#  [[6], [7], [8]],
#  [[5], [9], [22]],
#  [[12, 13], [15]],
#  [[0, 1], [2], [10]],
#  [[5, 6], [24, 25], [42, 43, 44, 45], [47, 48]],
#  [[6], [11, 12], [9, 46]],
#  [[6], [8, 9, 10]],
#  [[2], [11, 12]],
#  [[8], [14]],
#  [[12], [13, 14, 15], [21]],
#  [[16], [24], [36], [47, 48], [59]],
#  [[5, 6], [8]],
#  [[3, 4], [6], [11]],
#  [[1], [26], [28, 29], [34, 35], [36, 37], [39, 40]],
#  [[39], [40]],
#  [[8, 9, 10], [12], [13], [19]],
#  [[14, 15], [17, 18]],
#  [[0, 1], [6], [6]],
#  [[7, 8], [10], [13]],
#  [[8], [9]],
#  [[18, 19], [29], [31], [33, 34]],
#  [[19], [20], [22], [24], [34]],
#  [[1], [12]],
#  [[0], [16]],
#  [[19, 20], [22, 23], [25], [30]],
#  [[1], [5, 6], [1]],
#  [[1], [7], [10, 11], [13, 14], [19, 20]],
#  [[13], [17, 18], [24], [26], [28]],
#  [[6, 7, 8], [15], [29, 30, 31], [33]],
#  [[25, 26], [28]],
#  [[14, 15], [26, 27], [29], [31]],
#  [[18, 19], [22]],
#  [[16, 17], [20]],
#  [[9, 10], [12]],
#  [[1], [9, 10], [17, 18], [30, 31]],
#  [[31], [52, 53]],
#  [[5, 6], [5]],
#  [[13], [14]],
#  [[4, 5], [8], [12, 13, 14], [16]],
#  [[13], [26], [28, 29], [31]],
#  [[20, 21], [24, 25], [28], [78]],
#  [[5], [10], [17], [18, 19]],
#  [[7], [13, 14], [17]],
#  ...]

# %%
i_entityLabels = []
for i in range(len(sentWords)):
    eL = []
    sDict = list(enumerate(sentWords[i]))
    for item in entlabWords[i]:
        j = 0
        el = []
        for e in item:
            while j < len(sDict):
                if e == sDict[j][1]:
                    el.append(sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    i_entityLabels.append(eL)

# %%
i_em1Text = []
for i in range(len(sentWords)):
    temp = list(zip(sum(i_entityLabels[i], []), sum(entlabWords[i], [])))
    eM1 = []
    for ee in em1Words[i]:
        j = 0
        em1 = []
        for e in ee:
            while j < len(temp):
                if e == temp[j][1] and Counter(sum(entlabWords[i], []))[e] == 1:
                    em1.append(temp[j][0])
                    break
                if e == temp[j][1] and Counter(sum(entlabWords[i], []))[e] > 1:
                    em1.append(temp[j][0])
                    j += 1
                    break
                j += 1
        eM1.append(em1)
    i_em1Text.append(eM1)

i_em2Text = []
for i in range(len(sentWords)):
    temp = list(zip(sum(i_entityLabels[i], []), sum(entlabWords[i], [])))
    eM2 = []
    for ee in em2Words[i]:
        j = 0
        em2 = []
        for e in ee:
            while j < len(temp):
                if e == temp[j][1] and Counter(sum(entlabWords[i], []))[e] == 1:
                    em2.append(temp[j][0])
                    break
                if e == temp[j][1] and Counter(sum(entlabWords[i], []))[e] > 1:
                    em2.append(temp[j][0])
                    j += 1
                    break
                j += 1
        eM2.append(em2)
    i_em2Text.append(eM2)

# %%
i_em1Text
# Out:
# [[[14, 15], [32], [32], [14, 15]],
#  [[26, 27]],
#  [[9]],
#  [[13, 14, 15], [13, 14, 15], [13, 14, 15]],
#  [[13], [13], [12], [13]],
#  [[12]],
#  [[1]],
#  [[24, 25, 26]],
#  [[30, 31, 32]],
#  [[25]],
#  [[8], [8]],
#  [[40, 41], [25], [25], [25]],
#  [[2], [10, 11], [2], [2]],
#  [[5]],
#  [[23, 24]],
#  [[6, 7]],
#  [[9], [9], [5, 6], [8]],
#  [[9, 10], [30, 31]],
#  [[32], [32]],
#  [[2]],
#  [[3]],
#  [[6, 7]],
#  [[19, 20]],
#  [[3, 4]],
#  [[2, 3]],
#  [[36, 37]],
#  [[12], [12]],
#  [[32, 33], [42, 43]],
#  [[16, 17, 18]],
#  [[2, 3], [13, 14], [15]],
#  [[21, 22], [21, 22]],
#  [[15, 16]],
#  [[40, 41, 42]],
#  [[18, 37], [18, 37]],
#  [[70], [70]],
#  [[22], [3], [22], [22], [3], [45]],
#  [[5, 6], [5, 6], [5, 6]],
#  [[16, 17]],
#  [[3, 4]],
#  [[0], [0]],
#  [[6, 7], [6, 7], [6, 7]],
#  [[17, 18]],
#  [[39]],
#  [[7]],
#  [[7, 8], [20]],
#  [[41]],
#  [[23, 24]],
#  [[11, 12]],
#  [[21, 22]],
#  [[3, 4]],
#  [[8, 9]],
#  [[19], [19], [19], [18]],
#  [[31]],
#  [[20], [1]],
#  [[4, 5]],
#  [[9], [9], [9], [9]],
#  [[86, 87], [86, 87]],
#  [[21, 22]],
#  [[14], [14]],
#  [[3, 4]],
#  [[0, 1]],
#  [[11, 12], [11, 12]],
#  [[49, 50], [49, 50]],
#  [[7, 8]],
#  [[33], [33]],
#  [[6, 7]],
#  [[36, 37]],
#  [[1, 2], [7, 8]],
#  [[26, 27, 28]],
#  [[8]],
#  [[10, 11]],
#  [[16]],
#  [[8], [8]],
#  [[18, 19]],
#  [[34]],
#  [[20, 21]],
#  [[4, 5, 6]],
#  [[17, 18]],
#  [[12, 13]],
#  [[7, 8]],
#  [[0, 1]],
#  [[9, 10]],
#  [[5], [3, 4], [5], [5]],
#  [[8], [8]],
#  [[25], [14], [25], [14], [14], [14]],
#  [[32], [32], [29]],
#  [[2], [2], [14], [2], [14], [2]],
#  [[19], [7], [19]],
#  [[44], [24], [44]],
#  [[5], [5], [1]],
#  [[0], [20], [0]],
#  [[14, 15]],
#  [[10], [10]],
#  [[0, 1]],
#  [[7, 8]],
#  [[14]],
#  [[0, 1, 2]],
#  [[29]],
#  [[25, 26]],
#  [[41, 42], [41, 42]],
#  [[11]],
#  [[2, 3], [12, 13]],
#  [[23, 24], [1]],
#  [[12, 13]],
#  [[10, 11]],
#  [[23, 24], [30]],
#  [[28], [28], [8]],
#  [[14, 15]],
#  [[30]],
#  [[20, 21]],
#  [[5]],
#  [[0], [0]],
#  [[27]],
#  [[3, 4]],
#  [[35]],
#  [[14, 15, 16], [17]],
#  [[26, 27]],
#  [[9, 10]],
#  [[1, 2]],
#  [[6, 7]],
#  [[19, 20]],
#  [[7, 8]],
#  [[17, 18]],
#  [[18, 19]],
#  [[8, 9]],
#  [[6, 7]],
#  [[0, 1]],
#  [[9, 10, 11], [1]],
#  [[0], [0]],
#  [[12, 13], [12, 13]],
#  [[0]],
#  [[0]],
#  [[0], [0]],
#  [[1, 2]],
#  [[11, 12]],
#  [[65, 66], [16]],
#  [[12, 13]],
#  [[18], [15]],
#  [[23, 24]],
#  [[10]],
#  [[14]],
#  [[18, 19]],
#  [[25, 26]],
#  [[12, 13]],
#  [[22, 23], [8, 9]],
#  [[53], [51, 52]],
#  [[27]],
#  [[40, 41], [13, 14, 15], [10, 11], [44], [44]],
#  [[27], [23, 24]],
#  [[14, 15, 16], [17]],
#  [[1, 2, 3], [8, 9], [1, 2, 3]],
#  [[35]],
#  [[41], [41], [39], [47], [41]],
#  [[12]],
#  [[17, 18], [25], [17, 18]],
#  [[0, 1, 2]],
#  [[6, 7]],
#  [[31, 32]],
#  [[18, 19], [20]],
#  [[0, 1]],
#  [[18], [17]],
#  [[3, 4]],
#  [[2, 3, 4]],
#  [[11]],
#  [[3, 4]],
#  [[24]],
#  [[4, 5]],
#  [[5, 6], [5, 6]],
#  [[10], [34], [34], [10]],
#  [[15], [1], [1], [1]],
#  [[25, 26, 27]],
#  [[4], [5], [4], [5], [5], [5]],
#  [[11], [11], [11], [33]],
#  [[23]],
#  [[18, 19]],
#  [[14, 15], [14, 15]],
#  [[14, 15], [14, 15]],
#  [[0], [0], [0], [20]],
#  [[21, 22], [21, 22], [52, 53, 54], [21, 22], [32, 33, 34]],
#  [[7]],
#  [[20]],
#  [[34, 35], [14, 15]],
#  [[27], [27]],
#  [[0]],
#  [[2]],
#  [[15], [1], [1]],
#  [[1], [15], [1]],
#  [[51, 52]],
#  [[23]],
#  [[39, 40], [13], [13]],
#  [[30], [30]],
#  [[7]],
#  [[9]],
#  [[11]],
#  [[22]],
#  [[21], [21]],
#  [[3]],
#  [[1]],
#  [[41, 42]],
#  [[14]],
#  [[7, 8]],
#  [[57, 58], [57, 58], [18], [18], [57, 58], [18]],
#  [[19]],
#  [[12, 13], [46]],
#  [[5], [23], [23], [23]],
#  [[27], [27]],
#  [[19, 20]],
#  [[16, 17], [1, 2], [1, 2], [5], [22, 23]],
#  [[3, 4]],
#  [[10]],
#  [[1]],
#  [[1]],
#  [[23, 24]],
#  [[7]],
#  [[5]],
#  [[1, 2], [8, 9]],
#  [[28], [28]],
#  [[11, 12]],
#  [[20], [17, 18]],
#  [[3, 4, 5]],
#  [[21, 22]],
#  [[4], [4], [15], [4]],
#  [[21], [13], [21], [21], [21]],
#  [[0, 1]],
#  [[4, 5]],
#  [[16, 17]],
#  [[9]],
#  [[8], [4], [4], [4]],
#  [[29, 30]],
#  [[14, 15, 16]],
#  [[7, 8]],
#  [[33, 34]],
#  [[18]],
#  [[19, 20]],
#  [[13]],
#  [[0, 1], [5]],
#  [[32], [34]],
#  [[13]],
#  [[2], [23], [23], [23]],
#  [[16], [16]],
#  [[7, 8]],
#  [[6, 7]],
#  [[6, 7]],
#  [[24, 25]],
#  [[9, 10], [11]],
#  [[11, 12]],
#  [[7, 8]],
#  [[18]],
#  [[25]],
#  [[18],
#   [30],
#   [23],
#   [30],
#   [30],
#   [23],
#   [23],
#   [22],
#   [30],
#   [18],
#   [17],
#   [30],
#   [30],
#   [18]],
#  [[16], [16], [13], [13]],
#  [[17], [17], [17]],
#  [[5], [5]],
#  [[11, 12]],
#  [[25, 26]],
#  [[16, 17]],
#  [[1, 2], [1, 2]],
#  [[0], [0]],
#  [[11, 12]],
#  [[14]],
#  [[7]],
#  [[15, 16]],
#  [[35]],
#  [[39]],
#  [[46]],
#  [[7]],
#  [[12]],
#  [[10], [10], [9], [10]],
#  [[15], [10], [10], [10]],
#  [[2, 3]],
#  [[2, 3]],
#  [[21, 22, 23]],
#  [[0, 32]],
#  [[3]],
#  [[0]],
#  [[28, 29]],
#  [[4, 5]],
#  [[40]],
#  [[42, 43]],
#  [[28]],
#  [[14]],
#  [[23, 24]],
#  [[11], [11], [11], [11]],
#  [[6], [9], [11]],
#  [[12, 13]],
#  [[7]],
#  [[10]],
#  [[2]],
#  [[7]],
#  [[30], [30], [28, 29], [30]],
#  [[11], [38, 39]],
#  [[16], [22], [12], [16], [16], [16]],
#  [[20, 21]],
#  [[24], [24]],
#  [[1], [1], [1]],
#  [[31, 32, 33], [15]],
#  [[7, 8], [7, 8]],
#  [[17, 18], [17, 18], [17, 18], [17, 18]],
#  [[41, 42]],
#  [[29]],
#  [[3, 4, 5]],
#  [[0], [20]],
#  [[6], [16]],
#  [[27], [27], [8], [0], [0], [27], [27], [27]],
#  [[19]],
#  [[23]],
#  [[18]],
#  [[14], [13]],
#  [[17, 90], [17, 90], [17, 90]],
#  [[9, 10, 11]],
#  [[5, 6]],
#  [[34, 35], [34, 35]],
#  [[26], [26]],
#  [[19]],
#  [[22]],
#  [[28, 29]],
#  [[2, 3]],
#  [[25]],
#  [[7, 8], [7, 8]],
#  [[1, 2, 3]],
#  [[20]],
#  [[7, 8], [11]],
#  [[25]],
#  [[11], [13], [11], [11]],
#  [[36], [36]],
#  [[23], [23], [3], [23]],
#  [[7], [7], [18], [7]],
#  [[15, 16]],
#  [[0, 1], [0, 1], [0, 1], [0, 1]],
#  [[10, 11], [9], [10, 11], [10, 11]],
#  [[15]],
#  [[4, 5], [12], [12], [12], [4, 5], [4, 5]],
#  [[7, 8, 9]],
#  [[29, 30, 31]],
#  [[47, 48, 49]],
#  [[10], [7, 8, 9]],
#  [[16, 17, 18], [32, 33]],
#  [[11], [6], [6], [6]],
#  [[14, 15], [38, 39], [38, 39], [14, 15]],
#  [[13, 14], [13, 14]],
#  [[0, 1], [50], [50], [70]],
#  [[0, 1]],
#  [[12, 13], [5, 6]],
#  [[19], [22]],
#  [[18, 19]],
#  [[14]],
#  [[11]],
#  [[15]],
#  [[15]],
#  [[18], [18], [18]],
#  [[15]],
#  [[6, 7]],
#  [[10, 11]],
#  [[30, 31]],
#  [[24, 25]],
#  [[18, 19]],
#  [[26]],
#  [[10]],
#  [[17]],
#  [[2, 3]],
#  [[17]],
#  [[21, 22], [21, 22]],
#  [[44, 45], [44, 45], [41, 42], [41, 42], [41, 42]],
#  [[0, 1], [0, 1]],
#  [[37, 38]],
#  [[18, 19], [34, 35]],
#  [[3], [3]],
#  [[18, 19]],
#  [[39]],
#  [[0, 1]],
#  [[10], [19], [10], [10], [19], [10], [10], [10]],
#  [[19], [4], [19], [19]],
#  [[17, 18]],
#  [[0, 1], [0, 1]],
#  [[23, 24]],
#  [[25, 26]],
#  [[26, 27]],
#  [[28]],
#  [[3], [3]],
#  [[12, 13]],
#  [[27, 28]],
#  [[11, 12], [11, 12], [11, 12], [11, 12]],
#  [[21, 22]],
#  [[19]],
#  [[15, 16]],
#  [[17], [0], [0], [0]],
#  [[9], [9], [9], [47]],
#  [[8], [8], [8], [3]],
#  [[0, 1]],
#  [[10, 11]],
#  [[25, 26]],
#  [[32, 33], [35]],
#  [[5], [5], [5], [4]],
#  [[28], [28], [7, 8], [28], [7, 8]],
#  [[5, 6], [5, 6]],
#  [[22]],
#  [[16, 17]],
#  [[0, 1, 2]],
#  [[4, 5]],
#  [[20], [17, 18]],
#  [[11]],
#  [[0]],
#  [[7, 8]],
#  [[11, 12]],
#  [[13, 14]],
#  [[8]],
#  [[9, 10]],
#  [[4]],
#  [[23], [34, 35], [23]],
#  [[2, 3]],
#  [[18, 19]],
#  [[28], [21], [21], [21], [10, 11], [10, 11]],
#  [[0]],
#  [[13]],
#  [[0, 1]],
#  [[28], [18]],
#  [[9]],
#  [[35, 36]],
#  [[14, 15, 16]],
#  [[9, 10]],
#  [[11, 12]],
#  [[45, 46], [45, 46]],
#  [[6]],
#  [[9],
#   [9],
#   [9],
#   [26],
#   [9],
#   [9],
#   [9],
#   [9],
#   [26],
#   [9],
#   [13],
#   [9],
#   [13],
#   [9],
#   [9],
#   [9],
#   [9],
#   [9],
#   [14],
#   [9],
#   [9],
#   [14]],
#  [[22, 23]],
#  [[13], [18, 19]],
#  [[9, 10]],
#  [[27, 28], [27, 28], [27, 28], [27, 28]],
#  [[11, 12]],
#  [[27, 28]],
#  [[2], [2]],
#  [[10]],
#  [[18, 19], [18, 19], [18, 19]],
#  [[35], [21], [21], [21]],
#  [[23], [23]],
#  [[18]],
#  [[23, 24]],
#  [[17], [17], [17], [17]],
#  [[33, 34]],
#  [[19, 20]],
#  [[15]],
#  [[1, 2, 3], [5]],
#  [[0, 1]],
#  [[17], [7, 8]],
#  [[16, 17, 18]],
#  [[48]],
#  [[18]],
#  [[25]],
#  [[38, 48]],
#  [[8]],
#  [[30], [32, 33], [32, 33]],
#  [[15, 16]],
#  [[1, 2]],
#  [[8, 9], [8, 9], [8, 9]],
#  [[7], [7]],
#  [[2, 3]],
#  [[29, 30], [29, 30], [29, 30]],
#  [[8], [8]],
#  [[0, 1], [0, 1]],
#  [[14]],
#  [[13, 14], [13, 14]],
#  [[1, 2]],
#  [[13], [13], [3], [13], [3], [3], [3], [3], [13], [3], [13]],
#  [[10, 11]],
#  [[18, 19], [18, 19], [18, 19]],
#  [[13, 14]],
#  [[21], [21], [24]],
#  [[8, 9]],
#  [[20, 21], [20, 21]],
#  [[14, 15], [14, 15]],
#  [[19, 20]],
#  [[19, 20, 21]],
#  [[16, 17]],
#  [[6]],
#  [[11]],
#  [[37, 38]],
#  [[44], [20], [44]],
#  [[45]],
#  [[17]],
#  [[5]],
#  [[1], [1], [1]],
#  [[31, 32, 33], [15]],
#  [[7, 8], [7, 8]],
#  [[17, 18], [17, 18], [17, 18], [17, 18]],
#  [[41, 42]],
#  [[5]],
#  [[25, 26]],
#  [[3, 4]],
#  [[0, 1]],
#  [[17, 18]],
#  [[13, 14, 15], [0, 1, 2]],
#  [[13, 14]],
#  [[13, 14], [2, 3]],
#  [[9, 10]],
#  [[41, 42]],
#  [[19, 20]],
#  [[26]],
#  [[17]],
#  [[10, 11]],
#  [[49]],
#  [[14], [12, 13]],
#  [[12]],
#  [[9, 10]],
#  [[17]],
#  [[12]],
#  [[17, 18]],
#  [[39, 40]],
#  [[20, 21]],
#  [[12]],
#  [[7], [7], [15], [7], [7], [15]],
#  [[18], [18], [24]],
#  [[24, 25]],
#  [[0, 1, 2], [0, 1, 2]],
#  [[30], [60], [60], [51, 52, 53], [30]],
#  [[15]],
#  [[23, 24, 25]],
#  [[14]],
#  [[0, 1], [3, 4]],
#  [[20, 21, 22]],
#  [[6, 7]],
#  [[9, 10]],
#  [[6], [6]],
#  [[0, 1]],
#  [[12]],
#  [[16], [17]],
#  [[5]],
#  [[5]],
#  [[34, 35], [34, 35]],
#  [[12, 13], [12, 13], [3], [3]],
#  [[16], [15]],
#  [[6], [5]],
#  [[5, 6]],
#  [[21]],
#  [[8, 9], [12], [12]],
#  [[27, 28]],
#  [[1], [1]],
#  [[40]],
#  [[5, 6]],
#  [[34, 35]],
#  [[39], [39]],
#  [[30]],
#  [[63]],
#  [[7]],
#  [[18], [18]],
#  [[19], [19]],
#  [[0, 1], [0, 1]],
#  [[4]],
#  [[7, 8]],
#  [[18, 19]],
#  [[18, 19]],
#  [[47], [44, 45, 46]],
#  [[9, 10]],
#  [[19]],
#  [[9]],
#  [[10, 11], [12]],
#  [[25]],
#  [[6, 7, 8]],
#  [[0, 1]],
#  [[4, 5]],
#  [[15, 16], [18, 19]],
#  [[8, 9]],
#  [[2, 3], [2, 3]],
#  [[15], [7, 8]],
#  [[7, 8], [2]],
#  [[24], [25]],
#  [[13], [11, 12]],
#  [[24, 25], [28], [28]],
#  [[13], [17], [17], [17], [13], [17]],
#  [[2], [6], [2]],
#  [[0, 1], [0]],
#  [[23, 24], [21]],
#  [[7], [7, 8]],
#  [[29, 30], [29, 30], [26, 27]],
#  [[4]],
#  [[8, 9]],
#  [[12, 13], [17, 18], [14, 15]],
#  [[2, 3], [17], [2, 3]],
#  [[19, 20], [19, 20]],
#  [[2, 3]],
#  [[6, 7]],
#  [[53]],
#  [[28], [28], [28]],
#  [[48], [47]],
#  [[33], [32]],
#  [[15, 16, 17], [18]],
#  [[10, 11]],
#  [[3, 4]],
#  [[7, 8]],
#  [[5, 6], [5, 6]],
#  [[6, 7], [6, 7]],
#  [[29], [29]],
#  [[6, 7]],
#  [[4], [4]],
#  [[7]],
#  [[12]],
#  [[9], [9], [9], [9], [27], [27], [9], [9], [9], [9]],
#  [[16], [4], [4], [4]],
#  [[39, 40, 41]],
#  [[17, 18]],
#  [[0, 1]],
#  [[23, 24, 25]],
#  [[6]],
#  [[15, 16]],
#  [[10], [11], [11], [11], [11], [10]],
#  [[4, 5]],
#  [[11, 12]],
#  [[15, 16]],
#  [[13], [11, 12]],
#  [[10], [8, 9]],
#  [[13, 14]],
#  [[8, 9]],
#  [[2, 3]],
#  [[15, 16]],
#  [[4, 5], [4, 5], [21, 22]],
#  [[26], [25], [26], [26]],
#  [[19]],
#  [[0, 1], [0, 1]],
#  [[10]],
#  [[21, 22]],
#  [[39, 40]],
#  [[27]],
#  [[11]],
#  [[2], [2]],
#  [[18, 19]],
#  [[21], [24], [24], [24]],
#  [[3, 4]],
#  [[28, 29]],
#  [[23, 24], [17, 18]],
#  [[29], [29]],
#  [[46, 47], [14, 15, 16], [14, 15]],
#  [[16]],
#  [[0, 1, 2]],
#  [[13], [13], [12]],
#  [[26], [13, 14]],
#  [[20, 21]],
#  [[29]],
#  [[19], [7, 8]],
#  [[8, 9]],
#  [[6, 7]],
#  [[42, 43, 44]],
#  [[4]],
#  [[8]],
#  [[30], [30], [30]],
#  [[4]],
#  [[4]],
#  [[4]],
#  [[1]],
#  [[21, 22]],
#  [[48, 49, 50]],
#  [[4], [4], [4], [18]],
#  [[14, 15], [14, 15], [14, 15]],
#  [[7, 8]],
#  [[23], [22], [23]],
#  [[22]],
#  [[7]],
#  [[1]],
#  [[11, 12, 13], [18, 19, 20]],
#  [[12, 13], [14]],
#  [[45, 46], [43, 44]],
#  [[18], [18, 41]],
#  [[20], [38], [38]],
#  [[12]],
#  [[9], [9], [9], [9]],
#  [[46]],
#  [[2, 3]],
#  [[18]],
#  [[15], [24], [14], [44], [15], [3, 4], [22, 23], [15, 16], [3, 4], [18, 19]],
#  [[0, 1], [0, 1], [0, 1], [27]],
#  [[12], [22], [12], [12]],
#  [[9, 10], [31], [7], [7], [7], [7], [32]],
#  [[10], [10]],
#  [[9, 10]],
#  [[1]],
#  [[27, 28], [9], [27, 28], [27, 28]],
#  [[12], [12]],
#  [[30]],
#  [[22]],
#  [[25]],
#  [[18]],
#  [[13, 14], [13, 14]],
#  [[28], [28]],
#  [[9], [9], [9], [9]],
#  [[15, 16]],
#  [[10]],
#  [[1, 2], [1, 2]],
#  [[13]],
#  [[24, 25]],
#  [[2]],
#  [[9, 10]],
#  [[32], [8], [8], [8]],
#  [[32], [32]],
#  [[30, 31]],
#  [[27, 28], [27, 28]],
#  [[2, 3], [2, 3], [2, 3]],
#  [[6]],
#  [[32, 33, 34], [32, 33, 34], [11, 12], [11, 12]],
#  [[20, 21]],
#  [[0, 1]],
#  [[39]],
#  [[45]],
#  [[52]],
#  [[19]],
#  [[21, 22]],
#  [[25, 33], [25]],
#  [[15]],
#  [[29, 30]],
#  [[22]],
#  [[22, 23]],
#  [[12, 13]],
#  [[4, 5]],
#  [[12, 13], [12, 13]],
#  [[13, 14]],
#  [[4, 5], [4, 5], [4, 5]],
#  [[1, 2], [1, 2], [1, 2]],
#  [[12, 13], [12, 13], [12, 13], [12, 13], [12, 13], [12, 13]],
#  [[5, 6], [5, 6], [5, 6]],
#  [[7, 8]],
#  [[18]],
#  [[28, 29]],
#  [[22]],
#  [[12], [12]],
#  [[2, 3]],
#  [[7, 8]],
#  [[24]],
#  [[22], [45], [22], [45], [22], [22], [45], [22], [22], [22], [22], [22]],
#  [[38, 39]],
#  [[12], [33], [33], [33]],
#  [[6], [6], [18], [6]],
#  [[6, 7]],
#  [[18, 19]],
#  [[31]],
#  [[11, 12, 13]],
#  [[23, 24], [25]],
#  [[1, 2]],
#  [[25], [20], [25], [25], [25], [25]],
#  [[9]],
#  [[13], [12]],
#  [[23]],
#  [[11, 12]],
#  [[29]],
#  [[13, 14, 15]],
#  [[7, 8]],
#  [[13]],
#  [[4]],
#  [[12]],
#  [[11, 12, 13]],
#  [[58, 59]],
#  [[15], [1], [1], [1]],
#  [[0], [0], [0], [32]],
#  [[16]],
#  [[0], [0], [25]],
#  [[5, 6], [5, 6]],
#  [[9, 10], [9, 10]],
#  [[32, 33]],
#  [[44, 45]],
#  [[29, 30]],
#  [[19, 20], [7], [19, 20], [34], [7], [7]],
#  [[7, 8, 9], [7, 8, 9]],
#  [[7, 8]],
#  [[1, 2]],
#  [[0, 1]],
#  [[9], [9], [8], [9]],
#  [[12, 13]],
#  [[26, 27]],
#  [[2]],
#  [[2, 3]],
#  [[1, 2]],
#  [[11, 12]],
#  [[12, 13]],
#  [[52], [52], [52], [52]],
#  [[44], [44], [44]],
#  [[20], [20], [20]],
#  [[17], [17], [17]],
#  [[29], [26, 27]],
#  [[40, 41], [43, 44]],
#  [[31]],
#  [[0, 1]],
#  [[1, 2]],
#  [[20, 21]],
#  [[9]],
#  [[8], [2]],
#  [[6], [10]],
#  [[1], [1]],
#  [[4, 5]],
#  [[4]],
#  [[7], [6], [7], [7]],
#  [[29]],
#  [[32, 33]],
#  [[27, 28], [27, 28]],
#  [[12], [12]],
#  [[11], [17]],
#  [[25], [25], [11], [25]],
#  [[4], [16], [4], [4]],
#  [[14, 15]],
#  [[30]],
#  [[11, 12], [11, 12]],
#  [[34, 35]],
#  [[12, 13]],
#  [[35]],
#  [[35]],
#  [[0, 1]],
#  [[34, 35]],
#  [[25, 26]],
#  [[28, 29]],
#  [[10, 11]],
#  [[6, 7], [10]],
#  [[36, 37]],
#  [[18, 19]],
#  [[16, 17]],
#  [[28, 29]],
#  [[9]],
#  [[10, 11], [0, 1]],
#  [[15, 16]],
#  [[0, 1]],
#  [[25, 26], [32, 33]],
#  [[14]],
#  [[10, 11]],
#  [[13, 14]],
#  [[7, 8]],
#  [[18, 19]],
#  [[17, 18]],
#  [[8, 9]],
#  [[35, 36, 37]],
#  [[9, 10], [3], [11], [11]],
#  [[12]],
#  [[17], [17], [25], [17]],
#  [[16], [17], [17], [17]],
#  [[38, 39], [14]],
#  [[51], [33, 34]],
#  [[14], [15]],
#  [[2, 3], [30, 31], [30, 31]],
#  [[6, 7]],
#  [[11, 12]],
#  [[28]],
#  [[6], [2], [2], [2]],
#  [[17], [17], [17], [17]],
#  [[6], [6]],
#  [[23], [23]],
#  [[0, 1]],
#  [[41, 42]],
#  [[33, 34]],
#  [[16, 17]],
#  [[7, 8]],
#  [[26, 27]],
#  [[19], [19]],
#  [[0, 1, 2]],
#  [[1]],
#  [[14]],
#  [[24, 25], [24, 25]],
#  [[10, 11]],
#  [[23], [5], [5]],
#  [[7]],
#  [[22, 23]],
#  [[15, 16]],
#  [[12], [12]],
#  [[16, 17, 18]],
#  [[0, 1]],
#  [[14, 15]],
#  [[8, 9]],
#  [[12]],
#  [[2]],
#  [[24]],
#  [[22], [22]],
#  [[30, 31], [30, 31, 32]],
#  [[12, 13, 14]],
#  [[11], [11]],
#  [[18]],
#  [[13, 14]],
#  [[0, 1], [23]],
#  [[8]],
#  [[10, 11], [1, 2]],
#  [[15, 16]],
#  [[22, 23]],
#  [[33, 34, 35], [14]],
#  [[22, 23]],
#  [[48, 49, 50], [48, 49, 50]],
#  [[18, 19], [18, 19]],
#  [[14, 27]],
#  [[22, 23], [22, 23]],
#  [[15, 16]],
#  [[28, 29], [3], [19, 20, 21]],
#  [[16], [20, 21], [16], [20, 21]],
#  [[5]],
#  [[18]],
#  [[11, 12], [11, 12]],
#  [[21, 22], [21, 22]],
#  [[23, 24]],
#  [[17, 18]],
#  [[17, 18], [14, 15]],
#  [[0, 1]],
#  [[2], [2], [2]],
#  [[48]],
#  [[5, 6]],
#  [[3, 4, 5]],
#  [[6, 27]],
#  [[7, 8]],
#  [[6, 7]],
#  [[1], [1], [1], [1], [29], [36]],
#  [[10], [10]],
#  [[1, 20]],
#  [[31, 32, 33], [43]],
#  [[23, 24], [23, 24]],
#  [[10]],
#  [[14, 15]],
#  [[21]],
#  [[0, 1, 2], [0, 1, 2]],
#  [[26]],
#  [[4]],
#  [[36]],
#  [[14, 15]],
#  [[8]],
#  [[22]],
#  [[7]],
#  [[27], [27]],
#  [[34, 35]],
#  [[11, 12]],
#  [[11, 12]],
#  [[24], [10], [10], [10]],
#  [[10], [10], [23], [10]],
#  [[1], [1]],
#  [[17, 18]],
#  [[25, 26]],
#  [[20, 21]],
#  [[10, 11], [10, 11]],
#  [[11]],
#  [[6, 7], [32], [6, 7], [33]],
#  [[7, 8]],
#  [[16, 17]],
#  [[23, 24]],
#  [[5]],
#  [[5]],
#  [[5]],
#  [[12]],
#  [[13], [13]],
#  [[1], [14], [12, 13], [5, 6, 7]],
#  [[8], [1, 2], [8], [8], [11, 12], [11, 12], [8], [8]],
#  [[16]],
#  [[16, 17]],
#  [[6, 7]],
#  [[19, 20]],
#  [[8]],
#  [[7, 8]],
#  [[0, 1, 2]],
#  [[22, 23]],
#  [[8, 9]],
#  [[11], [12]],
#  [[26], [28], [28]],
#  [[29]],
#  [[0], [0]],
#  [[24], [25], [25], [25]],
#  [[1]],
#  [[7]],
#  [[11, 12]],
#  [[4], [4]],
#  [[30]],
#  [[26, 27]],
#  [[0, 1], [0, 1]],
#  [[8]],
#  [[5]],
#  [[12, 13]],
#  [[2], [0, 1]],
#  [[47, 48]],
#  [[6]],
#  [[6]],
#  [[11, 12]],
#  [[14]],
#  [[21], [12], [12]],
#  [[24], [24]],
#  [[8]],
#  [[6]],
#  [[39, 40]],
#  [[39], [40]],
#  [[13]],
#  [[14, 15]],
#  [[6], [6], [6], [0, 1], [0, 1], [6]],
#  [[10], [7, 8]],
#  [[9], [9]],
#  [[31]],
#  [[34], [34], [34]],
#  [[1], [1]],
#  [[16], [0], [0]],
#  [[22, 23]],
#  [[5, 6], [5, 6]],
#  [[10, 11]],
#  [[13], [13], [13], [13]],
#  [[33]],
#  [[28]],
#  [[14, 15]],
#  [[18, 19]],
#  [[16, 17]],
#  [[9, 10]],
#  [[17, 18], [30, 31]],
#  [[52, 53]],
#  [[5]],
#  [[14]],
#  [[4, 5], [4, 5]],
#  [[13], [13]],
#  [[28], [24, 25]],
#  [[18, 19]],
#  [[17]],
#  ...]

# %%
adjacencyList = []
sentence = []
new_entityLabels = []
newi_entityLabels = []
padDict = ['POI', 'RE', 'EOP']
for i in range(len(sentWords)):
    # POI means pointer
    # RE means relation label
    # EOP means end of pointer   
    aL = ''
    for j in entityLabels[i]:
        dictEn = dict((b, a) for a, b in enumerate(entityLabels[i]))
        # Exclude further "None" label
        if j in em1Text[i] and j in [it['em1Text'] for it in relationMentions[i] if it['label'].split('/')[-1] in t_relationTypes]:
            aL += j
            in_em1Text = [dictEn[item] for item in em1Text[i]]
            in_em2Text = [dictEn[item] for item in em2Text[i]]
            new_em1 = [m[0] for m in sorted(list(zip(in_em1Text, in_em2Text)))]
            new_em2 = [n[1] for n in sorted(list(zip(in_em1Text, in_em2Text)))]
            new_em1 = [entityLabels[i][e1] for e1 in new_em1]
            new_em2 = [entityLabels[i][e2] for e2 in new_em2]
            listRe = list(zip(zip(in_em1Text, in_em2Text), relationLabels[i]))
            new_rel = [r[-1] for r in sorted(listRe, key=lambda z: z[0])]
            for item in enumerate(new_em1):
                if j == item[1] and new_rel[item[0]] in t_relationTypes:
                    aL = aL + ' POI ' + new_em2[item[0]] + ' RE ' + new_rel[item[0]]
            aL += ' EOP '
    if len(sentWords[i]) > MAX_SENT_LEN: #or len(aL.split()) > MAX_ADJL_LEN:
        aL = ''
    if aL != '':
        adjacencyList.append(aL)
        sentence.append(sentWords[i])
        new_entityLabels.append(entlabWords[i])
        newi_entityLabels.append(i_entityLabels[i])

# %%
i_adjacencyList = []
for i in range(len(adjacencyList)):
    aL = []
    replace = dict(zip(sum(new_entityLabels[i], []), sum(newi_entityLabels[i], [])))
    aL = [replace[j] if j not in padDict+t_relationTypes else j for j in cut(adjacencyList[i])]
    #aL = [s if type(s) == str else str(s) for s in aL]
    i_adjacencyList.append(aL)

# %%
#[i for i in i_adjacencyList if type(i[-2]) == int]

# %%
#all(type(al[-2]) == int for al in i_adjacencyList)

# %%
#[i for i in i_adjacencyList if i[1] == 'POI']

# %%
#[eT[0] for eT in enumerate(em1Text) for i in eT[1] if i == 'Édith Piaf']

# %% [markdown]
# ### Make Adjacency List of Test Data

# %%
# Clean words
t_sentWords = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_sentWords]

# %%
ti_entityLabels = []
for i in range(len(t_sentWords)):
    eL = []
    t_sDict = list(enumerate(t_sentWords[i]))
    for item in t_entlabWords[i]:
        j = 0
        el = []
        for e in item:
            while j < len(t_sDict):
                if e == t_sDict[j][1]:
                    el.append(t_sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    ti_entityLabels.append(eL)

# %%
t_adjacencyList = []
padDict = ['POI', 'RE', 'EOP']
for i in range(len(t_sentWords)):
    # POI means pointer
    # RE means relation label
    # EOP means end of pointer   
    aL = ''
    for j in t_entityLabels[i]:
        t_dictEn = dict((b, a) for a, b in enumerate(t_entityLabels[i]))
        # Exclude further "None" label
        if j in [it['em1Text'] for it in t_relationMentions[i] if it['label'] != 'None' and j in it['em1Text']]:
            aL += j
            tin_em1Text = [t_dictEn[item] for item in t_em1Text[i]]
            tin_em2Text = [t_dictEn[item] for item in t_em2Text[i]]
            new_tem1 = [m[0] for m in sorted(list(zip(tin_em1Text, tin_em2Text)))]
            new_tem2 = [n[1] for n in sorted(list(zip(tin_em1Text, tin_em2Text)))]
            new_tem1 = [t_entityLabels[i][e1] for e1 in new_tem1]
            new_tem2 = [t_entityLabels[i][e2] for e2 in new_tem2]
            t_listRe = list(zip(zip(tin_em1Text, tin_em2Text), t_relationLabels[i]))
            new_trel = [r[-1] for r in sorted(t_listRe, key=lambda z: z[0])]
            for item in enumerate(new_tem1):
                if j == item[1] and new_trel[item[0]] != 'None':
                    aL = aL + ' POI ' + new_tem2[item[0]] + ' RE ' + new_trel[item[0]]
            aL += ' EOP '
    if aL != '':
        t_adjacencyList.append(aL)

# %%
ti_adjacencyList = []
for i in range(len(t_adjacencyList)):
    aL = []
    replace = dict(zip(sum(t_entlabWords[i], []), sum(ti_entityLabels[i], [])))
    aL = [replace[j] if j not in padDict+t_relationTypes else j for j in cut(t_adjacencyList[i])]
    #aL = [s if type(s) == str else str(s) for s in aL]
    ti_adjacencyList.append(aL)

# %%
ti_adjacencyList[254]
# Out:
# [35, 36, 37, 'POI', 36, 37, 'RE', 'children', 'EOP']

# %%
t_adjacencyList[254]
# Out:
# 'Frank Lloyd Wright POI Lloyd Wright RE children EOP '

# %%
t_sentText[254]
# Out:
# '"His idea -- one that has rarely , if ever , been tried on a large scale by a major museum -- is to collect significant pieces of midcentury residential architecture , including houses by Rudolf M. Schindler , Richard Neutra , Frank Lloyd Wright and his son Lloyd Wright , and to treat them as both museum objects and as residences for curators ."\r\n'

# %%
set([len(i) for i in ti_adjacencyList])
# Out:
# {6, 7, 8, 9, 10, 11, 12, 14, 15, 18, 20, 24, 28}

# %%
[8, 38, 227, 263, 287, 341, 373]

# %%
ti_adjacencyList[287]
# Out:
# [5, 6, 'POI', 5, 'RE', 'country', 'EOP']

# %%
t_relationMentions[287]
# Out:
# [{'em1Text': 'Mexico City', 'em2Text': 'Basel', 'label': 'None'},
#  {'em1Text': 'Basel', 'em2Text': 'Mexico City', 'label': 'None'},
#  {'em1Text': 'Basel', 'em2Text': 'Mexico', 'label': 'None'},
#  {'em1Text': 'Mexico', 'em2Text': 'Basel', 'label': 'None'},
#  {'em1Text': 'Mexico City',
#   'em2Text': 'Mexico',
#   'label': '/location/administrative_division/country'},
#  {'em1Text': 'Mexico', 'em2Text': 'Mexico City', 'label': 'None'}]

# %%
ti_adjacencyList[8]
# Out:
# [29, 'POI', 25, 26, 27, 'RE', 'contains', 'EOP']

# %%
' '.join(t_sentWords[287])
# Out:
# 'Curators have been snapping up Mexico City artwork in places like Basel now they will descend on the city this April for Mexico Arte Contemporaneo its fledging contemporary art fair'

# %%
ti_adjacencyList[38]
# Out:
# [26,
#  'POI',
#  119,
#  'RE',
#  'country',
#  'EOP',
#  26,
#  'POI',
#  119,
#  'RE',
#  'country',
#  'EOP',
#  26,
#  'POI',
#  119,
#  'RE',
#  'country',
#  'EOP']

# %%
#import numpy as np
#np.max([len(i) for i in ti_adjacencyList])

# %%
#len([i for i in i_adjacencyList if len(i) > 20])

# %%
#all(al[1] == 'POI' for al in ti_adjacencyList)

# %% [markdown]
# # Word to Vector

# %% [markdown]
# ## Tokenize Text

# %%
from keras.preprocessing.text import Tokenizer
from nltk import WordNetLemmatizer
# Out:
# Using TensorFlow backend.

# %%
wnl = WordNetLemmatizer()
sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in sentence]
t_sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in t_sentWords]
tok_sentWords = sentWords.copy()
tok_sentWords.extend(t_sentWords)
tokTexts = [' '.join(i) for i in tok_sentWords]

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts(tokTexts)
word2index = tokenizer.word_index
index2word = {i: w for w, i in word2index.items()}
print('Found %s unique tokens.' % len(word2index))
# Out:
# Found 68747 unique tokens.

# %% [markdown]
# ## Create Word Embeddings with GloVe

# %%
VOCAB_SIZE = 68748
EMBEDDING_SIZE = 300
SEED = 42

# %% [markdown]
# ### Read GloVe

# %%
import numpy as np

# %%
glove_n_symbols = !wc -l /Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt
glove_n_symbols = int(glove_n_symbols[0].split()[0])
glove_n_symbols
# Out:
# 1917495

# %%
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_n_symbols, EMBEDDING_SIZE))
globale_scale = 0.1
with open('/Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt', 'r') as fp:
    index = 0
    for l in fp:
        l = l.strip().split()
        word = l[0]
        glove_index_dict[word] = index
        glove_embedding_weights[index, :] = [float(n) for n in l[1:]]
        index += 1
glove_embedding_weights *= globale_scale

# %% [markdown]
# ### Use Glove to Initialize Embedding Matrix

# %%
from nltk import PorterStemmer, LancasterStemmer

# %%
# Generate random embedding with same scale as glove
np.random.seed(SEED)
shape = (VOCAB_SIZE, EMBEDDING_SIZE)
scale = glove_embedding_weights.std() * np.sqrt(12) / 2 
embedding = np.random.uniform(low=-scale, high=scale, size=shape)

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()

# %%
# Copy from glove weights of words that appear in index2word
count = 0 
for i in range(1, VOCAB_SIZE):
    w = index2word[i]
    g = glove_index_dict.get(w)
    if g is None:
        w = porter.stem(w)
        g = glove_index_dict.get(w)
    if g is None:
        w = lancaster.stem(w)
        g = glove_index_dict.get(w)
    if g is not None:
        embedding[i, :] = glove_embedding_weights[g, :]
        count += 1
print('{num_tokens}-{per:.2f}% tokens in vocab found in glove and copied to embedding.'.format(num_tokens=count, per=count/float(VOCAB_SIZE)*100))
# Out:
# 63799-92.80% tokens in vocab found in glove and copied to embedding.

# %% [markdown]
# # Build Dateset

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
new_sentText = [' '.join(i) for i in sentWords]
sentSeq = tokenizer.texts_to_sequences(new_sentText)
sentData = pad_sequences(sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

t_new_sentText = [' '.join(i) for i in t_sentWords]
t_sentSeq = tokenizer.texts_to_sequences(t_new_sentText)
t_sentData = pad_sequences(t_sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

token2index = dict((j, i+120) for i, j in enumerate(['PAD']+padDict+t_relationTypes))
token2index['PAD'] = 0
index2token = {i: w for w, i in token2index.items()}
newi_adjacencyList = [[token2index[i] if i in token2index else i+1 for i in aL] for aL in i_adjacencyList]
newi_adjacencyList = pad_sequences(newi_adjacencyList, maxlen=MAX_ADJL_LEN, padding='post', truncating='pre')
newti_adjacencyList = [[token2index[i] if i in token2index else i+1 for i in aL] for aL in ti_adjacencyList]
newti_adjacencyList = pad_sequences(newti_adjacencyList, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

# %%
#np.max([int(i) for aL in i_adjacencyList for i in aL if i not in padDict+t_relationTypes])

# %%
# Split the data into a training set, a validation set and a test set
x_train_all = sentData
y_train_all = newi_adjacencyList

x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, test_size=0.15, random_state=SEED)
x_train_all, _, y_train_all, _  = train_test_split(x_train_all, y_train_all, test_size=0., random_state=SEED)
 
x_test = t_sentData
y_test = newti_adjacencyList

x_test, _, y_test, _ = train_test_split(x_test, y_test, test_size=0., random_state=SEED)

# %% [markdown]
# # Save Dataset

# %%
import h5py
import pickle

# %%
fh = h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_3_2/allData_gla.h5', 'w')
fh['x_train'] = x_train
fh['y_train'] = y_train
fh['x_val'] = x_val
fh['y_val'] = y_val
fh['x_train_all'] = x_train_all
fh['y_train_all'] = y_train_all
fh['x_test'] = x_test
fh['y_test'] = y_test
fh['embedding'] = embedding
fh.close()

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_3_2/index_gla.pkl', 'wb') as fp:
    pickle.dump((word2index, index2word, token2index, index2token), fp, -1)

# %% [markdown]
# # Checkpoint

# %%
import h5py
import pickle

# %%
with h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_3_2/allData_w2v.h5', 'r') as fh:
    x_train = fh['x_train'][:]
    y_train = fh['y_train'][:]
    x_val = fh['x_val'][:]
    y_val = fh['y_val'][:]
    x_train_all = fh['x_train_all'][:]
    y_train_all = fh['y_train_all'][:]
    x_test = fh['x_test'][:]
    y_test = fh['y_test'][:]
    embedding = fh['embedding'][:]

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_3_2/index_w2v.pkl', 'rb') as fp:
    word2index, index2word, token2index, index2token = pickle.load(fp)

# %%
#len([i for i in y_test if i[0] == 213])

# %% [markdown]
# # Build Model

# %% [markdown]
# ##  Set Hyperparameters

# %%
#300-300-0.5-512-79-20-5
MAX_SENT_LEN = 120
MAX_ADJL_LEN = 20
VOCAB_SIZE = len(word2index)+1
NUM_CLASSES = 136
EMBEDDING_SIZE = 300

ENC_RNN_SIZE = 300
DEC_RNN_SIZE = 300
DROPOUT_RATE = 0.5
NUM_EPOCHS = 512
BATCH_SIZE = 79
STEPS_PER_EPOCH = 20
TEST_STEPS = len(x_test)//BATCH_SIZE

VALIDATION_STEPS = 3

# %%
print('NUM_EPOCHS: \t\t%d' % NUM_EPOCHS)
print('STEPS_PER_EPOCH: \t%d' % STEPS_PER_EPOCH)
print('TEST_STEPS: \t\t%d' % TEST_STEPS)
print('VALIDATION_STEPS: \t%d' % VALIDATION_STEPS)
print('TRAIN_BATCHES: \t\t%d' % (NUM_EPOCHS * STEPS_PER_EPOCH))
print('NUM_BATCHES \t\t%d' % (len(x_train)//BATCH_SIZE+1))
# Out:
# NUM_EPOCHS: 		512
# STEPS_PER_EPOCH: 	20
# TEST_STEPS: 		5
# VALIDATION_STEPS: 	3
# TRAIN_BATCHES: 		10240
# NUM_BATCHES 		672

# %% [markdown]
# ## Import Libraries

# %%
from keras.layers import Input, Embedding, Dropout, Bidirectional, LSTM, RepeatVector, TimeDistributed, Dense
from keras.models import Model
import keras.backend as K
from keras.callbacks import*
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Build Graph

# %%
K.clear_session()
sequence = Input(shape=(MAX_SENT_LEN,), name='INPUT') 
emb_seq = Embedding(VOCAB_SIZE, EMBEDDING_SIZE, weights=[embedding], mask_zero=True, input_length=MAX_SENT_LEN, trainable=True, name='EMBEDDING')(sequence)
emb_seq = Dropout(DROPOUT_RATE)(emb_seq)
blstm = Bidirectional(LSTM(ENC_RNN_SIZE, return_sequences=True, implementation=0), merge_mode='concat', name='ENC_BLSTM_1')(emb_seq)
blstm = Dropout(DROPOUT_RATE)(blstm)
blstm = Bidirectional(LSTM(ENC_RNN_SIZE, return_sequences=False, implementation=0), merge_mode='concat', name='ENC_BLSTM_2')(blstm)
blstm = Dropout(DROPOUT_RATE)(blstm)
context = RepeatVector(MAX_ADJL_LEN, name='CONTEXT')(blstm)
lstm = LSTM(DEC_RNN_SIZE, return_sequences=True, implementation=0, name='DEC_LSTM')(context)
lstm = Dropout(DROPOUT_RATE)(lstm)
output = TimeDistributed(Dense(NUM_CLASSES, activation='softmax'), name='OUTPUT')(lstm)
model = Model(inputs=sequence, outputs=output)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %% [markdown]
# ## Model Visualization

# %%
model.summary()
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# INPUT (InputLayer)           (None, 120)               0
# _________________________________________________________________
# EMBEDDING (Embedding)        (None, 120, 300)          20624400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120, 300)          0
# _________________________________________________________________
# ENC_BLSTM_1 (Bidirectional)  (None, 120, 600)          1442400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 120, 600)          0
# _________________________________________________________________
# ENC_BLSTM_2 (Bidirectional)  (None, 600)               2162400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 600)               0
# _________________________________________________________________
# CONTEXT (RepeatVector)       (None, 20, 600)           0
# _________________________________________________________________
# DEC_LSTM (LSTM)              (None, 20, 300)           1081200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20, 300)           0
# _________________________________________________________________
# OUTPUT (TimeDistributed)     (None, 20, 136)           40936
# =================================================================
# Total params: 25,351,336
# Trainable params: 25,351,336
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
def gen_label(s):
    """
    One-hot encoding
    """
    gen = to_categorical(s, num_classes=NUM_CLASSES)
    return gen

def data_generator_all(data, label, batch_size):
    """
    Yield batches of all data
    """
    count = 0
    while True:
        if count >= len(data): 
            count = 0
        x = np.zeros((batch_size, MAX_SENT_LEN))
        y = np.zeros((batch_size, MAX_ADJL_LEN, NUM_CLASSES))
        for i in range(batch_size):
            n = i + count
            if n > len(data)-1:
                break
            x[i, :] = data[n]
            y[i, :, :] = gen_label(label[n])
        count += batch_size
        yield (x, y)
        
def data_generator(data, label, batch_size): 
    """
    Yield batches 
    """
    index = np.arange(len(data))
    np.random.shuffle(index)    
    batches = [index[range(batch_size*i, min(len(data), batch_size*(i+1)))] for i in range(len(data)//batch_size)]
    while True:
        for i in batches:
            x, y = data[i], np.array(list(map(gen_label, label[i])))
            yield (x, y)

# %%
gen_train_all = data_generator(x_train_all, y_train_all, BATCH_SIZE)
gen_test = data_generator_all(x_test, y_test, BATCH_SIZE)
gen_train = data_generator(x_train, y_train, BATCH_SIZE)
gen_val = data_generator(x_val, y_val, BATCH_SIZE)

# %%
# Continue Trian
# filename = 'cp_logs/.hdf5'
# model.load_weights(filename)
# model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['acc'])

# %%
filepath = '/Users/lizhn7/Downloads/DATA/nyt/experiment_3_2/cp_logs/weights.{epoch:03d}-{val_loss:.6f}.hdf5'
log_string = '/Users/lizhn7/Downloads/DATA/nyt/experiment_3_2/tb_logs/300-300-0.5-512-79-20-5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
tensorboard = TensorBoard(log_dir=log_string, 
                          histogram_freq=1, 
                          write_graph=False, 
                          write_grads=False, 
                          batch_size=BATCH_SIZE, 
                          write_images=True, 
                          embeddings_freq=1, 
                          embeddings_layer_names=None,
                          embeddings_metadata=None)

# %%
history = model.fit_generator(gen_train_all, 
                              steps_per_epoch=STEPS_PER_EPOCH, 
                              epochs=NUM_EPOCHS, 
                              verbose=1,
                              #callbacks=[checkpoint, tensorboard],
                              validation_data=gen_test, 
                              validation_steps=TEST_STEPS)

# %% [markdown]
# # Evaluate

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_3_2/cp_logs/allLSTM_w2v/weights.050-0.592349.hdf5'
model.load_weights(filename)

# %%
result = np.argmax(model.predict(x_test, batch_size=BATCH_SIZE, verbose=1), -1)
# Out:
# 395/395 [==============================] - 15s

# %%
preResult = [' '.join([index2token.get(i, str(i)) for i in sent if i != 0]) for sent in result]
actResult = [' '.join([index2token.get(i, str(i)) for i in sent if i != 0]) for sent in y_test]
for i in range(395):
    print('Predict: \t%s' % preResult[i])
    print('Ground-Truth: \t%s' % actResult[i])
    print('---')
# Out:
# Predict: 	9 POI 9 RE contains EOP
# Ground-Truth: 	9 POI 10 RE country EOP
# ---
# Predict: 	2 POI 15 RE contains EOP
# Ground-Truth: 	16 POI 14 RE country EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE EOP
# Ground-Truth: 	11 POI 13 RE nationality EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 9 RE contains EOP
# ---
# Predict: 	13 POI 14 RE place_lived EOP
# Ground-Truth: 	12 POI 15 RE place_lived EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 9 RE contains EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	8 POI 1 RE founders EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	20 POI 16 RE country EOP
# ---
# Predict: 	9 POI 32 RE contains EOP
# Ground-Truth: 	19 POI 13 RE country POI 13 RE country EOP 19 POI 13 RE country POI 13 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP RE EOP
# Ground-Truth: 	17 POI 6 RE contains EOP
# ---
# Predict: 	12 POI 10 RE contains EOP
# Ground-Truth: 	26 POI 29 RE company EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 11 RE contains EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	2 POI 7 RE contains EOP
# ---
# Predict: 	14 POI 17 RE place_lived EOP
# Ground-Truth: 	15 POI 18 RE place_lived EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	3 POI 6 RE place_lived EOP
# ---
# Predict: 	4 POI 4 RE contains POI RE EOP
# Ground-Truth: 	4 POI 16 RE country EOP
# ---
# Predict: 	18 POI 20 RE company EOP
# Ground-Truth: 	23 POI 26 RE company EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	4 POI 6 RE country EOP
# ---
# Predict: 	18 POI 18 RE country EOP POI RE POI RE RE EOP
# Ground-Truth: 	20 POI 21 RE country EOP
# ---
# Predict: 	29 POI 32 RE place_lived EOP
# Ground-Truth: 	28 POI 37 RE company EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	13 POI 16 RE nationality EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	9 POI 15 RE company EOP
# ---
# Predict: 	14 POI 14 RE company EOP
# Ground-Truth: 	20 POI 12 RE founders EOP
# ---
# Predict: 	2 POI 2 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE place_lived EOP
# Ground-Truth: 	20 POI 31 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains EOP
# Ground-Truth: 	18 POI 13 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 34 RE country EOP
# ---
# Predict: 	9 POI 12 RE company EOP
# Ground-Truth: 	8 POI 15 RE place_lived EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	6 POI 15 RE company EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	29 POI 1 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	18 POI 16 RE contains EOP
# ---
# Predict: 	18 POI 18 RE nationality EOP
# Ground-Truth: 	21 POI 17 RE nationality EOP
# ---
# Predict: 	23 POI 29 RE contains EOP
# Ground-Truth: 	30 POI 34 RE country EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	11 POI 17 RE company EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	26 POI 24 RE contains EOP
# ---
# Predict: 	8 POI 44 RE contains EOP
# Ground-Truth: 	38 POI 43 RE company EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	8 POI 15 RE company EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	14 POI 12 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	29 POI 34 RE contains POI 34 RE contains EOP 29 POI 34 RE contains POI 34 RE contains EOP
# ---
# Predict: 	12 POI 12 RE country EOP RE capital EOP POI POI RE
# Ground-Truth: 	15 POI 14 RE contains EOP
# ---
# Predict: 	26 POI 32 RE contains EOP
# Ground-Truth: 	29 POI 31 RE country EOP
# ---
# Predict: 	2 POI 8 RE place_lived EOP
# Ground-Truth: 	3 POI 6 RE place_lived EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 21 RE country EOP
# ---
# Predict: 	2 POI 24 RE contains EOP
# Ground-Truth: 	42 POI 31 RE country EOP
# ---
# Predict: 	20 POI 18 RE contains EOP
# Ground-Truth: 	38 POI 43 RE place_of_birth EOP
# ---
# Predict: 	1 POI 2 RE nationality EOP
# Ground-Truth: 	38 POI 41 RE nationality EOP
# ---
# Predict: 	18 POI 18 RE nationality EOP
# Ground-Truth: 	16 POI 21 RE nationality EOP
# ---
# Predict: 	23 POI 24 RE nationality EOP
# Ground-Truth: 	28 POI 30 RE country EOP
# ---
# Predict: 	2 POI 6 RE place_lived EOP
# Ground-Truth: 	3 POI 7 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 11 RE contains EOP
# ---
# Predict: 	12 POI 12 RE place_lived EOP
# Ground-Truth: 	10 POI 14 RE place_lived EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 21 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	21 POI 16 RE company POI 16 RE company EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	5 POI 8 RE contains EOP
# ---
# Predict: 	9 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 7 RE contains EOP
# ---
# Predict: 	6 POI 6 RE country EOP
# Ground-Truth: 	6 POI 7 RE country EOP
# ---
# Predict: 	16 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	7 POI 6 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 10 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	14 POI 22 RE country EOP
# ---
# Predict: 	26 POI 28 RE neighborhood_of EOP POI RE contains EOP
# Ground-Truth: 	37 POI 34 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 7 RE contains EOP
# ---
# Predict: 	2 POI 32 RE contains EOP
# Ground-Truth: 	38 POI 39 RE country EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	1 POI 9 RE company EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 10 RE contains EOP
# ---
# Predict: 	13 POI 12 RE place_lived EOP
# Ground-Truth: 	14 POI 18 RE place_lived EOP
# ---
# Predict: 	26 POI 24 RE contains EOP
# Ground-Truth: 	29 POI 27 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 5 RE contains EOP
# ---
# Predict: 	9 POI 8 RE company EOP
# Ground-Truth: 	5 POI 8 RE company EOP
# ---
# Predict: 	6 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 6 RE contains EOP
# ---
# Predict: 	16 POI 15 RE contains EOP
# Ground-Truth: 	18 POI 16 RE contains EOP
# ---
# Predict: 	9 POI 12 RE contains EOP
# Ground-Truth: 	9 POI 13 RE country EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	18 POI 14 RE contains EOP
# ---
# Predict: 	12 POI 12 RE nationality EOP
# Ground-Truth: 	4 POI 15 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	10 POI 19 RE company EOP
# ---
# Predict: 	16 POI 18 RE place_lived EOP
# Ground-Truth: 	17 POI 20 RE place_lived EOP
# ---
# Predict: 	16 POI 16 RE nationality EOP
# Ground-Truth: 	19 POI 14 RE nationality EOP
# ---
# Predict: 	7 POI 6 RE nationality EOP
# Ground-Truth: 	19 POI 7 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	32 POI 35 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	19 POI 1 RE contains EOP
# ---
# Predict: 	9 POI 32 RE contains EOP
# Ground-Truth: 	31 POI 33 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	9 POI 30 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 11 RE contains EOP
# ---
# Predict: 	13 POI 23 RE contains POI RE contains EOP
# Ground-Truth: 	12 POI 25 RE contains EOP
# ---
# Predict: 	10 POI 12 RE place_lived EOP
# Ground-Truth: 	9 POI 12 RE place_lived EOP
# ---
# Predict: 	12 POI 10 RE contains EOP
# Ground-Truth: 	12 POI 10 RE contains EOP
# ---
# Predict: 	1 POI 1 RE company EOP
# Ground-Truth: 	1 POI 8 RE company EOP
# ---
# Predict: 	1 POI 23 RE contains POI RE EOP
# Ground-Truth: 	27 POI 18 RE country EOP
# ---
# Predict: 	33 POI 44 RE contains EOP
# Ground-Truth: 	39 POI 40 RE contains EOP
# ---
# Predict: 	24 POI 32 RE nationality EOP
# Ground-Truth: 	36 POI 33 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 4 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	12 POI 1 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	6 POI 10 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 8 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 34 RE country EOP
# ---
# Predict: 	6 POI 6 RE nationality EOP
# Ground-Truth: 	5 POI 8 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 23 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 9 RE contains EOP 10 POI 9 RE contains EOP
# ---
# Predict: 	11 POI 44 RE contains EOP
# Ground-Truth: 	51 POI 49 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 10 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	9 POI 1 RE contains EOP
# ---
# Predict: 	33 POI 37 RE contains EOP
# Ground-Truth: 	49 POI 47 RE contains EOP
# ---
# Predict: 	11 POI 44 RE contains EOP
# Ground-Truth: 	40 POI 14 RE country EOP
# ---
# Predict: 	19 POI 23 RE contains EOP
# Ground-Truth: 	18 POI 26 RE country EOP
# ---
# Predict: 	20 POI 20 RE company EOP
# Ground-Truth: 	15 POI 26 RE company EOP
# ---
# Predict: 	12 POI 12 RE nationality EOP
# Ground-Truth: 	12 POI 11 RE nationality POI 11 RE nationality EOP
# ---
# Predict: 	10 POI 12 RE place_lived EOP
# Ground-Truth: 	7 POI 13 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE nationality EOP
# Ground-Truth: 	7 POI 13 RE nationality EOP
# ---
# Predict: 	6 POI 6 RE place_lived EOP
# Ground-Truth: 	5 POI 8 RE place_lived EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 10 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	9 POI 5 RE administrative_divisions EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 27 RE contains EOP
# ---
# Predict: 	13 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	17 POI 12 RE country EOP
# ---
# Predict: 	26 POI 24 RE contains EOP
# Ground-Truth: 	29 POI 31 RE contains EOP
# ---
# Predict: 	18 POI 20 RE contains EOP
# Ground-Truth: 	17 POI 20 RE country EOP
# ---
# Predict: 	19 POI 18 RE contains EOP
# Ground-Truth: 	38 POI 24 RE country EOP
# ---
# Predict: 	26 POI 27 RE contains EOP
# Ground-Truth: 	30 POI 28 RE contains EOP
# ---
# Predict: 	10 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 13 RE country EOP
# ---
# Predict: 	1 POI 35 RE contains POI RE capital EOP
# Ground-Truth: 	38 POI 19 RE country EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	37 POI 34 RE contains EOP
# ---
# Predict: 	18 POI 20 RE contains EOP
# Ground-Truth: 	23 POI 20 RE contains EOP
# ---
# Predict: 	33 POI 32 RE contains EOP
# Ground-Truth: 	29 POI 34 RE contains EOP
# ---
# Predict: 	32 POI 37 RE contains EOP
# Ground-Truth: 	41 POI 40 RE contains EOP
# ---
# Predict: 	23 POI 27 RE contains EOP
# Ground-Truth: 	29 POI 26 RE contains EOP
# ---
# Predict: 	20 POI 20 RE neighborhood_of EOP 23 POI 20 RE contains EOP
# Ground-Truth: 	23 POI 20 RE contains EOP
# ---
# Predict: 	9 POI 12 RE nationality EOP
# Ground-Truth: 	11 POI 10 RE contains EOP
# ---
# Predict: 	12 POI 18 RE contains EOP
# Ground-Truth: 	13 POI 19 RE place_lived EOP
# ---
# Predict: 	18 POI 18 RE contains POI RE EOP
# Ground-Truth: 	17 POI 20 RE administrative_divisions EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	1 POI 33 RE place_of_death EOP
# ---
# Predict: 	6 POI 35 RE contains POI RE contains EOP
# Ground-Truth: 	21 POI 7 RE contains POI 7 RE contains EOP
# ---
# Predict: 	4 POI 31 RE contains POI RE contains EOP
# Ground-Truth: 	20 POI 4 RE country POI 4 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 10 RE contains EOP
# ---
# Predict: 	9 POI 9 RE nationality EOP
# Ground-Truth: 	6 POI 9 RE nationality EOP
# ---
# Predict: 	24 POI 24 RE company EOP
# Ground-Truth: 	22 POI 30 RE company EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	13 POI 2 RE contains EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE capital EOP
# Ground-Truth: 	7 POI 13 RE contains EOP
# ---
# Predict: 	26 POI 32 RE neighborhood_of EOP POI RE contains EOP
# Ground-Truth: 	33 POI 30 RE contains EOP
# ---
# Predict: 	8 POI 9 RE country EOP RE EOP POI RE
# Ground-Truth: 	10 POI 11 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	6 POI 6 RE country EOP 6 POI 6 RE country EOP
# ---
# Predict: 	18 POI 20 RE nationality EOP
# Ground-Truth: 	11 POI 20 RE nationality EOP
# ---
# Predict: 	6 POI 6 RE country EOP RE
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	27 POI 27 RE place_lived EOP
# Ground-Truth: 	21 POI 29 RE place_lived EOP 21 POI 29 RE place_lived EOP
# ---
# Predict: 	18 POI 22 RE capital POI RE capital EOP
# Ground-Truth: 	14 POI 12 RE country EOP 14 POI 12 RE country EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 6 RE country EOP
# ---
# Predict: 	1 POI 31 RE company EOP
# Ground-Truth: 	1 POI 7 RE company EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	12 POI 4 RE contains EOP
# ---
# Predict: 	9 POI 8 RE company EOP
# Ground-Truth: 	5 POI 11 RE company EOP
# ---
# Predict: 	24 POI 24 RE nationality EOP
# Ground-Truth: 	16 POI 12 RE contains EOP
# ---
# Predict: 	20 POI 20 RE nationality EOP
# Ground-Truth: 	21 POI 33 RE administrative_divisions EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	18 POI 16 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	35 POI 33 RE country EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	10 POI 16 RE place_lived EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	5 POI 5 RE country EOP 5 POI 5 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	1 POI 24 RE place_of_death EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 6 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains POI RE EOP
# Ground-Truth: 	18 POI 41 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	9 POI 8 RE contains EOP
# ---
# Predict: 	9 POI 8 RE company EOP
# Ground-Truth: 	4 POI 11 RE company EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	2 POI 20 RE place_lived EOP
# Ground-Truth: 	19 POI 22 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 26 RE country EOP
# ---
# Predict: 	13 POI 18 RE country EOP RE capital EOP RE
# Ground-Truth: 	16 POI 17 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 19 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 19 RE contains EOP
# ---
# Predict: 	10 POI 11 RE contains POI RE EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	35 POI 37 RE company EOP
# Ground-Truth: 	47 POI 42 RE founders EOP
# ---
# Predict: 	1 POI 12 RE contains EOP
# Ground-Truth: 	46 POI 38 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	6 POI 12 RE country EOP
# ---
# Predict: 	20 POI 30 RE nationality EOP
# Ground-Truth: 	24 POI 44 RE country EOP
# ---
# Predict: 	18 POI 18 RE neighborhood_of EOP 18 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 10 RE contains EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 4 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 6 RE place_lived EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	3 POI 30 RE country EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 6 RE contains EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE capital EOP
# Ground-Truth: 	12 POI 7 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 23 RE contains EOP
# ---
# Predict: 	2 POI 20 RE contains EOP
# Ground-Truth: 	19 POI 3 RE neighborhood_of EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	36 POI 42 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 17 RE contains EOP
# ---
# Predict: 	14 POI 14 RE company EOP
# Ground-Truth: 	13 POI 9 RE company EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	23 POI 23 RE place_lived EOP
# Ground-Truth: 	23 POI 26 RE place_lived EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 6 RE place_lived EOP
# ---
# Predict: 	20 POI 23 RE place_lived EOP
# Ground-Truth: 	28 POI 31 RE place_lived EOP
# ---
# Predict: 	1 POI 31 RE contains POI RE capital POI EOP
# Ground-Truth: 	28 POI 6 RE country EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	2 POI 25 RE contains EOP
# ---
# Predict: 	7 POI 8 RE place_lived EOP
# Ground-Truth: 	13 POI 6 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 22 RE contains EOP
# ---
# Predict: 	32 POI 37 RE place_lived EOP
# Ground-Truth: 	38 POI 41 RE place_lived EOP
# ---
# Predict: 	26 POI 28 RE contains EOP
# Ground-Truth: 	30 POI 34 RE contains EOP
# ---
# Predict: 	20 POI 20 RE place_lived EOP
# Ground-Truth: 	13 POI 16 RE place_lived EOP
# ---
# Predict: 	13 POI 18 RE contains EOP
# Ground-Truth: 	16 POI 27 RE country EOP
# ---
# Predict: 	20 POI 20 RE contains EOP
# Ground-Truth: 	20 POI 23 RE country EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	3 POI 10 RE country EOP
# ---
# Predict: 	10 POI 10 RE contains EOP
# Ground-Truth: 	12 POI 9 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains POI RE contains EOP
# Ground-Truth: 	11 POI 19 RE country EOP
# ---
# Predict: 	9 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	9 POI 7 RE country EOP
# ---
# Predict: 	19 POI 20 RE contains EOP
# Ground-Truth: 	18 POI 24 RE country EOP
# ---
# Predict: 	42 POI 44 RE contains POI RE contains EOP
# Ground-Truth: 	27 POI 120 RE country EOP 27 POI 120 RE country EOP 27 POI 120 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	26 POI 22 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 24 RE country EOP
# ---
# Predict: 	26 POI 28 RE country EOP
# Ground-Truth: 	30 POI 28 RE contains EOP
# ---
# Predict: 	28 POI 28 RE nationality EOP
# Ground-Truth: 	32 POI 34 RE nationality EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	17 POI 21 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	23 POI 20 RE contains EOP
# ---
# Predict: 	1 POI 31 RE contains POI RE contains EOP
# Ground-Truth: 	1 POI 6 RE nationality EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	34 POI 14 RE contains EOP
# ---
# Predict: 	26 POI 28 RE nationality EOP
# Ground-Truth: 	33 POI 29 RE nationality EOP
# ---
# Predict: 	35 POI 37 RE contains EOP
# Ground-Truth: 	32 POI 13 RE country POI 13 RE country EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	1 POI 4 RE contains EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	17 POI 15 RE contains EOP
# ---
# Predict: 	20 POI 20 RE contains POI EOP
# Ground-Truth: 	23 POI 22 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	13 POI 13 RE contains EOP 13 POI 13 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	13 POI 14 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	18 POI 36 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	39 POI 33 RE contains EOP
# ---
# Predict: 	13 POI 15 RE nationality EOP
# Ground-Truth: 	11 POI 14 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 23 RE contains EOP
# ---
# Predict: 	19 POI 18 RE contains EOP
# Ground-Truth: 	17 POI 27 RE country EOP
# ---
# Predict: 	13 POI 14 RE place_lived EOP
# Ground-Truth: 	12 POI 16 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	26 POI 28 RE contains EOP
# ---
# Predict: 	30 POI 37 RE nationality EOP
# Ground-Truth: 	45 POI 42 RE nationality EOP
# ---
# Predict: 	8 POI 6 RE contains EOP
# Ground-Truth: 	5 POI 8 RE contains EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	9 POI 3 RE country EOP
# ---
# Predict: 	1 POI 31 RE company EOP
# Ground-Truth: 	1 POI 37 RE founders POI 37 RE founders EOP 1 POI 37 RE founders POI 37 RE founders EOP
# ---
# Predict: 	24 POI 24 RE nationality EOP
# Ground-Truth: 	25 POI 28 RE nationality EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	13 POI 14 RE country EOP
# ---
# Predict: 	27 POI 28 RE contains EOP
# Ground-Truth: 	31 POI 28 RE contains EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	16 POI 14 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	30 POI 29 RE contains EOP
# ---
# Predict: 	14 POI 15 RE company EOP
# Ground-Truth: 	10 POI 22 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	15 POI 17 RE contains EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 17 RE contains EOP
# ---
# Predict: 	8 POI 8 RE place_lived EOP
# Ground-Truth: 	6 POI 8 RE place_lived EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 9 RE contains EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	4 POI 2 RE country EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 16 RE contains EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	19 POI 17 RE contains EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	3 POI 3 RE country EOP 3 POI 3 RE country EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	1 POI 24 RE company EOP
# Ground-Truth: 	18 POI 3 RE company EOP
# ---
# Predict: 	6 POI 32 RE contains POI RE capital EOP
# Ground-Truth: 	31 POI 10 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	5 POI 6 RE country EOP
# ---
# Predict: 	1 POI 4 RE nationality EOP
# Ground-Truth: 	3 POI 6 RE nationality EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	24 POI 30 RE place_lived EOP
# Ground-Truth: 	32 POI 39 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	10 POI 18 RE company EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 24 RE country EOP
# ---
# Predict: 	17 POI 18 RE place_lived EOP
# Ground-Truth: 	13 POI 17 RE place_lived EOP
# ---
# Predict: 	4 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	9 POI 10 RE place_lived EOP
# Ground-Truth: 	8 POI 11 RE place_lived EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	1 POI 22 RE country EOP 1 POI 22 RE country EOP
# ---
# Predict: 	12 POI 9 RE contains EOP
# Ground-Truth: 	13 POI 9 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	32 POI 11 RE country EOP
# ---
# Predict: 	6 POI 2 RE contains EOP
# Ground-Truth: 	4 POI 3 RE contains EOP
# ---
# Predict: 	42 POI 44 RE contains EOP
# Ground-Truth: 	79 POI 47 RE country EOP
# ---
# Predict: 	1 POI 1 RE nationality EOP
# Ground-Truth: 	1 POI 4 RE nationality EOP
# ---
# Predict: 	1 POI 15 RE company EOP
# Ground-Truth: 	1 POI 11 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	15 POI 16 RE country EOP
# ---
# Predict: 	1 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	3 POI 13 RE contains POI 13 RE contains EOP 3 POI 13 RE contains POI 13 RE contains EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	9 POI 32 RE contains EOP
# Ground-Truth: 	31 POI 8 RE capital EOP
# ---
# Predict: 	35 POI 44 RE contains EOP
# Ground-Truth: 	54 POI 45 RE contains EOP
# ---
# Predict: 	32 POI 35 RE contains EOP
# Ground-Truth: 	42 POI 40 RE contains EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	10 POI 16 RE company EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	5 POI 6 RE country EOP
# ---
# Predict: 	8 POI 8 RE place_lived EOP
# Ground-Truth: 	5 POI 9 RE place_lived EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	5 POI 4 RE contains EOP
# ---
# Predict: 	26 POI 28 RE nationality EOP
# Ground-Truth: 	23 POI 29 RE company EOP
# ---
# Predict: 	8 POI 8 RE neighborhood_of EOP 8 POI 6 RE contains EOP
# Ground-Truth: 	10 POI 7 RE contains EOP
# ---
# Predict: 	28 POI 30 RE company EOP
# Ground-Truth: 	36 POI 37 RE children EOP 37 EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	23 POI 22 RE contains EOP
# ---
# Predict: 	1 POI 23 RE contains POI RE capital POI RE EOP
# Ground-Truth: 	23 POI 8 RE country EOP
# ---
# Predict: 	4 POI 4 RE country EOP RE EOP RE
# Ground-Truth: 	5 POI 4 RE contains EOP
# ---
# Predict: 	16 POI 15 RE contains EOP
# Ground-Truth: 	17 POI 14 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	20 POI 2 RE country EOP
# ---
# Predict: 	8 POI 8 RE neighborhood_of EOP POI 8 RE contains EOP
# Ground-Truth: 	8 POI 7 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains POI RE capital POI RE EOP
# Ground-Truth: 	16 POI 11 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 36 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 20 RE contains EOP
# ---
# Predict: 	9 POI 8 RE nationality EOP
# Ground-Truth: 	11 POI 6 RE nationality EOP
# ---
# Predict: 	26 POI 32 RE contains EOP
# Ground-Truth: 	33 POI 19 RE contains EOP
# ---
# Predict: 	4 POI 2 RE contains EOP
# Ground-Truth: 	6 POI 12 RE contains EOP
# ---
# Predict: 	23 POI 24 RE contains EOP
# Ground-Truth: 	7 POI 21 RE country POI 21 RE country EOP 7 POI 21 RE country POI 21 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	23 POI 22 RE contains EOP
# ---
# Predict: 	27 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 30 RE contains EOP
# ---
# Predict: 	29 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 31 RE contains EOP
# ---
# Predict: 	6 POI 6 RE nationality EOP
# Ground-Truth: 	4 POI 7 RE nationality EOP
# ---
# Predict: 	1 POI 15 RE nationality EOP
# Ground-Truth: 	14 POI 17 RE nationality EOP
# ---
# Predict: 	9 POI 9 RE country EOP RE capital EOP
# Ground-Truth: 	8 POI 21 RE country EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	1 POI 10 RE company EOP
# ---
# Predict: 	9 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 6 RE contains EOP
# ---
# Predict: 	1 POI 35 RE contains POI RE contains EOP
# Ground-Truth: 	44 POI 19 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 15 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	36 POI 9 RE country EOP
# ---
# Predict: 	1 POI 12 RE company EOP
# Ground-Truth: 	1 POI 3 RE company EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	23 POI 29 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	9 POI 6 RE contains EOP
# ---
# Predict: 	2 POI 4 RE contains EOP
# Ground-Truth: 	2 POI 6 RE company EOP
# ---
# Predict: 	27 POI 26 RE contains EOP
# Ground-Truth: 	30 POI 26 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 7 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains EOP
# Ground-Truth: 	16 POI 13 RE contains EOP
# ---
# Predict: 	15 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 15 RE contains EOP
# ---
# Predict: 	2 POI 26 RE contains EOP
# Ground-Truth: 	3 POI 28 RE contains EOP
# ---
# Predict: 	1 POI 29 RE company EOP
# Ground-Truth: 	36 POI 41 RE company EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 10 RE contains EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 7 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	16 POI 11 RE contains EOP
# ---
# Predict: 	32 POI 35 RE contains EOP
# Ground-Truth: 	41 POI 35 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	15 POI 16 RE country EOP
# ---
# Predict: 	13 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 15 RE country POI 15 RE country EOP
# ---
# Predict: 	18 POI 20 RE nationality EOP
# Ground-Truth: 	27 POI 20 RE country EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	11 POI 18 RE company EOP
# ---
# Predict: 	15 POI 14 RE contains EOP
# Ground-Truth: 	18 POI 17 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	21 POI 11 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	29 POI 1 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 19 RE contains EOP
# ---
# Predict: 	24 POI 23 RE contains EOP
# Ground-Truth: 	27 POI 21 RE contains EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	7 POI 5 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 4 RE country EOP
# ---
# Predict: 	1 POI 12 RE company EOP
# Ground-Truth: 	1 POI 4 RE company EOP
# ---
# Predict: 	32 POI 37 RE contains EOP
# Ground-Truth: 	44 POI 42 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	27 POI 24 RE contains EOP
# ---
# Predict: 	18 POI 18 RE country POI RE capital POI EOP RE
# Ground-Truth: 	19 POI 20 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	7 POI 5 RE contains EOP
# ---
# Predict: 	27 POI 27 RE contains EOP
# Ground-Truth: 	27 POI 24 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	13 POI 15 RE company EOP
# Ground-Truth: 	22 POI 19 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	28 POI 29 RE capital EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	5 POI 4 RE contains EOP
# ---
# Predict: 	35 POI 44 RE contains EOP
# Ground-Truth: 	50 POI 47 RE contains EOP
# ---
# Predict: 	42 POI 44 RE contains EOP
# Ground-Truth: 	95 POI 64 RE country EOP
# ---
# Predict: 	2 POI 1 RE contains EOP
# Ground-Truth: 	13 POI 11 RE contains EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	8 POI 14 RE company EOP
# ---
# Predict: 	15 POI 18 RE contains EOP
# Ground-Truth: 	17 POI 15 RE contains EOP
# ---
# Predict: 	23 POI 30 RE contains EOP
# Ground-Truth: 	40 POI 37 RE contains EOP
# ---
# Predict: 	6 POI 18 RE contains EOP
# Ground-Truth: 	4 POI 6 RE country POI 6 RE country EOP 4 POI 6 RE country POI 6 RE country EOP
# ---
# Predict: 	7 POI 8 RE place_lived EOP
# Ground-Truth: 	4 POI 8 RE place_lived EOP
# ---
# Predict: 	10 POI 10 RE contains EOP
# Ground-Truth: 	5 POI 11 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	13 POI 14 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 15 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE EOP
# Ground-Truth: 	34 POI 33 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	15 POI 11 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 17 RE contains EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	41 POI 42 RE country EOP
# ---
# Predict: 	1 POI 20 RE contains POI RE capital EOP
# Ground-Truth: 	21 POI 20 RE contains EOP
# ---
# Predict: 	13 POI 18 RE contains POI EOP
# Ground-Truth: 	1 POI 19 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	9 POI 7 RE country EOP
# ---
# Predict: 	6 POI 6 RE country EOP RE capital EOP POI RE POI RE POI
# Ground-Truth: 	8 POI 7 RE contains EOP
# ---
# Predict: 	20 POI 20 RE nationality EOP
# Ground-Truth: 	14 POI 22 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE nationality EOP
# Ground-Truth: 	25 POI 24 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 18 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains EOP
# Ground-Truth: 	17 POI 11 RE contains EOP
# ---
# Predict: 	23 POI 23 RE place_lived EOP
# Ground-Truth: 	15 POI 18 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 11 RE contains EOP
# ---
# Predict: 	1 POI 24 RE company EOP
# Ground-Truth: 	1 POI 14 RE company EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	10 POI 7 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	6 POI 20 RE country EOP 6 POI 20 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	16 POI 14 RE contains EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 17 RE contains EOP
# ---
# Predict: 	1 POI 37 RE contains EOP
# Ground-Truth: 	17 POI 11 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 32 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains POI EOP
# Ground-Truth: 	58 POI 16 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 13 RE country POI 13 RE country EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 4 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	16 POI 11 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	21 POI 37 RE country EOP 23 POI 37 RE country EOP 21 POI 37 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains POI RE contains EOP
# Ground-Truth: 	10 POI 12 RE country POI 12 RE country EOP 10 POI 12 RE country POI 12 RE country EOP
# ---
# Predict: 	12 POI 12 RE place_lived EOP
# Ground-Truth: 	9 POI 12 RE place_lived EOP
# ---
# Predict: 	6 POI 4 RE place_lived EOP
# Ground-Truth: 	21 POI 25 RE place_lived EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	7 POI 6 RE contains EOP
# ---
# Predict: 	10 POI 10 RE contains EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	1 POI 1 RE nationality EOP
# Ground-Truth: 	7 POI 1 RE nationality EOP
# ---
# Predict: 	6 POI 32 RE contains EOP
# Ground-Truth: 	29 POI 26 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 6 RE country EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	38 POI 13 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	1 POI 14 RE place_lived EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	18 POI 15 RE contains EOP
# ---
# Predict: 	1 POI 1 RE nationality POI RE EOP
# Ground-Truth: 	3 POI 1 RE country EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	9 POI 5 RE contains EOP
# ---
# Predict: 	26 POI 24 RE contains EOP
# Ground-Truth: 	20 POI 28 RE company EOP
# ---
# Predict: 	20 POI 20 RE nationality EOP
# Ground-Truth: 	15 POI 23 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	12 POI 1 RE children EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	9 POI 8 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE EOP
# Ground-Truth: 	35 POI 31 RE contains EOP
# ---
# Predict: 	20 POI 22 RE company EOP
# Ground-Truth: 	15 POI 23 RE company EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 5 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	2 POI 8 RE place_lived EOP
# Ground-Truth: 	1 POI 5 RE place_lived EOP
# ---

# %%
set([len(i.split()) for i in actResult])
# Out:
# {6, 8, 10, 12, 18, 20}

# %%
A = [i for j, i in enumerate(actResult) if len(i.split()) == 6]
a = [preResult[j] for j, i in enumerate(actResult) if len(i.split()) == 6]
for i in range(len(A)):
    print('Predict: \t%s' % a[i])
    print('Ground-Truth: \t%s' % A[i])
    print('---')
# Out:
# Predict: 	9 POI 9 RE contains EOP
# Ground-Truth: 	9 POI 10 RE country EOP
# ---
# Predict: 	2 POI 15 RE contains EOP
# Ground-Truth: 	16 POI 14 RE country EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE EOP
# Ground-Truth: 	11 POI 13 RE nationality EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 9 RE contains EOP
# ---
# Predict: 	13 POI 14 RE place_lived EOP
# Ground-Truth: 	12 POI 15 RE place_lived EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 9 RE contains EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	8 POI 1 RE founders EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	20 POI 16 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP RE EOP
# Ground-Truth: 	17 POI 6 RE contains EOP
# ---
# Predict: 	12 POI 10 RE contains EOP
# Ground-Truth: 	26 POI 29 RE company EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 11 RE contains EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	2 POI 7 RE contains EOP
# ---
# Predict: 	14 POI 17 RE place_lived EOP
# Ground-Truth: 	15 POI 18 RE place_lived EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	3 POI 6 RE place_lived EOP
# ---
# Predict: 	4 POI 4 RE contains POI RE EOP
# Ground-Truth: 	4 POI 16 RE country EOP
# ---
# Predict: 	18 POI 20 RE company EOP
# Ground-Truth: 	23 POI 26 RE company EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	4 POI 6 RE country EOP
# ---
# Predict: 	18 POI 18 RE country EOP POI RE POI RE RE EOP
# Ground-Truth: 	20 POI 21 RE country EOP
# ---
# Predict: 	29 POI 32 RE place_lived EOP
# Ground-Truth: 	28 POI 37 RE company EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	13 POI 16 RE nationality EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	9 POI 15 RE company EOP
# ---
# Predict: 	14 POI 14 RE company EOP
# Ground-Truth: 	20 POI 12 RE founders EOP
# ---
# Predict: 	2 POI 2 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE place_lived EOP
# Ground-Truth: 	20 POI 31 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains EOP
# Ground-Truth: 	18 POI 13 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 34 RE country EOP
# ---
# Predict: 	9 POI 12 RE company EOP
# Ground-Truth: 	8 POI 15 RE place_lived EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	6 POI 15 RE company EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	29 POI 1 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	18 POI 16 RE contains EOP
# ---
# Predict: 	18 POI 18 RE nationality EOP
# Ground-Truth: 	21 POI 17 RE nationality EOP
# ---
# Predict: 	23 POI 29 RE contains EOP
# Ground-Truth: 	30 POI 34 RE country EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	11 POI 17 RE company EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	26 POI 24 RE contains EOP
# ---
# Predict: 	8 POI 44 RE contains EOP
# Ground-Truth: 	38 POI 43 RE company EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	8 POI 15 RE company EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	14 POI 12 RE contains EOP
# ---
# Predict: 	12 POI 12 RE country EOP RE capital EOP POI POI RE
# Ground-Truth: 	15 POI 14 RE contains EOP
# ---
# Predict: 	26 POI 32 RE contains EOP
# Ground-Truth: 	29 POI 31 RE country EOP
# ---
# Predict: 	2 POI 8 RE place_lived EOP
# Ground-Truth: 	3 POI 6 RE place_lived EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 21 RE country EOP
# ---
# Predict: 	2 POI 24 RE contains EOP
# Ground-Truth: 	42 POI 31 RE country EOP
# ---
# Predict: 	20 POI 18 RE contains EOP
# Ground-Truth: 	38 POI 43 RE place_of_birth EOP
# ---
# Predict: 	1 POI 2 RE nationality EOP
# Ground-Truth: 	38 POI 41 RE nationality EOP
# ---
# Predict: 	18 POI 18 RE nationality EOP
# Ground-Truth: 	16 POI 21 RE nationality EOP
# ---
# Predict: 	23 POI 24 RE nationality EOP
# Ground-Truth: 	28 POI 30 RE country EOP
# ---
# Predict: 	2 POI 6 RE place_lived EOP
# Ground-Truth: 	3 POI 7 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 11 RE contains EOP
# ---
# Predict: 	12 POI 12 RE place_lived EOP
# Ground-Truth: 	10 POI 14 RE place_lived EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 21 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	5 POI 8 RE contains EOP
# ---
# Predict: 	9 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 7 RE contains EOP
# ---
# Predict: 	6 POI 6 RE country EOP
# Ground-Truth: 	6 POI 7 RE country EOP
# ---
# Predict: 	16 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	7 POI 6 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 10 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	14 POI 22 RE country EOP
# ---
# Predict: 	26 POI 28 RE neighborhood_of EOP POI RE contains EOP
# Ground-Truth: 	37 POI 34 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 7 RE contains EOP
# ---
# Predict: 	2 POI 32 RE contains EOP
# Ground-Truth: 	38 POI 39 RE country EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	1 POI 9 RE company EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 10 RE contains EOP
# ---
# Predict: 	13 POI 12 RE place_lived EOP
# Ground-Truth: 	14 POI 18 RE place_lived EOP
# ---
# Predict: 	26 POI 24 RE contains EOP
# Ground-Truth: 	29 POI 27 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 5 RE contains EOP
# ---
# Predict: 	9 POI 8 RE company EOP
# Ground-Truth: 	5 POI 8 RE company EOP
# ---
# Predict: 	6 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 6 RE contains EOP
# ---
# Predict: 	16 POI 15 RE contains EOP
# Ground-Truth: 	18 POI 16 RE contains EOP
# ---
# Predict: 	9 POI 12 RE contains EOP
# Ground-Truth: 	9 POI 13 RE country EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	18 POI 14 RE contains EOP
# ---
# Predict: 	12 POI 12 RE nationality EOP
# Ground-Truth: 	4 POI 15 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	10 POI 19 RE company EOP
# ---
# Predict: 	16 POI 18 RE place_lived EOP
# Ground-Truth: 	17 POI 20 RE place_lived EOP
# ---
# Predict: 	16 POI 16 RE nationality EOP
# Ground-Truth: 	19 POI 14 RE nationality EOP
# ---
# Predict: 	7 POI 6 RE nationality EOP
# Ground-Truth: 	19 POI 7 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	32 POI 35 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	19 POI 1 RE contains EOP
# ---
# Predict: 	9 POI 32 RE contains EOP
# Ground-Truth: 	31 POI 33 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	9 POI 30 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 11 RE contains EOP
# ---
# Predict: 	13 POI 23 RE contains POI RE contains EOP
# Ground-Truth: 	12 POI 25 RE contains EOP
# ---
# Predict: 	10 POI 12 RE place_lived EOP
# Ground-Truth: 	9 POI 12 RE place_lived EOP
# ---
# Predict: 	12 POI 10 RE contains EOP
# Ground-Truth: 	12 POI 10 RE contains EOP
# ---
# Predict: 	1 POI 1 RE company EOP
# Ground-Truth: 	1 POI 8 RE company EOP
# ---
# Predict: 	1 POI 23 RE contains POI RE EOP
# Ground-Truth: 	27 POI 18 RE country EOP
# ---
# Predict: 	33 POI 44 RE contains EOP
# Ground-Truth: 	39 POI 40 RE contains EOP
# ---
# Predict: 	24 POI 32 RE nationality EOP
# Ground-Truth: 	36 POI 33 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 4 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	12 POI 1 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	6 POI 10 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 8 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 34 RE country EOP
# ---
# Predict: 	6 POI 6 RE nationality EOP
# Ground-Truth: 	5 POI 8 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 23 RE contains EOP
# ---
# Predict: 	11 POI 44 RE contains EOP
# Ground-Truth: 	51 POI 49 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 10 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	9 POI 1 RE contains EOP
# ---
# Predict: 	33 POI 37 RE contains EOP
# Ground-Truth: 	49 POI 47 RE contains EOP
# ---
# Predict: 	11 POI 44 RE contains EOP
# Ground-Truth: 	40 POI 14 RE country EOP
# ---
# Predict: 	19 POI 23 RE contains EOP
# Ground-Truth: 	18 POI 26 RE country EOP
# ---
# Predict: 	20 POI 20 RE company EOP
# Ground-Truth: 	15 POI 26 RE company EOP
# ---
# Predict: 	10 POI 12 RE place_lived EOP
# Ground-Truth: 	7 POI 13 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE nationality EOP
# Ground-Truth: 	7 POI 13 RE nationality EOP
# ---
# Predict: 	6 POI 6 RE place_lived EOP
# Ground-Truth: 	5 POI 8 RE place_lived EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 10 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	9 POI 5 RE administrative_divisions EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 27 RE contains EOP
# ---
# Predict: 	13 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	17 POI 12 RE country EOP
# ---
# Predict: 	26 POI 24 RE contains EOP
# Ground-Truth: 	29 POI 31 RE contains EOP
# ---
# Predict: 	18 POI 20 RE contains EOP
# Ground-Truth: 	17 POI 20 RE country EOP
# ---
# Predict: 	19 POI 18 RE contains EOP
# Ground-Truth: 	38 POI 24 RE country EOP
# ---
# Predict: 	26 POI 27 RE contains EOP
# Ground-Truth: 	30 POI 28 RE contains EOP
# ---
# Predict: 	10 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 13 RE country EOP
# ---
# Predict: 	1 POI 35 RE contains POI RE capital EOP
# Ground-Truth: 	38 POI 19 RE country EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	37 POI 34 RE contains EOP
# ---
# Predict: 	18 POI 20 RE contains EOP
# Ground-Truth: 	23 POI 20 RE contains EOP
# ---
# Predict: 	33 POI 32 RE contains EOP
# Ground-Truth: 	29 POI 34 RE contains EOP
# ---
# Predict: 	32 POI 37 RE contains EOP
# Ground-Truth: 	41 POI 40 RE contains EOP
# ---
# Predict: 	23 POI 27 RE contains EOP
# Ground-Truth: 	29 POI 26 RE contains EOP
# ---
# Predict: 	20 POI 20 RE neighborhood_of EOP 23 POI 20 RE contains EOP
# Ground-Truth: 	23 POI 20 RE contains EOP
# ---
# Predict: 	9 POI 12 RE nationality EOP
# Ground-Truth: 	11 POI 10 RE contains EOP
# ---
# Predict: 	12 POI 18 RE contains EOP
# Ground-Truth: 	13 POI 19 RE place_lived EOP
# ---
# Predict: 	18 POI 18 RE contains POI RE EOP
# Ground-Truth: 	17 POI 20 RE administrative_divisions EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	1 POI 33 RE place_of_death EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 10 RE contains EOP
# ---
# Predict: 	9 POI 9 RE nationality EOP
# Ground-Truth: 	6 POI 9 RE nationality EOP
# ---
# Predict: 	24 POI 24 RE company EOP
# Ground-Truth: 	22 POI 30 RE company EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	13 POI 2 RE contains EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE capital EOP
# Ground-Truth: 	7 POI 13 RE contains EOP
# ---
# Predict: 	26 POI 32 RE neighborhood_of EOP POI RE contains EOP
# Ground-Truth: 	33 POI 30 RE contains EOP
# ---
# Predict: 	8 POI 9 RE country EOP RE EOP POI RE
# Ground-Truth: 	10 POI 11 RE country EOP
# ---
# Predict: 	18 POI 20 RE nationality EOP
# Ground-Truth: 	11 POI 20 RE nationality EOP
# ---
# Predict: 	6 POI 6 RE country EOP RE
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 6 RE country EOP
# ---
# Predict: 	1 POI 31 RE company EOP
# Ground-Truth: 	1 POI 7 RE company EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	12 POI 4 RE contains EOP
# ---
# Predict: 	9 POI 8 RE company EOP
# Ground-Truth: 	5 POI 11 RE company EOP
# ---
# Predict: 	24 POI 24 RE nationality EOP
# Ground-Truth: 	16 POI 12 RE contains EOP
# ---
# Predict: 	20 POI 20 RE nationality EOP
# Ground-Truth: 	21 POI 33 RE administrative_divisions EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	18 POI 16 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	35 POI 33 RE country EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	10 POI 16 RE place_lived EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	1 POI 24 RE place_of_death EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 6 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains POI RE EOP
# Ground-Truth: 	18 POI 41 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	9 POI 8 RE contains EOP
# ---
# Predict: 	9 POI 8 RE company EOP
# Ground-Truth: 	4 POI 11 RE company EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	2 POI 20 RE place_lived EOP
# Ground-Truth: 	19 POI 22 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 26 RE country EOP
# ---
# Predict: 	13 POI 18 RE country EOP RE capital EOP RE
# Ground-Truth: 	16 POI 17 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 19 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 19 RE contains EOP
# ---
# Predict: 	10 POI 11 RE contains POI RE EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	35 POI 37 RE company EOP
# Ground-Truth: 	47 POI 42 RE founders EOP
# ---
# Predict: 	1 POI 12 RE contains EOP
# Ground-Truth: 	46 POI 38 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	6 POI 12 RE country EOP
# ---
# Predict: 	20 POI 30 RE nationality EOP
# Ground-Truth: 	24 POI 44 RE country EOP
# ---
# Predict: 	18 POI 18 RE neighborhood_of EOP 18 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 10 RE contains EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 4 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 6 RE place_lived EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	3 POI 30 RE country EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 6 RE contains EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE capital EOP
# Ground-Truth: 	12 POI 7 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 23 RE contains EOP
# ---
# Predict: 	2 POI 20 RE contains EOP
# Ground-Truth: 	19 POI 3 RE neighborhood_of EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	36 POI 42 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 17 RE contains EOP
# ---
# Predict: 	14 POI 14 RE company EOP
# Ground-Truth: 	13 POI 9 RE company EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	23 POI 23 RE place_lived EOP
# Ground-Truth: 	23 POI 26 RE place_lived EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 6 RE place_lived EOP
# ---
# Predict: 	20 POI 23 RE place_lived EOP
# Ground-Truth: 	28 POI 31 RE place_lived EOP
# ---
# Predict: 	1 POI 31 RE contains POI RE capital POI EOP
# Ground-Truth: 	28 POI 6 RE country EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	2 POI 25 RE contains EOP
# ---
# Predict: 	7 POI 8 RE place_lived EOP
# Ground-Truth: 	13 POI 6 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 22 RE contains EOP
# ---
# Predict: 	32 POI 37 RE place_lived EOP
# Ground-Truth: 	38 POI 41 RE place_lived EOP
# ---
# Predict: 	26 POI 28 RE contains EOP
# Ground-Truth: 	30 POI 34 RE contains EOP
# ---
# Predict: 	20 POI 20 RE place_lived EOP
# Ground-Truth: 	13 POI 16 RE place_lived EOP
# ---
# Predict: 	13 POI 18 RE contains EOP
# Ground-Truth: 	16 POI 27 RE country EOP
# ---
# Predict: 	20 POI 20 RE contains EOP
# Ground-Truth: 	20 POI 23 RE country EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	3 POI 10 RE country EOP
# ---
# Predict: 	10 POI 10 RE contains EOP
# Ground-Truth: 	12 POI 9 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains POI RE contains EOP
# Ground-Truth: 	11 POI 19 RE country EOP
# ---
# Predict: 	9 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	9 POI 7 RE country EOP
# ---
# Predict: 	19 POI 20 RE contains EOP
# Ground-Truth: 	18 POI 24 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	26 POI 22 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	29 POI 24 RE country EOP
# ---
# Predict: 	26 POI 28 RE country EOP
# Ground-Truth: 	30 POI 28 RE contains EOP
# ---
# Predict: 	28 POI 28 RE nationality EOP
# Ground-Truth: 	32 POI 34 RE nationality EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	17 POI 21 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	23 POI 20 RE contains EOP
# ---
# Predict: 	1 POI 31 RE contains POI RE contains EOP
# Ground-Truth: 	1 POI 6 RE nationality EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	34 POI 14 RE contains EOP
# ---
# Predict: 	26 POI 28 RE nationality EOP
# Ground-Truth: 	33 POI 29 RE nationality EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	1 POI 4 RE contains EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	17 POI 15 RE contains EOP
# ---
# Predict: 	20 POI 20 RE contains POI EOP
# Ground-Truth: 	23 POI 22 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	13 POI 14 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	18 POI 36 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	39 POI 33 RE contains EOP
# ---
# Predict: 	13 POI 15 RE nationality EOP
# Ground-Truth: 	11 POI 14 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 23 RE contains EOP
# ---
# Predict: 	19 POI 18 RE contains EOP
# Ground-Truth: 	17 POI 27 RE country EOP
# ---
# Predict: 	13 POI 14 RE place_lived EOP
# Ground-Truth: 	12 POI 16 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	26 POI 28 RE contains EOP
# ---
# Predict: 	30 POI 37 RE nationality EOP
# Ground-Truth: 	45 POI 42 RE nationality EOP
# ---
# Predict: 	8 POI 6 RE contains EOP
# Ground-Truth: 	5 POI 8 RE contains EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	9 POI 3 RE country EOP
# ---
# Predict: 	24 POI 24 RE nationality EOP
# Ground-Truth: 	25 POI 28 RE nationality EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	13 POI 14 RE country EOP
# ---
# Predict: 	27 POI 28 RE contains EOP
# Ground-Truth: 	31 POI 28 RE contains EOP
# ---
# Predict: 	15 POI 15 RE contains EOP
# Ground-Truth: 	16 POI 14 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	30 POI 29 RE contains EOP
# ---
# Predict: 	14 POI 15 RE company EOP
# Ground-Truth: 	10 POI 22 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	15 POI 17 RE contains EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 17 RE contains EOP
# ---
# Predict: 	8 POI 8 RE place_lived EOP
# Ground-Truth: 	6 POI 8 RE place_lived EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 9 RE contains EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	4 POI 2 RE country EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	12 POI 16 RE contains EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	19 POI 17 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	1 POI 24 RE company EOP
# Ground-Truth: 	18 POI 3 RE company EOP
# ---
# Predict: 	6 POI 32 RE contains POI RE capital EOP
# Ground-Truth: 	31 POI 10 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	5 POI 6 RE country EOP
# ---
# Predict: 	1 POI 4 RE nationality EOP
# Ground-Truth: 	3 POI 6 RE nationality EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	24 POI 30 RE place_lived EOP
# Ground-Truth: 	32 POI 39 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	10 POI 18 RE company EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 24 RE country EOP
# ---
# Predict: 	17 POI 18 RE place_lived EOP
# Ground-Truth: 	13 POI 17 RE place_lived EOP
# ---
# Predict: 	4 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	9 POI 10 RE place_lived EOP
# Ground-Truth: 	8 POI 11 RE place_lived EOP
# ---
# Predict: 	12 POI 9 RE contains EOP
# Ground-Truth: 	13 POI 9 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	32 POI 11 RE country EOP
# ---
# Predict: 	6 POI 2 RE contains EOP
# Ground-Truth: 	4 POI 3 RE contains EOP
# ---
# Predict: 	42 POI 44 RE contains EOP
# Ground-Truth: 	79 POI 47 RE country EOP
# ---
# Predict: 	1 POI 1 RE nationality EOP
# Ground-Truth: 	1 POI 4 RE nationality EOP
# ---
# Predict: 	1 POI 15 RE company EOP
# Ground-Truth: 	1 POI 11 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	15 POI 16 RE country EOP
# ---
# Predict: 	10 POI 12 RE contains POI RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	9 POI 32 RE contains EOP
# Ground-Truth: 	31 POI 8 RE capital EOP
# ---
# Predict: 	35 POI 44 RE contains EOP
# Ground-Truth: 	54 POI 45 RE contains EOP
# ---
# Predict: 	32 POI 35 RE contains EOP
# Ground-Truth: 	42 POI 40 RE contains EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	10 POI 16 RE company EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	5 POI 6 RE country EOP
# ---
# Predict: 	8 POI 8 RE place_lived EOP
# Ground-Truth: 	5 POI 9 RE place_lived EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	5 POI 4 RE contains EOP
# ---
# Predict: 	26 POI 28 RE nationality EOP
# Ground-Truth: 	23 POI 29 RE company EOP
# ---
# Predict: 	8 POI 8 RE neighborhood_of EOP 8 POI 6 RE contains EOP
# Ground-Truth: 	10 POI 7 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	23 POI 22 RE contains EOP
# ---
# Predict: 	1 POI 23 RE contains POI RE capital POI RE EOP
# Ground-Truth: 	23 POI 8 RE country EOP
# ---
# Predict: 	4 POI 4 RE country EOP RE EOP RE
# Ground-Truth: 	5 POI 4 RE contains EOP
# ---
# Predict: 	16 POI 15 RE contains EOP
# Ground-Truth: 	17 POI 14 RE contains EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	20 POI 2 RE country EOP
# ---
# Predict: 	8 POI 8 RE neighborhood_of EOP POI 8 RE contains EOP
# Ground-Truth: 	8 POI 7 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains POI RE capital POI RE EOP
# Ground-Truth: 	16 POI 11 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 36 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 20 RE contains EOP
# ---
# Predict: 	9 POI 8 RE nationality EOP
# Ground-Truth: 	11 POI 6 RE nationality EOP
# ---
# Predict: 	26 POI 32 RE contains EOP
# Ground-Truth: 	33 POI 19 RE contains EOP
# ---
# Predict: 	4 POI 2 RE contains EOP
# Ground-Truth: 	6 POI 12 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	23 POI 22 RE contains EOP
# ---
# Predict: 	27 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 30 RE contains EOP
# ---
# Predict: 	29 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 31 RE contains EOP
# ---
# Predict: 	6 POI 6 RE nationality EOP
# Ground-Truth: 	4 POI 7 RE nationality EOP
# ---
# Predict: 	1 POI 15 RE nationality EOP
# Ground-Truth: 	14 POI 17 RE nationality EOP
# ---
# Predict: 	9 POI 9 RE country EOP RE capital EOP
# Ground-Truth: 	8 POI 21 RE country EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	1 POI 10 RE company EOP
# ---
# Predict: 	9 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 6 RE contains EOP
# ---
# Predict: 	1 POI 35 RE contains POI RE contains EOP
# Ground-Truth: 	44 POI 19 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	11 POI 15 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE contains EOP
# Ground-Truth: 	36 POI 9 RE country EOP
# ---
# Predict: 	1 POI 12 RE company EOP
# Ground-Truth: 	1 POI 3 RE company EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	23 POI 29 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	9 POI 6 RE contains EOP
# ---
# Predict: 	2 POI 4 RE contains EOP
# Ground-Truth: 	2 POI 6 RE company EOP
# ---
# Predict: 	27 POI 26 RE contains EOP
# Ground-Truth: 	30 POI 26 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 7 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains EOP
# Ground-Truth: 	16 POI 13 RE contains EOP
# ---
# Predict: 	15 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 15 RE contains EOP
# ---
# Predict: 	2 POI 26 RE contains EOP
# Ground-Truth: 	3 POI 28 RE contains EOP
# ---
# Predict: 	1 POI 29 RE company EOP
# Ground-Truth: 	36 POI 41 RE company EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	11 POI 10 RE contains EOP
# ---
# Predict: 	9 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 7 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	16 POI 11 RE contains EOP
# ---
# Predict: 	32 POI 35 RE contains EOP
# Ground-Truth: 	41 POI 35 RE contains EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	15 POI 16 RE country EOP
# ---
# Predict: 	18 POI 20 RE nationality EOP
# Ground-Truth: 	27 POI 20 RE country EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	11 POI 18 RE company EOP
# ---
# Predict: 	15 POI 14 RE contains EOP
# Ground-Truth: 	18 POI 17 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	21 POI 11 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	29 POI 1 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 19 RE contains EOP
# ---
# Predict: 	24 POI 23 RE contains EOP
# Ground-Truth: 	27 POI 21 RE contains EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	7 POI 5 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 4 RE country EOP
# ---
# Predict: 	1 POI 12 RE company EOP
# Ground-Truth: 	1 POI 4 RE company EOP
# ---
# Predict: 	32 POI 37 RE contains EOP
# Ground-Truth: 	44 POI 42 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	27 POI 24 RE contains EOP
# ---
# Predict: 	18 POI 18 RE country POI RE capital POI EOP RE
# Ground-Truth: 	19 POI 20 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	7 POI 5 RE contains EOP
# ---
# Predict: 	27 POI 27 RE contains EOP
# Ground-Truth: 	27 POI 24 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 12 RE contains EOP
# ---
# Predict: 	13 POI 15 RE company EOP
# Ground-Truth: 	22 POI 19 RE contains EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	28 POI 29 RE capital EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	5 POI 4 RE contains EOP
# ---
# Predict: 	35 POI 44 RE contains EOP
# Ground-Truth: 	50 POI 47 RE contains EOP
# ---
# Predict: 	42 POI 44 RE contains EOP
# Ground-Truth: 	95 POI 64 RE country EOP
# ---
# Predict: 	2 POI 1 RE contains EOP
# Ground-Truth: 	13 POI 11 RE contains EOP
# ---
# Predict: 	12 POI 12 RE company EOP
# Ground-Truth: 	8 POI 14 RE company EOP
# ---
# Predict: 	15 POI 18 RE contains EOP
# Ground-Truth: 	17 POI 15 RE contains EOP
# ---
# Predict: 	23 POI 30 RE contains EOP
# Ground-Truth: 	40 POI 37 RE contains EOP
# ---
# Predict: 	7 POI 8 RE place_lived EOP
# Ground-Truth: 	4 POI 8 RE place_lived EOP
# ---
# Predict: 	10 POI 10 RE contains EOP
# Ground-Truth: 	5 POI 11 RE company EOP
# ---
# Predict: 	13 POI 15 RE contains EOP
# Ground-Truth: 	13 POI 14 RE country EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	6 POI 5 RE contains EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 15 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE EOP
# Ground-Truth: 	34 POI 33 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	15 POI 11 RE contains EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 17 RE contains EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	41 POI 42 RE country EOP
# ---
# Predict: 	1 POI 20 RE contains POI RE capital EOP
# Ground-Truth: 	21 POI 20 RE contains EOP
# ---
# Predict: 	13 POI 18 RE contains POI EOP
# Ground-Truth: 	1 POI 19 RE country EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	9 POI 7 RE country EOP
# ---
# Predict: 	6 POI 6 RE country EOP RE capital EOP POI RE POI RE POI
# Ground-Truth: 	8 POI 7 RE contains EOP
# ---
# Predict: 	20 POI 20 RE nationality EOP
# Ground-Truth: 	14 POI 22 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE nationality EOP
# Ground-Truth: 	25 POI 24 RE contains EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	19 POI 18 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains EOP
# Ground-Truth: 	17 POI 11 RE contains EOP
# ---
# Predict: 	23 POI 23 RE place_lived EOP
# Ground-Truth: 	15 POI 18 RE place_lived EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	13 POI 11 RE contains EOP
# ---
# Predict: 	1 POI 24 RE company EOP
# Ground-Truth: 	1 POI 14 RE company EOP
# ---
# Predict: 	1 POI 8 RE company EOP
# Ground-Truth: 	10 POI 7 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	16 POI 14 RE contains EOP
# ---
# Predict: 	16 POI 18 RE contains EOP
# Ground-Truth: 	20 POI 17 RE contains EOP
# ---
# Predict: 	1 POI 37 RE contains EOP
# Ground-Truth: 	17 POI 11 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	34 POI 32 RE contains EOP
# ---
# Predict: 	13 POI 14 RE contains POI EOP
# Ground-Truth: 	58 POI 16 RE country EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	6 POI 4 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	16 POI 11 RE contains EOP
# ---
# Predict: 	12 POI 12 RE place_lived EOP
# Ground-Truth: 	9 POI 12 RE place_lived EOP
# ---
# Predict: 	6 POI 4 RE place_lived EOP
# Ground-Truth: 	21 POI 25 RE place_lived EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	7 POI 6 RE contains EOP
# ---
# Predict: 	10 POI 10 RE contains EOP
# Ground-Truth: 	14 POI 13 RE contains EOP
# ---
# Predict: 	1 POI 1 RE nationality EOP
# Ground-Truth: 	7 POI 1 RE nationality EOP
# ---
# Predict: 	6 POI 32 RE contains EOP
# Ground-Truth: 	29 POI 26 RE contains EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	17 POI 6 RE country EOP
# ---
# Predict: 	32 POI 32 RE contains EOP
# Ground-Truth: 	38 POI 13 RE contains EOP
# ---
# Predict: 	12 POI 12 RE contains EOP
# Ground-Truth: 	1 POI 14 RE place_lived EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	18 POI 15 RE contains EOP
# ---
# Predict: 	1 POI 1 RE nationality POI RE EOP
# Ground-Truth: 	3 POI 1 RE country EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	9 POI 5 RE contains EOP
# ---
# Predict: 	26 POI 24 RE contains EOP
# Ground-Truth: 	20 POI 28 RE company EOP
# ---
# Predict: 	20 POI 20 RE nationality EOP
# Ground-Truth: 	15 POI 23 RE nationality EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	12 POI 1 RE children EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	9 POI 8 RE contains EOP
# ---
# Predict: 	28 POI 32 RE contains POI RE EOP
# Ground-Truth: 	35 POI 31 RE contains EOP
# ---
# Predict: 	20 POI 22 RE company EOP
# Ground-Truth: 	15 POI 23 RE company EOP
# ---
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	8 POI 5 RE contains EOP
# ---
# Predict: 	2 POI 5 RE place_lived EOP
# Ground-Truth: 	2 POI 5 RE place_lived EOP
# ---
# Predict: 	2 POI 8 RE place_lived EOP
# Ground-Truth: 	1 POI 5 RE place_lived EOP
# ---

# %%
B = [i for j, i in enumerate(actResult) if len(i.split()) == 8]
b = [preResult[j] for j, i in enumerate(actResult) if len(i.split()) == 8]
for i in range(len(B)):
    print('Predict: \t%s' % b[i])
    print('Ground-Truth: \t%s' % B[i])
    print('---')
# Out:
# Predict: 	28 POI 30 RE company EOP
# Ground-Truth: 	36 POI 37 RE children EOP 37 EOP
# ---

# %%
C = [i for j, i in enumerate(actResult) if len(i.split()) == 10]
c = [preResult[j] for j, i in enumerate(actResult) if len(i.split()) == 10]
for i in range(len(C)):
    print('Predict: \t%s' % c[i])
    print('Ground-Truth: \t%s' % C[i])
    print('---')
# Out:
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	21 POI 16 RE company POI 16 RE company EOP
# ---
# Predict: 	12 POI 12 RE nationality EOP
# Ground-Truth: 	12 POI 11 RE nationality POI 11 RE nationality EOP
# ---
# Predict: 	6 POI 35 RE contains POI RE contains EOP
# Ground-Truth: 	21 POI 7 RE contains POI 7 RE contains EOP
# ---
# Predict: 	4 POI 31 RE contains POI RE contains EOP
# Ground-Truth: 	20 POI 4 RE country POI 4 RE country EOP
# ---
# Predict: 	35 POI 37 RE contains EOP
# Ground-Truth: 	32 POI 13 RE country POI 13 RE country EOP
# ---
# Predict: 	13 POI 18 RE contains EOP
# Ground-Truth: 	21 POI 15 RE country POI 15 RE country EOP
# ---
# Predict: 	23 POI 23 RE contains EOP
# Ground-Truth: 	24 POI 13 RE country POI 13 RE country EOP
# ---

# %%
D = [i for j, i in enumerate(actResult) if len(i.split()) == 12]
d = [preResult[j] for j, i in enumerate(actResult) if len(i.split()) == 12]
for i in range(len(D)):
    print('Predict: \t%s' % d[i])
    print('Ground-Truth: \t%s' % D[i])
    print('---')
# Out:
# Predict: 	8 POI 8 RE contains EOP
# Ground-Truth: 	10 POI 9 RE contains EOP 10 POI 9 RE contains EOP
# ---
# Predict: 	6 POI 6 RE contains EOP
# Ground-Truth: 	6 POI 6 RE country EOP 6 POI 6 RE country EOP
# ---
# Predict: 	27 POI 27 RE place_lived EOP
# Ground-Truth: 	21 POI 29 RE place_lived EOP 21 POI 29 RE place_lived EOP
# ---
# Predict: 	18 POI 22 RE capital POI RE capital EOP
# Ground-Truth: 	14 POI 12 RE country EOP 14 POI 12 RE country EOP
# ---
# Predict: 	6 POI 4 RE contains EOP
# Ground-Truth: 	5 POI 5 RE country EOP 5 POI 5 RE country EOP
# ---
# Predict: 	28 POI 32 RE contains EOP
# Ground-Truth: 	13 POI 13 RE contains EOP 13 POI 13 RE contains EOP
# ---
# Predict: 	2 POI 2 RE contains EOP
# Ground-Truth: 	3 POI 3 RE country EOP 3 POI 3 RE country EOP
# ---
# Predict: 	1 POI 1 RE contains EOP
# Ground-Truth: 	1 POI 22 RE country EOP 1 POI 22 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	6 POI 20 RE country EOP 6 POI 20 RE country EOP
# ---

# %%
E = [i for j, i in enumerate(actResult) if len(i.split()) == 18]
e = [preResult[j] for j, i in enumerate(actResult) if len(i.split()) == 18]
for i in range(len(E)):
    print('Predict: \t%s' % e[i])
    print('Ground-Truth: \t%s' % E[i])
    print('---')
# Out:
# Predict: 	42 POI 44 RE contains POI RE contains EOP
# Ground-Truth: 	27 POI 120 RE country EOP 27 POI 120 RE country EOP 27 POI 120 RE country EOP
# ---
# Predict: 	13 POI 12 RE contains EOP
# Ground-Truth: 	21 POI 37 RE country EOP 23 POI 37 RE country EOP 21 POI 37 RE country EOP
# ---

# %%
F = [i for j, i in enumerate(actResult) if len(i.split()) == 20]
f = [preResult[j] for j, i in enumerate(actResult) if len(i.split()) == 20]
for i in range(len(F)):
    print('Predict: \t%s' % f[i])
    print('Ground-Truth: \t%s' % F[i])
    print('---')
# Out:
# Predict: 	9 POI 32 RE contains EOP
# Ground-Truth: 	19 POI 13 RE country POI 13 RE country EOP 19 POI 13 RE country POI 13 RE country EOP
# ---
# Predict: 	18 POI 18 RE contains EOP
# Ground-Truth: 	29 POI 34 RE contains POI 34 RE contains EOP 29 POI 34 RE contains POI 34 RE contains EOP
# ---
# Predict: 	1 POI 31 RE company EOP
# Ground-Truth: 	1 POI 37 RE founders POI 37 RE founders EOP 1 POI 37 RE founders POI 37 RE founders EOP
# ---
# Predict: 	1 POI 18 RE contains POI RE capital EOP
# Ground-Truth: 	3 POI 13 RE contains POI 13 RE contains EOP 3 POI 13 RE contains POI 13 RE contains EOP
# ---
# Predict: 	23 POI 24 RE contains EOP
# Ground-Truth: 	7 POI 21 RE country POI 21 RE country EOP 7 POI 21 RE country POI 21 RE country EOP
# ---
# Predict: 	6 POI 18 RE contains EOP
# Ground-Truth: 	4 POI 6 RE country POI 6 RE country EOP 4 POI 6 RE country POI 6 RE country EOP
# ---
# Predict: 	12 POI 12 RE contains POI RE contains EOP
# Ground-Truth: 	10 POI 12 RE country POI 12 RE country EOP 10 POI 12 RE country POI 12 RE country EOP
# ---

# %%
[j for j, i in enumerate(actResult) if len(i.split()) == 20]
# Out:
# [8, 38, 227, 263, 287, 341, 373]
