# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#GPU" data-toc-modified-id="GPU-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>GPU</a></div><div class="lev1 toc-item"><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Preprocessing</a></div><div class="lev2 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load Data</a></div><div class="lev3 toc-item"><a href="#Load-Train-Data" data-toc-modified-id="Load-Train-Data-211"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Load Train Data</a></div><div class="lev3 toc-item"><a href="#Load-Test-Data" data-toc-modified-id="Load-Test-Data-212"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Load Test Data</a></div><div class="lev3 toc-item"><a href="#Relation-Types" data-toc-modified-id="Relation-Types-213"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Relation Types</a></div><div class="lev2 toc-item"><a href="#Participle" data-toc-modified-id="Participle-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Participle</a></div><div class="lev2 toc-item"><a href="#Make-Adjacency-List" data-toc-modified-id="Make-Adjacency-List-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Make Adjacency List</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Train-Data" data-toc-modified-id="Make-Adjacency-List-of-Train-Data-231"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Make Adjacency List of Train Data</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Test-Data" data-toc-modified-id="Make-Adjacency-List-of-Test-Data-232"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Make Adjacency List of Test Data</a></div><div class="lev1 toc-item"><a href="#Word-to-Vector" data-toc-modified-id="Word-to-Vector-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Word to Vector</a></div><div class="lev2 toc-item"><a href="#Tokenize-Text" data-toc-modified-id="Tokenize-Text-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Tokenize Text</a></div><div class="lev2 toc-item"><a href="#Create-Word-Embeddings-with-GloVe" data-toc-modified-id="Create-Word-Embeddings-with-GloVe-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Create Word Embeddings with GloVe</a></div><div class="lev3 toc-item"><a href="#Read-GloVe" data-toc-modified-id="Read-GloVe-321"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Read GloVe</a></div><div class="lev3 toc-item"><a href="#Use-Glove-to-Initialize-Embedding-Matrix" data-toc-modified-id="Use-Glove-to-Initialize-Embedding-Matrix-322"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Use Glove to Initialize Embedding Matrix</a></div><div class="lev1 toc-item"><a href="#Build-Dateset" data-toc-modified-id="Build-Dateset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Build Dateset</a></div><div class="lev1 toc-item"><a href="#Save-Dataset" data-toc-modified-id="Save-Dataset-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Save Dataset</a></div><div class="lev1 toc-item"><a href="#Checkpoint" data-toc-modified-id="Checkpoint-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Checkpoint</a></div><div class="lev1 toc-item"><a href="#Build-Model" data-toc-modified-id="Build-Model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Build Model</a></div><div class="lev2 toc-item"><a href="#Set-Hyperparameters" data-toc-modified-id="Set-Hyperparameters-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Set Hyperparameters</a></div><div class="lev2 toc-item"><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Import Libraries</a></div><div class="lev2 toc-item"><a href="#Build-Graph" data-toc-modified-id="Build-Graph-73"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Build Graph</a></div><div class="lev2 toc-item"><a href="#Model-Visualization" data-toc-modified-id="Model-Visualization-74"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Model Visualization</a></div><div class="lev2 toc-item"><a href="#Train" data-toc-modified-id="Train-75"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Train</a></div><div class="lev1 toc-item"><a href="#Evaluate" data-toc-modified-id="Evaluate-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Evaluate</a></div><div class="lev1 toc-item"><a href="#Play" data-toc-modified-id="Play-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Play</a></div>

# %% [markdown]
# # GPU

# %%
import tensorflow as tf 
print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Default GPU Device:

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Load Train Data

# %%
import json

# %%
sentText = []
relationMentions = []
relationLabels = []
entityMentions = []
entityLabels = []
em1Text = []
em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/train.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    # Exclude "None" label
    if not all(i['label'] == 'None' for i in item['relationMentions']):
        sentText.append(item['sentText'])
        relationMentions.append(item['relationMentions'])
        entityMentions.append(item['entityMentions'])
    
relationLabels = [[i['label'].split('/')[-1] for i in rM] for rM in relationMentions]
entityLabels = [[i['text'] for i in eM] for eM in entityMentions]
em1Text = [[i['em1Text'] for i in rM] for rM in relationMentions]
em2Text = [[i['em2Text'] for i in rM] for rM in relationMentions]

# %%
# Clean words
replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
em1Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em1Text]
em2Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em2Text]

# %% [markdown]
# ### Load Test Data

# %%
t_sentText = []
t_relationMentions = []
t_relationLabels = []
t_entityMentions = []
t_entityLabels = []
t_em1Text = []
t_em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/test.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    t_sentText.append(item['sentText'])
    t_relationMentions.append(item['relationMentions'])
    t_entityMentions.append(item['entityMentions'])
    
t_relationLabels = [[i['label'].split('/')[-1] for i in rM] for rM in t_relationMentions]
t_entityLabels = [[i['text'] for i in eM] for eM in t_entityMentions]
t_em1Text = [[i['em1Text'] for i in rM] for rM in t_relationMentions]
t_em2Text = [[i['em2Text'] for i in rM] for rM in t_relationMentions]

# %%
# Clean words
t_replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
t_em1Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em1Text]
t_em2Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em2Text]
t_entityLabels = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_entityLabels]

# %% [markdown]
# ###  Relation Types

# %%
relationTypes = list(set([r for rl in relationLabels for r in rl]))
relationTypes
# Out:
# ['major_shareholder_of',
#  'ethnicity',
#  'religion',
#  'people',
#  'founders',
#  'advisors',
#  'country',
#  'place_of_birth',
#  'contains',
#  'major_shareholders',
#  'neighborhood_of',
#  'place_lived',
#  'geographic_distribution',
#  'profession',
#  'capital',
#  'place_founded',
#  'industry',
#  'place_of_death',
#  'nationality',
#  'company',
#  'teams',
#  'location',
#  'administrative_divisions',
#  'children']

# %%
t_relationTypes = list(set([r for rl in t_relationLabels for r in rl if r != 'None']))
t_relationTypes
# Out:
# ['place_lived',
#  'country',
#  'company',
#  'capital',
#  'neighborhood_of',
#  'contains',
#  'place_of_birth',
#  'administrative_divisions',
#  'place_of_death',
#  'founders',
#  'nationality',
#  'children']

# %% [markdown]
# ## Participle

# %%
from nltk import regexp_tokenize

# %%
def cut(s):
    """
    Participle
    """
    pattern = r'''
              (?x)                   # set flag to allow verbose regexps 
              (?:[A-Z]\.)+           # abbreviations, e.g. U.S.A. 
              |\d+(?:\.\d+)?%?       # numbers, incl. currency and percentages 
              |\w+(?:[-&']\w+)*       # words w/ optional internal hyphens/apostrophe  
           '''  
    return regexp_tokenize(s, pattern=pattern)

# %%
filename = "stopwords_666.txt"
stopWords = {w: None for w in open(filename).read().split()}

# %%
sentWords = [cut(s) for s in sentText]
entlabWords = [[cut(s) for s in eL] for eL in entityLabels]
em1Words = [[cut(s) for s in eL] for eL in em1Text]
em2Words = [[cut(s) for s in eL] for eL in em2Text]
t_sentWords = [cut(s) for s in t_sentText]
t_entlabWords = [[cut(s) for s in eL] for eL in t_entityLabels]
t_em1Words = [[cut(s) for s in eL] for eL in t_em1Text]
t_em2Words = [[cut(s) for s in eL] for eL in t_em2Text]
# Clean words
t_sentWords = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_sentWords]

# %%
# Delete stopwords
for n in range(len(sentWords)):
    sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in sentWords[n]] if i != None]
    entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in entlabWords[n]]
    entlabWords[n] = [[i for i in item if i != None] for item in entlabWords[n]]
    em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em1Words[n]]
    em1Words[n] = [[i for i in item if i != None] for item in em1Words[n]]
    em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em2Words[n]]
    em2Words[n] = [[i for i in item if i != None] for item in em2Words[n]] 

for n in range(len(t_sentWords)):
    t_sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in t_sentWords[n]] if i != None]
    t_entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_entlabWords[n]]
    t_entlabWords[n] = [[i for i in item if i != None] for item in t_entlabWords[n]]
    t_em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em1Words[n]]
    t_em1Words[n] = [[i for i in item if i != None] for item in t_em1Words[n]]
    t_em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em2Words[n]]
    t_em2Words[n] = [[i for i in item if i != None] for item in t_em2Words[n]]

# %%
#max([len(i) for i in t_sentWords])

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8

# %% [markdown]
# ## Make Adjacency List

# %% [markdown]
# ### Make Adjacency List of Train Data

# %%
from collections import Counter

# %%
i_entityLabels = []
for i in range(len(sentWords)):
    eL = []
    sDict = list(enumerate(sentWords[i]))
    j = 0
    for item in entlabWords[i]:
        el = []
        for e in item:
            while j < len(sDict):
                if e == sDict[j][1]:
                    el.append(sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    i_entityLabels.append(eL)

# %%
rmSet = []
for item in range(len(relationMentions)):
    rms = [(em1Words[item][i][0], em2Words[item][i][0], relationLabels[item][i]) for i in range(len(relationLabels[item]))]
    rms = [' '.join(list(i)) for i in rms]
    rmSet.append(rms)
rmSet = [set(i) for i in rmSet]

# %%
i_adjacencyList = []
new_sentWords = []
pad = ['EOP']
for n in range(len(sentWords)):
    aL = []
    for l in range(len(relationLabels[n])):
        e1 = []
        e2 = []
        for item in i_entityLabels[n]:
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em2Words[n][l]):
                e2.append(item[0])
        c1 = [(a, b) for a in e1 for b in e2 if ' '.join([sentWords[n][a], sentWords[n][b], relationLabels[n][l]]) in rmSet[n]]
        c2 = [(a, b) for a in e2 for b in e1 if ' '.join([sentWords[n][b], sentWords[n][a], relationLabels[n][l]]) in rmSet[n]]
        c = c1 + c2
        m = min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[-1]
        r = [i[0] for i in [(i, abs(j[0]-j[1])) for i, j in enumerate(c)] if i[-1] == m]
        for i in r:
            if ' '.join([sentWords[n][c[i][0]], sentWords[n][c[i][1]], relationLabels[n][l]]) in rmSet[n]:
                al = (c[i][0], c[i][1], relationLabels[n][l], pad[0])
                if al[2] in t_relationTypes and al[0] < MAX_SENT_LEN and al[1] < MAX_SENT_LEN: 
                    aL.append(al)
    aL = sorted([list(i) for i in set(aL)])
    if len(aL) == 1 or len(aL) == 2:
        i_adjacencyList.append(aL)
        new_sentWords.append(sentWords[n])
i_adjacencyList = [sum(i, []) for i in i_adjacencyList]

# %%
#([len(i) for i in t_sentWords])

# %% [markdown]
# ### Make Adjacency List of Test Data

# %%
ti_entityLabels = []
for i in range(len(t_sentWords)):
    eL = []
    t_sDict = list(enumerate(t_sentWords[i]))
    j = 0
    for item in t_entlabWords[i]:
        el = []
        for e in item:
            while j < len(t_sDict):
                if e == t_sDict[j][1]:
                    el.append(t_sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    ti_entityLabels.append(eL)

# %%
ti_trueLables = [[i for i, j in enumerate(rl) if j != 'None'] for rl in t_relationLabels]
t_trueMentions = [[j for i, j in enumerate(rl) if j['label'] != 'None'] for rl in t_relationMentions]
pad = ['EOP']
ti_adjacencyList = []
for n in range(len(t_sentWords)): 
    e1 = []
    e2 = []
    aL = []
    for l in ti_trueLables[n]:
        for item in ti_entityLabels[n]:
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em2Words[n][l]):
                e2.append(item[0])
    c = [(a, b) for a in e1 for b in e2]
    r = c[min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[0]]
    aL = aL + [r[0], r[1], t_relationLabels[n][l], pad[0]]
    ti_adjacencyList.append(aL)

# Modify 
ti_adjacencyList[26] = [18, 20, 'founders', 'EOP']
ti_adjacencyList[191] = [13, 19, 'country', 'EOP', 18, 19, 'country', 'EOP']

# %%
#max([max(sum(i, [])) for i in ti_entityLabels])

# %% [markdown]
# # Word to Vector

# %% [markdown]
# ## Tokenize Text

# %%
from keras.preprocessing.text import Tokenizer
from nltk import WordNetLemmatizer
# Out:
# Using TensorFlow backend.

# %%
wnl = WordNetLemmatizer()
sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in new_sentWords]
t_sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in t_sentWords]
tok_sentWords = sentWords.copy()
tok_sentWords.extend(t_sentWords)
tokTexts = [' '.join(i) for i in tok_sentWords]

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts(tokTexts)
word2index = tokenizer.word_index
index2word = {i: w for w, i in word2index.items()}
print('Found %s unique tokens.' % len(word2index))
# Out:
# Found 65131 unique tokens.

# %% [markdown]
# ## Create Word Embeddings with GloVe

# %%
VOCAB_SIZE = 65132
EMBEDDING_SIZE = 300
SEED = 42

# %% [markdown]
# ### Read GloVe

# %%
import numpy as np

# %%
#glove_n_symbols = !wc -l /Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt
#glove_n_symbols = int(glove_n_symbols[0].split()[0])
glove_n_symbols = 1917495

# %%
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_n_symbols, EMBEDDING_SIZE))
globale_scale = 0.1
with open('/Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt', 'r') as fp:
    index = 0
    for l in fp:
        l = l.strip().split()
        word = l[0]
        glove_index_dict[word] = index
        glove_embedding_weights[index, :] = [float(n) for n in l[1:]]
        index += 1
glove_embedding_weights *= globale_scale

# %% [markdown]
# ### Use Glove to Initialize Embedding Matrix

# %%
from nltk import PorterStemmer, LancasterStemmer

# %%
# Generate random embedding with same scale as glove
np.random.seed(SEED)
shape = (VOCAB_SIZE, EMBEDDING_SIZE)
scale = glove_embedding_weights.std() * np.sqrt(12) / 2 
embedding = np.random.uniform(low=-scale, high=scale, size=shape)

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()

# %%
# Copy from glove weights of words that appear in index2word
count = 0 
for i in range(1, VOCAB_SIZE):
    w = index2word[i]
    g = glove_index_dict.get(w)
    if g is None:
        w = porter.stem(w)
        g = glove_index_dict.get(w)
    if g is None:
        w = lancaster.stem(w)
        g = glove_index_dict.get(w)
    if g is not None:
        embedding[i, :] = glove_embedding_weights[g, :]
        count += 1
print('{num_tokens}-{per:.2f}% tokens in vocab found in glove and copied to embedding.'.format(num_tokens=count, per=count/float(VOCAB_SIZE)*100))
# Out:
# 60641-93.10% tokens in vocab found in glove and copied to embedding.

# %% [markdown]
# # Build Dateset

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
new_sentText = [' '.join(i) for i in sentWords]
sentSeq = tokenizer.texts_to_sequences(new_sentText)
sentData = pad_sequences(sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

t_new_sentText = [' '.join(i) for i in t_sentWords]
t_sentSeq = tokenizer.texts_to_sequences(t_new_sentText)
t_sentData = pad_sequences(t_sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

token2index = dict((j, i+MAX_SENT_LEN) for i, j in enumerate(pad+t_relationTypes))
token2index['PAD'] = 0
token2index['GO'] = 77
index2token = {i: w for w, i in token2index.items()}


newi_adjacencyList = [[token2index[i] if i in token2index else i+1 for i in aL] for aL in i_adjacencyList]
oi_adjacencyList = pad_sequences(newi_adjacencyList, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
[i.insert(0, 77) for i in newi_adjacencyList];
tFi_adjacencyList = pad_sequences(newi_adjacencyList, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

newti_adjacencyList = [[token2index[i] if i in token2index else i+1 for i in aL] for aL in ti_adjacencyList]
oti_adjacencyList = pad_sequences(newti_adjacencyList, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
[i.insert(0, 77) for i in newti_adjacencyList];
tFti_adjacencyList = pad_sequences(newti_adjacencyList, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

# %%
# Split the data into a training set, a validation set and a test set
x_train_all = sentData
tf_train_all = tFi_adjacencyList
y_train_all = oi_adjacencyList

x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, test_size=0.15, random_state=SEED)
tf_train, tf_val, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0.15, random_state=SEED)

x_train_all, _, y_train_all, _  = train_test_split(x_train_all, y_train_all, test_size=0., random_state=SEED)
tf_train_all, _, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0., random_state=SEED)
 
x_test = t_sentData
tf_test = tFti_adjacencyList
y_test = oti_adjacencyList

x_test, _, y_test, _ = train_test_split(x_test, y_test, test_size=0., random_state=SEED)
tf_test, _, _, _ = train_test_split(tf_test, tf_test, test_size=0., random_state=SEED)

t_sentWords, _, _, _ = train_test_split(t_sentWords, t_sentWords, test_size=0., random_state=SEED)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-777bf64be4fc> in <module>()
#       1 # Split the data into a training set, a validation set and a test set
# ----> 2 x_train_all = sentData
#       3 tf_train_all = tFi_adjacencyList
#       4 y_train_all = oi_adjacencyList
#       5
#
# NameError: name 'sentData' is not defined

# %% [markdown]
# # Save Dataset

# %%
import h5py
import pickle

# %%
fh = h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/allData_666.h5', 'w')
fh['x_train'] = x_train
fh['tf_train'] = tf_train
fh['y_train'] = y_train
fh['x_val'] = x_val
fh['tf_val'] = tf_val
fh['y_val'] = y_val
fh['x_train_all'] = x_train_all
fh['tf_train_all'] = tf_train_all
fh['y_train_all'] = y_train_all
fh['x_test'] = x_test
fh['tf_test'] = tf_test
fh['y_test'] = y_test
fh['embedding'] = embedding
fh.close()

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/index_666.pkl', 'wb') as fp:
    pickle.dump((word2index, index2word, token2index, index2token, t_sentWords), fp, -1)

# %% [markdown]
# # Checkpoint

# %%
import h5py
import pickle

# %%
with h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/allData_666.h5', 'r') as fh:
    x_train = fh['x_train'][:]
    tf_train = fh['tf_train'][:]
    y_train = fh['y_train'][:]
    x_val = fh['x_val'][:]
    tf_val = fh['tf_val'][:]
    y_val = fh['y_val'][:]
    x_train_all = fh['x_train_all'][:]
    tf_train_all = fh['tf_train_all'][:]
    y_train_all = fh['y_train_all'][:]
    x_test = fh['x_test'][:]
    tf_test = fh['tf_test'][:]
    y_test = fh['y_test'][:]
    embedding = fh['embedding'][:]

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/index_666.pkl', 'rb') as fp:
    word2index, index2word, token2index, index2token, t_sentWords = pickle.load(fp)

# %% [markdown]
# # Build Model

# %% [markdown]
# ##  Set Hyperparameters

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8
VOCAB_SIZE = len(word2index)+1
NUM_CLASSES = MAX_SENT_LEN+len(token2index)
EMBEDDING_SIZE = 300
TF_EMBEDDING_SIZE = 50

ENC_RNN_SIZE = 300
DEC_RNN_SIZE = 150
DROPOUT_RATE = 0.5
RNN_DROPOUT_RATE = 0.2
NUM_EPOCHS = 256
BATCH_SIZE = 79
STEPS_PER_EPOCH = 20
TEST_STEPS = len(x_test)//BATCH_SIZE

VALIDATION_STEPS = 3

# %%
print('NUM_EPOCHS: \t\t%d' % NUM_EPOCHS)
print('STEPS_PER_EPOCH: \t%d' % STEPS_PER_EPOCH)
print('TEST_STEPS: \t\t%d' % TEST_STEPS)
print('VALIDATION_STEPS: \t%d' % VALIDATION_STEPS)
print('TRAIN_BATCHES: \t\t%d' % (NUM_EPOCHS * STEPS_PER_EPOCH))
print('NUM_BATCHES \t\t%d' % (len(x_train)//BATCH_SIZE+1))
# Out:
# NUM_EPOCHS: 		256
# STEPS_PER_EPOCH: 	20
# TEST_STEPS: 		5
# VALIDATION_STEPS: 	3
# TRAIN_BATCHES: 		5120
# NUM_BATCHES 		612

# %% [markdown]
# ## Import Libraries

# %%
from keras.layers import Input, Embedding, Dropout, Bidirectional, LSTM, RepeatVector, concatenate, TimeDistributed, Dense
from keras.models import Model
import keras.backend as K
from keras.callbacks import*
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Build Graph

# %%
K.clear_session()
sequence = Input(shape=(MAX_SENT_LEN,), name='INPUT') 
emb_seq = Embedding(VOCAB_SIZE, EMBEDDING_SIZE, weights=[embedding], mask_zero=True, input_length=MAX_SENT_LEN, trainable=True, name='EMBEDDING')(sequence)
emb_seq = Dropout(DROPOUT_RATE)(emb_seq)
tf_seq = Input(shape=(MAX_ADJL_LEN,), name='TF_INPUT')
tf_emb = Embedding(NUM_CLASSES, TF_EMBEDDING_SIZE, mask_zero=True, input_length=MAX_ADJL_LEN, name='TF_EMBEDDING')(tf_seq)
tf_emb = Dropout(DROPOUT_RATE)(tf_emb)
blstm = Bidirectional(LSTM(ENC_RNN_SIZE, return_sequences=True, implementation=0, dropout=RNN_DROPOUT_RATE, recurrent_dropout=RNN_DROPOUT_RATE), merge_mode='concat', name='ENC_BLSTM_1')(emb_seq)
blstm = Dropout(DROPOUT_RATE)(blstm)
blstm = Bidirectional(LSTM(ENC_RNN_SIZE, return_sequences=False, implementation=0, dropout=RNN_DROPOUT_RATE, recurrent_dropout=RNN_DROPOUT_RATE), merge_mode='concat', name='ENC_BLSTM_2')(blstm)
blstm = Dropout(DROPOUT_RATE)(blstm)
context = RepeatVector(MAX_ADJL_LEN, name='CONTEXT')(blstm)
context = concatenate([context, tf_emb], axis=-1)
blstm = Bidirectional(LSTM(DEC_RNN_SIZE, return_sequences=True, implementation=2, dropout=RNN_DROPOUT_RATE, recurrent_dropout=RNN_DROPOUT_RATE, name='DEC_LSTM'), merge_mode='concat', name='DEC_BLSTM')(context)
lstm = Dropout(DROPOUT_RATE)(blstm)
output = TimeDistributed(Dense(NUM_CLASSES, activation='softmax'), name='OUTPUT')(lstm)
model = Model(inputs=[sequence, tf_seq], outputs=output)
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# %% [markdown]
# ## Model Visualization

# %%
model.summary()
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# INPUT (InputLayer)               (None, 64)            0
# ____________________________________________________________________________________________________
# EMBEDDING (Embedding)            (None, 64, 300)       19539600    INPUT[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 64, 300)       0           EMBEDDING[0][0]
# ____________________________________________________________________________________________________
# ENC_BLSTM_1 (Bidirectional)      (None, 64, 600)       1442400     dropout_1[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 64, 600)       0           ENC_BLSTM_1[0][0]
# ____________________________________________________________________________________________________
# ENC_BLSTM_2 (Bidirectional)      (None, 600)           2162400     dropout_3[0][0]
# ____________________________________________________________________________________________________
# TF_INPUT (InputLayer)            (None, 8)             0
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 600)           0           ENC_BLSTM_2[0][0]
# ____________________________________________________________________________________________________
# TF_EMBEDDING (Embedding)         (None, 8, 50)         3950        TF_INPUT[0][0]
# ____________________________________________________________________________________________________
# CONTEXT (RepeatVector)           (None, 8, 600)        0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 8, 50)         0           TF_EMBEDDING[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 8, 650)        0           CONTEXT[0][0]
#                                                                    dropout_2[0][0]
# ____________________________________________________________________________________________________
# DEC_BLSTM (Bidirectional)        (None, 8, 300)        961200      concatenate_1[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 8, 300)        0           DEC_BLSTM[0][0]
# ____________________________________________________________________________________________________
# OUTPUT (TimeDistributed)         (None, 8, 79)         23779       dropout_5[0][0]
# ====================================================================================================
# Total params: 24,133,329
# Trainable params: 24,133,329
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ## Train

# %%
def gen_label(s):
    """
    One-hot encoding
    """
    gen = to_categorical(s, num_classes=NUM_CLASSES)
    return gen

def data_generator_all(data, label, batch_size):
    """
    Yield batches of all data
    """
    count = 0
    while True:
        if count >= len(data[0]): 
            count = 0
        x_1 = np.zeros((batch_size, MAX_SENT_LEN))
        x_2 = np.zeros((batch_size, MAX_ADJL_LEN))
        y = np.zeros((batch_size, MAX_ADJL_LEN, NUM_CLASSES))
        for i in range(batch_size):
            n = i + count
            if n > len(data[0])-1:
                break
            x_1[i, :] = data[0][n]
            x_2[i, :] = data[1][n]
            y[i, :, :] = gen_label(label[n])
        count += batch_size
        yield ([x_1, x_2], y)
        
def data_generator(data, label, batch_size): 
    """
    Yield batches 
    """
    index = np.arange(len(data[0]))
    np.random.shuffle(index)    
    batches = [index[range(batch_size*i, min(len(data[0]), batch_size*(i+1)))] for i in range(len(data[0])//batch_size)]
    while True:
        for i in batches:
            x_1 = data[0][i]
            x_2 = data[1][i]
            y = np.array(list(map(gen_label, label[i])))
            yield ([x_1, x_2], y)

# %%
gen_train_all = data_generator([x_train_all, tf_train_all], y_train_all, BATCH_SIZE)
gen_test = data_generator_all([x_test, tf_test], y_test, BATCH_SIZE)
#gen_train = data_generator(x_train, y_train, BATCH_SIZE)
#gen_val = data_generator(x_val, y_val, BATCH_SIZE)

# %%
# Continue Trian
# filename = 'cp_logs/.hdf5'
# model.load_weights(filename)
# model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['acc'])

# %%
filepath = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/cp_logs/weights.{epoch:03d}-{val_loss:.6f}.hdf5'
log_string = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/tb_logs/666'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
tensorboard = TensorBoard(log_dir=log_string, 
                          histogram_freq=1, 
                          write_graph=False, 
                          write_grads=False, 
                          batch_size=BATCH_SIZE, 
                          write_images=True, 
                          embeddings_freq=1, 
                          embeddings_layer_names=None,
                          embeddings_metadata=None)

# %%
history = model.fit_generator(gen_train_all, 
                              steps_per_epoch=STEPS_PER_EPOCH, 
                              epochs=NUM_EPOCHS, 
                              verbose=1,
                              #callbacks=[checkpoint, tensorboard],
                              validation_data=gen_test, 
                              validation_steps=TEST_STEPS)
# Out:
# Epoch 1/256
# 15/20 [=====================>........] - ETA: 23s - loss: 2.6903

# %% [markdown]
# # Evaluate

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/cp_logs/weights.189-0.172831.hdf5'
model.load_weights(filename)

result = np.argmax(model.predict([x_test, tf_test], batch_size=BATCH_SIZE, verbose=1), -1)
# Out:
# 395/395 [==============================] - 7s

# %%
preResult = [[index2token.get(i, str(i)) for i in sent if i != 0] for sent in result]
actResult = [[index2token.get(i, str(i)) for i in sent if i != 0] for sent in y_test]
e1Count = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0]])
e2Count = sum([1 for i in range(395) if actResult[i][1] == preResult[i][1]])
enCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1]])
tripleCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1] and actResult[i][2] == preResult[i][2]])
print('E1 Accuracy: \t\t%.6f' % (e1Count/395))
print('E2 Accuracy: \t\t%.6f' % (e2Count/395))
print('En Accuracy: \t\t%.6f' % (enCount/395))
print('Triple Accuracy: \t%.6f' % (tripleCount/395))
# Out:
# E1 Accuracy: 		0.974684
# E2 Accuracy: 		0.977215
# En Accuracy: 		0.964557
# Triple Accuracy: 	0.837975

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(preResult[i]))
    print('Ground-Truth: \t%s' % ' '.join(actResult[i]))
    print('---')
# Out:
# Predict: 	5 6 country EOP
# Ground-Truth: 	5 6 country EOP
# ---
# Predict: 	9 8 place_of_birth EOP
# Ground-Truth: 	9 8 country EOP
# ---
# Predict: 	8 10 nationality EOP
# Ground-Truth: 	8 10 nationality EOP
# ---
# Predict: 	10 6 contains EOP
# Ground-Truth: 	10 6 contains EOP
# ---
# Predict: 	7 10 place_lived EOP 17 17 17
# Ground-Truth: 	7 10 place_lived EOP
# ---
# Predict: 	4 3 contains EOP
# Ground-Truth: 	4 3 contains EOP
# ---
# Predict: 	5 1 country EOP
# Ground-Truth: 	5 1 founders EOP
# ---
# Predict: 	11 8 place_of_birth EOP 8 8 8
# Ground-Truth: 	11 8 country EOP
# ---
# Predict: 	12 9 place_of_birth EOP
# Ground-Truth: 	12 9 country EOP
# ---
# Predict: 	9 3 contains EOP
# Ground-Truth: 	9 3 contains EOP
# ---
# Predict: 	18 20 company EOP
# Ground-Truth: 	18 20 company EOP
# ---
# Predict: 	6 5 contains EOP
# Ground-Truth: 	6 5 contains EOP
# ---
# Predict: 	1 4 contains EOP
# Ground-Truth: 	1 4 contains EOP
# ---
# Predict: 	9 11 place_lived EOP 4 4 4
# Ground-Truth: 	9 11 place_lived EOP
# ---
# Predict: 	3 5 place_lived EOP 4 4 4
# Ground-Truth: 	3 5 place_lived EOP
# ---
# Predict: 	2 8 place_of_birth EOP
# Ground-Truth: 	2 8 country EOP
# ---
# Predict: 	15 17 company EOP
# Ground-Truth: 	15 17 company EOP
# ---
# Predict: 	3 4 place_of_birth EOP
# Ground-Truth: 	3 4 country EOP
# ---
# Predict: 	12 13 place_of_birth EOP
# Ground-Truth: 	12 13 country EOP
# ---
# Predict: 	9 16 company EOP 4 4 4
# Ground-Truth: 	9 16 company EOP
# ---
# Predict: 	8 10 nationality EOP
# Ground-Truth: 	8 10 nationality EOP
# ---
# Predict: 	5 10 company EOP
# Ground-Truth: 	5 10 company EOP
# ---
# Predict: 	12 8 founders EOP
# Ground-Truth: 	12 8 founders EOP
# ---
# Predict: 	2 4 place_lived EOP
# Ground-Truth: 	2 4 place_lived EOP
# ---
# Predict: 	11 19 contains EOP
# Ground-Truth: 	11 19 contains EOP
# ---
# Predict: 	9 7 place_of_birth EOP
# Ground-Truth: 	9 7 country EOP
# ---
# Predict: 	8 14 country EOP 20 20 20
# Ground-Truth: 	8 14 country EOP
# ---
# Predict: 	2 5 place_lived EOP
# Ground-Truth: 	2 5 place_lived EOP
# ---
# Predict: 	3 8 company EOP
# Ground-Truth: 	3 8 company EOP
# ---
# Predict: 	16 1 place_of_birth EOP
# Ground-Truth: 	16 1 country EOP
# ---
# Predict: 	10 9 contains EOP
# Ground-Truth: 	10 9 contains EOP
# ---
# Predict: 	12 9 nationality EOP
# Ground-Truth: 	12 9 nationality EOP
# ---
# Predict: 	11 12 country EOP 4 4 4
# Ground-Truth: 	11 12 country EOP
# ---
# Predict: 	5 9 company EOP
# Ground-Truth: 	5 9 company EOP
# ---
# Predict: 	13 11 contains EOP
# Ground-Truth: 	13 11 contains EOP
# ---
# Predict: 	22 26 company EOP
# Ground-Truth: 	22 26 company EOP
# ---
# Predict: 	6 12 company EOP 17 17 17
# Ground-Truth: 	6 12 company EOP
# ---
# Predict: 	9 7 contains EOP
# Ground-Truth: 	9 7 contains EOP
# ---
# Predict: 	5 2 contains EOP
# Ground-Truth: 	29 28 contains EOP
# ---
# Predict: 	6 5 contains EOP
# Ground-Truth: 	6 5 contains EOP
# ---
# Predict: 	14 15 country EOP
# Ground-Truth: 	14 15 country EOP
# ---
# Predict: 	3 5 place_lived EOP
# Ground-Truth: 	3 5 place_lived EOP
# ---
# Predict: 	11 13 country EOP
# Ground-Truth: 	11 13 country EOP
# ---
# Predict: 	25 18 country EOP 4 4 4
# Ground-Truth: 	25 18 country EOP
# ---
# Predict: 	6 7 place_of_birth EOP
# Ground-Truth: 	21 23 place_of_birth EOP
# ---
# Predict: 	17 19 nationality EOP
# Ground-Truth: 	17 19 nationality EOP
# ---
# Predict: 	7 11 nationality EOP
# Ground-Truth: 	7 11 nationality EOP
# ---
# Predict: 	20 4 place_of_birth EOP 4 4 4
# Ground-Truth: 	20 22 country EOP
# ---
# Predict: 	3 6 place_lived EOP
# Ground-Truth: 	3 6 place_lived EOP
# ---
# Predict: 	9 6 contains EOP
# Ground-Truth: 	9 6 contains EOP
# ---
# Predict: 	8 11 place_lived EOP
# Ground-Truth: 	8 11 place_lived EOP
# ---
# Predict: 	6 12 country EOP
# Ground-Truth: 	6 12 country EOP
# ---
# Predict: 	6 3 company EOP
# Ground-Truth: 	6 3 company EOP
# ---
# Predict: 	3 5 contains EOP
# Ground-Truth: 	3 5 contains EOP
# ---
# Predict: 	9 5 contains EOP
# Ground-Truth: 	9 5 contains EOP
# ---
# Predict: 	5 6 place_of_birth EOP
# Ground-Truth: 	5 6 country EOP
# ---
# Predict: 	4 3 contains EOP
# Ground-Truth: 	4 3 contains EOP
# ---
# Predict: 	6 7 contains EOP
# Ground-Truth: 	6 7 contains EOP
# ---
# Predict: 	7 11 founders EOP
# Ground-Truth: 	7 11 country EOP
# ---
# Predict: 	18 16 contains EOP
# Ground-Truth: 	18 16 contains EOP
# ---
# Predict: 	6 3 contains EOP
# Ground-Truth: 	6 3 contains EOP
# ---
# Predict: 	26 27 country EOP
# Ground-Truth: 	26 27 country EOP
# ---
# Predict: 	1 6 company EOP
# Ground-Truth: 	1 6 company EOP
# ---
# Predict: 	6 4 contains EOP
# Ground-Truth: 	6 4 contains EOP
# ---
# Predict: 	8 11 place_lived EOP 4 4 4
# Ground-Truth: 	8 11 place_lived EOP
# ---
# Predict: 	16 15 contains EOP
# Ground-Truth: 	16 15 contains EOP
# ---
# Predict: 	5 3 contains EOP
# Ground-Truth: 	5 3 contains EOP
# ---
# Predict: 	2 4 company EOP
# Ground-Truth: 	2 4 company EOP
# ---
# Predict: 	4 3 contains EOP
# Ground-Truth: 	4 3 contains EOP
# ---
# Predict: 	15 13 contains EOP
# Ground-Truth: 	15 13 contains EOP
# ---
# Predict: 	5 7 country EOP
# Ground-Truth: 	5 7 country EOP
# ---
# Predict: 	12 9 contains EOP
# Ground-Truth: 	12 9 contains EOP
# ---
# Predict: 	2 12 place_lived EOP
# Ground-Truth: 	2 12 place_lived EOP
# ---
# Predict: 	4 11 company EOP 4 4 4
# Ground-Truth: 	4 11 company EOP
# ---
# Predict: 	13 15 place_lived EOP
# Ground-Truth: 	13 15 place_lived EOP
# ---
# Predict: 	9 6 nationality EOP 4 4 4
# Ground-Truth: 	9 6 nationality EOP
# ---
# Predict: 	12 4 nationality EOP
# Ground-Truth: 	12 4 nationality EOP
# ---
# Predict: 	11 18 contains EOP
# Ground-Truth: 	16 18 contains EOP
# ---
# Predict: 	8 1 contains EOP
# Ground-Truth: 	8 1 contains EOP
# ---
# Predict: 	15 16 place_of_birth EOP
# Ground-Truth: 	15 16 country EOP
# ---
# Predict: 	11 10 contains EOP
# Ground-Truth: 	11 10 contains EOP
# ---
# Predict: 	7 19 place_of_birth EOP 4 4 4
# Ground-Truth: 	7 19 country EOP
# ---
# Predict: 	3 5 contains EOP
# Ground-Truth: 	3 5 contains EOP
# ---
# Predict: 	6 12 contains EOP
# Ground-Truth: 	6 12 contains EOP
# ---
# Predict: 	5 7 place_lived EOP
# Ground-Truth: 	5 7 place_lived EOP
# ---
# Predict: 	6 4 contains EOP
# Ground-Truth: 	6 4 contains EOP
# ---
# Predict: 	1 6 company EOP
# Ground-Truth: 	1 6 company EOP
# ---
# Predict: 	13 9 country EOP
# Ground-Truth: 	13 9 country EOP
# ---
# Predict: 	20 21 contains EOP
# Ground-Truth: 	20 21 contains EOP
# ---
# Predict: 	19 17 contains EOP
# Ground-Truth: 	19 17 contains EOP
# ---
# Predict: 	6 1 contains EOP
# Ground-Truth: 	6 1 contains EOP
# ---
# Predict: 	8 1 place_of_birth EOP
# Ground-Truth: 	8 1 country EOP
# ---
# Predict: 	3 6 contains EOP
# Ground-Truth: 	3 6 contains EOP
# ---
# Predict: 	2 4 place_lived EOP 35 35 35
# Ground-Truth: 	2 4 place_lived EOP
# ---
# Predict: 	6 3 contains EOP
# Ground-Truth: 	6 3 contains EOP
# ---
# Predict: 	10 20 country EOP
# Ground-Truth: 	10 20 country EOP
# ---
# Predict: 	3 5 nationality EOP
# Ground-Truth: 	3 5 nationality EOP
# ---
# Predict: 	19 13 contains EOP
# Ground-Truth: 	19 13 contains EOP
# ---
# Predict: 	6 5 contains EOP
# Ground-Truth: 	6 5 contains EOP
# ---
# Predict: 	22 21 contains EOP
# Ground-Truth: 	22 21 contains EOP
# ---
# Predict: 	7 6 contains EOP
# Ground-Truth: 	7 6 contains EOP
# ---
# Predict: 	4 1 contains EOP
# Ground-Truth: 	4 1 contains EOP
# ---
# Predict: 	10 30 contains EOP
# Ground-Truth: 	32 30 contains EOP
# ---
# Predict: 	24 7 place_of_birth EOP
# Ground-Truth: 	24 7 country EOP
# ---
# Predict: 	9 13 place_of_birth EOP
# Ground-Truth: 	9 13 country EOP
# ---
# Predict: 	6 14 company EOP 28 28 28
# Ground-Truth: 	6 14 company EOP
# ---
# Predict: 	8 7 nationality EOP
# Ground-Truth: 	8 7 nationality EOP
# ---
# Predict: 	3 8 place_lived EOP
# Ground-Truth: 	3 8 place_lived EOP
# ---
# Predict: 	5 9 nationality EOP
# Ground-Truth: 	5 9 nationality EOP
# ---
# Predict: 	3 5 place_lived EOP 32 32 32
# Ground-Truth: 	3 5 place_lived EOP
# ---
# Predict: 	4 5 place_of_birth EOP
# Ground-Truth: 	4 5 country EOP
# ---
# Predict: 	5 2 administrative_divisions EOP
# Ground-Truth: 	5 2 administrative_divisions EOP
# ---
# Predict: 	18 16 contains EOP
# Ground-Truth: 	18 16 contains EOP
# ---
# Predict: 	10 6 country EOP
# Ground-Truth: 	10 6 country EOP
# ---
# Predict: 	16 17 contains EOP
# Ground-Truth: 	16 17 contains EOP
# ---
# Predict: 	10 12 country EOP 4 4 4
# Ground-Truth: 	10 12 country EOP
# ---
# Predict: 	23 13 country EOP
# Ground-Truth: 	23 13 country EOP
# ---
# Predict: 	21 19 contains EOP
# Ground-Truth: 	21 19 contains EOP
# ---
# Predict: 	7 8 place_of_birth EOP 4 4 4
# Ground-Truth: 	7 8 country EOP
# ---
# Predict: 	17 8 country EOP 4 4 4
# Ground-Truth: 	17 8 country EOP
# ---
# Predict: 	21 19 contains EOP
# Ground-Truth: 	21 19 contains EOP
# ---
# Predict: 	16 14 contains EOP
# Ground-Truth: 	16 14 contains EOP
# ---
# Predict: 	16 19 contains EOP
# Ground-Truth: 	16 19 contains EOP
# ---
# Predict: 	20 19 contains EOP
# Ground-Truth: 	20 19 contains EOP
# ---
# Predict: 	15 13 contains EOP
# Ground-Truth: 	15 13 contains EOP
# ---
# Predict: 	18 16 contains EOP
# Ground-Truth: 	18 16 contains EOP
# ---
# Predict: 	7 6 contains EOP
# Ground-Truth: 	7 6 contains EOP
# ---
# Predict: 	8 10 place_lived EOP
# Ground-Truth: 	8 10 place_lived EOP
# ---
# Predict: 	11 13 administrative_divisions EOP
# Ground-Truth: 	11 13 administrative_divisions EOP
# ---
# Predict: 	1 17 place_of_death EOP
# Ground-Truth: 	1 17 place_of_death EOP
# ---
# Predict: 	10 4 contains EOP
# Ground-Truth: 	10 4 contains EOP
# ---
# Predict: 	12 3 place_of_birth EOP
# Ground-Truth: 	12 3 country EOP
# ---
# Predict: 	7 5 contains EOP
# Ground-Truth: 	7 5 contains EOP
# ---
# Predict: 	2 4 nationality EOP
# Ground-Truth: 	2 4 nationality EOP
# ---
# Predict: 	10 16 company EOP
# Ground-Truth: 	10 16 company EOP
# ---
# Predict: 	8 1 contains EOP
# Ground-Truth: 	8 1 contains EOP
# ---
# Predict: 	4 8 contains EOP
# Ground-Truth: 	4 8 contains EOP
# ---
# Predict: 	17 15 contains EOP
# Ground-Truth: 	17 15 contains EOP
# ---
# Predict: 	5 6 founders EOP
# Ground-Truth: 	5 6 country EOP
# ---
# Predict: 	3 12 place_of_birth EOP
# Ground-Truth: 	3 12 country EOP
# ---
# Predict: 	5 11 nationality EOP
# Ground-Truth: 	5 11 nationality EOP
# ---
# Predict: 	4 3 contains EOP
# Ground-Truth: 	4 3 contains EOP
# ---
# Predict: 	15 17 place_lived EOP
# Ground-Truth: 	15 17 place_lived EOP
# ---
# Predict: 	7 6 neighborhood_of EOP
# Ground-Truth: 	7 6 country EOP
# ---
# Predict: 	5 3 country EOP 4 4 4
# Ground-Truth: 	5 3 country EOP
# ---
# Predict: 	1 6 company EOP 28 28 28
# Ground-Truth: 	1 6 company EOP
# ---
# Predict: 	10 3 contains EOP
# Ground-Truth: 	10 3 contains EOP
# ---
# Predict: 	2 6 company EOP
# Ground-Truth: 	2 6 company EOP
# ---
# Predict: 	9 6 contains EOP
# Ground-Truth: 	9 6 contains EOP
# ---
# Predict: 	14 21 administrative_divisions EOP
# Ground-Truth: 	14 21 administrative_divisions EOP
# ---
# Predict: 	9 8 contains EOP
# Ground-Truth: 	9 8 contains EOP
# ---
# Predict: 	20 19 place_of_birth EOP
# Ground-Truth: 	20 19 country EOP
# ---
# Predict: 	2 7 place_lived EOP
# Ground-Truth: 	2 7 place_lived EOP
# ---
# Predict: 	6 2 country EOP 22 22 22
# Ground-Truth: 	6 2 country EOP
# ---
# Predict: 	4 3 contains EOP
# Ground-Truth: 	4 3 contains EOP
# ---
# Predict: 	1 15 place_of_death EOP
# Ground-Truth: 	1 15 place_of_death EOP
# ---
# Predict: 	5 3 contains EOP
# Ground-Truth: 	5 3 contains EOP
# ---
# Predict: 	11 24 country EOP
# Ground-Truth: 	11 24 country EOP
# ---
# Predict: 	6 5 contains EOP
# Ground-Truth: 	6 5 contains EOP
# ---
# Predict: 	2 7 company EOP
# Ground-Truth: 	2 7 company EOP
# ---
# Predict: 	8 7 contains EOP
# Ground-Truth: 	8 7 contains EOP
# ---
# Predict: 	13 15 place_lived EOP
# Ground-Truth: 	13 15 place_lived EOP
# ---
# Predict: 	16 14 country EOP
# Ground-Truth: 	16 14 country EOP
# ---
# Predict: 	12 13 founders EOP
# Ground-Truth: 	12 13 country EOP
# ---
# Predict: 	12 11 contains EOP
# Ground-Truth: 	12 11 contains EOP
# ---
# Predict: 	12 11 contains EOP
# Ground-Truth: 	12 11 contains EOP
# ---
# Predict: 	10 9 contains EOP
# Ground-Truth: 	10 9 contains EOP
# ---
# Predict: 	27 23 capital EOP
# Ground-Truth: 	27 23 founders EOP
# ---
# Predict: 	21 17 contains EOP
# Ground-Truth: 	21 17 contains EOP
# ---
# Predict: 	2 7 country EOP
# Ground-Truth: 	2 7 country EOP
# ---
# Predict: 	18 30 place_of_birth EOP
# Ground-Truth: 	18 30 country EOP
# ---
# Predict: 	14 7 contains EOP
# Ground-Truth: 	14 7 contains EOP
# ---
# Predict: 	3 2 contains EOP
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	2 5 place_lived EOP
# Ground-Truth: 	2 5 place_lived EOP
# ---
# Predict: 	2 17 place_of_birth EOP
# Ground-Truth: 	2 17 country EOP
# ---
# Predict: 	8 4 contains EOP 32 32 32
# Ground-Truth: 	8 4 contains EOP
# ---
# Predict: 	6 3 country EOP 4 4 4
# Ground-Truth: 	6 3 country EOP
# ---
# Predict: 	13 12 contains EOP 32 32 32
# Ground-Truth: 	13 12 contains EOP
# ---
# Predict: 	9 11 neighborhood_of EOP 4 4 4
# Ground-Truth: 	9 11 neighborhood_of EOP
# ---
# Predict: 	20 25 place_of_birth EOP
# Ground-Truth: 	20 25 country EOP
# ---
# Predict: 	15 13 contains EOP
# Ground-Truth: 	15 13 contains EOP
# ---
# Predict: 	6 3 company EOP
# Ground-Truth: 	6 3 company EOP
# ---
# Predict: 	8 7 contains EOP
# Ground-Truth: 	8 7 contains EOP
# ---
# Predict: 	10 12 place_lived EOP
# Ground-Truth: 	10 12 place_lived EOP
# ---
# Predict: 	2 5 place_lived EOP 17 17 17
# Ground-Truth: 	2 5 place_lived EOP
# ---
# Predict: 	22 24 place_lived EOP
# Ground-Truth: 	22 24 place_lived EOP
# ---
# Predict: 	11 5 country EOP 8 8 8
# Ground-Truth: 	16 5 country EOP
# ---
# Predict: 	1 17 contains EOP
# Ground-Truth: 	1 17 contains EOP
# ---
# Predict: 	7 3 place_lived EOP
# Ground-Truth: 	7 3 place_lived EOP
# ---
# Predict: 	9 7 contains EOP
# Ground-Truth: 	9 7 contains EOP
# ---
# Predict: 	19 21 place_lived EOP
# Ground-Truth: 	19 21 place_lived EOP
# ---
# Predict: 	15 17 contains EOP
# Ground-Truth: 	15 17 contains EOP
# ---
# Predict: 	6 8 place_lived EOP
# Ground-Truth: 	6 8 place_lived EOP
# ---
# Predict: 	9 14 country EOP
# Ground-Truth: 	9 14 country EOP
# ---
# Predict: 	11 13 place_of_birth EOP 12 12 12
# Ground-Truth: 	11 13 country EOP
# ---
# Predict: 	2 6 country EOP
# Ground-Truth: 	2 6 country EOP
# ---
# Predict: 	11 8 contains EOP
# Ground-Truth: 	11 8 contains EOP
# ---
# Predict: 	6 12 country EOP
# Ground-Truth: 	6 12 country EOP
# ---
# Predict: 	6 4 place_of_birth EOP 8 8 8
# Ground-Truth: 	6 4 country EOP
# ---
# Predict: 	10 13 place_of_birth EOP
# Ground-Truth: 	10 13 country EOP
# ---
# Predict: 	16 21 place_of_death EOP 38 38 38
# Ground-Truth: 	55 EOP country EOP
# ---
# Predict: 	15 13 contains EOP
# Ground-Truth: 	15 13 contains EOP
# ---
# Predict: 	18 36 country EOP 38 38 38
# Ground-Truth: 	18 16 country EOP
# ---
# Predict: 	19 17 contains EOP 35 35 35
# Ground-Truth: 	19 17 contains EOP
# ---
# Predict: 	19 21 nationality EOP
# Ground-Truth: 	19 21 nationality EOP
# ---
# Predict: 	10 13 country EOP
# Ground-Truth: 	10 13 country EOP
# ---
# Predict: 	14 12 contains EOP
# Ground-Truth: 	14 12 contains EOP
# ---
# Predict: 	1 5 nationality EOP
# Ground-Truth: 	1 5 nationality EOP
# ---
# Predict: 	3 2 contains EOP
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	14 8 contains EOP
# Ground-Truth: 	14 8 contains EOP
# ---
# Predict: 	17 14 nationality EOP
# Ground-Truth: 	17 14 nationality EOP
# ---
# Predict: 	17 24 country EOP
# Ground-Truth: 	17 24 country EOP
# ---
# Predict: 	1 4 contains EOP
# Ground-Truth: 	1 4 contains EOP
# ---
# Predict: 	10 8 contains EOP
# Ground-Truth: 	10 8 contains EOP
# ---
# Predict: 	14 13 contains EOP
# Ground-Truth: 	14 13 contains EOP
# ---
# Predict: 	10 15 contains EOP
# Ground-Truth: 	10 15 contains EOP
# ---
# Predict: 	7 8 country EOP
# Ground-Truth: 	7 8 country EOP
# ---
# Predict: 	10 20 country EOP
# Ground-Truth: 	10 20 country EOP
# ---
# Predict: 	20 16 contains EOP 4 4 4
# Ground-Truth: 	20 16 contains EOP
# ---
# Predict: 	8 10 nationality EOP
# Ground-Truth: 	8 10 nationality EOP
# ---
# Predict: 	16 15 contains EOP
# Ground-Truth: 	16 15 contains EOP
# ---
# Predict: 	9 12 country EOP
# Ground-Truth: 	9 12 country EOP
# ---
# Predict: 	5 8 place_lived EOP
# Ground-Truth: 	5 8 place_lived EOP
# ---
# Predict: 	11 12 contains EOP
# Ground-Truth: 	11 12 contains EOP
# ---
# Predict: 	22 20 nationality EOP
# Ground-Truth: 	22 20 nationality EOP
# ---
# Predict: 	2 4 contains EOP
# Ground-Truth: 	2 4 contains EOP
# ---
# Predict: 	6 1 place_of_birth EOP
# Ground-Truth: 	6 1 country EOP
# ---
# Predict: 	19 21 capital EOP
# Ground-Truth: 	19 21 founders EOP
# ---
# Predict: 	11 13 nationality EOP 20 20 20
# Ground-Truth: 	11 13 nationality EOP
# ---
# Predict: 	7 8 place_of_birth EOP
# Ground-Truth: 	7 8 country EOP
# ---
# Predict: 	16 14 contains EOP
# Ground-Truth: 	16 14 contains EOP
# ---
# Predict: 	14 12 contains EOP
# Ground-Truth: 	14 12 contains EOP
# ---
# Predict: 	18 17 contains EOP
# Ground-Truth: 	18 17 contains EOP
# ---
# Predict: 	3 12 company EOP
# Ground-Truth: 	3 12 company EOP
# ---
# Predict: 	8 9 contains EOP
# Ground-Truth: 	8 9 contains EOP
# ---
# Predict: 	11 10 contains EOP
# Ground-Truth: 	11 10 contains EOP
# ---
# Predict: 	3 5 place_lived EOP
# Ground-Truth: 	3 5 place_lived EOP
# ---
# Predict: 	8 7 contains EOP
# Ground-Truth: 	8 7 contains EOP
# ---
# Predict: 	2 1 country EOP
# Ground-Truth: 	2 1 country EOP
# ---
# Predict: 	5 8 contains EOP
# Ground-Truth: 	5 8 contains EOP
# ---
# Predict: 	11 9 contains EOP
# Ground-Truth: 	11 9 contains EOP
# ---
# Predict: 	2 13 place_of_birth EOP
# Ground-Truth: 	2 13 country EOP
# ---
# Predict: 	2 4 place_lived EOP
# Ground-Truth: 	2 4 place_lived EOP
# ---
# Predict: 	13 1 company EOP
# Ground-Truth: 	13 1 company EOP
# ---
# Predict: 	17 5 country EOP 4 4 4
# Ground-Truth: 	17 5 country EOP
# ---
# Predict: 	3 4 place_of_birth EOP
# Ground-Truth: 	3 4 country EOP
# ---
# Predict: 	3 5 nationality EOP
# Ground-Truth: 	3 5 nationality EOP
# ---
# Predict: 	7 6 contains EOP
# Ground-Truth: 	7 6 contains EOP
# ---
# Predict: 	20 25 company EOP
# Ground-Truth: 	20 25 company EOP
# ---
# Predict: 	4 10 company EOP
# Ground-Truth: 	4 10 company EOP
# ---
# Predict: 	11 16 country EOP
# Ground-Truth: 	11 16 country EOP
# ---
# Predict: 	9 12 place_lived EOP
# Ground-Truth: 	9 12 place_lived EOP
# ---
# Predict: 	6 5 contains EOP
# Ground-Truth: 	6 5 contains EOP
# ---
# Predict: 	12 11 contains EOP
# Ground-Truth: 	12 11 contains EOP
# ---
# Predict: 	4 6 place_lived EOP
# Ground-Truth: 	4 6 place_lived EOP
# ---
# Predict: 	12 14 country EOP
# Ground-Truth: 	12 14 country EOP
# ---
# Predict: 	8 5 contains EOP
# Ground-Truth: 	8 5 contains EOP
# ---
# Predict: 	22 9 country EOP 4 4 4
# Ground-Truth: 	22 9 country EOP
# ---
# Predict: 	3 2 contains EOP 32 32 32
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	16 30 place_of_birth EOP
# Ground-Truth: 	48 30 country EOP
# ---
# Predict: 	1 3 nationality EOP
# Ground-Truth: 	1 3 nationality EOP
# ---
# Predict: 	1 8 company EOP 17 17 17
# Ground-Truth: 	1 8 company EOP
# ---
# Predict: 	7 8 country EOP
# Ground-Truth: 	7 8 country EOP
# ---
# Predict: 	13 10 contains EOP
# Ground-Truth: 	13 10 contains EOP
# ---
# Predict: 	10 9 contains EOP
# Ground-Truth: 	10 9 contains EOP
# ---
# Predict: 	14 4 capital EOP 32 32 32
# Ground-Truth: 	14 4 capital EOP
# ---
# Predict: 	18 16 contains EOP
# Ground-Truth: 	38 32 contains EOP
# ---
# Predict: 	23 21 contains EOP
# Ground-Truth: 	23 21 contains EOP
# ---
# Predict: 	5 9 company EOP
# Ground-Truth: 	5 9 company EOP
# ---
# Predict: 	2 3 place_of_death EOP 8 8 8
# Ground-Truth: 	2 3 country EOP
# ---
# Predict: 	5 8 place_lived EOP
# Ground-Truth: 	5 8 place_lived EOP
# ---
# Predict: 	2 1 contains EOP
# Ground-Truth: 	2 1 contains EOP
# ---
# Predict: 	12 15 company EOP
# Ground-Truth: 	12 15 company EOP
# ---
# Predict: 	10 7 contains EOP
# Ground-Truth: 	10 7 contains EOP
# ---
# Predict: 	21 25 children EOP
# Ground-Truth: 	21 25 children EOP
# ---
# Predict: 	13 12 contains EOP
# Ground-Truth: 	13 12 contains EOP
# ---
# Predict: 	14 6 place_of_birth EOP
# Ground-Truth: 	14 6 country EOP
# ---
# Predict: 	3 2 contains EOP
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	9 7 contains EOP
# Ground-Truth: 	9 7 contains EOP
# ---
# Predict: 	13 1 country EOP 8 8 8
# Ground-Truth: 	13 1 country EOP
# ---
# Predict: 	7 6 contains EOP
# Ground-Truth: 	7 6 contains EOP
# ---
# Predict: 	11 9 place_of_birth EOP
# Ground-Truth: 	11 9 country EOP
# ---
# Predict: 	15 16 place_of_birth EOP
# Ground-Truth: 	15 16 country EOP
# ---
# Predict: 	14 13 contains EOP
# Ground-Truth: 	14 13 contains EOP
# ---
# Predict: 	7 3 nationality EOP
# Ground-Truth: 	7 3 nationality EOP
# ---
# Predict: 	19 10 contains EOP
# Ground-Truth: 	19 10 contains EOP
# ---
# Predict: 	4 7 contains EOP
# Ground-Truth: 	4 7 contains EOP
# ---
# Predict: 	13 10 country EOP 20 20 20
# Ground-Truth: 	13 10 country EOP
# ---
# Predict: 	16 15 contains EOP
# Ground-Truth: 	16 15 contains EOP
# ---
# Predict: 	22 19 contains EOP
# Ground-Truth: 	22 19 contains EOP
# ---
# Predict: 	20 18 contains EOP
# Ground-Truth: 	20 18 contains EOP
# ---
# Predict: 	3 5 nationality EOP
# Ground-Truth: 	3 5 nationality EOP
# ---
# Predict: 	11 13 nationality EOP 4 4 4
# Ground-Truth: 	11 13 nationality EOP
# ---
# Predict: 	5 13 place_of_birth EOP 4 4 4
# Ground-Truth: 	5 13 country EOP
# ---
# Predict: 	1 7 company EOP
# Ground-Truth: 	1 7 company EOP
# ---
# Predict: 	8 4 contains EOP
# Ground-Truth: 	8 4 contains EOP
# ---
# Predict: 	30 13 country EOP
# Ground-Truth: 	30 13 country EOP
# ---
# Predict: 	7 10 contains EOP
# Ground-Truth: 	7 10 contains EOP
# ---
# Predict: 	16 3 country EOP
# Ground-Truth: 	16 3 country EOP
# ---
# Predict: 	1 3 company EOP
# Ground-Truth: 	1 3 company EOP
# ---
# Predict: 	12 14 founders EOP
# Ground-Truth: 	12 14 country EOP
# ---
# Predict: 	6 4 contains EOP
# Ground-Truth: 	6 4 contains EOP
# ---
# Predict: 	1 3 company EOP
# Ground-Truth: 	1 3 company EOP
# ---
# Predict: 	17 14 contains EOP
# Ground-Truth: 	17 14 contains EOP
# ---
# Predict: 	3 2 contains EOP
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	9 7 contains EOP
# Ground-Truth: 	9 7 contains EOP
# ---
# Predict: 	9 7 contains EOP
# Ground-Truth: 	9 7 contains EOP
# ---
# Predict: 	2 19 contains EOP
# Ground-Truth: 	2 19 contains EOP
# ---
# Predict: 	25 2 administrative_divisions EOP
# Ground-Truth: 	25 28 company EOP
# ---
# Predict: 	7 6 contains EOP
# Ground-Truth: 	7 6 contains EOP
# ---
# Predict: 	7 5 contains EOP
# Ground-Truth: 	7 5 contains EOP
# ---
# Predict: 	11 8 contains EOP
# Ground-Truth: 	11 8 contains EOP
# ---
# Predict: 	24 19 contains EOP
# Ground-Truth: 	24 19 contains EOP
# ---
# Predict: 	5 6 country EOP
# Ground-Truth: 	5 6 country EOP
# ---
# Predict: 	11 9 place_of_birth EOP 4 4 4
# Ground-Truth: 	11 9 country EOP
# ---
# Predict: 	14 11 country EOP
# Ground-Truth: 	14 11 country EOP
# ---
# Predict: 	5 11 company EOP
# Ground-Truth: 	5 11 company EOP
# ---
# Predict: 	16 15 contains EOP
# Ground-Truth: 	16 15 contains EOP
# ---
# Predict: 	13 7 contains EOP
# Ground-Truth: 	13 7 contains EOP
# ---
# Predict: 	21 19 contains EOP
# Ground-Truth: 	21 19 contains EOP
# ---
# Predict: 	14 12 contains EOP
# Ground-Truth: 	14 12 contains EOP
# ---
# Predict: 	17 13 contains EOP
# Ground-Truth: 	17 13 contains EOP
# ---
# Predict: 	6 4 contains EOP
# Ground-Truth: 	6 4 contains EOP
# ---
# Predict: 	7 6 country EOP
# Ground-Truth: 	7 6 country EOP
# ---
# Predict: 	1 4 company EOP
# Ground-Truth: 	1 4 company EOP
# ---
# Predict: 	27 25 contains EOP
# Ground-Truth: 	27 25 contains EOP
# ---
# Predict: 	2 4 place_lived EOP 26 26 26
# Ground-Truth: 	2 4 place_lived EOP
# ---
# Predict: 	19 16 contains EOP
# Ground-Truth: 	19 16 contains EOP
# ---
# Predict: 	13 14 place_of_birth EOP
# Ground-Truth: 	13 14 country EOP
# ---
# Predict: 	6 4 contains EOP
# Ground-Truth: 	6 4 contains EOP
# ---
# Predict: 	12 10 contains EOP
# Ground-Truth: 	12 10 contains EOP
# ---
# Predict: 	8 7 contains EOP
# Ground-Truth: 	8 7 contains EOP
# ---
# Predict: 	14 12 contains EOP
# Ground-Truth: 	14 12 contains EOP
# ---
# Predict: 	14 15 capital EOP
# Ground-Truth: 	14 15 capital EOP
# ---
# Predict: 	3 2 contains EOP
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	21 19 contains EOP
# Ground-Truth: 	21 19 contains EOP
# ---
# Predict: 	10 16 country EOP
# Ground-Truth: 	63 43 country EOP
# ---
# Predict: 	8 7 contains EOP
# Ground-Truth: 	8 7 contains EOP
# ---
# Predict: 	5 9 company EOP
# Ground-Truth: 	5 9 company EOP
# ---
# Predict: 	11 9 contains EOP
# Ground-Truth: 	11 9 contains EOP
# ---
# Predict: 	25 23 contains EOP
# Ground-Truth: 	25 23 contains EOP
# ---
# Predict: 	3 4 place_of_birth EOP
# Ground-Truth: 	3 4 country EOP
# ---
# Predict: 	3 6 place_lived EOP
# Ground-Truth: 	3 6 place_lived EOP
# ---
# Predict: 	4 9 company EOP
# Ground-Truth: 	4 9 company EOP
# ---
# Predict: 	7 8 place_of_birth EOP 8 8 8
# Ground-Truth: 	7 8 country EOP
# ---
# Predict: 	3 2 contains EOP
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	13 10 contains EOP
# Ground-Truth: 	13 10 contains EOP
# ---
# Predict: 	20 19 contains EOP
# Ground-Truth: 	20 19 contains EOP
# ---
# Predict: 	7 4 contains EOP
# Ground-Truth: 	7 4 contains EOP
# ---
# Predict: 	5 9 contains EOP
# Ground-Truth: 	5 9 contains EOP
# ---
# Predict: 	27 2 place_of_birth EOP
# Ground-Truth: 	27 28 country EOP
# ---
# Predict: 	12 11 contains EOP
# Ground-Truth: 	12 11 contains EOP
# ---
# Predict: 	1 9 country EOP
# Ground-Truth: 	1 9 country EOP
# ---
# Predict: 	4 3 country EOP
# Ground-Truth: 	4 3 country EOP
# ---
# Predict: 	5 4 contains EOP
# Ground-Truth: 	5 4 contains EOP
# ---
# Predict: 	7 14 nationality EOP
# Ground-Truth: 	7 14 nationality EOP
# ---
# Predict: 	14 13 contains EOP
# Ground-Truth: 	14 13 contains EOP
# ---
# Predict: 	12 11 contains EOP
# Ground-Truth: 	12 11 contains EOP
# ---
# Predict: 	12 7 contains EOP
# Ground-Truth: 	12 7 contains EOP
# ---
# Predict: 	11 13 place_lived EOP 8 8 8
# Ground-Truth: 	11 13 place_lived EOP
# ---
# Predict: 	9 8 contains EOP
# Ground-Truth: 	9 8 contains EOP
# ---
# Predict: 	1 8 company EOP
# Ground-Truth: 	1 8 company EOP
# ---
# Predict: 	7 5 contains EOP
# Ground-Truth: 	7 5 contains EOP
# ---
# Predict: 	12 14 country EOP
# Ground-Truth: 	12 14 country EOP
# ---
# Predict: 	10 9 contains EOP
# Ground-Truth: 	10 9 contains EOP
# ---
# Predict: 	13 11 contains EOP
# Ground-Truth: 	13 11 contains EOP
# ---
# Predict: 	12 8 contains EOP
# Ground-Truth: 	12 8 contains EOP
# ---
# Predict: 	22 20 contains EOP
# Ground-Truth: 	22 20 contains EOP
# ---
# Predict: 	5 8 place_of_birth EOP
# Ground-Truth: 	29 8 country EOP
# ---
# Predict: 	12 16 country EOP
# Ground-Truth: 	12 16 country EOP
# ---
# Predict: 	4 3 contains EOP
# Ground-Truth: 	4 3 contains EOP
# ---
# Predict: 	8 5 contains EOP
# Ground-Truth: 	8 5 contains EOP
# ---
# Predict: 	14 20 place_of_death EOP 19 20 place_of_birth EOP
# Ground-Truth: 	14 20 country EOP 19 20 country EOP
# ---
# Predict: 	5 6 country EOP
# Ground-Truth: 	5 6 country EOP
# ---
# Predict: 	5 7 place_lived EOP
# Ground-Truth: 	5 7 place_lived EOP
# ---
# Predict: 	12 15 place_lived EOP 22 22 22
# Ground-Truth: 	12 15 place_lived EOP
# ---
# Predict: 	4 3 contains EOP
# Ground-Truth: 	4 3 contains EOP
# ---
# Predict: 	7 6 contains EOP
# Ground-Truth: 	7 6 contains EOP
# ---
# Predict: 	6 1 nationality EOP
# Ground-Truth: 	6 1 nationality EOP
# ---
# Predict: 	16 14 contains EOP
# Ground-Truth: 	16 14 contains EOP
# ---
# Predict: 	7 3 place_of_birth EOP
# Ground-Truth: 	7 3 country EOP
# ---
# Predict: 	21 8 contains EOP
# Ground-Truth: 	21 8 contains EOP
# ---
# Predict: 	1 7 place_lived EOP 20 20 20
# Ground-Truth: 	1 7 place_lived EOP
# ---
# Predict: 	11 9 contains EOP
# Ground-Truth: 	11 9 contains EOP
# ---
# Predict: 	2 1 place_of_birth EOP
# Ground-Truth: 	2 1 country EOP
# ---
# Predict: 	5 2 contains EOP
# Ground-Truth: 	5 2 contains EOP
# ---
# Predict: 	12 18 company EOP
# Ground-Truth: 	12 18 company EOP
# ---
# Predict: 	10 13 nationality EOP
# Ground-Truth: 	10 13 nationality EOP
# ---
# Predict: 	9 6 capital EOP
# Ground-Truth: 	9 6 children EOP
# ---
# Predict: 	7 6 contains EOP
# Ground-Truth: 	7 6 contains EOP
# ---
# Predict: 	17 14 contains EOP
# Ground-Truth: 	17 14 contains EOP
# ---
# Predict: 	6 12 company EOP
# Ground-Truth: 	6 12 company EOP
# ---
# Predict: 	3 2 contains EOP
# Ground-Truth: 	3 2 contains EOP
# ---
# Predict: 	2 4 place_lived EOP
# Ground-Truth: 	2 4 place_lived EOP
# ---
# Predict: 	1 4 place_lived EOP 32 32 32
# Ground-Truth: 	1 4 place_lived EOP
# ---

# %%
preResult = []
actResult = []
for n in range(395):
    pR = [index2token.get(i, str(i)) if i > len(t_sentWords[n]) else t_sentWords[n][i-1] for i in result[n] if i != 0]
    aR = [index2token.get(i, str(i)) if i > len(t_sentWords[n]) else t_sentWords[n][i-1] for i in y_test[n] if i != 0]
    preResult.append(pR)
    actResult.append(aR)
e1Count = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0]])
e2Count = sum([1 for i in range(395) if actResult[i][1] == preResult[i][1]])
enCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1]])
tripleCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1] and actResult[i][2] == preResult[i][2]])
print('E1 Accuracy: \t\t%.6f' % (e1Count/395))
print('E2 Accuracy: \t\t%.6f' % (e2Count/395))
print('En Accuracy: \t\t%.6f' % (enCount/395))
print('Triple Accuracy: \t%.6f' % (tripleCount/395))
# Out:
# E1 Accuracy: 		0.974684
# E2 Accuracy: 		0.977215
# En Accuracy: 		0.964557
# Triple Accuracy: 	0.837975

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(preResult[i]))
    print('Ground-Truth: \t%s' % ' '.join(actResult[i]))
    print('---')
# Out:
# Predict: 	glut condo country EOP
# Ground-Truth: 	glut condo country EOP
# ---
# Predict: 	hockey connecticut place_of_birth EOP
# Ground-Truth: 	hockey connecticut country EOP
# ---
# Predict: 	sidewinder porush nationality EOP
# Ground-Truth: 	sidewinder porush nationality EOP
# ---
# Predict: 	immigrated latvia contains EOP
# Ground-Truth: 	immigrated latvia contains EOP
# ---
# Predict: 	week protester place_lived EOP paris paris paris
# Ground-Truth: 	week protester place_lived EOP
# ---
# Predict: 	poorest closed contains EOP
# Ground-Truth: 	poorest closed contains EOP
# ---
# Predict: 	8 final country EOP
# Ground-Truth: 	8 final founders EOP
# ---
# Predict: 	11 chicago place_of_birth EOP chicago chicago chicago
# Ground-Truth: 	11 chicago country EOP
# ---
# Predict: 	university enforcement place_of_birth EOP
# Ground-Truth: 	university enforcement country EOP
# ---
# Predict: 	experiment argument contains EOP
# Ground-Truth: 	experiment argument contains EOP
# ---
# Predict: 	18 20 company EOP
# Ground-Truth: 	18 20 company EOP
# ---
# Predict: 	stood toll contains EOP
# Ground-Truth: 	stood toll contains EOP
# ---
# Predict: 	sercotel ac contains EOP
# Ground-Truth: 	sercotel ac contains EOP
# ---
# Predict: 	committee political place_lived EOP mississippi mississippi mississippi
# Ground-Truth: 	committee political place_lived EOP
# ---
# Predict: 	canada portland place_lived EOP raised raised raised
# Ground-Truth: 	canada portland place_lived EOP
# ---
# Predict: 	haefliger german place_of_birth EOP
# Ground-Truth: 	haefliger german country EOP
# ---
# Predict: 	bosnia 17 company EOP
# Ground-Truth: 	bosnia 17 company EOP
# ---
# Predict: 	successor ranged place_of_birth EOP
# Ground-Truth: 	successor ranged country EOP
# ---
# Predict: 	12 13 place_of_birth EOP
# Ground-Truth: 	12 13 country EOP
# ---
# Predict: 	9 16 company EOP 4 4 4
# Ground-Truth: 	9 16 company EOP
# ---
# Predict: 	germany rotating nationality EOP
# Ground-Truth: 	germany rotating nationality EOP
# ---
# Predict: 	empathy professor company EOP
# Ground-Truth: 	empathy professor company EOP
# ---
# Predict: 	black campaign founders EOP
# Ground-Truth: 	black campaign founders EOP
# ---
# Predict: 	revolutionary shot place_lived EOP
# Ground-Truth: 	revolutionary shot place_lived EOP
# ---
# Predict: 	france 19 contains EOP
# Ground-Truth: 	france 19 contains EOP
# ---
# Predict: 	reside 1 place_of_birth EOP
# Ground-Truth: 	reside 1 country EOP
# ---
# Predict: 	pour bound country EOP sleeping sleeping sleeping
# Ground-Truth: 	pour bound country EOP
# ---
# Predict: 	attacked ira place_lived EOP
# Ground-Truth: 	attacked ira place_lived EOP
# ---
# Predict: 	country a company EOP
# Ground-Truth: 	country a company EOP
# ---
# Predict: 	president court place_of_birth EOP
# Ground-Truth: 	president court country EOP
# ---
# Predict: 	insignificant statistically contains EOP
# Ground-Truth: 	insignificant statistically contains EOP
# ---
# Predict: 	chuck politician nationality EOP
# Ground-Truth: 	chuck politician nationality EOP
# ---
# Predict: 	by-100 freestyle country EOP lenton lenton lenton
# Ground-Truth: 	by-100 freestyle country EOP
# ---
# Predict: 	e-mail year-old company EOP
# Ground-Truth: 	e-mail year-old company EOP
# ---
# Predict: 	13 11 contains EOP
# Ground-Truth: 	13 11 contains EOP
# ---
# Predict: 	22 26 company EOP
# Ground-Truth: 	22 26 company EOP
# ---
# Predict: 	42 park company EOP staten staten staten
# Ground-Truth: 	42 park company EOP
# ---
# Predict: 	snowmass vail contains EOP
# Ground-Truth: 	snowmass vail contains EOP
# ---
# Predict: 	kenny effective contains EOP
# Ground-Truth: 	29 28 contains EOP
# ---
# Predict: 	incentive commercial contains EOP
# Ground-Truth: 	incentive commercial contains EOP
# ---
# Predict: 	14 15 country EOP
# Ground-Truth: 	14 15 country EOP
# ---
# Predict: 	chief officer place_lived EOP
# Ground-Truth: 	chief officer place_lived EOP
# ---
# Predict: 	2007 13 country EOP
# Ground-Truth: 	2007 13 country EOP
# ---
# Predict: 	25 18 country EOP france france france
# Ground-Truth: 	25 18 country EOP
# ---
# Predict: 	germany secretive place_of_birth EOP
# Ground-Truth: 	21 23 place_of_birth EOP
# ---
# Predict: 	resolution president nationality EOP
# Ground-Truth: 	resolution president nationality EOP
# ---
# Predict: 	jose spain nationality EOP
# Ground-Truth: 	jose spain nationality EOP
# ---
# Predict: 	20 a place_of_birth EOP a a a
# Ground-Truth: 	20 22 country EOP
# ---
# Predict: 	australian howard place_lived EOP
# Ground-Truth: 	australian howard place_lived EOP
# ---
# Predict: 	county d. contains EOP
# Ground-Truth: 	county d. contains EOP
# ---
# Predict: 	8 11 place_lived EOP
# Ground-Truth: 	8 11 place_lived EOP
# ---
# Predict: 	26 simultaneously country EOP
# Ground-Truth: 	26 simultaneously country EOP
# ---
# Predict: 	a 2005 company EOP
# Ground-Truth: 	a 2005 company EOP
# ---
# Predict: 	boston raised contains EOP
# Ground-Truth: 	boston raised contains EOP
# ---
# Predict: 	medium child contains EOP
# Ground-Truth: 	medium child contains EOP
# ---
# Predict: 	lesley university place_of_birth EOP
# Ground-Truth: 	lesley university country EOP
# ---
# Predict: 	team race contains EOP
# Ground-Truth: 	team race contains EOP
# ---
# Predict: 	rebuilt soda contains EOP
# Ground-Truth: 	rebuilt soda contains EOP
# ---
# Predict: 	led founder founders EOP
# Ground-Truth: 	led founder country EOP
# ---
# Predict: 	civilian target contains EOP
# Ground-Truth: 	civilian target contains EOP
# ---
# Predict: 	greenwich jefferson contains EOP
# Ground-Truth: 	greenwich jefferson contains EOP
# ---
# Predict: 	26 27 country EOP
# Ground-Truth: 	26 27 country EOP
# ---
# Predict: 	roberto literature company EOP
# Ground-Truth: 	roberto literature company EOP
# ---
# Predict: 	distinction garden contains EOP
# Ground-Truth: 	distinction garden contains EOP
# ---
# Predict: 	development country place_lived EOP vermont vermont vermont
# Ground-Truth: 	development country place_lived EOP
# ---
# Predict: 	16 15 contains EOP
# Ground-Truth: 	16 15 contains EOP
# ---
# Predict: 	isolated security contains EOP
# Ground-Truth: 	isolated security contains EOP
# ---
# Predict: 	a resident company EOP
# Ground-Truth: 	a resident company EOP
# ---
# Predict: 	march funeral contains EOP
# Ground-Truth: 	march funeral contains EOP
# ---
# Predict: 	15 consumer contains EOP
# Ground-Truth: 	15 consumer contains EOP
# ---
# Predict: 	nation blend country EOP
# Ground-Truth: 	nation blend country EOP
# ---
# Predict: 	rebuilding governor contains EOP
# Ground-Truth: 	rebuilding governor contains EOP
# ---
# Predict: 	organization knapp place_lived EOP
# Ground-Truth: 	organization knapp place_lived EOP
# ---
# Predict: 	iran 11 company EOP iran iran iran
# Ground-Truth: 	iran 11 company EOP
# ---
# Predict: 	13 15 place_lived EOP
# Ground-Truth: 	13 15 place_lived EOP
# ---
# Predict: 	drab hamlet nationality EOP includes includes includes
# Ground-Truth: 	drab hamlet nationality EOP
# ---
# Predict: 	acre dream nationality EOP
# Ground-Truth: 	acre dream nationality EOP
# ---
# Predict: 	india 18 contains EOP
# Ground-Truth: 	16 18 contains EOP
# ---
# Predict: 	game a contains EOP
# Ground-Truth: 	game a contains EOP
# ---
# Predict: 	predicted a place_of_birth EOP
# Ground-Truth: 	predicted a country EOP
# ---
# Predict: 	mount base contains EOP
# Ground-Truth: 	mount base contains EOP
# ---
# Predict: 	interest 19 place_of_birth EOP republican republican republican
# Ground-Truth: 	interest 19 country EOP
# ---
# Predict: 	bottom reservoir contains EOP
# Ground-Truth: 	bottom reservoir contains EOP
# ---
# Predict: 	lrb spain contains EOP
# Ground-Truth: 	lrb spain contains EOP
# ---
# Predict: 	rouge build place_lived EOP
# Ground-Truth: 	rouge build place_lived EOP
# ---
# Predict: 	corporation held contains EOP
# Ground-Truth: 	corporation held contains EOP
# ---
# Predict: 	lower-level a company EOP
# Ground-Truth: 	lower-level a company EOP
# ---
# Predict: 	role utmost country EOP
# Ground-Truth: 	role utmost country EOP
# ---
# Predict: 	20 21 contains EOP
# Ground-Truth: 	20 21 contains EOP
# ---
# Predict: 	iraq militia contains EOP
# Ground-Truth: 	iraq militia contains EOP
# ---
# Predict: 	vahradian a contains EOP
# Ground-Truth: 	vahradian a contains EOP
# ---
# Predict: 	california national place_of_birth EOP
# Ground-Truth: 	california national country EOP
# ---
# Predict: 	defendant 6 contains EOP
# Ground-Truth: 	defendant 6 contains EOP
# ---
# Predict: 	threat troop place_lived EOP 35 35 35
# Ground-Truth: 	threat troop place_lived EOP
# ---
# Predict: 	nava bordertown contains EOP
# Ground-Truth: 	nava bordertown contains EOP
# ---
# Predict: 	never-ending 20 country EOP
# Ground-Truth: 	never-ending 20 country EOP
# ---
# Predict: 	united murdering nationality EOP
# Ground-Truth: 	united murdering nationality EOP
# ---
# Predict: 	19 spain contains EOP
# Ground-Truth: 	19 spain contains EOP
# ---
# Predict: 	hagel chuck contains EOP
# Ground-Truth: 	hagel chuck contains EOP
# ---
# Predict: 	22 anytime contains EOP
# Ground-Truth: 	22 anytime contains EOP
# ---
# Predict: 	offering s.c. contains EOP
# Ground-Truth: 	offering s.c. contains EOP
# ---
# Predict: 	production wagoner contains EOP
# Ground-Truth: 	production wagoner contains EOP
# ---
# Predict: 	britain 30 contains EOP
# Ground-Truth: 	32 30 contains EOP
# ---
# Predict: 	24 programming place_of_birth EOP
# Ground-Truth: 	24 programming country EOP
# ---
# Predict: 	office a place_of_birth EOP
# Ground-Truth: 	office a country EOP
# ---
# Predict: 	whortleberry metaphorical company EOP spain spain spain
# Ground-Truth: 	whortleberry metaphorical company EOP
# ---
# Predict: 	grew somers nationality EOP
# Ground-Truth: 	grew somers nationality EOP
# ---
# Predict: 	wind spain place_lived EOP
# Ground-Truth: 	wind spain place_lived EOP
# ---
# Predict: 	attorney attorney nationality EOP
# Ground-Truth: 	attorney attorney nationality EOP
# ---
# Predict: 	martha a place_lived EOP 9 9 9
# Ground-Truth: 	martha a place_lived EOP
# ---
# Predict: 	park mile place_of_birth EOP
# Ground-Truth: 	park mile country EOP
# ---
# Predict: 	syria fighter administrative_divisions EOP
# Ground-Truth: 	syria fighter administrative_divisions EOP
# ---
# Predict: 	vintage scrap contains EOP
# Ground-Truth: 	vintage scrap contains EOP
# ---
# Predict: 	west result country EOP
# Ground-Truth: 	west result country EOP
# ---
# Predict: 	sex working contains EOP
# Ground-Truth: 	sex working contains EOP
# ---
# Predict: 	real manufacturer country EOP mexico mexico mexico
# Ground-Truth: 	real manufacturer country EOP
# ---
# Predict: 	league a country EOP
# Ground-Truth: 	league a country EOP
# ---
# Predict: 	21 museum contains EOP
# Ground-Truth: 	21 museum contains EOP
# ---
# Predict: 	7 8 place_of_birth EOP fletcher fletcher fletcher
# Ground-Truth: 	7 8 country EOP
# ---
# Predict: 	government extremist country EOP israel israel israel
# Ground-Truth: 	government extremist country EOP
# ---
# Predict: 	21 19 contains EOP
# Ground-Truth: 	21 19 contains EOP
# ---
# Predict: 	w. president contains EOP
# Ground-Truth: 	w. president contains EOP
# ---
# Predict: 	16 19 contains EOP
# Ground-Truth: 	16 19 contains EOP
# ---
# Predict: 	federal 000 contains EOP
# Ground-Truth: 	federal 000 contains EOP
# ---
# Predict: 	15 13 contains EOP
# Ground-Truth: 	15 13 contains EOP
# ---
# Predict: 	18 16 contains EOP
# Ground-Truth: 	18 16 contains EOP
# ---
# Predict: 	will work contains EOP
# Ground-Truth: 	will work contains EOP
# ---
# Predict: 	chicago 10 place_lived EOP
# Ground-Truth: 	chicago 10 place_lived EOP
# ---
# Predict: 	processor ingredient administrative_divisions EOP
# Ground-Truth: 	processor ingredient administrative_divisions EOP
# ---
# Predict: 	vali politician place_of_death EOP
# Ground-Truth: 	vali politician place_of_death EOP
# ---
# Predict: 	britain revolutionary contains EOP
# Ground-Truth: 	britain revolutionary contains EOP
# ---
# Predict: 	swimming port place_of_birth EOP
# Ground-Truth: 	swimming port country EOP
# ---
# Predict: 	name 1990 contains EOP
# Ground-Truth: 	name 1990 contains EOP
# ---
# Predict: 	memorial will nationality EOP
# Ground-Truth: 	memorial will nationality EOP
# ---
# Predict: 	vienna 16 company EOP
# Ground-Truth: 	vienna 16 company EOP
# ---
# Predict: 	will curator contains EOP
# Ground-Truth: 	will curator contains EOP
# ---
# Predict: 	denied academy contains EOP
# Ground-Truth: 	denied academy contains EOP
# ---
# Predict: 	17 15 contains EOP
# Ground-Truth: 	17 15 contains EOP
# ---
# Predict: 	executive chad founders EOP
# Ground-Truth: 	executive chad country EOP
# ---
# Predict: 	michoacan hometown place_of_birth EOP
# Ground-Truth: 	michoacan hometown country EOP
# ---
# Predict: 	21 pro nationality EOP
# Ground-Truth: 	21 pro nationality EOP
# ---
# Predict: 	north-central mountain contains EOP
# Ground-Truth: 	north-central mountain contains EOP
# ---
# Predict: 	15 17 place_lived EOP
# Ground-Truth: 	15 17 place_lived EOP
# ---
# Predict: 	enlarged fall neighborhood_of EOP
# Ground-Truth: 	enlarged fall country EOP
# ---
# Predict: 	india state country EOP northern northern northern
# Ground-Truth: 	india state country EOP
# ---
# Predict: 	time advertising company EOP sport-fishing sport-fishing sport-fishing
# Ground-Truth: 	time advertising company EOP
# ---
# Predict: 	boston shopping contains EOP
# Ground-Truth: 	boston shopping contains EOP
# ---
# Predict: 	a. group company EOP
# Ground-Truth: 	a. group company EOP
# ---
# Predict: 	9 minister contains EOP
# Ground-Truth: 	9 minister contains EOP
# ---
# Predict: 	14 21 administrative_divisions EOP
# Ground-Truth: 	14 21 administrative_divisions EOP
# ---
# Predict: 	westchester mamaroneck contains EOP
# Ground-Truth: 	westchester mamaroneck contains EOP
# ---
# Predict: 	abc stephanopoulos place_of_birth EOP
# Ground-Truth: 	abc stephanopoulos country EOP
# ---
# Predict: 	joined mcconnell place_lived EOP
# Ground-Truth: 	joined mcconnell place_lived EOP
# ---
# Predict: 	border result country EOP led led led
# Ground-Truth: 	border result country EOP
# ---
# Predict: 	a xwb contains EOP
# Ground-Truth: 	a xwb contains EOP
# ---
# Predict: 	bay banned place_of_death EOP
# Ground-Truth: 	bay banned place_of_death EOP
# ---
# Predict: 	african walt contains EOP
# Ground-Truth: 	african walt contains EOP
# ---
# Predict: 	31 24 country EOP
# Ground-Truth: 	31 24 country EOP
# ---
# Predict: 	italy brazil contains EOP
# Ground-Truth: 	italy brazil contains EOP
# ---
# Predict: 	competed win company EOP
# Ground-Truth: 	competed win company EOP
# ---
# Predict: 	county harris contains EOP
# Ground-Truth: 	county harris contains EOP
# ---
# Predict: 	time member place_lived EOP
# Ground-Truth: 	time member place_lived EOP
# ---
# Predict: 	subsidiary mich country EOP
# Ground-Truth: 	subsidiary mich country EOP
# ---
# Predict: 	12 13 founders EOP
# Ground-Truth: 	12 13 country EOP
# ---
# Predict: 	12 11 contains EOP
# Ground-Truth: 	12 11 contains EOP
# ---
# Predict: 	ambitious year contains EOP
# Ground-Truth: 	ambitious year contains EOP
# ---
# Predict: 	malcom eli contains EOP
# Ground-Truth: 	malcom eli contains EOP
# ---
# Predict: 	27 23 capital EOP
# Ground-Truth: 	27 23 founders EOP
# ---
# Predict: 	21 17 contains EOP
# Ground-Truth: 	21 17 contains EOP
# ---
# Predict: 	awkward berlin country EOP
# Ground-Truth: 	awkward berlin country EOP
# ---
# Predict: 	18 30 place_of_birth EOP
# Ground-Truth: 	18 30 country EOP
# ---
# Predict: 	college 50 contains EOP
# Ground-Truth: 	college 50 contains EOP
# ---
# Predict: 	included statement contains EOP
# Ground-Truth: 	included statement contains EOP
# ---
# Predict: 	plant indiana place_lived EOP
# Ground-Truth: 	plant indiana place_lived EOP
# ---
# Predict: 	tim three place_of_birth EOP
# Ground-Truth: 	tim three country EOP
# ---
# Predict: 	island terry contains EOP jersey jersey jersey
# Ground-Truth: 	island terry contains EOP
# ---
# Predict: 	defeat lebanon country EOP experience experience experience
# Ground-Truth: 	defeat lebanon country EOP
# ---
# Predict: 	school choice contains EOP 32 32 32
# Ground-Truth: 	school choice contains EOP
# ---
# Predict: 	a medalist neighborhood_of EOP princeton princeton princeton
# Ground-Truth: 	a medalist neighborhood_of EOP
# ---
# Predict: 	20 25 place_of_birth EOP
# Ground-Truth: 	20 25 country EOP
# ---
# Predict: 	holocaust engineering contains EOP
# Ground-Truth: 	holocaust engineering contains EOP
# ---
# Predict: 	talk firm company EOP
# Ground-Truth: 	talk firm company EOP
# ---
# Predict: 	bank west contains EOP
# Ground-Truth: 	bank west contains EOP
# ---
# Predict: 	shrinking east place_lived EOP
# Ground-Truth: 	shrinking east place_lived EOP
# ---
# Predict: 	november a place_lived EOP washington washington washington
# Ground-Truth: 	november a place_lived EOP
# ---
# Predict: 	22 24 place_lived EOP
# Ground-Truth: 	22 24 place_lived EOP
# ---
# Predict: 	11 search country EOP india india india
# Ground-Truth: 	16 search country EOP
# ---
# Predict: 	gordon 17 contains EOP
# Ground-Truth: 	gordon 17 contains EOP
# ---
# Predict: 	herzstein jewish place_lived EOP
# Ground-Truth: 	herzstein jewish place_lived EOP
# ---
# Predict: 	olmert minister contains EOP
# Ground-Truth: 	olmert minister contains EOP
# ---
# Predict: 	19 21 place_lived EOP
# Ground-Truth: 	19 21 place_lived EOP
# ---
# Predict: 	15 17 contains EOP
# Ground-Truth: 	15 17 contains EOP
# ---
# Predict: 	a museum place_lived EOP
# Ground-Truth: 	a museum place_lived EOP
# ---
# Predict: 	decision a country EOP
# Ground-Truth: 	decision a country EOP
# ---
# Predict: 	mcconnell senate place_of_birth EOP kentucky kentucky kentucky
# Ground-Truth: 	mcconnell senate country EOP
# ---
# Predict: 	mystique draw country EOP
# Ground-Truth: 	mystique draw country EOP
# ---
# Predict: 	dovetailed veteran contains EOP
# Ground-Truth: 	dovetailed veteran contains EOP
# ---
# Predict: 	voice cry country rrb
# Ground-Truth: 	voice cry country rrb
# ---
# Predict: 	buyer 1946 place_of_birth EOP peck peck peck
# Ground-Truth: 	buyer 1946 country EOP
# ---
# Predict: 	1977 a place_of_birth EOP
# Ground-Truth: 	1977 a country EOP
# ---
# Predict: 	height knorr place_of_death EOP wilton wilton wilton
# Ground-Truth: 	55 EOP country EOP
# ---
# Predict: 	15 13 contains EOP
# Ground-Truth: 	15 13 contains EOP
# ---
# Predict: 	lrb headquarters country EOP india india india
# Ground-Truth: 	lrb named country EOP
# ---
# Predict: 	hunter rep contains EOP tancredo tancredo tancredo
# Ground-Truth: 	hunter rep contains EOP
# ---
# Predict: 	automobile industry nationality EOP
# Ground-Truth: 	automobile industry nationality EOP
# ---
# Predict: 	patrick laid-back country EOP
# Ground-Truth: 	patrick laid-back country EOP
# ---
# Predict: 	mediterranean 11 contains EOP
# Ground-Truth: 	mediterranean 11 contains EOP
# ---
# Predict: 	news capital nationality EOP
# Ground-Truth: 	news capital nationality EOP
# ---
# Predict: 	france paris contains EOP
# Ground-Truth: 	france paris contains EOP
# ---
# Predict: 	jonathan andrew contains EOP
# Ground-Truth: 	jonathan andrew contains EOP
# ---
# Predict: 	17 chicago nationality EOP
# Ground-Truth: 	17 chicago nationality EOP
# ---
# Predict: 	magisterial 24 country EOP
# Ground-Truth: 	magisterial 24 country EOP
# ---
# Predict: 	fossil century contains EOP
# Ground-Truth: 	fossil century contains EOP
# ---
# Predict: 	andrew 1944 contains EOP
# Ground-Truth: 	andrew 1944 contains EOP
# ---
# Predict: 	music bridegroom contains EOP
# Ground-Truth: 	music bridegroom contains EOP
# ---
# Predict: 	kofmehl kofmehl contains EOP
# Ground-Truth: 	kofmehl kofmehl contains EOP
# ---
# Predict: 	israel mourn country EOP
# Ground-Truth: 	israel mourn country EOP
# ---
# Predict: 	a 20 country EOP
# Ground-Truth: 	a 20 country EOP
# ---
# Predict: 	20 16 contains EOP germany germany germany
# Ground-Truth: 	20 16 contains EOP
# ---
# Predict: 	assisted israel nationality EOP
# Ground-Truth: 	assisted israel nationality EOP
# ---
# Predict: 	tehran cooperation contains EOP
# Ground-Truth: 	tehran cooperation contains EOP
# ---
# Predict: 	production lady country EOP
# Ground-Truth: 	production lady country EOP
# ---
# Predict: 	met dalia place_lived EOP
# Ground-Truth: 	met dalia place_lived EOP
# ---
# Predict: 	official popular contains EOP
# Ground-Truth: 	official popular contains EOP
# ---
# Predict: 	22 carve nationality EOP
# Ground-Truth: 	22 carve nationality EOP
# ---
# Predict: 	conference sighting contains EOP
# Ground-Truth: 	conference sighting contains EOP
# ---
# Predict: 	rrb fry place_of_birth EOP
# Ground-Truth: 	rrb fry country EOP
# ---
# Predict: 	19 21 capital EOP
# Ground-Truth: 	19 21 founders EOP
# ---
# Predict: 	trained early nationality EOP house house house
# Ground-Truth: 	trained early nationality EOP
# ---
# Predict: 	pentagon iraq place_of_birth EOP
# Ground-Truth: 	pentagon iraq country EOP
# ---
# Predict: 	israel envoy contains EOP
# Ground-Truth: 	israel envoy contains EOP
# ---
# Predict: 	14 12 contains EOP
# Ground-Truth: 	14 12 contains EOP
# ---
# Predict: 	corp evaluating contains EOP
# Ground-Truth: 	corp evaluating contains EOP
# ---
# Predict: 	face 12 company EOP
# Ground-Truth: 	face 12 company EOP
# ---
# Predict: 	telepan york contains EOP
# Ground-Truth: 	telepan york contains EOP
# ---
# Predict: 	fla tampa contains EOP
# Ground-Truth: 	fla tampa contains EOP
# ---
# Predict: 	r. jr place_lived EOP
# Ground-Truth: 	r. jr place_lived EOP
# ---
# Predict: 	general massachusetts contains EOP
# Ground-Truth: 	general massachusetts contains EOP
# ---
# Predict: 	lower russia country EOP
# Ground-Truth: 	lower russia country EOP
# ---
# Predict: 	hyderabad globally contains EOP
# Ground-Truth: 	hyderabad globally contains EOP
# ---
# Predict: 	signed iraq contains EOP
# Ground-Truth: 	signed iraq contains EOP
# ---
# Predict: 	senator finger place_of_birth EOP
# Ground-Truth: 	senator finger country EOP
# ---
# Predict: 	manufactured preternaturally place_lived EOP
# Ground-Truth: 	manufactured preternaturally place_lived EOP
# ---
# Predict: 	unleashed a company EOP
# Ground-Truth: 	unleashed a company EOP
# ---
# Predict: 	17 rochus country EOP australia australia australia
# Ground-Truth: 	17 rochus country EOP
# ---
# Predict: 	black 15 place_of_birth EOP
# Ground-Truth: 	black 15 country EOP
# ---
# Predict: 	nelson nebraska nationality EOP
# Ground-Truth: 	nelson nebraska nationality EOP
# ---
# Predict: 	chhattisgarh zone contains EOP
# Ground-Truth: 	chhattisgarh zone contains EOP
# ---
# Predict: 	goalie 25 company EOP
# Ground-Truth: 	goalie 25 company EOP
# ---
# Predict: 	chairman head company EOP
# Ground-Truth: 	chairman head company EOP
# ---
# Predict: 	house italy country EOP
# Ground-Truth: 	house italy country EOP
# ---
# Predict: 	point calderon place_lived EOP
# Ground-Truth: 	point calderon place_lived EOP
# ---
# Predict: 	florida raton contains EOP
# Ground-Truth: 	florida raton contains EOP
# ---
# Predict: 	debate senate contains EOP
# Ground-Truth: 	debate senate contains EOP
# ---
# Predict: 	chulanont thursday place_lived EOP
# Ground-Truth: 	chulanont thursday place_lived EOP
# ---
# Predict: 	12 14 country EOP
# Ground-Truth: 	12 14 country EOP
# ---
# Predict: 	electric chief contains EOP
# Ground-Truth: 	electric chief contains EOP
# ---
# Predict: 	22 9 country EOP uyo uyo uyo
# Ground-Truth: 	22 9 country EOP
# ---
# Predict: 	book companion contains EOP montclair montclair montclair
# Ground-Truth: 	book companion contains EOP
# ---
# Predict: 	16 30 place_of_birth EOP
# Ground-Truth: 	48 30 country EOP
# ---
# Predict: 	grant a nationality EOP
# Ground-Truth: 	grant a nationality EOP
# ---
# Predict: 	despite session company EOP kentucky kentucky kentucky
# Ground-Truth: 	despite session company EOP
# ---
# Predict: 	pradesh central country EOP
# Ground-Truth: 	pradesh central country EOP
# ---
# Predict: 	yearly post contains EOP
# Ground-Truth: 	yearly post contains EOP
# ---
# Predict: 	built israel contains EOP
# Ground-Truth: 	built israel contains EOP
# ---
# Predict: 	tax shorn capital EOP hamas hamas hamas
# Ground-Truth: 	tax shorn capital EOP
# ---
# Predict: 	18 16 contains EOP
# Ground-Truth: 	38 32 contains EOP
# ---
# Predict: 	23 21 contains EOP
# Ground-Truth: 	23 21 contains EOP
# ---
# Predict: 	chief discussion company EOP
# Ground-Truth: 	chief discussion company EOP
# ---
# Predict: 	job lined place_of_death EOP river river river
# Ground-Truth: 	job lined country EOP
# ---
# Predict: 	demolition urgently place_lived EOP
# Ground-Truth: 	demolition urgently place_lived EOP
# ---
# Predict: 	senator republican contains EOP
# Ground-Truth: 	senator republican contains EOP
# ---
# Predict: 	inside escape company EOP
# Ground-Truth: 	inside escape company EOP
# ---
# Predict: 	saturday dodge contains EOP
# Ground-Truth: 	saturday dodge contains EOP
# ---
# Predict: 	21 25 children EOP
# Ground-Truth: 	21 25 children EOP
# ---
# Predict: 	cancer lung contains EOP
# Ground-Truth: 	cancer lung contains EOP
# ---
# Predict: 	criticized senator place_of_birth EOP
# Ground-Truth: 	criticized senator country EOP
# ---
# Predict: 	radiologist a contains EOP
# Ground-Truth: 	radiologist a contains EOP
# ---
# Predict: 	boat a contains EOP
# Ground-Truth: 	boat a contains EOP
# ---
# Predict: 	13 beautiful country EOP gazing gazing gazing
# Ground-Truth: 	13 beautiful country EOP
# ---
# Predict: 	nuclear iran contains EOP
# Ground-Truth: 	nuclear iran contains EOP
# ---
# Predict: 	pennsylvania delaware place_of_birth EOP
# Ground-Truth: 	pennsylvania delaware country EOP
# ---
# Predict: 	15 16 place_of_birth EOP
# Ground-Truth: 	15 16 country EOP
# ---
# Predict: 	coney street contains EOP
# Ground-Truth: 	coney street contains EOP
# ---
# Predict: 	second-largest member nationality EOP
# Ground-Truth: 	second-largest member nationality EOP
# ---
# Predict: 	june mexico contains EOP
# Ground-Truth: 	june mexico contains EOP
# ---
# Predict: 	j. nita contains EOP
# Ground-Truth: 	j. nita contains EOP
# ---
# Predict: 	19 singapore country EOP france france france
# Ground-Truth: 	19 singapore country EOP
# ---
# Predict: 	a undergone contains EOP
# Ground-Truth: 	a undergone contains EOP
# ---
# Predict: 	worth april contains EOP
# Ground-Truth: 	worth april contains EOP
# ---
# Predict: 	massive class contains iran
# Ground-Truth: 	massive class contains iran
# ---
# Predict: 	receive production nationality EOP
# Ground-Truth: 	receive production nationality EOP
# ---
# Predict: 	11 13 nationality EOP joy joy joy
# Ground-Truth: 	11 13 nationality EOP
# ---
# Predict: 	university 13 place_of_birth EOP iowa iowa iowa
# Ground-Truth: 	university 13 country EOP
# ---
# Predict: 	member 50 company EOP
# Ground-Truth: 	member 50 company EOP
# ---
# Predict: 	won currently contains EOP
# Ground-Truth: 	won currently contains EOP
# ---
# Predict: 	30 amansala country EOP
# Ground-Truth: 	30 amansala country EOP
# ---
# Predict: 	opening yesterday contains EOP
# Ground-Truth: 	opening yesterday contains EOP
# ---
# Predict: 	school bed country EOP
# Ground-Truth: 	school bed country EOP
# ---
# Predict: 	m country company EOP
# Ground-Truth: 	m country company EOP
# ---
# Predict: 	12 14 founders EOP
# Ground-Truth: 	12 14 country EOP
# ---
# Predict: 	aspen operates contains EOP
# Ground-Truth: 	aspen operates contains EOP
# ---
# Predict: 	white april company EOP
# Ground-Truth: 	white april company EOP
# ---
# Predict: 	building power contains EOP
# Ground-Truth: 	building power contains EOP
# ---
# Predict: 	senator warner contains EOP
# Ground-Truth: 	senator warner contains EOP
# ---
# Predict: 	work fire contains EOP
# Ground-Truth: 	work fire contains EOP
# ---
# Predict: 	kentucky va contains EOP
# Ground-Truth: 	kentucky va contains EOP
# ---
# Predict: 	held status contains EOP
# Ground-Truth: 	held status contains EOP
# ---
# Predict: 	25 published administrative_divisions EOP
# Ground-Truth: 	25 28 company EOP
# ---
# Predict: 	president harvard contains EOP
# Ground-Truth: 	president harvard contains EOP
# ---
# Predict: 	rebuffed syria contains EOP
# Ground-Truth: 	rebuffed syria contains EOP
# ---
# Predict: 	11 india contains EOP
# Ground-Truth: 	11 india contains EOP
# ---
# Predict: 	24 19 contains EOP
# Ground-Truth: 	24 19 contains EOP
# ---
# Predict: 	kerem shalom country EOP
# Ground-Truth: 	kerem shalom country EOP
# ---
# Predict: 	universal shortly place_of_birth EOP henry henry henry
# Ground-Truth: 	universal shortly country EOP
# ---
# Predict: 	change faction country EOP
# Ground-Truth: 	change faction country EOP
# ---
# Predict: 	58 official company EOP
# Ground-Truth: 	58 official company EOP
# ---
# Predict: 	70 includes contains EOP
# Ground-Truth: 	70 includes contains EOP
# ---
# Predict: 	13 iran contains EOP
# Ground-Truth: 	13 iran contains EOP
# ---
# Predict: 	21 recess contains EOP
# Ground-Truth: 	21 recess contains EOP
# ---
# Predict: 	14 12 contains EOP
# Ground-Truth: 	14 12 contains EOP
# ---
# Predict: 	16 year contains EOP
# Ground-Truth: 	16 year contains EOP
# ---
# Predict: 	grant history contains EOP
# Ground-Truth: 	grant history contains EOP
# ---
# Predict: 	spain italy country EOP
# Ground-Truth: 	spain italy country EOP
# ---
# Predict: 	carbon nitrogen company EOP
# Ground-Truth: 	carbon nitrogen company EOP
# ---
# Predict: 	27 25 contains EOP
# Ground-Truth: 	27 25 contains EOP
# ---
# Predict: 	white appears place_lived EOP 26 26 26
# Ground-Truth: 	white appears place_lived EOP
# ---
# Predict: 	gaza palestinian contains EOP
# Ground-Truth: 	gaza palestinian contains EOP
# ---
# Predict: 	hurricane response place_of_birth EOP
# Ground-Truth: 	hurricane response country EOP
# ---
# Predict: 	kingston queen contains EOP
# Ground-Truth: 	kingston queen contains EOP
# ---
# Predict: 	audition week contains EOP
# Ground-Truth: 	audition week contains EOP
# ---
# Predict: 	chief hurley contains EOP
# Ground-Truth: 	chief hurley contains EOP
# ---
# Predict: 	england recruitment contains EOP
# Ground-Truth: 	england recruitment contains EOP
# ---
# Predict: 	14 15 capital EOP
# Ground-Truth: 	14 15 capital EOP
# ---
# Predict: 	completed bridge contains EOP
# Ground-Truth: 	completed bridge contains EOP
# ---
# Predict: 	21 19 contains EOP
# Ground-Truth: 	21 19 contains EOP
# ---
# Predict: 	berlin 16 country EOP
# Ground-Truth: 	63 43 country EOP
# ---
# Predict: 	a arraignment contains EOP
# Ground-Truth: 	a arraignment contains EOP
# ---
# Predict: 	1932 graduated company EOP
# Ground-Truth: 	1932 graduated company EOP
# ---
# Predict: 	hamas border contains EOP
# Ground-Truth: 	hamas border contains EOP
# ---
# Predict: 	25 23 contains EOP
# Ground-Truth: 	25 23 contains EOP
# ---
# Predict: 	at&t bellsouth place_of_birth EOP
# Ground-Truth: 	at&t bellsouth country EOP
# ---
# Predict: 	ibrahim a place_lived EOP
# Ground-Truth: 	ibrahim a place_lived EOP
# ---
# Predict: 	alternative breaking company EOP
# Ground-Truth: 	alternative breaking company EOP
# ---
# Predict: 	leahy vermont place_of_birth EOP vermont vermont vermont
# Ground-Truth: 	leahy vermont country EOP
# ---
# Predict: 	story referring contains EOP
# Ground-Truth: 	story referring contains EOP
# ---
# Predict: 	26 clinic contains EOP
# Ground-Truth: 	26 clinic contains EOP
# ---
# Predict: 	20 19 contains EOP
# Ground-Truth: 	20 19 contains EOP
# ---
# Predict: 	tuesday middle contains EOP
# Ground-Truth: 	tuesday middle contains EOP
# ---
# Predict: 	23 intern contains EOP
# Ground-Truth: 	23 intern contains EOP
# ---
# Predict: 	reported harrelson place_of_birth EOP
# Ground-Truth: 	reported yesterday country EOP
# ---
# Predict: 	senior rice contains EOP
# Ground-Truth: 	senior rice contains EOP
# ---
# Predict: 	williams west country EOP
# Ground-Truth: 	williams west country EOP
# ---
# Predict: 	foreign deputy country EOP
# Ground-Truth: 	foreign deputy country EOP
# ---
# Predict: 	162 14 contains EOP
# Ground-Truth: 	162 14 contains EOP
# ---
# Predict: 	reyes brown nationality EOP
# Ground-Truth: 	reyes brown nationality EOP
# ---
# Predict: 	american including contains EOP
# Ground-Truth: 	american including contains EOP
# ---
# Predict: 	warner nebraska contains EOP
# Ground-Truth: 	warner nebraska contains EOP
# ---
# Predict: 	official plane contains EOP
# Ground-Truth: 	official plane contains EOP
# ---
# Predict: 	11 13 place_lived EOP bay bay bay
# Ground-Truth: 	11 13 place_lived EOP
# ---
# Predict: 	burned building contains EOP
# Ground-Truth: 	burned building contains EOP
# ---
# Predict: 	california statewide company EOP
# Ground-Truth: 	california statewide company EOP
# ---
# Predict: 	spain region contains EOP
# Ground-Truth: 	spain region contains EOP
# ---
# Predict: 	display collection country EOP
# Ground-Truth: 	display collection country EOP
# ---
# Predict: 	10 9 contains EOP
# Ground-Truth: 	10 9 contains EOP
# ---
# Predict: 	13 11 contains EOP
# Ground-Truth: 	13 11 contains EOP
# ---
# Predict: 	planned office contains EOP
# Ground-Truth: 	planned office contains EOP
# ---
# Predict: 	22 20 contains EOP
# Ground-Truth: 	22 20 contains EOP
# ---
# Predict: 	kwame a place_of_birth EOP
# Ground-Truth: 	29 a country EOP
# ---
# Predict: 	12 16 country EOP
# Ground-Truth: 	12 16 country EOP
# ---
# Predict: 	a kline contains EOP
# Ground-Truth: 	a kline contains EOP
# ---
# Predict: 	department relation contains EOP
# Ground-Truth: 	department relation contains EOP
# ---
# Predict: 	restaurant villain place_of_death EOP night villain place_of_birth EOP
# Ground-Truth: 	restaurant villain country EOP night villain country EOP
# ---
# Predict: 	washington moscow country EOP
# Ground-Truth: 	washington moscow country EOP
# ---
# Predict: 	hick staff place_lived EOP
# Ground-Truth: 	hick staff place_lived EOP
# ---
# Predict: 	service late place_lived EOP delhi delhi delhi
# Ground-Truth: 	service late place_lived EOP
# ---
# Predict: 	bonderman david contains EOP
# Ground-Truth: 	bonderman david contains EOP
# ---
# Predict: 	son brignone contains EOP
# Ground-Truth: 	son brignone contains EOP
# ---
# Predict: 	decade teddy nationality EOP
# Ground-Truth: 	decade teddy nationality EOP
# ---
# Predict: 	arab joined contains EOP
# Ground-Truth: 	arab joined contains EOP
# ---
# Predict: 	republican sonny place_of_birth EOP
# Ground-Truth: 	republican sonny country EOP
# ---
# Predict: 	punjab kansa contains EOP
# Ground-Truth: 	punjab kansa contains EOP
# ---
# Predict: 	united czech place_lived EOP iran iran iran
# Ground-Truth: 	united czech place_lived EOP
# ---
# Predict: 	reading france contains EOP
# Ground-Truth: 	reading france contains EOP
# ---
# Predict: 	june included place_of_birth EOP
# Ground-Truth: 	june included country EOP
# ---
# Predict: 	dozen article contains EOP
# Ground-Truth: 	dozen article contains EOP
# ---
# Predict: 	airport 18 company EOP
# Ground-Truth: 	airport 18 company EOP
# ---
# Predict: 	prosecutor betrayed nationality EOP
# Ground-Truth: 	prosecutor betrayed nationality EOP
# ---
# Predict: 	zusak united capital EOP
# Ground-Truth: 	zusak united children EOP
# ---
# Predict: 	ayelet writer contains EOP
# Ground-Truth: 	ayelet writer contains EOP
# ---
# Predict: 	17 14 contains EOP
# Ground-Truth: 	17 14 contains EOP
# ---
# Predict: 	minister mahmoud company EOP
# Ground-Truth: 	minister mahmoud company EOP
# ---
# Predict: 	member committee contains EOP
# Ground-Truth: 	member committee contains EOP
# ---
# Predict: 	active united place_lived EOP
# Ground-Truth: 	active united place_lived EOP
# ---
# Predict: 	a captured place_lived EOP cuba cuba cuba
# Ground-Truth: 	a captured place_lived EOP
# ---

# %%
t_sentWords[7]
# Out:
# ['9',
#  'police',
#  'called',
#  'a',
#  'bloody',
#  'crime',
#  'scene',
#  'chicago',
#  'west',
#  'side']

# %% [markdown]
# # Play

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_1/cp_logs/weights.062-0.216543.hdf5'
model.load_weights(filename)

result = np.argmax(model.predict([x_test, a], batch_size=BATCH_SIZE, verbose=1), -1)
# Out:
# 395/395 [==============================] - 7s

# %%
a = np.zeros((395, 8))

# %%
tf_test
# Out:
# array([[77,  5,  6, ...,  0,  0,  0],
#        [77,  9,  8, ...,  0,  0,  0],
#        [77,  8, 10, ...,  0,  0,  0],
#        ...,
#        [77,  3,  2, ...,  0,  0,  0],
#        [77,  2,  4, ...,  0,  0,  0],
#        [77,  1,  4, ...,  0,  0,  0]], dtype=int32)

# %%
result[:10]
# Out:
# array([[34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34],
#        [34, 34, 34, 34, 34, 34, 34, 34]])

# %%
def keras_rnn_predict(samples, empty=empty, model=model, maxlen=maxlen):
    """
    supply RNN model and maxlen(the length of sequences it can handle)
    for every sample, calculate probability for every possible label
    """
    sample_lengths = map(len, samples)
    # pad from right(post) so the first c_maxlen will be content followed by title
    data = sequence.pad_sequences(samples, maxlen=maxlen, value=empty, padding='post', truncating='post')
    probs = model.predict(data, verbose=0, batch_size=batch_size)
    return np.array([prob[sample_length-c_maxlen-1] for prob, sample_length in zip(probs, sample_lengths)]) # []x40000

# %%
def keras_rnn_predict(samples, empty=empty, model=model, maxlen=maxlen):
    """
    supply RNN model and maxlen(the length of sequences it can handle)
    for every sample, calculate probability for every possible label
    """
    sample_lengths = map(len, samples)
    # pad from right(post) so the first c_maxlen will be content followed by title
    data = sequence.pad_sequences(samples, maxlen=maxlen, value=empty, padding='post', truncating='post')
    probs = model.predict(data, verbose=0, batch_size=batch_size)
    return np.array([prob[sample_length-c_maxlen-1] for prob, sample_length in zip(probs, sample_lengths)]) # []x40000
