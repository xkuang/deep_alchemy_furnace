# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></div><div class="lev2 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load Data</a></div><div class="lev3 toc-item"><a href="#Load-Train-Data" data-toc-modified-id="Load-Train-Data-111"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Load Train Data</a></div><div class="lev3 toc-item"><a href="#Load-Test-Data" data-toc-modified-id="Load-Test-Data-112"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Load Test Data</a></div><div class="lev3 toc-item"><a href="#Relation-Types" data-toc-modified-id="Relation-Types-113"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Relation Types</a></div><div class="lev2 toc-item"><a href="#Participle" data-toc-modified-id="Participle-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Participle</a></div><div class="lev2 toc-item"><a href="#Make-Adjacency-List" data-toc-modified-id="Make-Adjacency-List-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Make Adjacency List</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Train-Data" data-toc-modified-id="Make-Adjacency-List-of-Train-Data-131"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Make Adjacency List of Train Data</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Test-Data" data-toc-modified-id="Make-Adjacency-List-of-Test-Data-132"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Make Adjacency List of Test Data</a></div><div class="lev1 toc-item"><a href="#Word-to-Vector" data-toc-modified-id="Word-to-Vector-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Word to Vector</a></div><div class="lev2 toc-item"><a href="#Tokenize-Text" data-toc-modified-id="Tokenize-Text-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Tokenize Text</a></div><div class="lev2 toc-item"><a href="#Create-Word-Embeddings-with-GloVe" data-toc-modified-id="Create-Word-Embeddings-with-GloVe-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Create Word Embeddings with GloVe</a></div><div class="lev3 toc-item"><a href="#Read-GloVe" data-toc-modified-id="Read-GloVe-221"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Read GloVe</a></div><div class="lev3 toc-item"><a href="#Use-Glove-to-Initialize-Embedding-Matrix" data-toc-modified-id="Use-Glove-to-Initialize-Embedding-Matrix-222"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Use Glove to Initialize Embedding Matrix</a></div><div class="lev1 toc-item"><a href="#Build-Dateset" data-toc-modified-id="Build-Dateset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Build Dateset</a></div><div class="lev1 toc-item"><a href="#Save-Dataset" data-toc-modified-id="Save-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Save Dataset</a></div><div class="lev1 toc-item"><a href="#Checkpoint" data-toc-modified-id="Checkpoint-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Checkpoint</a></div><div class="lev1 toc-item"><a href="#Build-Model" data-toc-modified-id="Build-Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Build Model</a></div><div class="lev2 toc-item"><a href="#Set-Hyperparameters" data-toc-modified-id="Set-Hyperparameters-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Set Hyperparameters</a></div><div class="lev2 toc-item"><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Import Libraries</a></div><div class="lev2 toc-item"><a href="#Build-Graph" data-toc-modified-id="Build-Graph-63"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Build Graph</a></div><div class="lev2 toc-item"><a href="#Model-Visualization" data-toc-modified-id="Model-Visualization-64"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Model Visualization</a></div><div class="lev2 toc-item"><a href="#Train" data-toc-modified-id="Train-65"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Train</a></div><div class="lev1 toc-item"><a href="#Evaluate" data-toc-modified-id="Evaluate-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Evaluate</a></div><div class="lev2 toc-item"><a href="#Naive-Evaluate" data-toc-modified-id="Naive-Evaluate-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Naive Evaluate</a></div><div class="lev2 toc-item"><a href="#Beam-Search-Evaluate" data-toc-modified-id="Beam-Search-Evaluate-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Beam Search Evaluate</a></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Load Train Data

# %%
import json

# %%
sentText = []
relationMentions = []
relationLabels = []
entityMentions = []
entityLabels = []
em1Text = []
em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/train.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    # Exclude "None" label
    if not all(i['label'] == 'None' for i in item['relationMentions']):
        sentText.append(item['sentText'])
        relationMentions.append(item['relationMentions'])
        entityMentions.append(item['entityMentions'])
    
relationLabels = [[i['label'] for i in rM] for rM in relationMentions]
entityLabels = [[i['text'] for i in eM] for eM in entityMentions]
em1Text = [[i['em1Text'] for i in rM] for rM in relationMentions]
em2Text = [[i['em2Text'] for i in rM] for rM in relationMentions]

# %%
# Clean words
replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
em1Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em1Text]
em2Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em2Text]

# %% [markdown]
# ### Load Test Data

# %%
t_sentText = []
t_relationMentions = []
t_relationLabels = []
t_entityMentions = []
t_entityLabels = []
t_em1Text = []
t_em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/test.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    t_sentText.append(item['sentText'])
    t_relationMentions.append(item['relationMentions'])
    t_entityMentions.append(item['entityMentions'])
    
t_relationLabels = [[i['label'] for i in rM] for rM in t_relationMentions]
t_entityLabels = [[i['text'] for i in eM] for eM in t_entityMentions]
t_em1Text = [[i['em1Text'] for i in rM] for rM in t_relationMentions]
t_em2Text = [[i['em2Text'] for i in rM] for rM in t_relationMentions]

# %%
# Clean words
t_replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
t_em1Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em1Text]
t_em2Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em2Text]
t_entityLabels = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_entityLabels]

# %% [markdown]
# ###  Relation Types

# %%
relationTypes = list(set([r for rl in relationLabels for r in rl]))
relationTypes
# Out:
# ['/people/person/nationality',
#  '/people/person/place_lived',
#  '/people/person/ethnicity',
#  '/sports/sports_team/location',
#  '/location/neighborhood/neighborhood_of',
#  '/location/country/capital',
#  '/location/administrative_division/country',
#  '/business/person/company',
#  '/people/person/children',
#  '/location/location/contains',
#  '/business/company/place_founded',
#  '/people/ethnicity/people',
#  '/people/deceased_person/place_of_death',
#  '/people/person/profession',
#  '/location/country/administrative_divisions',
#  '/people/ethnicity/geographic_distribution',
#  '/business/company/founders',
#  '/business/company/industry',
#  '/people/person/place_of_birth',
#  '/business/company_shareholder/major_shareholder_of',
#  '/business/company/major_shareholders',
#  '/business/company/advisors',
#  '/sports/sports_team_location/teams',
#  '/people/person/religion']

# %%
t_relationTypes = list(set([r for rl in t_relationLabels for r in rl if r != 'None']))
t_relationTypes
# Out:
# ['/people/person/nationality',
#  '/people/person/place_of_birth',
#  '/people/deceased_person/place_of_death',
#  '/business/person/company',
#  '/people/person/children',
#  '/location/location/contains',
#  '/people/person/place_lived',
#  '/location/country/administrative_divisions',
#  '/business/company/founders',
#  '/location/neighborhood/neighborhood_of',
#  '/location/country/capital',
#  '/location/administrative_division/country']

# %% [markdown]
# ## Participle

# %%
from nltk import regexp_tokenize

# %%
def cut(s):
    """
    Participle
    """
    pattern = r'''
              (?x)                   # set flag to allow verbose regexps 
              (?:[A-Z]\.)+           # abbreviations, e.g. U.S.A. 
              |\d+(?:\.\d+)?%?       # numbers, incl. currency and percentages 
              |\w+(?:[-&']\w+)*       # words w/ optional internal hyphens/apostrophe  
           '''  
    return regexp_tokenize(s, pattern=pattern)

# %%
filename = "stopwords_666.txt"
stopWords = {w: None for w in open(filename).read().split()}

# %%
sentWords = [cut(s) for s in sentText]
entlabWords = [[cut(s) for s in eL] for eL in entityLabels]
em1Words = [[cut(s) for s in eL] for eL in em1Text]
em2Words = [[cut(s) for s in eL] for eL in em2Text]
t_sentWords = [cut(s) for s in t_sentText]
t_entlabWords = [[cut(s) for s in eL] for eL in t_entityLabels]
t_em1Words = [[cut(s) for s in eL] for eL in t_em1Text]
t_em2Words = [[cut(s) for s in eL] for eL in t_em2Text]
# Clean words
t_sentWords = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_sentWords]

# %%
# Delete stopwords
for n in range(len(sentWords)):
    sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in sentWords[n]] if i != None]
    entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in entlabWords[n]]
    entlabWords[n] = [[i for i in item if i != None] for item in entlabWords[n]]
    em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em1Words[n]]
    em1Words[n] = [[i for i in item if i != None] for item in em1Words[n]]
    em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em2Words[n]]
    em2Words[n] = [[i for i in item if i != None] for item in em2Words[n]] 

for n in range(len(t_sentWords)):
    t_sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in t_sentWords[n]] if i != None]
    t_entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_entlabWords[n]]
    t_entlabWords[n] = [[i for i in item if i != None] for item in t_entlabWords[n]]
    t_em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em1Words[n]]
    t_em1Words[n] = [[i for i in item if i != None] for item in t_em1Words[n]]
    t_em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em2Words[n]]
    t_em2Words[n] = [[i for i in item if i != None] for item in t_em2Words[n]]

# %%
#max([len(i) for i in t_sentWords])

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8

# %% [markdown]
# ## Make Adjacency List

# %% [markdown]
# ### Make Adjacency List of Train Data

# %%
from collections import Counter

# %%
i_entityLabels = []
for i in range(len(sentWords)):
    eL = []
    sDict = list(enumerate(sentWords[i]))
    j = 0
    for item in entlabWords[i]:
        el = []
        for e in item:
            while j < len(sDict):
                if e == sDict[j][1]:
                    el.append(sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    i_entityLabels.append(eL)

# %%
rmSet = []
for item in range(len(relationMentions)):
    rms = [(em1Words[item][i][0], em2Words[item][i][0], relationLabels[item][i]) for i in range(len(relationLabels[item]))]
    rms = [' '.join(list(i)) for i in rms]
    rmSet.append(rms)
rmSet = [set(i) for i in rmSet]

# %%
i_adjacencyList = []
new_sentWords = []
pad = ['/eop', '/eos']
for n in range(len(sentWords)):
    aL = []
    for l in range(len(relationLabels[n])):
        e1 = []
        e2 = []
        for item in i_entityLabels[n]:
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em2Words[n][l]):
                e2.append(item[0])
        c1 = [(a, b) for a in e1 for b in e2 if ' '.join([sentWords[n][a], sentWords[n][b], relationLabels[n][l]]) in rmSet[n]]
        c2 = [(a, b) for a in e2 for b in e1 if ' '.join([sentWords[n][b], sentWords[n][a], relationLabels[n][l]]) in rmSet[n]]
        c = c1 + c2
        m = min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[-1]
        r = [i[0] for i in [(i, abs(j[0]-j[1])) for i, j in enumerate(c)] if i[-1] == m]
        for i in r:
            if ' '.join([sentWords[n][c[i][0]], sentWords[n][c[i][1]], relationLabels[n][l]]) in rmSet[n]:
                al = (c[i][0], c[i][1], relationLabels[n][l], pad[0])
                if al[2] in t_relationTypes and al[0] < MAX_SENT_LEN and al[1] < MAX_SENT_LEN: 
                    aL.append(al)
    aL = sorted([list(i) for i in set(aL)])
    if len(aL) == 1 or len(aL) == 2:
        i_adjacencyList.append(aL)
        new_sentWords.append(sentWords[n])
i_adjacencyList = [sum(i, []) for i in i_adjacencyList]
for i in i_adjacencyList:
    i[-1] = pad[-1]

# %% [markdown]
# ### Make Adjacency List of Test Data

# %%
ti_entityLabels = []
for i in range(len(t_sentWords)):
    eL = []
    t_sDict = list(enumerate(t_sentWords[i]))
    j = 0
    for item in t_entlabWords[i]:
        el = []
        for e in item:
            while j < len(t_sDict):
                if e == t_sDict[j][1]:
                    el.append(t_sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    ti_entityLabels.append(eL)

# %%
ti_trueLables = [[i for i, j in enumerate(rl) if j != 'None'] for rl in t_relationLabels]
t_trueMentions = [[j for i, j in enumerate(rl) if j['label'] != 'None'] for rl in t_relationMentions]
pad = ['/eop', '/eos']
ti_adjacencyList = []
for n in range(len(t_sentWords)): 
    e1 = []
    e2 = []
    aL = []
    for l in ti_trueLables[n]:
        for item in ti_entityLabels[n]:
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em2Words[n][l]):
                e2.append(item[0])
    c = [(a, b) for a in e1 for b in e2]
    r = c[min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[0]]
    aL = aL + [r[0], r[1], t_relationLabels[n][l], pad[-1]]
    ti_adjacencyList.append(aL)

# Modify 
#ti_adjacencyList[26] = [18, 20, '/business/company/founders', pad[-1]]
ti_adjacencyList[191] = [13, 19, '/location/administrative_division/country', pad[0], 18, 19, '/location/administrative_division/country', pad[-1]]

# %%
#max([max(sum(i, [])) for i in ti_entityLabels])

# %% [markdown]
# # Word to Vector

# %% [markdown]
# ## Tokenize Text

# %%
from keras.preprocessing.text import Tokenizer
from nltk import WordNetLemmatizer
# Out:
# Using TensorFlow backend.

# %%
wnl = WordNetLemmatizer()
sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in new_sentWords]
t_sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in t_sentWords]
tok_sentWords = sentWords.copy()
tok_sentWords.extend(t_sentWords)
tokTexts = [' '.join(i) for i in tok_sentWords]

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts(tokTexts)
word2index = tokenizer.word_index
for i in [i for i in zip(list(range(65132, 65147)), pad+['/go']+t_relationTypes)]:
    word2index[i[-1]] = i[0]
index2word = {i: w for w, i in word2index.items()}
print('Found %s unique tokens.' % len(word2index))
# Out:
# Found 65146 unique tokens.

# %% [markdown]
# ## Create Word Embeddings with GloVe

# %%
VOCAB_SIZE = 65147
EMBEDDING_SIZE = 300
SEED = 42

# %% [markdown]
# ### Read GloVe

# %%
import numpy as np

# %%
#glove_n_symbols = !wc -l /Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt
#glove_n_symbols = int(glove_n_symbols[0].split()[0])
glove_n_symbols = 1917495

# %%
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_n_symbols, EMBEDDING_SIZE))
globale_scale = 0.1
with open('/Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt', 'r') as fp:
    index = 0
    for l in fp:
        l = l.strip().split()
        word = l[0]
        glove_index_dict[word] = index
        glove_embedding_weights[index, :] = [float(n) for n in l[1:]]
        index += 1
glove_embedding_weights *= globale_scale

# %% [markdown]
# ### Use Glove to Initialize Embedding Matrix

# %%
from nltk import PorterStemmer, LancasterStemmer

# %%
# Generate random embedding with same scale as glove
np.random.seed(SEED)
shape = (VOCAB_SIZE, EMBEDDING_SIZE)
scale = glove_embedding_weights.std() * np.sqrt(12) / 2 
embedding = np.random.uniform(low=-scale, high=scale, size=shape)

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()

# %%
# Copy from glove weights of words that appear in index2word
count = 0 
for i in range(1, 65132):
    w = index2word[i]
    g = glove_index_dict.get(w)
    if g is None:
        w = porter.stem(w)
        g = glove_index_dict.get(w)
    if g is None:
        w = lancaster.stem(w)
        g = glove_index_dict.get(w)
    if g is not None:
        embedding[i, :] = glove_embedding_weights[g, :]
        count += 1
print('{num_tokens}-{per:.2f}% tokens in vocab found in glove and copied to embedding.'.format(num_tokens=count, per=count/float(VOCAB_SIZE)*100))
# Out:
# 60641-93.08% tokens in vocab found in glove and copied to embedding.

# %%
for i in range(65132, 65147):
    item = np.random.uniform(low=-scale, high=scale, size=(EMBEDDING_SIZE,))
    item[i-65132] = 1
    embedding[i, :] = item

# %% [markdown]
# # Build Dateset

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
new_sentText = [' '.join(i) for i in sentWords]
sentSeq = tokenizer.texts_to_sequences(new_sentText)
sentData = pad_sequences(sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

t_new_sentText = [' '.join(i) for i in t_sentWords]
t_sentSeq = tokenizer.texts_to_sequences(t_new_sentText)
t_sentData = pad_sequences(t_sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

new_adjacencyList = [[sentWords[c][j] if i < 2 or i == 4 or i == 5 else j for i, j in enumerate(item)] for c, item in enumerate(i_adjacencyList)]
adjlText = [' '.join(i) for i in new_adjacencyList]
adjlSeq = tokenizer.texts_to_sequences(adjlText)
adjlData = pad_sequences(adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

newt_adjacencyList = [[t_sentWords[c][j] if i < 2 or i == 4 or i == 5 else j for i, j in enumerate(item)] for c, item in enumerate(ti_adjacencyList)]
t_adjlText = [' '.join(i) for i in newt_adjacencyList]
t_adjlSeq = tokenizer.texts_to_sequences(t_adjlText)
t_adjlData = pad_sequences(t_adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

[i.insert(0, '/go') for i in new_adjacencyList];
adjlText = [' '.join(i) for i in new_adjacencyList]
adjlSeq = tokenizer.texts_to_sequences(adjlText)
tfData = pad_sequences(adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

[i.insert(0, '/go') for i in newt_adjacencyList];
t_adjlText = [' '.join(i) for i in newt_adjacencyList]
t_adjlSeq = tokenizer.texts_to_sequences(t_adjlText)
t_tfData = pad_sequences(t_adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

# %%
# Split the data into a training set, a validation set and a test set
x_train_all = sentData
tf_train_all = tfData
y_train_all = adjlData

x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, test_size=0.15, random_state=SEED)
tf_train, tf_val, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0.15, random_state=SEED)

x_train_all, _, y_train_all, _  = train_test_split(x_train_all, y_train_all, test_size=0., random_state=SEED)
tf_train_all, _, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0., random_state=SEED)
 
x_test = t_sentData
tf_test = t_tfData
y_test = t_adjlData

x_test, _, y_test, _ = train_test_split(x_test, y_test, test_size=0., random_state=SEED)
tf_test, _, _, _ = train_test_split(tf_test, tf_test, test_size=0., random_state=SEED)

# %% [markdown]
# # Save Dataset

# %%
import h5py
import pickle

# %%
fh = h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/allData.h5', 'w')
fh['x_train'] = x_train
fh['tf_train'] = tf_train
fh['y_train'] = y_train
fh['x_val'] = x_val
fh['tf_val'] = tf_val
fh['y_val'] = y_val
fh['x_train_all'] = x_train_all
fh['tf_train_all'] = tf_train_all
fh['y_train_all'] = y_train_all
fh['x_test'] = x_test
fh['tf_test'] = tf_test
fh['y_test'] = y_test
fh['embedding'] = embedding
fh.close()

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/index.pkl', 'wb') as fp:
    pickle.dump((word2index, index2word), fp, -1)

# %% [markdown]
# # Checkpoint

# %%
import h5py
import pickle

# %%
with h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/allData.h5', 'r') as fh:
    x_train = fh['x_train'][:]
    tf_train = fh['tf_train'][:]
    y_train = fh['y_train'][:]
    x_val = fh['x_val'][:]
    tf_val = fh['tf_val'][:]
    y_val = fh['y_val'][:]
    x_train_all = fh['x_train_all'][:]
    tf_train_all = fh['tf_train_all'][:]
    y_train_all = fh['y_train_all'][:]
    x_test = fh['x_test'][:]
    tf_test = fh['tf_test'][:]
    y_test = fh['y_test'][:]
    embedding = fh['embedding'][:]

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/index.pkl', 'rb') as fp:
    word2index, index2word = pickle.load(fp)

# %% [markdown]
# # Build Model

# %% [markdown]
# ##  Set Hyperparameters

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8
VOCAB_SIZE = len(word2index)+1
NUM_CLASSES = VOCAB_SIZE
EMBEDDING_SIZE = 300
TF_EMBEDDING_SIZE = 300

ENC_1_RNN_SIZE = 300
ENC_2_RNN_SIZE = 150
DEC_RNN_SIZE = 300
DROPOUT_RATE = 0.5
RNN_DROPOUT_RATE = 0.2
NUM_EPOCHS = 1024
BATCH_SIZE = 79
STEPS_PER_EPOCH = 20
TEST_STEPS = len(x_test)//BATCH_SIZE

VALIDATION_STEPS = 3

# %%
print('NUM_EPOCHS: \t\t%d' % NUM_EPOCHS)
print('STEPS_PER_EPOCH: \t%d' % STEPS_PER_EPOCH)
print('TEST_STEPS: \t\t%d' % TEST_STEPS)
print('VALIDATION_STEPS: \t%d' % VALIDATION_STEPS)
print('TRAIN_BATCHES: \t\t%d' % (NUM_EPOCHS * STEPS_PER_EPOCH))
print('NUM_BATCHES \t\t%d' % (len(x_train)//BATCH_SIZE+1))
# Out:
# NUM_EPOCHS: 		1024
# STEPS_PER_EPOCH: 	20
# TEST_STEPS: 		5
# VALIDATION_STEPS: 	3
# TRAIN_BATCHES: 		20480
# NUM_BATCHES 		612

# %% [markdown]
# ## Import Libraries

# %%
from keras.layers import Input, Embedding, Dropout, Bidirectional, LSTM, RepeatVector, concatenate, TimeDistributed, Dense
from keras.models import Model
import keras.backend as K
from keras.callbacks import*
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Build Graph

# %%
K.clear_session()
sequence = Input(shape=(MAX_SENT_LEN,), name='INPUT') 
emb_seq = Embedding(VOCAB_SIZE, EMBEDDING_SIZE, weights=[embedding], mask_zero=True, input_length=MAX_SENT_LEN, trainable=False, name='EMBEDDING')(sequence)
tf_seq = Input(shape=(MAX_ADJL_LEN,), name='TF_INPUT')
tf_emb = Embedding(NUM_CLASSES, TF_EMBEDDING_SIZE, weights=[embedding], mask_zero=True, input_length=MAX_ADJL_LEN, trainable=False, name='TF_EMBEDDING')(tf_seq)
blstm = Bidirectional(LSTM(ENC_1_RNN_SIZE, return_sequences=True, implementation=0, dropout=RNN_DROPOUT_RATE, recurrent_dropout=RNN_DROPOUT_RATE), merge_mode='concat', name='ENC_BLSTM_1')(emb_seq)
blstm = Dropout(DROPOUT_RATE)(blstm)
blstm = Bidirectional(LSTM(ENC_2_RNN_SIZE, return_sequences=False, implementation=0, dropout=RNN_DROPOUT_RATE, recurrent_dropout=RNN_DROPOUT_RATE), merge_mode='concat', name='ENC_BLSTM_2')(blstm)
blstm = Dropout(DROPOUT_RATE)(blstm)
context = RepeatVector(MAX_ADJL_LEN, name='CONTEXT')(blstm)
context = concatenate([context, tf_emb], axis=-1)
blstm = LSTM(DEC_RNN_SIZE, return_sequences=True, implementation=0, dropout=RNN_DROPOUT_RATE, recurrent_dropout=RNN_DROPOUT_RATE, name='DEC_LSTM')(context)
lstm = Dropout(DROPOUT_RATE)(blstm)
output = TimeDistributed(Dense(NUM_CLASSES, activation='softmax'), name='OUTPUT')(lstm)
model = Model(inputs=[sequence, tf_seq], outputs=output)
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# %% [markdown]
# ## Model Visualization

# %%
model.summary()
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# INPUT (InputLayer)               (None, 64)            0
# ____________________________________________________________________________________________________
# EMBEDDING (Embedding)            (None, 64, 300)       19544100    INPUT[0][0]
# ____________________________________________________________________________________________________
# ENC_BLSTM_1 (Bidirectional)      (None, 64, 600)       1442400     EMBEDDING[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 64, 600)       0           ENC_BLSTM_1[0][0]
# ____________________________________________________________________________________________________
# ENC_BLSTM_2 (Bidirectional)      (None, 300)           901200      dropout_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 300)           0           ENC_BLSTM_2[0][0]
# ____________________________________________________________________________________________________
# TF_INPUT (InputLayer)            (None, 8)             0
# ____________________________________________________________________________________________________
# CONTEXT (RepeatVector)           (None, 8, 300)        0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# TF_EMBEDDING (Embedding)         (None, 8, 300)        19544100    TF_INPUT[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 8, 600)        0           CONTEXT[0][0]
#                                                                    TF_EMBEDDING[0][0]
# ____________________________________________________________________________________________________
# DEC_LSTM (LSTM)                  (None, 8, 300)        1081200     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 8, 300)        0           DEC_LSTM[0][0]
# ____________________________________________________________________________________________________
# OUTPUT (TimeDistributed)         (None, 8, 65147)      19609247    dropout_3[0][0]
# ====================================================================================================
# Total params: 62,122,247
# Trainable params: 23,034,047
# Non-trainable params: 39,088,200
# ____________________________________________________________________________________________________

# %% [markdown]
# ## Train

# %%
def gen_label(s):
    """
    One-hot encoding
    """
    gen = to_categorical(s, num_classes=NUM_CLASSES)
    return gen

def data_generator_all(data, label, batch_size):
    """
    Yield batches of all data
    """
    count = 0
    while True:
        if count >= len(data[0]): 
            count = 0
        x_1 = np.zeros((batch_size, MAX_SENT_LEN))
        x_2 = np.zeros((batch_size, MAX_ADJL_LEN))
        y = np.zeros((batch_size, MAX_ADJL_LEN, NUM_CLASSES))
        for i in range(batch_size):
            n = i + count
            if n > len(data[0])-1:
                break
            x_1[i, :] = data[0][n]
            x_2[i, :] = data[1][n]
            y[i, :, :] = gen_label(label[n])
        count += batch_size
        yield ([x_1, x_2], y)
        
def data_generator(data, label, batch_size): 
    """
    Yield batches 
    """
    index = np.arange(len(data[0]))
    np.random.shuffle(index)    
    batches = [index[range(batch_size*i, min(len(data[0]), batch_size*(i+1)))] for i in range(len(data[0])//batch_size)]
    while True:
        for i in batches:
            x_1 = data[0][i]
            x_2 = data[1][i]
            y = np.array(list(map(gen_label, label[i])))
            yield ([x_1, x_2], y)

# %%
gen_train_all = data_generator([x_train_all, tf_train_all], y_train_all, BATCH_SIZE)
gen_test = data_generator_all([x_test, tf_test], y_test, BATCH_SIZE)
#gen_train = data_generator(x_train, y_train, BATCH_SIZE)
#gen_val = data_generator(x_val, y_val, BATCH_SIZE)

# %%
# Continue Trian
# filename = 'cp_logs/.hdf5'
# model.load_weights(filename)
# model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['acc'])

# %%
filepath = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/cp_logs/weights.{epoch:03d}-{val_loss:.6f}.hdf5'
log_string = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/tb_logs/1'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
tensorboard = TensorBoard(log_dir=log_string, 
                          histogram_freq=1, 
                          write_graph=False, 
                          write_grads=False, 
                          batch_size=BATCH_SIZE, 
                          write_images=True, 
                          embeddings_freq=1, 
                          embeddings_layer_names=None,
                          embeddings_metadata=None)

# %%
history = model.fit_generator(gen_train_all, 
                              steps_per_epoch=STEPS_PER_EPOCH, 
                              epochs=NUM_EPOCHS, 
                              verbose=1,
                              #callbacks=[checkpoint, tensorboard],
                              validation_data=gen_test, 
                              validation_steps=TEST_STEPS)

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Naive Evaluate

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4_pro/cp_logs/trival_true/weights.256-2.689965.hdf5'
model.load_weights(filename)

result = np.argmax(model.predict([x_test, tf_test], batch_size=BATCH_SIZE, verbose=1), -1)
# Out:
# 395/395 [==============================] - 12s

# %%
preResult = [[index2word[i] for i in sent if i != 0] for sent in result]
actResult = [[index2word[i] for i in sent if i != 0] for sent in y_test]
e1Count = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0]]) + sum([1 for i in range(372, 373) if actResult[i][-4] == preResult[i][-4] and actResult[i][3] == preResult[i][3]])
e2Count = sum([1 for i in range(395) if actResult[i][1] == preResult[i][1]]) + sum([1 for i in range(372, 373) if actResult[i][-3] == preResult[i][-3] and actResult[i][3] == preResult[i][3]])
enCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1]]) + sum([1 for i in range(372, 373) if actResult[i][-4] == preResult[i][-4] and actResult[i][-3] == preResult[i][-3] and actResult[i][3] == preResult[i][3]])      
reCount = sum([1 for i in range(395) if actResult[i][2] == preResult[i][2]]) + sum([1 for i in range(372, 373) if actResult[i][-2] == preResult[i][-2] and actResult[i][3] == preResult[i][3]])
tripleCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1] and actResult[i][2] == preResult[i][2]]) + sum([1 for i in range(372, 373) if actResult[i][-4] == preResult[i][-4] and actResult[i][-3] == preResult[i][-3] and actResult[i][-2] == preResult[i][-2] and actResult[i][3] == preResult[i][3]]) 
print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
print('En Accuracy: \t\t%.6f' % (enCount/396))
print('Re Accuracy: \t\t%.6f' % (reCount/396))
print('Triple Accuracy: \t%.6f' % (tripleCount/396))
# Out:
# E1 Accuracy: 		0.419192
# E2 Accuracy: 		0.280303
# En Accuracy: 		0.121212
# Re Accuracy: 		0.671717
# Triple Accuracy: 	0.093434

# %%
' '.join(preResult[372])
# Out:
# 'europe russia /location/location/contains /eop russia warsaw /location/location/contains /eos'

# %%
' '.join(actResult[372])
# Out:
# 'washington iran /location/administrative_division/country /eop russia iran /location/administrative_division/country /eos'

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(preResult[i]))
    print('Ground-Truth: \t%s' % ' '.join(actResult[i]))
    print('---')
# Out:
# Predict: 	germany madrid /people/person/nationality /eop
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---
# Predict: 	connecticut connecticut /location/location/contains /eop
# Ground-Truth: 	westchester connecticut /location/administrative_division/country /eos
# ---
# Predict: 	lebanon beirut /people/person/nationality /eos
# Ground-Truth: 	dalia israel /people/person/nationality /eos
# ---
# Predict: 	india india /people/person/place_of_birth /eos
# Ground-Truth: 	hyderabad potti /location/location/contains /eos
# ---
# Predict: 	north north /people/person/place_lived /eos
# Ground-Truth: 	kent north /people/person/place_lived /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos
# Ground-Truth: 	ontario waterloo /location/location/contains /eos
# ---
# Predict: 	robert enron /business/company/founders /eop
# Ground-Truth: 	blackstone stephen /business/company/founders /eos
# ---
# Predict: 	germany madrid /people/person/nationality /eop
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	iran isfahan /location/location/contains /eop
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	paris strasbourg /people/deceased_person/place_of_death /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	george george /business/person/company /eos
# Ground-Truth: 	george abc /business/person/company /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida jacksonville /location/location/contains /eos
# ---
# Predict: 	nigeria abuja /location/location/contains /eos
# Ground-Truth: 	nigeria uyo /location/location/contains /eos
# ---
# Predict: 	arkansas arkansas /people/person/place_lived /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---
# Predict: 	kentucky canada /people/person/place_lived /eos
# Ground-Truth: 	patrick huntington /people/person/place_lived /eos
# ---
# Predict: 	germany netherlands /location/location/contains /eop
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	robert enron /business/person/company /eos
# Ground-Truth: 	jeffrey lazard /business/person/company /eos
# ---
# Predict: 	israel gaza /location/country/capital /eop
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	italy italy /location/location/contains /eop
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---
# Predict: 	george york /business/person/company /eos
# Ground-Truth: 	mark york /business/person/company /eos
# ---
# Predict: 	australia australia /people/person/nationality /eos
# Ground-Truth: 	markus australia /people/person/nationality /eos
# ---
# Predict: 	princeton princeton /business/person/company /eos
# Ground-Truth: 	kwame princeton /business/person/company /eos
# ---
# Predict: 	john morgan /business/company/founders /eos
# Ground-Truth: 	endemol john /business/company/founders /eos
# ---
# Predict: 	minnesota minnesota /people/person/place_lived /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---
# Predict: 	john greenwich /location/location/contains /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---
# Predict: 	europe natanz /location/location/contains /eop
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	india india /people/person/nationality /eop
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---
# Predict: 	paul mexico /people/person/place_lived /eop
# Ground-Truth: 	bill dawsonville /people/person/place_lived /eos
# ---
# Predict: 	africa columbia /business/person/company /eos
# Ground-Truth: 	daniel university /business/person/company /eos
# ---
# Predict: 	russia moscow /location/location/contains /eos
# Ground-Truth: 	soviet russia /location/administrative_division/country /eos
# ---
# Predict: 	boston boston /location/location/contains /eos
# Ground-Truth: 	boston wbz-tv /location/location/contains /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	virginia baltimore /location/location/contains /eos
# Ground-Truth: 	virginia united /location/administrative_division/country /eos
# ---
# Predict: 	jack memphis /business/person/company /eos
# Ground-Truth: 	ira system /business/person/company /eos
# ---
# Predict: 	utah rio /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	york york /people/person/place_lived /eos
# Ground-Truth: 	anthony york /business/person/company /eos
# ---
# Predict: 	warren philippine /business/person/company /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---
# Predict: 	massachusetts capitol /location/location/contains /eos
# Ground-Truth: 	washington bainbridge /location/location/contains /eos
# ---
# Predict: 	washington capitol /location/location/contains /eos
# Ground-Truth: 	washington olympia /location/location/contains /eos
# ---
# Predict: 	south south /location/location/contains /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---
# Predict: 	spain madrid /location/administrative_division/country /eop
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	europe strasbourg /people/person/nationality /eop
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	middle natanz /location/location/contains /eop
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	colorado colorado /people/person/place_lived /eos
# Ground-Truth: 	kellen colorado /people/person/place_of_birth /eos
# ---
# Predict: 	benjamin paris /people/person/nationality /eos
# Ground-Truth: 	tony france /people/person/nationality /eos
# ---
# Predict: 	spain spain /people/person/nationality /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---
# Predict: 	italy bangalore /people/person/nationality /eop
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	york staten /location/location/contains /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	israel west /location/country/capital /eop
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	san san /business/person/company /eos
# Ground-Truth: 	ralph at&t /business/person/company /eos
# ---
# Predict: 	connecticut hartford /location/location/contains /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---
# Predict: 	somalia mogadishu /location/location/contains /eos
# Ground-Truth: 	somalia puntland /location/location/contains /eos
# ---
# Predict: 	sri warren /location/location/contains /eop
# Ground-Truth: 	riga latvia /location/administrative_division/country /eos
# ---
# Predict: 	iran turin /location/location/contains /eos
# Ground-Truth: 	switzerland davos /location/location/contains /eos
# ---
# Predict: 	colorado denver /location/location/contains /eos
# Ground-Truth: 	colorado vail /location/location/contains /eos
# ---
# Predict: 	paris louvre /location/location/contains /eop
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	queen queen /location/location/contains /eop
# Ground-Truth: 	lower hudson /location/location/contains /eos
# ---
# Predict: 	san san /location/location/contains /eos
# Ground-Truth: 	san north /location/location/contains /eos
# ---
# Predict: 	york great /location/location/contains /eop
# Ground-Truth: 	nassau suffolk /location/administrative_division/country /eos
# ---
# Predict: 	warren philippine /business/person/company /eop
# Ground-Truth: 	chad youtube /business/person/company /eos
# ---
# Predict: 	westchester rochelle /location/location/contains /eos
# Ground-Truth: 	westchester kensico /location/location/contains /eos
# ---
# Predict: 	susan nebraska /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---
# Predict: 	italy naples /location/location/contains /eos
# Ground-Truth: 	italy orvieto /location/location/contains /eos
# ---
# Predict: 	morocco warren /location/location/contains /eos
# Ground-Truth: 	greenville furman /location/location/contains /eos
# ---
# Predict: 	alan princeton /business/person/company /eos
# Ground-Truth: 	charles princeton /business/person/company /eos
# ---
# Predict: 	kentucky canada /location/location/contains /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	egypt gaza /people/person/nationality /eop
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	john john /location/location/contains /eos
# Ground-Truth: 	baltimore john /location/location/contains /eos
# ---
# Predict: 	india india /people/person/nationality /eos
# Ground-Truth: 	samantha india /people/person/place_lived /eos
# ---
# Predict: 	david youngstown /business/person/company /eos
# Ground-Truth: 	david digitas /business/person/company /eos
# ---
# Predict: 	jim iowa /people/person/place_lived /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---
# Predict: 	rafik lebanon /people/person/nationality /eos
# Ground-Truth: 	rafik lebanon /people/person/nationality /eos
# ---
# Predict: 	daniel nigeria /people/person/nationality /eos
# Ground-Truth: 	atiku nigeria /people/person/nationality /eos
# ---
# Predict: 	jersey rochelle /location/location/contains /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida panama /location/location/contains /eos
# ---
# Predict: 	iraq isfahan /location/location/contains /eop
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---
# Predict: 	paris strasbourg /people/person/place_of_birth /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	spain madrid /location/administrative_division/country /eop
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---
# Predict: 	orange warren /location/location/contains /eos
# Ground-Truth: 	clarkstown city /location/location/contains /eos
# ---
# Predict: 	india mumbai /location/country/capital /eop
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---
# Predict: 	haley mississippi /people/person/place_lived /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	warren youngstown /business/person/company /eos
# Ground-Truth: 	gordon continental /business/person/company /eos
# ---
# Predict: 	paris louvre /location/location/contains /eop
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	california los /location/location/contains /eos
# Ground-Truth: 	california long /location/location/contains /eos
# ---
# Predict: 	jacques strasbourg /location/location/contains /eos
# Ground-Truth: 	france correze /location/location/contains /eos
# ---
# Predict: 	st st /location/location/contains /eos
# Ground-Truth: 	fairfax westfield /location/location/contains /eos
# ---
# Predict: 	israel gaza /people/person/nationality /eop
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	spain madrid /location/location/contains /eos
# Ground-Truth: 	spain valencia /location/location/contains /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	greenwich greenwich /location/location/contains /eos
# Ground-Truth: 	greenwich jefferson /location/location/contains /eos
# ---
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	jacques france /people/person/nationality /eos
# Ground-Truth: 	jacques france /people/person/nationality /eos
# ---
# Predict: 	warren philippine /location/location/contains /eos
# Ground-Truth: 	mahwah ramapo /location/location/contains /eos
# ---
# Predict: 	warren philippine /location/country/capital /eos
# Ground-Truth: 	guyana linden /location/location/contains /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india punjab /location/location/contains /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos
# Ground-Truth: 	ontario tobermory /location/location/contains /eos
# ---
# Predict: 	middle iran /location/location/contains /eos
# Ground-Truth: 	middle iran /location/location/contains /eos
# ---
# Predict: 	pakistan islamabad /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	italy rome /location/location/contains /eop
# Ground-Truth: 	italy israel /location/administrative_division/country /eos
# ---
# Predict: 	spain france barcelona /eop
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---
# Predict: 	warren bank /business/person/company /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	alabama minnesota /people/person/place_lived /eos
# Ground-Truth: 	amy minnesota /people/person/place_lived /eos
# ---
# Predict: 	john australia /people/person/nationality /eos
# Ground-Truth: 	john australia /people/person/nationality /eos
# ---
# Predict: 	kentucky canada /people/person/place_lived /eos
# Ground-Truth: 	ernie kentucky /people/person/place_lived /eos
# ---
# Predict: 	iran isfahan /location/location/contains /eos
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india bihar /location/country/administrative_divisions /eos
# ---
# Predict: 	ireland dublin /location/location/contains /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---
# Predict: 	south kenya /location/location/contains /eop
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---
# Predict: 	italy naples /location/location/contains /eos
# Ground-Truth: 	italy umbria /location/location/contains /eos
# ---
# Predict: 	italy milan /location/location/contains /eop
# Ground-Truth: 	campania italy /location/administrative_division/country /eos
# ---
# Predict: 	middle tehran /location/location/contains /eop
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	spain cologne /location/administrative_division/country /eop
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---
# Predict: 	paris louvre /location/location/contains /eop
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	manhattan cleveland /location/location/contains /eos
# Ground-Truth: 	cleveland karamu /location/location/contains /eos
# ---
# Predict: 	ireland dublin /location/location/contains /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---
# Predict: 	washington seattle /location/location/contains /eos
# Ground-Truth: 	california san /location/location/contains /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos
# Ground-Truth: 	france albertville /location/location/contains /eos
# ---
# Predict: 	warren thailand /location/location/contains /eos
# Ground-Truth: 	bosnia srebrenica /location/location/contains /eos
# ---
# Predict: 	manhattan manhattan /location/location/contains /eos
# Ground-Truth: 	upper fort /location/location/contains /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos
# Ground-Truth: 	france valence /location/location/contains /eos
# ---
# Predict: 	spain spain /people/person/place_of_birth /eos
# Ground-Truth: 	james tampa /people/person/place_lived /eos
# ---
# Predict: 	bashar /people/person/nationality /location/location/contains /eos
# Ground-Truth: 	syria damascus /location/country/administrative_divisions /eos
# ---
# Predict: 	warren st /people/person/place_lived /eos
# Ground-Truth: 	marshall fremont /people/deceased_person/place_of_death /eos
# ---
# Predict: 	israel jerusalem /location/country/capital /eos
# Ground-Truth: 	israel jerusalem /location/location/contains /eos
# ---
# Predict: 	iraq isfahan /location/location/contains /eop
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	indiana harvard /location/location/contains /eos
# Ground-Truth: 	cambridge lesley /location/location/contains /eos
# ---
# Predict: 	australia australia /people/person/nationality /eos
# Ground-Truth: 	chris australia /people/person/nationality /eos
# ---
# Predict: 	california santa /business/person/company /eos
# Ground-Truth: 	dennis disney /business/person/company /eos
# ---
# Predict: 	colorado denver /location/location/contains /eos
# Ground-Truth: 	colorado aspen /location/location/contains /eos
# ---
# Predict: 	indonesia indonesia /location/country/capital /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---
# Predict: 	fort fort /location/location/contains /eos
# Ground-Truth: 	staten fort /location/location/contains /eos
# ---
# Predict: 	carlos la /location/location/contains /eop
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eop
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---
# Predict: 	france france /people/person/nationality /eos
# Ground-Truth: 	jean-louis france /people/person/nationality /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---
# Predict: 	bob kentucky /people/person/place_lived /eos
# Ground-Truth: 	jim kentucky /people/person/place_lived /eos
# ---
# Predict: 	germany netherlands /location/location/contains /eop
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	israel west /location/location/contains /eop
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---
# Predict: 	john philippine /business/person/company /eos
# Ground-Truth: 	brett priceline /business/person/company /eos
# ---
# Predict: 	jersey jersey /location/location/contains /eos
# Ground-Truth: 	newark jersey /location/location/contains /eos
# ---
# Predict: 	paul columbia /business/person/company /eos
# Ground-Truth: 	peter columbia /business/person/company /eos
# ---
# Predict: 	warren amsterdam /location/location/contains /eos
# Ground-Truth: 	leningrad vaganova /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos
# Ground-Truth: 	mexico jalisco /location/country/administrative_divisions /eos
# ---
# Predict: 	westchester rochelle /location/location/contains /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---
# Predict: 	europe isfahan /location/location/contains /eop
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---
# Predict: 	warren st /people/person/place_lived /eos
# Ground-Truth: 	brittany seminole /people/person/place_lived /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eop
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---
# Predict: 	germany munich /location/location/contains /eos
# Ground-Truth: 	germany munich /location/location/contains /eos
# ---
# Predict: 	switzerland switzerland /people/person/place_lived /eos
# Ground-Truth: 	ernst davos /people/deceased_person/place_of_death /eos
# ---
# Predict: 	park beslan /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	haven columbia /location/location/contains /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---
# Predict: 	germany munich /location/location/contains /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---
# Predict: 	robert enron /business/person/company /eos
# Ground-Truth: 	jeffrey general /business/person/company /eos
# ---
# Predict: 	poland warsaw /location/location/contains /eos
# Ground-Truth: 	poland cracow /location/location/contains /eos
# ---
# Predict: 	minnesota minnesota /people/person/place_lived /eos
# Ground-Truth: 	norm minnesota /people/person/place_lived /eos
# ---
# Predict: 	north north /location/location/contains /eos
# Ground-Truth: 	south iowa /location/administrative_division/country /eos
# ---
# Predict: 	south denver /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---
# Predict: 	paris strasbourg /location/country/administrative_divisions /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	paris strasbourg /location/country/administrative_divisions /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	jordan amman /location/country/capital /eop
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---
# Predict: 	robert american /business/company/founders /eos
# Ground-Truth: 	black robert /business/company/founders /eos
# ---
# Predict: 	minnesota nashville /location/location/contains /eos
# Ground-Truth: 	arkansas arkadelphia /location/location/contains /eos
# ---
# Predict: 	spain spain /location/administrative_division/country /eop
# Ground-Truth: 	navarre spain /location/administrative_division/country /eos
# ---
# Predict: 	canada canada /location/location/contains /eos
# Ground-Truth: 	toronto canada /location/administrative_division/country /eos
# ---
# Predict: 	brooklyn brooklyn /location/neighborhood/neighborhood_of /eop
# Ground-Truth: 	coney york /location/location/contains /eos
# ---
# Predict: 	hawaii moscow /location/location/contains /eos
# Ground-Truth: 	port harborside /location/location/contains /eos
# ---
# Predict: 	iowa iowa /people/person/place_lived /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---
# Predict: 	israel gaza /location/country/capital /eop
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	california sacramento /location/location/contains /eos
# Ground-Truth: 	california lawrence /location/location/contains /eos
# ---
# Predict: 	paris louvre /location/location/contains /eop
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	mexico monterrey /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---
# Predict: 	york york /location/neighborhood/neighborhood_of /eop
# Ground-Truth: 	lower york /location/neighborhood/neighborhood_of /eos
# ---
# Predict: 	italy rome /people/person/nationality /eop
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	san santa /location/location/contains /eos
# Ground-Truth: 	sonoma occidental /location/location/contains /eos
# ---
# Predict: 	john yale /business/person/company /eos
# Ground-Truth: 	christopher security /business/person/company /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india hyderabad /location/location/contains /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	ben nebraska /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---
# Predict: 	sam kansa /people/person/place_lived /eos
# Ground-Truth: 	tommy wisconsin /people/person/place_lived /eos
# ---
# Predict: 	indonesia thailand /location/location/contains /eos
# Ground-Truth: 	bangkok thailand /location/administrative_division/country /eos
# ---
# Predict: 	california santa /location/location/contains /eos
# Ground-Truth: 	california malibu /location/location/contains /eos
# ---
# Predict: 	berkeley miami /people/person/place_lived /eos
# Ground-Truth: 	ayelet berkeley /people/person/place_lived /eos
# ---
# Predict: 	africa lahore /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	annandale-on-hudson kansa /people/person/place_lived /eos
# Ground-Truth: 	kathleen kansa /people/person/place_lived /eos
# ---
# Predict: 	york greenwich /location/location/contains /eop
# Ground-Truth: 	york greenwich /location/location/contains /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	washington mount /location/location/contains /eop
# Ground-Truth: 	mount tanzania /location/administrative_division/country /eos
# ---
# Predict: 	israel west /location/location/contains /eop
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---
# Predict: 	ireland dublin /location/location/contains /eos
# Ground-Truth: 	ireland athenry /location/location/contains /eos
# ---
# Predict: 	iran tehran /location/location/contains /eop
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	netherlands louvre /location/location/contains /eop
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	israel jerusalem /location/location/contains /eop
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---
# Predict: 	europe beslan /location/location/contains /eop
# Ground-Truth: 	russia iran /location/administrative_division/country /eos
# ---
# Predict: 	detroit university /location/location/contains /eos
# Ground-Truth: 	eugene university /location/location/contains /eos
# ---
# Predict: 	spain spain /location/location/contains /eop
# Ground-Truth: 	catalonia spain /location/administrative_division/country /eos
# ---
# Predict: 	australia brisbane /location/location/contains /eos
# Ground-Truth: 	australia port /location/location/contains /eos
# ---
# Predict: 	evo bolivia /people/person/nationality /eos
# Ground-Truth: 	evo bolivia /people/person/nationality /eos
# ---
# Predict: 	germany netherlands /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	south south /location/location/contains /eos
# Ground-Truth: 	south darlington /location/location/contains /eos
# ---
# Predict: 	jeffrey wal-mart /people/person/nationality /eos
# Ground-Truth: 	nelson zimbabwe /people/person/nationality /eos
# ---
# Predict: 	israel jenin /location/location/contains /eos
# Ground-Truth: 	israel ra'anana /location/location/contains /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	india india /location/location/contains /eos
# Ground-Truth: 	gujarat india /location/administrative_division/country /eos
# ---
# Predict: 	cleveland cleveland /location/location/contains /eos
# Ground-Truth: 	cuyahoga cleveland /location/location/contains /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos
# Ground-Truth: 	florida gulf /location/location/contains /eos
# ---
# Predict: 	india delhi /location/country/capital /eos
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/location/contains /eos
# ---
# Predict: 	india milan /location/location/contains /eop
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	israel sadr /location/location/contains /eos
# Ground-Truth: 	jerusalem yad /location/location/contains /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	italy milan /location/location/contains /eos
# Ground-Truth: 	italy maranello /location/location/contains /eos
# ---
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	ben nebraska /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---
# Predict: 	bashar syria /people/person/nationality /eos
# Ground-Truth: 	bashar syria /people/person/nationality /eos
# ---
# Predict: 	louisiana orleans /location/location/contains /eos
# Ground-Truth: 	louisiana baton /location/location/contains /eos
# ---
# Predict: 	middle tehran /location/location/contains /eop
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---
# Predict: 	warren berkshire /business/company/founders /eos
# Ground-Truth: 	sony akio /business/company/founders /eos
# ---
# Predict: 	israel israel /people/person/nationality /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---
# Predict: 	india milan /location/location/contains /eop
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---
# Predict: 	sri jacksonville /location/location/contains /eos
# Ground-Truth: 	calabria crotone /location/location/contains /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	mexico monterrey /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---
# Predict: 	david philippine /business/person/company /eos
# Ground-Truth: 	derrick ford /business/person/company /eos
# ---
# Predict: 	washington university /location/location/contains /eos
# Ground-Truth: 	chicago west /location/location/contains /eos
# ---
# Predict: 	virginia richmond /location/location/contains /eos
# Ground-Truth: 	virginia middleburg /location/location/contains /eos
# ---
# Predict: 	jim oklahoma /people/person/place_lived /eos
# Ground-Truth: 	brad oklahoma /people/person/place_lived /eos
# ---
# Predict: 	california santa /location/location/contains /eos
# Ground-Truth: 	california berkeley /location/location/contains /eos
# ---
# Predict: 	italy milan /location/location/contains /eop
# Ground-Truth: 	italy germany /location/administrative_division/country /eos
# ---
# Predict: 	chicago chicago /location/location/contains /eos
# Ground-Truth: 	cook chicago /location/location/contains /eos
# ---
# Predict: 	suffolk suffolk /location/location/contains /eos
# Ground-Truth: 	fire ocean /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	david google /business/person/company /eos
# Ground-Truth: 	shona google /business/person/company /eos
# ---
# Predict: 	paris louvre /location/administrative_division/country /eop
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	mexico mexico /location/administrative_division/country /eop
# Ground-Truth: 	juarez mexico /location/administrative_division/country /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	israel tel /location/location/contains /eos
# Ground-Truth: 	israel rehovot /location/location/contains /eos
# ---
# Predict: 	york york /people/person/place_lived /eos
# Ground-Truth: 	will york /business/person/company /eos
# ---
# Predict: 	boston boston /people/person/place_lived /eos
# Ground-Truth: 	juliet boston /business/person/company /eos
# ---
# Predict: 	italy milan /location/location/contains /eop
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	mexico monterrey /location/location/contains /eos
# Ground-Truth: 	mexico puebla /location/location/contains /eos
# ---
# Predict: 	spain madrid /location/location/contains /eos
# Ground-Truth: 	spain cordoba /location/location/contains /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	suffolk mount /location/location/contains /eos
# Ground-Truth: 	toronto mount /location/location/contains /eos
# ---
# Predict: 	india india /location/location/contains /eop
# Ground-Truth: 	delhi india /location/administrative_division/country /eos
# ---
# Predict: 	alberta calgary /location/location/contains /eos
# Ground-Truth: 	canada calgary /location/location/contains /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eop
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---
# Predict: 	belgium russia /people/person/nationality /eos
# Ground-Truth: 	nikolay russia /people/person/nationality /eos
# ---
# Predict: 	warren memphis /business/person/company /eos
# Ground-Truth: 	vali naval /business/person/company /eos
# ---
# Predict: 	germany madrid /people/person/nationality /eop
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---
# Predict: 	paris louvre /location/location/contains /eos
# Ground-Truth: 	paris ecole /location/location/contains /eos
# ---
# Predict: 	jordan amman /location/country/capital /eop
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---
# Predict: 	europe europe europe /eop
# Ground-Truth: 	algeria algiers /location/country/capital /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india dharamsala /location/location/contains /eos
# ---
# Predict: 	florida st /location/location/contains /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---
# Predict: 	george washington /business/person/company /eos
# Ground-Truth: 	donald washington /business/person/company /eos
# ---
# Predict: 	europe toronto /location/location/contains /eop
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---
# Predict: 	california california /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	dana california /people/person/place_lived /eos
# ---
# Predict: 	germany cologne /location/location/contains /eos
# Ground-Truth: 	germany nuremberg /location/location/contains /eos
# ---
# Predict: 	israel bank /business/person/company /eos
# Ground-Truth: 	stanley bank /business/person/company /eos
# ---
# Predict: 	manhattan manhattan /location/location/contains /eop
# Ground-Truth: 	lower battery /location/location/contains /eos
# ---
# Predict: 	richard american /people/person/children /eos
# Ground-Truth: 	frank lloyd /people/person/children /eos
# ---
# Predict: 	mexico monterrey /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---
# Predict: 	rafik lebanon /location/location/contains /eop
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---
# Predict: 	paris strasbourg /people/person/place_of_birth /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	york york /location/location/contains /eos
# Ground-Truth: 	york peck /location/location/contains /eos
# ---
# Predict: 	europe natanz /location/location/contains /eop
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	taiwan china /location/location/contains /eos
# Ground-Truth: 	taiwan taipei /location/location/contains /eos
# ---
# Predict: 	carlos la /location/location/contains /eop
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---
# Predict: 	europe milan /location/location/contains /eop
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---
# Predict: 	israel israel /people/person/nationality /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---
# Predict: 	mexico johnson /location/location/contains /eos
# Ground-Truth: 	mexico baja /location/location/contains /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india chhattisgarh /location/location/contains /eos
# ---
# Predict: 	mexico mexico /location/location/contains /eop
# Ground-Truth: 	michoacan mexico /location/administrative_division/country /eos
# ---
# Predict: 	mexico monterrey /location/location/contains /eos
# Ground-Truth: 	mexico tulum /location/location/contains /eos
# ---
# Predict: 	atlanta emory /location/location/contains /eos
# Ground-Truth: 	atlanta georgia /location/location/contains /eos
# ---
# Predict: 	berkeley chez /location/location/contains /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---
# Predict: 	australia australia /people/person/nationality /eos
# Ground-Truth: 	libby australia /people/person/nationality /eos
# ---
# Predict: 	spain spain /people/person/nationality /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---
# Predict: 	saudi riyadh /location/location/contains /eop
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---
# Predict: 	mark hewlett-packard /business/person/company /eos
# Ground-Truth: 	mark hewlett-packard /business/person/company /eos
# ---
# Predict: 	paris louvre /location/location/contains /eos
# Ground-Truth: 	paris musee /location/location/contains /eos
# ---
# Predict: 	austria louvre /location/location/contains /eop
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	houston houston /location/location/contains /eos
# Ground-Truth: 	harris houston /location/location/contains /eos
# ---
# Predict: 	fidel kenya /location/location/contains /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---
# Predict: 	robert philippine /business/person/company /eos
# Ground-Truth: 	will time /business/person/company /eos
# ---
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	chicago university /location/location/contains /eos
# Ground-Truth: 	chicago winston /location/location/contains /eos
# ---
# Predict: 	warren philippine /business/person/company /eos
# Ground-Truth: 	amory rocky /business/person/company /eos
# ---
# Predict: 	washington portland /location/location/contains /eos
# Ground-Truth: 	rochester george /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos
# Ground-Truth: 	mexico cancun /location/location/contains /eos
# ---
# Predict: 	idaho boise /location/location/contains /eos
# Ground-Truth: 	idaho salmon /location/location/contains /eos
# ---
# Predict: 	africa liberia /location/country/capital /eos
# Ground-Truth: 	west senegal /location/location/contains /eos
# ---
# Predict: 	york manhattan /location/location/contains /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---
# Predict: 	john morgan /business/person/company /eop
# Ground-Truth: 	stephen blackstone /business/person/company /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---
# Predict: 	fairfield rochelle /location/location/contains /eos
# Ground-Truth: 	westport winslow /location/location/contains /eos
# ---
# Predict: 	maryland baltimore /location/location/contains /eos
# Ground-Truth: 	baltimore m&t /location/location/contains /eos
# ---
# Predict: 	washington seattle /location/location/contains /eos
# Ground-Truth: 	washington walter /location/location/contains /eos
# ---
# Predict: 	mexico mexico /location/location/contains /eop
# Ground-Truth: 	guanajuato mexico /location/administrative_division/country /eos
# ---
# Predict: 	india india /location/location/contains /eop
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---
# Predict: 	italy rome /people/person/nationality /eop
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---
# Predict: 	york york /people/person/place_lived /eos
# Ground-Truth: 	dennis york /business/person/company /eos
# ---
# Predict: 	kansa topeka /location/location/contains /eos
# Ground-Truth: 	kansa atchison /location/location/contains /eos
# ---
# Predict: 	boston massachusetts /location/location/contains /eos
# Ground-Truth: 	boston massachusetts /location/location/contains /eos
# ---
# Predict: 	washington mount /location/location/contains /eos
# Ground-Truth: 	washington mount /location/location/contains /eos
# ---
# Predict: 	pakistan philippine /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	washington seattle /location/location/contains /eos
# Ground-Truth: 	washington united /location/location/contains /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	spain milan /location/location/contains /eop
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---
# Predict: 	richard yale /business/person/company /eos
# Ground-Truth: 	eddie reebok /business/person/company /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos
# Ground-Truth: 	ontario st /location/location/contains /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida ponte /location/location/contains /eos
# ---
# Predict: 	south university /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---
# Predict: 	florida miami /location/location/contains /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---
# Predict: 	los miami /location/location/contains /eos
# Ground-Truth: 	chicago sears /location/location/contains /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos
# Ground-Truth: 	ontario woodbridge /location/location/contains /eos
# ---
# Predict: 	george seattle /location/location/contains /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---
# Predict: 	warren jacksonville /location/country/capital /eop
# Ground-Truth: 	guinea conakry /location/country/capital /eos
# ---
# Predict: 	iowa de /location/location/contains /eos
# Ground-Truth: 	iowa waterloo /location/location/contains /eos
# ---
# Predict: 	italy naples /location/location/contains /eos
# Ground-Truth: 	italy amalfi /location/location/contains /eos
# ---
# Predict: 	france rome /location/location/contains /eop
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---
# Predict: 	jersey rochelle /location/location/contains /eos
# Ground-Truth: 	westchester hudson /location/location/contains /eos
# ---
# Predict: 	indiana indiana /people/person/place_lived /eos
# Ground-Truth: 	g. georgia /business/person/company /eos
# ---
# Predict: 	africa philippine /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	york chez /location/location/contains /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---
# Predict: 	israel gaza /location/country/capital /eop
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	kentucky canada /people/person/place_lived /eos
# Ground-Truth: 	tyler york /business/person/company /eos
# ---
# Predict: 	india milan /location/location/contains /eop
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---
# Predict: 	europe luxembourg /location/location/contains /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---
# Predict: 	st university /location/location/contains /eos
# Ground-Truth: 	toledo ottawa /location/location/contains /eos
# ---
# Predict: 	sri warren /location/country/capital /eos
# Ground-Truth: 	namibia windhoek /location/location/contains /eos
# ---
# Predict: 	rockland university /location/location/contains /eos
# Ground-Truth: 	mamaroneck united /location/location/contains /eos
# ---
# Predict: 	vermont louisville /location/location/contains /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---
# Predict: 	europe rome /location/location/contains /eop
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---
# Predict: 	iraq iraq /location/location/contains /eop
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---
# Predict: 	france france /location/location/contains /eop
# Ground-Truth: 	corsica france /location/administrative_division/country /eos
# ---
# Predict: 	carlos /people/person/nationality /location/location/contains /eos
# Ground-Truth: 	syria damascus /location/location/contains /eos
# ---
# Predict: 	india india /people/person/nationality /eos
# Ground-Truth: 	shilpa india /people/person/nationality /eos
# ---
# Predict: 	finland helsinki /location/location/contains /eos
# Ground-Truth: 	finland turku /location/location/contains /eos
# ---
# Predict: 	germany munich /location/location/contains /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---
# Predict: 	boston boston /location/location/contains /eos
# Ground-Truth: 	boston beth /location/location/contains /eos
# ---
# Predict: 	haley mississippi /people/person/place_lived /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---
# Predict: 	westchester rochelle /location/location/contains /eos
# Ground-Truth: 	rockland city /location/location/contains /eos
# ---
# Predict: 	robert columbia /business/person/company /eos
# Ground-Truth: 	martin national /business/person/company /eos
# ---
# Predict: 	michael harvard /location/location/contains /eos
# Ground-Truth: 	toronto barrick /location/location/contains /eos
# ---
# Predict: 	illinois chicago /location/location/contains /eop
# Ground-Truth: 	lake chicago /location/administrative_division/country /eos
# ---
# Predict: 	maryland warren /location/location/contains /eos
# Ground-Truth: 	marlborough cytyc /location/location/contains /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos
# Ground-Truth: 	france alzonne /location/location/contains /eos
# ---
# Predict: 	york york /location/location/contains /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos
# Ground-Truth: 	mexico ciudad /location/location/contains /eos
# ---
# Predict: 	saudi natanz /location/location/contains /eop
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	vermont louisville /location/location/contains /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---
# Predict: 	connecticut westport /location/location/contains /eos
# Ground-Truth: 	connecticut hamden /location/location/contains /eos
# ---
# Predict: 	europe russia /location/location/contains /eop russia warsaw /location/location/contains /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eop russia iran /location/administrative_division/country /eos
# ---
# Predict: 	iran mount /location/location/contains /eop
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	iowa de /location/location/contains /eos
# Ground-Truth: 	iowa waverly /location/location/contains /eos
# ---
# Predict: 	boston phoenix /location/location/contains /eos
# Ground-Truth: 	cuba bayamo /location/location/contains /eos
# ---
# Predict: 	africa south /people/person/nationality /eos
# Ground-Truth: 	aziz south /people/person/nationality /eos
# ---
# Predict: 	canada denver /location/location/contains /eos
# Ground-Truth: 	italy reggio /location/location/contains /eos
# ---
# Predict: 	iran natanz /location/location/contains /eop
# Ground-Truth: 	iran washington /location/administrative_division/country /eos
# ---
# Predict: 	vermont nashville /location/location/contains /eos
# Ground-Truth: 	hampshire cannon /location/location/contains /eos
# ---
# Predict: 	warren youngstown /people/person/place_lived /eos
# Ground-Truth: 	helen guatemala /people/person/place_lived /eos
# ---
# Predict: 	iraq iraq /location/location/contains /eos
# Ground-Truth: 	romania black /location/location/contains /eos
# ---
# Predict: 	iran natanz /location/location/contains /eop
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	florida florida /location/location/contains /eos
# Ground-Truth: 	decatur agnes /location/location/contains /eos
# ---
# Predict: 	north north /people/person/place_lived /eos
# Ground-Truth: 	robin north /business/person/company /eos
# ---
# Predict: 	warren philippine /people/person/nationality /eos
# Ground-Truth: 	imelda philippine /people/person/nationality /eos
# ---
# Predict: 	warren miami /people/person/place_lived /eos
# Ground-Truth: 	charles woody /people/person/children /eos
# ---
# Predict: 	maryland baltimore /location/location/contains /eos
# Ground-Truth: 	maryland annapolis /location/location/contains /eos
# ---
# Predict: 	paris louvre /location/location/contains /eos
# Ground-Truth: 	paris gare /location/location/contains /eos
# ---
# Predict: 	michael yale /business/person/company /eos
# Ground-Truth: 	stephen case /business/person/company /eos
# ---
# Predict: 	boston boston /location/location/contains /eos
# Ground-Truth: 	boston church /location/location/contains /eos
# ---
# Predict: 	haley mississippi /people/person/place_lived /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---
# Predict: 	arkansas arkansas /people/person/place_lived /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---

# %% [markdown]
# ## Beam Search Evaluate

# %%
from keras.preprocessing.sequence import pad_sequences
from tqdm import tqdm

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4_pro/cp_logs/trival_true/weights.256-2.689965.hdf5'
model.load_weights(filename)

# %%
def greedysearch():
    pred = []
    for i in tqdm(range(395)):
        pR = []
        tag = 0
        fb_words = np.array([word2index['/go']])
        x = np.array([x_test[i]])
    
        for j in range(MAX_ADJL_LEN):
            fb_input = pad_sequences([fb_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
            prob = model.predict([x, fb_input], batch_size=BATCH_SIZE)[0][j]
            if j in [0, 1, 4, 5]:
                for item in [i for i in x_test[i] if i != 0]:
                    prob[item] = float(prob[item]+1)
            if j in [2, 6]:
                prob[:65135] = -1
            if j == 3:
                prob[:65132] = -1
                prob[65134:] = -1
            if j == 8:
                prob[65133] = float(prob[65133]+1)
            prob[0] = -1
            prob[tag] = -1
            result = prob.argmax()
            tag = result
            pR.append(result)
            fb_words = np.append(fb_words, result)
            if index2word[result] == '/eos':
                break
        pred.append(pR)
        
    pred = [[index2word[i] for i in sent if i != 0] for sent in pred]
    actu = [[index2word[i] for i in sent if i != 0] for sent in y_test]
    e1Count = sum([1 for i in range(395) if actu[i][0] == pred[i][0]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][3] == pred[i][3]])
    e2Count = sum([1 for i in range(395) if actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])
    enCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])      
    reCount = sum([1 for i in range(395) if actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]])
    tripleCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1] and actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]]) 
    print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
    print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
    print('En Accuracy: \t\t%.6f' % (enCount/396))
    print('Re Accuracy: \t\t%.6f' % (reCount/396))
    print('Triple Accuracy: \t%.6f' % (tripleCount/396))
    
    for i in range(395):
        print('Predict: \t%s' % ' '.join(pred[i]))
        print('Ground-Truth: \t%s' % ' '.join(actu[i]))
        print('---------')

# %%
greedysearch()
# Out:
# 100%|██████████| 395/395 [03:37<00:00,  1.76it/s]
# E1 Accuracy: 		0.330808
# E2 Accuracy: 		0.300505
# En Accuracy: 		0.176768
# Re Accuracy: 		0.487374
# Triple Accuracy: 	0.126263
# Predict: 	italy spain /location/location/contains /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---------
# Predict: 	connecticut long /location/location/contains /eos
# Ground-Truth: 	westchester connecticut /location/administrative_division/country /eos
# ---------
# Predict: 	israel jordan /location/country/capital /eop israel amman /location/location/contains /eos
# Ground-Truth: 	dalia israel /people/person/nationality /eos
# ---------
# Predict: 	india hyderabad /location/location/contains /eos
# Ground-Truth: 	hyderabad potti /location/location/contains /eos
# ---------
# Predict: 	north bush /location/location/contains /eos
# Ground-Truth: 	kent north /people/person/place_lived /eos
# ---------
# Predict: 	ontario waterloo /location/location/contains /eos
# Ground-Truth: 	ontario waterloo /location/location/contains /eos
# ---------
# Predict: 	stephen blackstone /business/person/company /eop stephen blackstone /business/person/company /eos
# Ground-Truth: 	blackstone stephen /business/company/founders /eos
# ---------
# Predict: 	italy spain /location/location/contains /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	iran russia /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	george abc /business/person/company /eos
# Ground-Truth: 	george abc /business/person/company /eos
# ---------
# Predict: 	florida jacksonville /location/location/contains /eos
# Ground-Truth: 	florida jacksonville /location/location/contains /eos
# ---------
# Predict: 	nigeria resort /location/location/contains /eos
# Ground-Truth: 	nigeria uyo /location/location/contains /eos
# ---------
# Predict: 	vermont rhode /location/location/contains /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---------
# Predict: 	kentucky patrick /location/location/contains /eos
# Ground-Truth: 	patrick huntington /people/person/place_lived /eos
# ---------
# Predict: 	germany berlin /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	a weinberg /business/person/company /eos
# Ground-Truth: 	jeffrey lazard /business/person/company /eos
# ---------
# Predict: 	israel gaza /location/country/capital /eop israel gaza /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	u.s. a /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	mark york /business/person/company /eos
# Ground-Truth: 	mark york /business/person/company /eos
# ---------
# Predict: 	australia rita /location/location/contains /eos
# Ground-Truth: 	markus australia /people/person/nationality /eos
# ---------
# Predict: 	princeton university /location/location/contains /eos
# Ground-Truth: 	kwame princeton /business/person/company /eos
# ---------
# Predict: 	deal a /business/person/company /eos
# Ground-Truth: 	endemol john /business/company/founders /eos
# ---------
# Predict: 	state month /location/location/contains /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---------
# Predict: 	george connecticut /people/person/place_lived /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---------
# Predict: 	iran russia /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	india state /location/location/contains /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---------
# Predict: 	bill elliott /business/person/company /eop bill elliott /business/person/company /eos
# Ground-Truth: 	bill dawsonville /people/person/place_lived /eos
# ---------
# Predict: 	british columbia /location/location/contains /eos
# Ground-Truth: 	daniel university /business/person/company /eos
# ---------
# Predict: 	russia soviet /location/location/contains /eos
# Ground-Truth: 	soviet russia /location/administrative_division/country /eos
# ---------
# Predict: 	boston johnson /location/location/contains /eos
# Ground-Truth: 	boston wbz-tv /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	a virginia /location/location/contains /eos
# Ground-Truth: 	virginia united /location/administrative_division/country /eos
# ---------
# Predict: 	security ira /business/company/founders /eos
# Ground-Truth: 	ira system /business/person/company /eos
# ---------
# Predict: 	a legal /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a hoboken /location/location/contains /eos
# Ground-Truth: 	anthony york /business/person/company /eos
# ---------
# Predict: 	a google /business/person/company /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---------
# Predict: 	evans a /location/location/contains /eos
# Ground-Truth: 	washington bainbridge /location/location/contains /eos
# ---------
# Predict: 	cross lrb /location/location/contains /eos
# Ground-Truth: 	washington olympia /location/location/contains /eos
# ---------
# Predict: 	south korea /location/location/contains /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---------
# Predict: 	spain france /location/administrative_division/country /eop spain france /location/administrative_division/country /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	a germany /people/person/nationality /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	a iraq /people/person/place_lived /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	player colorado /people/person/place_lived /eos
# Ground-Truth: 	kellen colorado /people/person/place_of_birth /eos
# ---------
# Predict: 	united france /people/person/nationality /eos
# Ground-Truth: 	tony france /people/person/nationality /eos
# ---------
# Predict: 	spain luis /location/location/contains /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---------
# Predict: 	include germany /people/person/nationality /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	island staten /location/neighborhood/neighborhood_of /eop island staten /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---------
# Predict: 	alternative nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	at&t san /location/neighborhood/neighborhood_of /eop at&t san /location/location/contains /eos
# Ground-Truth: 	ralph at&t /business/person/company /eos
# ---------
# Predict: 	connecticut hartford /location/location/contains /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---------
# Predict: 	somalia american /location/location/contains /eos
# Ground-Truth: 	somalia puntland /location/location/contains /eos
# ---------
# Predict: 	latvia riga /location/location/contains /eos
# Ground-Truth: 	riga latvia /location/administrative_division/country /eos
# ---------
# Predict: 	iran tehran /location/country/capital /eop iran tehran /location/location/contains /eos
# Ground-Truth: 	switzerland davos /location/location/contains /eos
# ---------
# Predict: 	free ski /location/location/contains /eos
# Ground-Truth: 	colorado vail /location/location/contains /eos
# ---------
# Predict: 	paris louvre /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	queen staten /location/location/contains /eos
# Ground-Truth: 	lower hudson /location/location/contains /eos
# ---------
# Predict: 	a san /location/neighborhood/neighborhood_of /eop a san /location/location/contains /eos
# Ground-Truth: 	san north /location/location/contains /eos
# ---------
# Predict: 	york county /location/location/contains /eos
# Ground-Truth: 	nassau suffolk /location/administrative_division/country /eos
# ---------
# Predict: 	youtube chad /business/company/founders /eop youtube chad /business/company/founders /eos
# Ground-Truth: 	chad youtube /business/person/company /eos
# ---------
# Predict: 	westchester city /location/location/contains /eos
# Ground-Truth: 	westchester kensico /location/location/contains /eos
# ---------
# Predict: 	susan maine /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	italy house /location/location/contains /eos
# Ground-Truth: 	italy orvieto /location/location/contains /eos
# ---------
# Predict: 	fresh university /location/location/contains /eos
# Ground-Truth: 	greenville furman /location/location/contains /eos
# ---------
# Predict: 	a princeton /business/person/company /eos
# Ground-Truth: 	charles princeton /business/person/company /eos
# ---------
# Predict: 	kentucky canada /location/location/contains /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	egypt sinai /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	john baltimore /people/person/place_lived /eos
# Ground-Truth: 	baltimore john /location/location/contains /eos
# ---------
# Predict: 	a india /people/person/nationality /eos
# Ground-Truth: 	samantha india /people/person/place_lived /eos
# ---------
# Predict: 	david kenny /business/person/company /eos
# Ground-Truth: 	david digitas /business/person/company /eos
# ---------
# Predict: 	iowa tom /location/location/contains /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---------
# Predict: 	rafik lebanon /people/person/nationality /eos
# Ground-Truth: 	rafik lebanon /people/person/nationality /eos
# ---------
# Predict: 	president abubakar /people/deceased_person/place_of_death /eos
# Ground-Truth: 	atiku nigeria /people/person/nationality /eos
# ---------
# Predict: 	a watching /location/location/contains /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---------
# Predict: 	a florida /people/person/place_lived /eos
# Ground-Truth: 	florida panama /location/location/contains /eos
# ---------
# Predict: 	iraq north /location/location/contains /eos
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	percent will /location/location/contains /eop percent will /location/location/contains /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---------
# Predict: 	town wall /location/location/contains /eos
# Ground-Truth: 	clarkstown city /location/location/contains /eos
# ---------
# Predict: 	india mumbai /location/location/contains /eos
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---------
# Predict: 	haley mississippi /people/person/place_lived /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	chief jetblue /business/person/company /eos
# Ground-Truth: 	gordon continental /business/person/company /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	san percent /location/location/contains /eop san percent /location/location/contains /eos
# Ground-Truth: 	california long /location/location/contains /eos
# ---------
# Predict: 	france time /location/location/contains /eos
# Ground-Truth: 	france correze /location/location/contains /eos
# ---------
# Predict: 	school county /location/location/contains /eos
# Ground-Truth: 	fairfax westfield /location/location/contains /eos
# ---------
# Predict: 	a palestinian /location/country/capital /eop a palestinian /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	city spain /people/person/nationality /eos
# Ground-Truth: 	spain valencia /location/location/contains /eos
# ---------
# Predict: 	iraq a /location/location/contains /eop iraq a /location/location/contains /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	greenwich jefferson /location/location/contains /eos
# Ground-Truth: 	greenwich jefferson /location/location/contains /eos
# ---------
# Predict: 	a hamas /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	france jacques /location/country/capital /eop france jacques /location/location/contains /eos
# Ground-Truth: 	jacques france /people/person/nationality /eos
# ---------
# Predict: 	ramapo mahwah /location/location/contains /eos
# Ground-Truth: 	mahwah ramapo /location/location/contains /eos
# ---------
# Predict: 	guyana money /location/country/capital /eop guyana money /location/location/contains /eos
# Ground-Truth: 	guyana linden /location/location/contains /eos
# ---------
# Predict: 	dr singh /people/person/place_of_birth /eos
# Ground-Truth: 	india punjab /location/location/contains /eos
# ---------
# Predict: 	ontario hill /location/location/contains /eos
# Ground-Truth: 	ontario tobermory /location/location/contains /eos
# ---------
# Predict: 	a iran /people/person/nationality /eos
# Ground-Truth: 	middle iran /location/location/contains /eos
# ---------
# Predict: 	a africa /people/person/place_lived /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a italy /people/person/nationality /eos
# Ground-Truth: 	italy israel /location/administrative_division/country /eos
# ---------
# Predict: 	spain france /location/administrative_division/country /eop spain france /location/administrative_division/country /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---------
# Predict: 	a google /business/person/company /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---------
# Predict: 	israel palestinian /location/location/contains /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	minnesota amy /location/location/contains /eos
# Ground-Truth: 	amy minnesota /people/person/place_lived /eos
# ---------
# Predict: 	australian australia /people/person/nationality /eos
# Ground-Truth: 	john australia /people/person/nationality /eos
# ---------
# Predict: 	kentucky ernie /location/location/contains /eos
# Ground-Truth: 	ernie kentucky /people/person/place_lived /eos
# ---------
# Predict: 	iran north /location/location/contains /eos
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---------
# Predict: 	india economic /location/location/contains /eos
# Ground-Truth: 	india bihar /location/country/administrative_divisions /eos
# ---------
# Predict: 	a ireland /location/location/contains /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---------
# Predict: 	1 cuba /people/person/nationality /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	italy house /location/location/contains /eos
# Ground-Truth: 	italy umbria /location/location/contains /eos
# ---------
# Predict: 	italy spain /location/location/contains /eos
# Ground-Truth: 	campania italy /location/administrative_division/country /eos
# ---------
# Predict: 	a iraq /people/person/place_lived /eos
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---------
# Predict: 	city sahn /people/person/place_lived /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	spain canada /location/location/contains /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	manhattan cleveland /location/location/contains /eos
# Ground-Truth: 	cleveland karamu /location/location/contains /eos
# ---------
# Predict: 	airport ireland /location/location/contains /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---------
# Predict: 	school seattle /location/location/contains /eos
# Ground-Truth: 	california san /location/location/contains /eos
# ---------
# Predict: 	france joyce /location/location/contains /eos
# Ground-Truth: 	france albertville /location/location/contains /eos
# ---------
# Predict: 	time eastern /location/location/contains /eos
# Ground-Truth: 	bosnia srebrenica /location/location/contains /eos
# ---------
# Predict: 	a manhattan /location/neighborhood/neighborhood_of /eop a manhattan /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	upper fort /location/location/contains /eos
# ---------
# Predict: 	pic chef /business/person/company /eos
# Ground-Truth: 	france valence /location/location/contains /eos
# ---------
# Predict: 	spain tampa /location/location/contains /eos
# Ground-Truth: 	james tampa /people/person/place_lived /eos
# ---------
# Predict: 	house president /business/person/company /eos
# Ground-Truth: 	syria damascus /location/country/administrative_divisions /eos
# ---------
# Predict: 	a marshall /location/location/contains /eos
# Ground-Truth: 	marshall fremont /people/deceased_person/place_of_death /eos
# ---------
# Predict: 	jerusalem israel /location/location/contains /eos
# Ground-Truth: 	israel jerusalem /location/location/contains /eos
# ---------
# Predict: 	sunni iraq /location/location/contains /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	cambridge university /location/location/contains /eos
# Ground-Truth: 	cambridge lesley /location/location/contains /eos
# ---------
# Predict: 	australia chris /location/location/contains /eos
# Ground-Truth: 	chris australia /people/person/nationality /eos
# ---------
# Predict: 	dennis rice /business/person/company /eos
# Ground-Truth: 	dennis disney /business/person/company /eos
# ---------
# Predict: 	company aspen /location/location/contains /eos
# Ground-Truth: 	colorado aspen /location/location/contains /eos
# ---------
# Predict: 	soviet seoul /location/country/capital /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---------
# Predict: 	fort staten /location/neighborhood/neighborhood_of /eop staten fort /location/location/contains /eos
# Ground-Truth: 	staten fort /location/location/contains /eos
# ---------
# Predict: 	syria damascus /location/location/contains /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	mexico city /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	a france /people/person/nationality /eos
# Ground-Truth: 	jean-louis france /people/person/nationality /eos
# ---------
# Predict: 	france airbus /location/location/contains /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---------
# Predict: 	jim kentucky /people/person/place_lived /eos
# Ground-Truth: 	jim kentucky /people/person/place_lived /eos
# ---------
# Predict: 	berlin germany /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	israel lebanon /location/location/contains /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	james brett /people/person/children /eos
# Ground-Truth: 	brett priceline /business/person/company /eos
# ---------
# Predict: 	center newark /location/location/contains /eos
# Ground-Truth: 	newark jersey /location/location/contains /eos
# ---------
# Predict: 	peter columbia /business/person/company /eos
# Ground-Truth: 	peter columbia /business/person/company /eos
# ---------
# Predict: 	mikhail diana /people/person/children /eos
# Ground-Truth: 	leningrad vaganova /location/location/contains /eos
# ---------
# Predict: 	a mexico /people/person/nationality /eos
# Ground-Truth: 	mexico jalisco /location/country/administrative_divisions /eos
# ---------
# Predict: 	westchester mamaroneck /location/location/contains /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---------
# Predict: 	europe iran /location/location/contains /eos
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---------
# Predict: 	seminole brittany /location/location/contains /eos
# Ground-Truth: 	brittany seminole /people/person/place_lived /eos
# ---------
# Predict: 	mexico city /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	germany munich /location/location/contains /eos
# Ground-Truth: 	germany munich /location/location/contains /eos
# ---------
# Predict: 	a switzerland /people/person/nationality /eos
# Ground-Truth: 	ernst davos /people/deceased_person/place_of_death /eos
# ---------
# Predict: 	a review /people/person/place_lived /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a baseball /people/person/place_lived /eop a baseball /people/person/place_of_birth /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	germany stuttgart /location/location/contains /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---------
# Predict: 	jeffrey general /business/person/company /eos
# Ground-Truth: 	jeffrey general /business/person/company /eos
# ---------
# Predict: 	a poland /people/person/nationality /eos
# Ground-Truth: 	poland cracow /location/location/contains /eos
# ---------
# Predict: 	senator minnesota /people/person/place_lived /eos
# Ground-Truth: 	norm minnesota /people/person/place_lived /eos
# ---------
# Predict: 	south iowa /location/location/contains /eos
# Ground-Truth: 	south iowa /location/administrative_division/country /eos
# ---------
# Predict: 	south michigan /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	kofmehl charleston /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	kofmehl charleston /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	will meet /people/person/place_lived /eop will meet /people/person/place_of_birth /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---------
# Predict: 	black robert /business/company/founders /eos
# Ground-Truth: 	black robert /business/company/founders /eos
# ---------
# Predict: 	a arkansas /people/person/place_lived /eos
# Ground-Truth: 	arkansas arkadelphia /location/location/contains /eos
# ---------
# Predict: 	a spain /location/administrative_division/country /eop a spain /location/administrative_division/country /eos
# Ground-Truth: 	navarre spain /location/administrative_division/country /eos
# ---------
# Predict: 	a grant /location/location/contains /eos
# Ground-Truth: 	toronto canada /location/administrative_division/country /eos
# ---------
# Predict: 	brooklyn coney /location/location/contains /eop coney brooklyn /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	coney york /location/location/contains /eos
# ---------
# Predict: 	washington amsterdam /location/location/contains /eos
# Ground-Truth: 	port harborside /location/location/contains /eos
# ---------
# Predict: 	iowa tom /location/location/contains /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---------
# Predict: 	israel gaza /location/country/capital /eop israel gaza /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	national california /location/location/contains /eos
# Ground-Truth: 	california lawrence /location/location/contains /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	mexico latin /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	york city /location/location/contains /eos
# Ground-Truth: 	lower york /location/neighborhood/neighborhood_of /eos
# ---------
# Predict: 	cruise lrb /people/person/place_of_birth /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	san county /location/location/contains /eos
# Ground-Truth: 	sonoma occidental /location/location/contains /eos
# ---------
# Predict: 	a christopher /people/person/children /eos
# Ground-Truth: 	christopher security /business/person/company /eos
# ---------
# Predict: 	a india /people/person/nationality /eos
# Ground-Truth: 	india hyderabad /location/location/contains /eos
# ---------
# Predict: 	subject kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	ben nebraska /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	gov rep /location/location/contains /eos
# Ground-Truth: 	tommy wisconsin /people/person/place_lived /eos
# ---------
# Predict: 	thailand general /location/location/contains /eos
# Ground-Truth: 	bangkok thailand /location/administrative_division/country /eos
# ---------
# Predict: 	parent foundation /location/location/contains /eos
# Ground-Truth: 	california malibu /location/location/contains /eos
# ---------
# Predict: 	berkeley boy /location/location/contains /eos
# Ground-Truth: 	ayelet berkeley /people/person/place_lived /eos
# ---------
# Predict: 	cuba american /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	kansa kathleen /location/location/contains /eos
# Ground-Truth: 	kathleen kansa /people/person/place_lived /eos
# ---------
# Predict: 	york greenwich /location/location/contains /eop greenwich york /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	york greenwich /location/location/contains /eos
# ---------
# Predict: 	senator kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	west bank /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	mount ted /location/location/contains /eos
# Ground-Truth: 	mount tanzania /location/administrative_division/country /eos
# ---------
# Predict: 	israel lebanon /location/location/contains /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	ireland margaret /location/location/contains /eos
# Ground-Truth: 	ireland athenry /location/location/contains /eos
# ---------
# Predict: 	iran tehran /location/country/capital /eop iran tehran /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	germany frankfurt /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	a israel /people/person/nationality /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	a russia /people/person/nationality /eos
# Ground-Truth: 	russia iran /location/administrative_division/country /eos
# ---------
# Predict: 	a university /location/location/contains /eos
# Ground-Truth: 	eugene university /location/location/contains /eos
# ---------
# Predict: 	spain well /location/location/contains /eos
# Ground-Truth: 	catalonia spain /location/administrative_division/country /eos
# ---------
# Predict: 	australia warren /location/location/contains /eos
# Ground-Truth: 	australia port /location/location/contains /eos
# ---------
# Predict: 	a indigenous /people/person/place_of_birth /eos
# Ground-Truth: 	evo bolivia /people/person/nationality /eos
# ---------
# Predict: 	heart germany /people/person/nationality /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	south will /location/location/contains /eos
# Ground-Truth: 	south darlington /location/location/contains /eos
# ---------
# Predict: 	a official /business/person/company /eos
# Ground-Truth: 	nelson zimbabwe /people/person/nationality /eos
# ---------
# Predict: 	a israel /location/location/contains /eos
# Ground-Truth: 	israel ra'anana /location/location/contains /eos
# ---------
# Predict: 	india state /location/location/contains /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	india a /location/location/contains /eos
# Ground-Truth: 	gujarat india /location/administrative_division/country /eos
# ---------
# Predict: 	cleveland county /location/location/contains /eos
# Ground-Truth: 	cuyahoga cleveland /location/location/contains /eos
# ---------
# Predict: 	florida princeton /location/location/contains /eos
# Ground-Truth: 	florida gulf /location/location/contains /eos
# ---------
# Predict: 	india delhi /location/country/capital /eop india delhi /location/location/contains /eos
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---------
# Predict: 	mexico 30 /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/location/contains /eos
# ---------
# Predict: 	india italy /location/location/contains /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	a israel /people/person/nationality /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	jerusalem museum /location/location/contains /eos
# Ground-Truth: 	jerusalem yad /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	italy well /location/location/contains /eos
# Ground-Truth: 	italy maranello /location/location/contains /eos
# ---------
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	ben nebraska /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	india state /location/location/contains /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---------
# Predict: 	bashar syria /people/person/nationality /eos
# Ground-Truth: 	bashar syria /people/person/nationality /eos
# ---------
# Predict: 	louisiana baton /location/location/contains /eos
# Ground-Truth: 	louisiana baton /location/location/contains /eos
# ---------
# Predict: 	nuclear iran /people/person/nationality /eos
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---------
# Predict: 	sony state /location/location/contains /eos
# Ground-Truth: 	sony akio /business/company/founders /eos
# ---------
# Predict: 	israel shimon /location/location/contains /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---------
# Predict: 	india italy /location/location/contains /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	southern art /location/location/contains /eos
# Ground-Truth: 	calabria crotone /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	a claim /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	group congress /business/person/company /eos
# Ground-Truth: 	derrick ford /business/person/company /eos
# ---------
# Predict: 	chicago west /location/location/contains /eos
# Ground-Truth: 	chicago west /location/location/contains /eos
# ---------
# Predict: 	carter virginia /people/person/place_lived /eos
# Ground-Truth: 	virginia middleburg /location/location/contains /eos
# ---------
# Predict: 	state oklahoma /location/location/contains /eos
# Ground-Truth: 	brad oklahoma /people/person/place_lived /eos
# ---------
# Predict: 	california berkeley /location/location/contains /eos
# Ground-Truth: 	california berkeley /location/location/contains /eos
# ---------
# Predict: 	italy germany /location/location/contains /eos
# Ground-Truth: 	italy germany /location/administrative_division/country /eos
# ---------
# Predict: 	chicago state /location/location/contains /eos
# Ground-Truth: 	cook chicago /location/location/contains /eos
# ---------
# Predict: 	suffolk ocean /location/location/contains /eos
# Ground-Truth: 	fire ocean /location/location/contains /eos
# ---------
# Predict: 	mexico central /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	republican kentucky /location/location/contains /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	president chief /business/person/company /eos
# Ground-Truth: 	shona google /business/person/company /eos
# ---------
# Predict: 	paris france /location/administrative_division/country /eop paris france /location/administrative_division/country /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	mexico juarez /location/location/contains /eos
# Ground-Truth: 	juarez mexico /location/administrative_division/country /eos
# ---------
# Predict: 	minister work /people/person/place_lived /eop minister work /people/person/place_of_birth /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	pavony israel /location/location/contains /eos
# Ground-Truth: 	israel rehovot /location/location/contains /eos
# ---------
# Predict: 	zeitlin rochelle /location/location/contains /eos
# Ground-Truth: 	will york /business/person/company /eos
# ---------
# Predict: 	boston juliet /location/location/contains /eop boston juliet /location/location/contains /eos
# Ground-Truth: 	juliet boston /business/person/company /eos
# ---------
# Predict: 	italy milan /location/location/contains /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	leader kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	capuchinas mexico /location/location/contains /eos
# Ground-Truth: 	mexico puebla /location/location/contains /eos
# ---------
# Predict: 	lrb rrb /people/person/place_of_birth /eos
# Ground-Truth: 	spain cordoba /location/location/contains /eos
# ---------
# Predict: 	senator kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	israel gaza /location/country/capital /eop israel gaza /location/country/capital /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	toronto mount /location/location/contains /eos
# Ground-Truth: 	toronto mount /location/location/contains /eos
# ---------
# Predict: 	india delhi /location/country/capital /eop india delhi /location/location/contains /eos
# Ground-Truth: 	delhi india /location/administrative_division/country /eos
# ---------
# Predict: 	canada calgary /location/location/contains /eos
# Ground-Truth: 	canada calgary /location/location/contains /eos
# ---------
# Predict: 	p.m. toronto /location/location/contains /eos
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---------
# Predict: 	woman player /people/person/nationality /eos
# Ground-Truth: 	nikolay russia /people/person/nationality /eos
# ---------
# Predict: 	a national /business/person/company /eos
# Ground-Truth: 	vali naval /business/person/company /eos
# ---------
# Predict: 	italy spain /location/location/contains /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---------
# Predict: 	paris de /location/location/contains /eos
# Ground-Truth: 	paris ecole /location/location/contains /eos
# ---------
# Predict: 	a amman /location/country/capital /eop a amman /location/location/contains /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---------
# Predict: 	europe a /location/location/contains /eos
# Ground-Truth: 	algeria algiers /location/country/capital /eos
# ---------
# Predict: 	a india /people/person/nationality /eos
# Ground-Truth: 	india dharamsala /location/location/contains /eos
# ---------
# Predict: 	florida lake /location/location/contains /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---------
# Predict: 	time washington /location/location/contains /eos
# Ground-Truth: 	donald washington /business/person/company /eos
# ---------
# Predict: 	france canada /location/location/contains /eos
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---------
# Predict: 	california republican /location/location/contains /eos
# Ground-Truth: 	dana california /people/person/place_lived /eos
# ---------
# Predict: 	germany nuremberg /location/location/contains /eos
# Ground-Truth: 	germany nuremberg /location/location/contains /eos
# ---------
# Predict: 	israel bank /location/location/contains /eos
# Ground-Truth: 	stanley bank /business/person/company /eos
# ---------
# Predict: 	park battery /location/neighborhood/neighborhood_of /eop park battery /location/location/contains /eos
# Ground-Truth: 	lower battery /location/location/contains /eos
# ---------
# Predict: 	lloyd museum /business/person/company /eos
# Ground-Truth: 	frank lloyd /people/person/children /eos
# ---------
# Predict: 	mexico stony /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	state lebanon /location/location/contains /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	peck york /people/deceased_person/place_of_death /eos
# Ground-Truth: 	york peck /location/location/contains /eos
# ---------
# Predict: 	russia iran /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	taiwan taipei /location/location/contains /eos
# Ground-Truth: 	taiwan taipei /location/location/contains /eos
# ---------
# Predict: 	sex iraqi /people/person/nationality /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	a spain /people/person/nationality /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	ontario st /location/location/contains /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---------
# Predict: 	israel shimon /location/location/contains /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---------
# Predict: 	baja a /location/location/contains /eos
# Ground-Truth: 	mexico baja /location/location/contains /eos
# ---------
# Predict: 	police india /people/person/nationality /eos
# Ground-Truth: 	india chhattisgarh /location/location/contains /eos
# ---------
# Predict: 	michoacan mexico /location/location/contains /eos
# Ground-Truth: 	michoacan mexico /location/administrative_division/country /eos
# ---------
# Predict: 	amansala mexico /location/location/contains /eos
# Ground-Truth: 	mexico tulum /location/location/contains /eos
# ---------
# Predict: 	atlanta university /location/location/contains /eos
# Ground-Truth: 	atlanta georgia /location/location/contains /eos
# ---------
# Predict: 	water year /location/location/contains /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---------
# Predict: 	australia libby /location/location/contains /eos
# Ground-Truth: 	libby australia /people/person/nationality /eos
# ---------
# Predict: 	spain general /location/location/contains /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---------
# Predict: 	a moscow /location/country/capital /eop a iran /location/location/contains /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---------
# Predict: 	mark hewlett-packard /business/person/company /eos
# Ground-Truth: 	mark hewlett-packard /business/person/company /eos
# ---------
# Predict: 	paris national /location/location/contains /eos
# Ground-Truth: 	paris musee /location/location/contains /eos
# ---------
# Predict: 	a 1938 /location/country/capital /eop a 1938 /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	houston harris /location/location/contains /eos
# Ground-Truth: 	harris houston /location/location/contains /eos
# ---------
# Predict: 	a cuba /people/person/nationality /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	puzzle time /business/person/company /eos
# Ground-Truth: 	will time /business/person/company /eos
# ---------
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	chicago york /location/location/contains /eos
# Ground-Truth: 	chicago winston /location/location/contains /eos
# ---------
# Predict: 	energy rocky /business/person/company /eos
# Ground-Truth: 	amory rocky /business/person/company /eos
# ---------
# Predict: 	rochester eastman /location/location/contains /eos
# Ground-Truth: 	rochester george /location/location/contains /eos
# ---------
# Predict: 	mexico cancun /location/location/contains /eos
# Ground-Truth: 	mexico cancun /location/location/contains /eos
# ---------
# Predict: 	a river /location/location/contains /eos
# Ground-Truth: 	idaho salmon /location/location/contains /eos
# ---------
# Predict: 	africa ghana /location/location/contains /eos
# Ground-Truth: 	west senegal /location/location/contains /eos
# ---------
# Predict: 	a manhattan /location/neighborhood/neighborhood_of /eop a manhattan /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---------
# Predict: 	txu group /business/person/company /eos
# Ground-Truth: 	stephen blackstone /business/person/company /eos
# ---------
# Predict: 	ontario university /location/location/contains /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---------
# Predict: 	park a /location/location/contains /eos
# Ground-Truth: 	westport winslow /location/location/contains /eos
# ---------
# Predict: 	baltimore cornell /location/location/contains /eos
# Ground-Truth: 	baltimore m&t /location/location/contains /eos
# ---------
# Predict: 	washington walter /location/location/contains /eos
# Ground-Truth: 	washington walter /location/location/contains /eos
# ---------
# Predict: 	mexico united /location/location/contains /eos
# Ground-Truth: 	guanajuato mexico /location/administrative_division/country /eos
# ---------
# Predict: 	india central /location/location/contains /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---------
# Predict: 	italy france /people/person/nationality /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	york university /location/location/contains /eos
# Ground-Truth: 	dennis york /business/person/company /eos
# ---------
# Predict: 	5 kansa /people/person/place_lived /eos
# Ground-Truth: 	kansa atchison /location/location/contains /eos
# ---------
# Predict: 	hospital boston /location/neighborhood/neighborhood_of /eop hospital boston /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	boston massachusetts /location/location/contains /eos
# ---------
# Predict: 	mount a /location/location/contains /eos
# Ground-Truth: 	washington mount /location/location/contains /eos
# ---------
# Predict: 	cuba naval /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	department right /location/location/contains /eos
# Ground-Truth: 	washington united /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	free spain /people/person/nationality /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	bill white /people/person/place_lived /eos
# Ground-Truth: 	eddie reebok /business/person/company /eos
# ---------
# Predict: 	ontario st /location/location/contains /eos
# Ground-Truth: 	ontario st /location/location/contains /eos
# ---------
# Predict: 	iraq nebraska /location/location/contains /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	florida john /location/location/contains /eos
# Ground-Truth: 	florida ponte /location/location/contains /eos
# ---------
# Predict: 	korea a /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	florida lake /location/location/contains /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---------
# Predict: 	miami chicago /location/location/contains /eos
# Ground-Truth: 	chicago sears /location/location/contains /eos
# ---------
# Predict: 	webkinz ontario /location/country/capital /eop webkinz ontario /location/location/contains /eos
# Ground-Truth: 	ontario woodbridge /location/location/contains /eos
# ---------
# Predict: 	washington congress /location/location/contains /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---------
# Predict: 	guinea people /location/country/capital /eop guinea people /location/location/contains /eos
# Ground-Truth: 	guinea conakry /location/country/capital /eos
# ---------
# Predict: 	iowa waterloo /location/location/contains /eos
# Ground-Truth: 	iowa waterloo /location/location/contains /eos
# ---------
# Predict: 	italy sorrento /location/location/contains /eos
# Ground-Truth: 	italy amalfi /location/location/contains /eos
# ---------
# Predict: 	a lrb /people/person/place_of_birth /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	jersey hudson /location/location/contains /eos
# Ground-Truth: 	westchester hudson /location/location/contains /eos
# ---------
# Predict: 	a georgia /people/person/place_lived /eos
# Ground-Truth: 	g. georgia /business/person/company /eos
# ---------
# Predict: 	cuba bush /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	hill blue /location/location/contains /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---------
# Predict: 	israel gaza /location/country/capital /eop israel gaza /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	photographer time /business/person/company /eos
# Ground-Truth: 	tyler york /business/person/company /eos
# ---------
# Predict: 	india italy /location/location/contains /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	france canada /location/location/contains /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---------
# Predict: 	government toledo /location/location/contains /eos
# Ground-Truth: 	toledo ottawa /location/location/contains /eos
# ---------
# Predict: 	namibia alexander /location/location/contains /eos
# Ground-Truth: 	namibia windhoek /location/location/contains /eos
# ---------
# Predict: 	united mamaroneck /location/location/contains /eos
# Ground-Truth: 	mamaroneck united /location/location/contains /eos
# ---------
# Predict: 	vermont stowe /location/location/contains /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---------
# Predict: 	work france /people/person/nationality /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	france airbus /location/location/contains /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---------
# Predict: 	iraq syria /location/location/contains /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---------
# Predict: 	france black /location/location/contains /eos
# Ground-Truth: 	corsica france /location/administrative_division/country /eos
# ---------
# Predict: 	syria damascus /location/location/contains /eos
# Ground-Truth: 	syria damascus /location/location/contains /eos
# ---------
# Predict: 	india british /location/location/contains /eos
# Ground-Truth: 	shilpa india /people/person/nationality /eos
# ---------
# Predict: 	finland a /location/location/contains /eos
# Ground-Truth: 	finland turku /location/location/contains /eos
# ---------
# Predict: 	director germany /people/person/nationality /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---------
# Predict: 	boston beth /location/location/contains /eos
# Ground-Truth: 	boston beth /location/location/contains /eos
# ---------
# Predict: 	chairman gov /people/person/place_lived /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---------
# Predict: 	drexler rockland /people/deceased_person/place_of_death /eos
# Ground-Truth: 	rockland city /location/location/contains /eos
# ---------
# Predict: 	a harvard /business/person/company /eos
# Ground-Truth: 	martin national /business/person/company /eos
# ---------
# Predict: 	peter toronto /people/person/place_lived /eos
# Ground-Truth: 	toronto barrick /location/location/contains /eos
# ---------
# Predict: 	lake chicago /location/location/contains /eos
# Ground-Truth: 	lake chicago /location/administrative_division/country /eos
# ---------
# Predict: 	mass bedford /location/location/contains /eos
# Ground-Truth: 	marlborough cytyc /location/location/contains /eos
# ---------
# Predict: 	france southern /location/location/contains /eos
# Ground-Truth: 	france alzonne /location/location/contains /eos
# ---------
# Predict: 	african art /location/location/contains /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---------
# Predict: 	mexico juarez /location/country/administrative_divisions /eop mexico juarez /location/country/administrative_divisions /eos
# Ground-Truth: 	mexico ciudad /location/location/contains /eos
# ---------
# Predict: 	american administration /location/location/contains /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	west bank /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	audubon vermont /location/location/contains /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---------
# Predict: 	a north /location/location/contains /eos
# Ground-Truth: 	connecticut hamden /location/location/contains /eos
# ---------
# Predict: 	russia system /location/location/contains /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eop russia iran /location/administrative_division/country /eos
# ---------
# Predict: 	syria iran /location/location/contains /eos
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---------
# Predict: 	a nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	iowa fall /location/location/contains /eos
# Ground-Truth: 	iowa waverly /location/location/contains /eos
# ---------
# Predict: 	boston cuba /location/location/contains /eos
# Ground-Truth: 	cuba bayamo /location/location/contains /eos
# ---------
# Predict: 	africa south /location/location/contains /eos
# Ground-Truth: 	aziz south /people/person/nationality /eos
# ---------
# Predict: 	university canada /location/location/contains /eos
# Ground-Truth: 	italy reggio /location/location/contains /eos
# ---------
# Predict: 	iran washington /location/location/contains /eos
# Ground-Truth: 	iran washington /location/administrative_division/country /eos
# ---------
# Predict: 	park mountain /location/location/contains /eos
# Ground-Truth: 	hampshire cannon /location/location/contains /eos
# ---------
# Predict: 	helen guatemala /people/person/place_lived /eos
# Ground-Truth: 	helen guatemala /people/person/place_lived /eos
# ---------
# Predict: 	iraq afghanistan /location/country/capital /eop iraq afghanistan /location/location/contains /eos
# Ground-Truth: 	romania black /location/location/contains /eos
# ---------
# Predict: 	iran syria /location/location/contains /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	college florida /location/neighborhood/neighborhood_of /eop college florida /location/location/contains /eos
# Ground-Truth: 	decatur agnes /location/location/contains /eos
# ---------
# Predict: 	natural north /people/person/place_lived /eos
# Ground-Truth: 	robin north /business/person/company /eos
# ---------
# Predict: 	love philippine /people/person/nationality /eos
# Ground-Truth: 	imelda philippine /people/person/nationality /eos
# ---------
# Predict: 	harrelson woody /people/person/place_lived /eos
# Ground-Truth: 	charles woody /people/person/children /eos
# ---------
# Predict: 	a maryland /location/location/contains /eos
# Ground-Truth: 	maryland annapolis /location/location/contains /eos
# ---------
# Predict: 	paris gare /location/location/contains /eos
# Ground-Truth: 	paris gare /location/location/contains /eos
# ---------
# Predict: 	good case /business/person/company /eos
# Ground-Truth: 	stephen case /business/person/company /eos
# ---------
# Predict: 	boston bay /location/location/contains /eop boston bay /location/location/contains /eos
# Ground-Truth: 	boston church /location/location/contains /eos
# ---------
# Predict: 	haley mississippi /people/person/place_lived /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---------
# Predict: 	democrat rhode /people/person/place_lived /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---------

# %%
def beamsearch(NUM_BEAMS):
    pred = []
    for i in tqdm(range(395)):
        fb_words = np.array([word2index['/go']])
        x = np.array([x_test[i]])
    
        st_words = np.array([word2index['/go']])
        st_input = pad_sequences([st_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
        prob = model.predict([x, st_input], batch_size=BATCH_SIZE)[0][0]
        prob[0] = -1
        for item in [i for i in x_test[i] if i != 0]:
            prob[item] = float(prob[item]+1)
        beam = {}
        for _ in range(NUM_BEAMS):
            b = prob.argmax()
            beam[b] = float(prob[b])
            prob[b] = -1
        
        allResult = []
        for b, s in beam.items():
            pR = [b]
            fb_words = np.append(fb_words, b)
            tag = b
            for j in range(1, MAX_ADJL_LEN):
                fb_input = pad_sequences([fb_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
                prob = model.predict([x, fb_input], batch_size=BATCH_SIZE)[0][j]
                if j in [1, 4, 5]:
                    for item in [i for i in x_test[i] if i != 0]:
                        prob[item] = float(prob[item]+1)
                if j in [2, 6]:
                    prob[:65135] = -1
                if j == 3:
                    prob[:65132] = -1
                    prob[65134:] = -1
                if j == 8:
                    prob[65133] = float(prob[65133]+1)                
                prob[0] = -1
                prob[tag] = -1
                result = prob.argmax()
                beam[b] += float(prob[result])
                tag = result
                pR.append(result)
                fb_words = np.append(fb_words, result)
                if index2word[result] == '/eos':
                    break
            allResult.append(pR)
        pR = sum([i for i in allResult if i[0] == max(beam, key=lambda x: beam[x])], [])
        pred.append(pR)

    pred = [[index2word[i] for i in sent if i != 0] for sent in pred]
    actu = [[index2word[i] for i in sent if i != 0] for sent in y_test]
    e1Count = sum([1 for i in range(395) if actu[i][0] == pred[i][0]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][3] == pred[i][3]])
    e2Count = sum([1 for i in range(395) if actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])
    enCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])      
    reCount = sum([1 for i in range(395) if actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]])
    tripleCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1] and actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]]) 
    print('Beam: \t\t\t%d' % NUM_BEAMS)
    print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
    print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
    print('En Accuracy: \t\t%.6f' % (enCount/396))
    print('Re Accuracy: \t\t%.6f' % (reCount/396))
    print('Triple Accuracy: \t%.6f' % (tripleCount/396))

# %%
for NUM_BEAMS in range(5, 6):
    beamsearch(NUM_BEAMS)
# Out:
# 100%|██████████| 395/395 [15:25<00:00,  2.56s/it]
# Beam: 			5
# E1 Accuracy: 		0.411616
# E2 Accuracy: 		0.277778
# En Accuracy: 		0.176768
# Re Accuracy: 		0.487374
# Triple Accuracy: 	0.128788

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(preResult[i]))
    print('Ground-Truth: \t%s' % ' '.join(actResult[i]))
    print('---')
