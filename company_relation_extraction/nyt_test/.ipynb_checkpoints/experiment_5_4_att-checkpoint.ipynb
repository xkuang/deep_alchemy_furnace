# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></div><div class="lev2 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load Data</a></div><div class="lev3 toc-item"><a href="#Load-Train-Data" data-toc-modified-id="Load-Train-Data-111"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Load Train Data</a></div><div class="lev3 toc-item"><a href="#Load-Test-Data" data-toc-modified-id="Load-Test-Data-112"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Load Test Data</a></div><div class="lev3 toc-item"><a href="#Relation-Types" data-toc-modified-id="Relation-Types-113"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Relation Types</a></div><div class="lev2 toc-item"><a href="#Participle" data-toc-modified-id="Participle-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Participle</a></div><div class="lev2 toc-item"><a href="#Make-Adjacency-List" data-toc-modified-id="Make-Adjacency-List-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Make Adjacency List</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Train-Data" data-toc-modified-id="Make-Adjacency-List-of-Train-Data-131"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Make Adjacency List of Train Data</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Test-Data" data-toc-modified-id="Make-Adjacency-List-of-Test-Data-132"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Make Adjacency List of Test Data</a></div><div class="lev1 toc-item"><a href="#Word-to-Vector" data-toc-modified-id="Word-to-Vector-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Word to Vector</a></div><div class="lev2 toc-item"><a href="#Tokenize-Text" data-toc-modified-id="Tokenize-Text-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Tokenize Text</a></div><div class="lev2 toc-item"><a href="#Create-Word-Embeddings-with-GloVe" data-toc-modified-id="Create-Word-Embeddings-with-GloVe-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Create Word Embeddings with GloVe</a></div><div class="lev3 toc-item"><a href="#Read-GloVe" data-toc-modified-id="Read-GloVe-221"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Read GloVe</a></div><div class="lev3 toc-item"><a href="#Use-Glove-to-Initialize-Embedding-Matrix" data-toc-modified-id="Use-Glove-to-Initialize-Embedding-Matrix-222"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Use Glove to Initialize Embedding Matrix</a></div><div class="lev1 toc-item"><a href="#Build-Dateset" data-toc-modified-id="Build-Dateset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Build Dateset</a></div><div class="lev1 toc-item"><a href="#Save-Dataset" data-toc-modified-id="Save-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Save Dataset</a></div><div class="lev1 toc-item"><a href="#Checkpoint" data-toc-modified-id="Checkpoint-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Checkpoint</a></div><div class="lev1 toc-item"><a href="#Build-Model" data-toc-modified-id="Build-Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Build Model</a></div><div class="lev2 toc-item"><a href="#Set-Hyperparameters" data-toc-modified-id="Set-Hyperparameters-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Set Hyperparameters</a></div><div class="lev2 toc-item"><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Import Libraries</a></div><div class="lev2 toc-item"><a href="#Build-Graph" data-toc-modified-id="Build-Graph-63"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Build Graph</a></div><div class="lev2 toc-item"><a href="#Model-Visualization" data-toc-modified-id="Model-Visualization-64"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Model Visualization</a></div><div class="lev2 toc-item"><a href="#Train" data-toc-modified-id="Train-65"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Train</a></div><div class="lev1 toc-item"><a href="#Evaluate" data-toc-modified-id="Evaluate-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Evaluate</a></div><div class="lev2 toc-item"><a href="#Naive-Evaluate" data-toc-modified-id="Naive-Evaluate-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Naive Evaluate</a></div><div class="lev2 toc-item"><a href="#Beam-Search-Evaluate" data-toc-modified-id="Beam-Search-Evaluate-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Beam Search Evaluate</a></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Load Train Data

# %%
import json

# %%
sentText = []
relationMentions = []
relationLabels = []
entityMentions = []
entityLabels = []
em1Text = []
em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/train.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    # Exclude "None" label
    if not all(i['label'] == 'None' for i in item['relationMentions']):
        sentText.append(item['sentText'])
        relationMentions.append(item['relationMentions'])
        entityMentions.append(item['entityMentions'])
    
relationLabels = [[i['label'] for i in rM] for rM in relationMentions]
entityLabels = [[i['text'] for i in eM] for eM in entityMentions]
em1Text = [[i['em1Text'] for i in rM] for rM in relationMentions]
em2Text = [[i['em2Text'] for i in rM] for rM in relationMentions]

# %%
# Clean words
replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
em1Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em1Text]
em2Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em2Text]

# %% [markdown]
# ### Load Test Data

# %%
t_sentText = []
t_relationMentions = []
t_relationLabels = []
t_entityMentions = []
t_entityLabels = []
t_em1Text = []
t_em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/test.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    t_sentText.append(item['sentText'])
    t_relationMentions.append(item['relationMentions'])
    t_entityMentions.append(item['entityMentions'])
    
t_relationLabels = [[i['label'] for i in rM] for rM in t_relationMentions]
t_entityLabels = [[i['text'] for i in eM] for eM in t_entityMentions]
t_em1Text = [[i['em1Text'] for i in rM] for rM in t_relationMentions]
t_em2Text = [[i['em2Text'] for i in rM] for rM in t_relationMentions]

# %%
# Clean words
t_replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
t_em1Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em1Text]
t_em2Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em2Text]
t_entityLabels = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_entityLabels]

# %% [markdown]
# ###  Relation Types

# %%
relationTypes = list(set([r for rl in relationLabels for r in rl]))
relationTypes
# Out:
# ['/people/person/nationality',
#  '/people/person/place_lived',
#  '/people/person/ethnicity',
#  '/sports/sports_team/location',
#  '/location/neighborhood/neighborhood_of',
#  '/location/country/capital',
#  '/location/administrative_division/country',
#  '/business/person/company',
#  '/people/person/children',
#  '/location/location/contains',
#  '/business/company/place_founded',
#  '/people/ethnicity/people',
#  '/people/deceased_person/place_of_death',
#  '/people/person/profession',
#  '/location/country/administrative_divisions',
#  '/people/ethnicity/geographic_distribution',
#  '/business/company/founders',
#  '/business/company/industry',
#  '/people/person/place_of_birth',
#  '/business/company_shareholder/major_shareholder_of',
#  '/business/company/major_shareholders',
#  '/business/company/advisors',
#  '/sports/sports_team_location/teams',
#  '/people/person/religion']

# %%
t_relationTypes = list(set([r for rl in t_relationLabels for r in rl if r != 'None']))
t_relationTypes
# Out:
# ['/people/person/nationality',
#  '/people/person/place_of_birth',
#  '/people/deceased_person/place_of_death',
#  '/business/person/company',
#  '/people/person/children',
#  '/location/location/contains',
#  '/people/person/place_lived',
#  '/location/country/administrative_divisions',
#  '/business/company/founders',
#  '/location/neighborhood/neighborhood_of',
#  '/location/country/capital',
#  '/location/administrative_division/country']

# %% [markdown]
# ## Participle

# %%
from nltk import regexp_tokenize

# %%
def cut(s):
    """
    Participle
    """
    pattern = r'''
              (?x)                   # set flag to allow verbose regexps 
              (?:[A-Z]\.)+           # abbreviations, e.g. U.S.A. 
              |\d+(?:\.\d+)?%?       # numbers, incl. currency and percentages 
              |\w+(?:[-&']\w+)*       # words w/ optional internal hyphens/apostrophe  
           '''  
    return regexp_tokenize(s, pattern=pattern)

# %%
filename = "stopwords_666.txt"
stopWords = {w: None for w in open(filename).read().split()}

# %%
sentWords = [cut(s) for s in sentText]
entlabWords = [[cut(s) for s in eL] for eL in entityLabels]
em1Words = [[cut(s) for s in eL] for eL in em1Text]
em2Words = [[cut(s) for s in eL] for eL in em2Text]
t_sentWords = [cut(s) for s in t_sentText]
t_entlabWords = [[cut(s) for s in eL] for eL in t_entityLabels]
t_em1Words = [[cut(s) for s in eL] for eL in t_em1Text]
t_em2Words = [[cut(s) for s in eL] for eL in t_em2Text]
# Clean words
t_sentWords = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_sentWords]

# %%
# Delete stopwords
for n in range(len(sentWords)):
    sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in sentWords[n]] if i != None]
    entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in entlabWords[n]]
    entlabWords[n] = [[i for i in item if i != None] for item in entlabWords[n]]
    em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em1Words[n]]
    em1Words[n] = [[i for i in item if i != None] for item in em1Words[n]]
    em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em2Words[n]]
    em2Words[n] = [[i for i in item if i != None] for item in em2Words[n]] 

for n in range(len(t_sentWords)):
    t_sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in t_sentWords[n]] if i != None]
    t_entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_entlabWords[n]]
    t_entlabWords[n] = [[i for i in item if i != None] for item in t_entlabWords[n]]
    t_em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em1Words[n]]
    t_em1Words[n] = [[i for i in item if i != None] for item in t_em1Words[n]]
    t_em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em2Words[n]]
    t_em2Words[n] = [[i for i in item if i != None] for item in t_em2Words[n]]

# %%
#max([len(i) for i in t_sentWords])

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8

# %% [markdown]
# ## Make Adjacency List

# %% [markdown]
# ### Make Adjacency List of Train Data

# %%
from collections import Counter

# %%
i_entityLabels = []
for i in range(len(sentWords)):
    eL = []
    sDict = list(enumerate(sentWords[i]))
    j = 0
    for item in entlabWords[i]:
        el = []
        for e in item:
            while j < len(sDict):
                if e == sDict[j][1]:
                    el.append(sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    i_entityLabels.append(eL)

# %%
rmSet = []
for item in range(len(relationMentions)):
    rms = [(em1Words[item][i][0], em2Words[item][i][0], relationLabels[item][i]) for i in range(len(relationLabels[item]))]
    rms = [' '.join(list(i)) for i in rms]
    rmSet.append(rms)
rmSet = [set(i) for i in rmSet]

# %%
i_adjacencyList = []
new_sentWords = []
pad = ['/eop', '/eos']
for n in range(len(sentWords)):
    aL = []
    for l in range(len(relationLabels[n])):
        e1 = []
        e2 = []
        for item in i_entityLabels[n]:
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em2Words[n][l]):
                e2.append(item[0])
        c1 = [(a, b) for a in e1 for b in e2 if ' '.join([sentWords[n][a], sentWords[n][b], relationLabels[n][l]]) in rmSet[n]]
        c2 = [(a, b) for a in e2 for b in e1 if ' '.join([sentWords[n][b], sentWords[n][a], relationLabels[n][l]]) in rmSet[n]]
        c = c1 + c2
        m = min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[-1]
        r = [i[0] for i in [(i, abs(j[0]-j[1])) for i, j in enumerate(c)] if i[-1] == m]
        for i in r:
            if ' '.join([sentWords[n][c[i][0]], sentWords[n][c[i][1]], relationLabels[n][l]]) in rmSet[n]:
                al = (c[i][0], c[i][1], relationLabels[n][l], pad[0])
                if al[2] in t_relationTypes and al[0] < MAX_SENT_LEN and al[1] < MAX_SENT_LEN: 
                    aL.append(al)
    aL = sorted([list(i) for i in set(aL)])
    if len(aL) == 1 or len(aL) == 2:
        i_adjacencyList.append(aL)
        new_sentWords.append(sentWords[n])
i_adjacencyList = [sum(i, []) for i in i_adjacencyList]
for i in i_adjacencyList:
    i[-1] = pad[-1]

# %% [markdown]
# ### Make Adjacency List of Test Data

# %%
ti_entityLabels = []
for i in range(len(t_sentWords)):
    eL = []
    t_sDict = list(enumerate(t_sentWords[i]))
    j = 0
    for item in t_entlabWords[i]:
        el = []
        for e in item:
            while j < len(t_sDict):
                if e == t_sDict[j][1]:
                    el.append(t_sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    ti_entityLabels.append(eL)

# %%
ti_trueLables = [[i for i, j in enumerate(rl) if j != 'None'] for rl in t_relationLabels]
t_trueMentions = [[j for i, j in enumerate(rl) if j['label'] != 'None'] for rl in t_relationMentions]
pad = ['/eop', '/eos']
ti_adjacencyList = []
for n in range(len(t_sentWords)): 
    e1 = []
    e2 = []
    aL = []
    for l in ti_trueLables[n]:
        for item in ti_entityLabels[n]:
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em2Words[n][l]):
                e2.append(item[0])
    c = [(a, b) for a in e1 for b in e2]
    r = c[min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[0]]
    aL = aL + [r[0], r[1], t_relationLabels[n][l], pad[-1]]
    ti_adjacencyList.append(aL)

# Modify 
#ti_adjacencyList[26] = [18, 20, '/business/company/founders', pad[-1]]
ti_adjacencyList[191] = [13, 19, '/location/administrative_division/country', pad[0], 18, 19, '/location/administrative_division/country', pad[-1]]

# %%
#max([max(sum(i, [])) for i in ti_entityLabels])

# %% [markdown]
# # Word to Vector

# %% [markdown]
# ## Tokenize Text

# %%
from keras.preprocessing.text import Tokenizer
from nltk import WordNetLemmatizer
# Out:
# Using TensorFlow backend.

# %%
wnl = WordNetLemmatizer()
sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in new_sentWords]
t_sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in t_sentWords]
tok_sentWords = sentWords.copy()
tok_sentWords.extend(t_sentWords)
tokTexts = [' '.join(i) for i in tok_sentWords]

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts(tokTexts)
word2index = tokenizer.word_index
for i in [i for i in zip(list(range(65132, 65147)), pad+['/go']+t_relationTypes)]:
    word2index[i[-1]] = i[0]
index2word = {i: w for w, i in word2index.items()}
print('Found %s unique tokens.' % len(word2index))
# Out:
# Found 65146 unique tokens.

# %% [markdown]
# ## Create Word Embeddings with GloVe

# %%
VOCAB_SIZE = 65147
EMBEDDING_SIZE = 300
SEED = 42

# %% [markdown]
# ### Read GloVe

# %%
import numpy as np

# %%
#glove_n_symbols = !wc -l /Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt
#glove_n_symbols = int(glove_n_symbols[0].split()[0])
glove_n_symbols = 1917495

# %%
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_n_symbols, EMBEDDING_SIZE))
globale_scale = 0.1
with open('/Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt', 'r') as fp:
    index = 0
    for l in fp:
        l = l.strip().split()
        word = l[0]
        glove_index_dict[word] = index
        glove_embedding_weights[index, :] = [float(n) for n in l[1:]]
        index += 1
glove_embedding_weights *= globale_scale

# %% [markdown]
# ### Use Glove to Initialize Embedding Matrix

# %%
from nltk import PorterStemmer, LancasterStemmer

# %%
# Generate random embedding with same scale as glove
np.random.seed(SEED)
shape = (VOCAB_SIZE, EMBEDDING_SIZE)
scale = glove_embedding_weights.std() * np.sqrt(12) / 2 
embedding = np.random.uniform(low=-scale, high=scale, size=shape)

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()

# %%
# Copy from glove weights of words that appear in index2word
count = 0 
for i in range(1, 65132):
    w = index2word[i]
    g = glove_index_dict.get(w)
    if g is None:
        w = porter.stem(w)
        g = glove_index_dict.get(w)
    if g is None:
        w = lancaster.stem(w)
        g = glove_index_dict.get(w)
    if g is not None:
        embedding[i, :] = glove_embedding_weights[g, :]
        count += 1
print('{num_tokens}-{per:.2f}% tokens in vocab found in glove and copied to embedding.'.format(num_tokens=count, per=count/float(VOCAB_SIZE)*100))
# Out:
# 60641-93.08% tokens in vocab found in glove and copied to embedding.

# %%
for i in range(65132, 65147):
    item = np.random.uniform(low=-scale, high=scale, size=(EMBEDDING_SIZE,))
    item[i-65132] = 1
    embedding[i, :] = item

# %% [markdown]
# # Build Dateset

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
new_sentText = [' '.join(i) for i in sentWords]
sentSeq = tokenizer.texts_to_sequences(new_sentText)
sentData = pad_sequences(sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

t_new_sentText = [' '.join(i) for i in t_sentWords]
t_sentSeq = tokenizer.texts_to_sequences(t_new_sentText)
t_sentData = pad_sequences(t_sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

new_adjacencyList = [[sentWords[c][j] if i < 2 or i == 4 or i == 5 else j for i, j in enumerate(item)] for c, item in enumerate(i_adjacencyList)]
adjlText = [' '.join(i) for i in new_adjacencyList]
adjlSeq = tokenizer.texts_to_sequences(adjlText)
adjlData = pad_sequences(adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

newt_adjacencyList = [[t_sentWords[c][j] if i < 2 or i == 4 or i == 5 else j for i, j in enumerate(item)] for c, item in enumerate(ti_adjacencyList)]
t_adjlText = [' '.join(i) for i in newt_adjacencyList]
t_adjlSeq = tokenizer.texts_to_sequences(t_adjlText)
t_adjlData = pad_sequences(t_adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

[i.insert(0, '/go') for i in new_adjacencyList];
adjlText = [' '.join(i) for i in new_adjacencyList]
adjlSeq = tokenizer.texts_to_sequences(adjlText)
tfData = pad_sequences(adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

[i.insert(0, '/go') for i in newt_adjacencyList];
t_adjlText = [' '.join(i) for i in newt_adjacencyList]
t_adjlSeq = tokenizer.texts_to_sequences(t_adjlText)
t_tfData = pad_sequences(t_adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

# %%
# Split the data into a training set, a validation set and a test set
x_train_all = sentData
tf_train_all = tfData
y_train_all = adjlData

x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, test_size=0.15, random_state=SEED)
tf_train, tf_val, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0.15, random_state=SEED)

x_train_all, _, y_train_all, _  = train_test_split(x_train_all, y_train_all, test_size=0., random_state=SEED)
tf_train_all, _, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0., random_state=SEED)
 
x_test = t_sentData
tf_test = t_tfData
y_test = t_adjlData

x_test, _, y_test, _ = train_test_split(x_test, y_test, test_size=0., random_state=SEED)
tf_test, _, _, _ = train_test_split(tf_test, tf_test, test_size=0., random_state=SEED)

# %% [markdown]
# # Save Dataset

# %%
import h5py
import pickle

# %%
fh = h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/allData.h5', 'w')
fh['x_train'] = x_train
fh['tf_train'] = tf_train
fh['y_train'] = y_train
fh['x_val'] = x_val
fh['tf_val'] = tf_val
fh['y_val'] = y_val
fh['x_train_all'] = x_train_all
fh['tf_train_all'] = tf_train_all
fh['y_train_all'] = y_train_all
fh['x_test'] = x_test
fh['tf_test'] = tf_test
fh['y_test'] = y_test
fh['embedding'] = embedding
fh.close()

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/index.pkl', 'wb') as fp:
    pickle.dump((word2index, index2word), fp, -1)

# %% [markdown]
# # Checkpoint

# %%
import h5py
import pickle

# %%
with h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/allData.h5', 'r') as fh:
    x_train = fh['x_train'][:]
    tf_train = fh['tf_train'][:]
    y_train = fh['y_train'][:]
    x_val = fh['x_val'][:]
    tf_val = fh['tf_val'][:]
    y_val = fh['y_val'][:]
    x_train_all = fh['x_train_all'][:]
    tf_train_all = fh['tf_train_all'][:]
    y_train_all = fh['y_train_all'][:]
    x_test = fh['x_test'][:]
    tf_test = fh['tf_test'][:]
    y_test = fh['y_test'][:]
    embedding = fh['embedding'][:]

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/index.pkl', 'rb') as fp:
    word2index, index2word = pickle.load(fp)

# %% [markdown]
# # Build Model

# %% [markdown]
# ##  Set Hyperparameters

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8
VOCAB_SIZE = len(word2index)+1
#NUM_CLASSES = VOCAB_SIZE
EMBEDDING_SIZE = 300
TF_EMBEDDING_SIZE = 300

RNN_SIZE = 600
DROPOUT_RATE = 0.5
RNN_DROPOUT_RATE = 0.2
NUM_EPOCHS = 1024
BATCH_SIZE = 79
STEPS_PER_EPOCH = 20
TEST_STEPS = len(x_test)//BATCH_SIZE

VALIDATION_STEPS = 3

# %%
print('NUM_EPOCHS: \t\t%d' % NUM_EPOCHS)
print('STEPS_PER_EPOCH: \t%d' % STEPS_PER_EPOCH)
print('TEST_STEPS: \t\t%d' % TEST_STEPS)
print('VALIDATION_STEPS: \t%d' % VALIDATION_STEPS)
print('TRAIN_BATCHES: \t\t%d' % (NUM_EPOCHS * STEPS_PER_EPOCH))
print('NUM_BATCHES \t\t%d' % (len(x_train)//BATCH_SIZE+1))
# Out:
# NUM_EPOCHS: 		1024
# STEPS_PER_EPOCH: 	20
# TEST_STEPS: 		5
# VALIDATION_STEPS: 	3
# TRAIN_BATCHES: 		20480
# NUM_BATCHES 		612

# %% [markdown]
# ## Import Libraries

# %%
from keras.layers import Lambda, Input, Embedding, Dropout, Bidirectional, LSTM, RepeatVector, concatenate, TimeDistributed, Dense
from keras.models import Model
from keras.models import Sequential
import keras.backend as K
from keras.callbacks import*
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Build Graph

# %%
def attention_context(x, mask):
    sent, adjl = x[:, :MAX_SENT_LEN, :], x[:, :MAX_ADJL_LEN, :]
    
    attention_energies = K.batch_dot(sent, adjl, axes=(2, 2))
    
    attention_energies = attention_energies + -1e20*K.expand_dims(1.-K.cast(mask[:, :MAX_SENT_LEN],'float32'),1)
    
    attention_energies = K.reshape(attention_energies, (-1, MAX_SENT_LEN))
    attention_weights = K.softmax(attention_energies)
    attention_weights = K.reshape(attention_weights, (-1, MAX_ADJL_LEN, MAX_SENT_LEN))
    
    attention_context = K.batch_dot(attention_weights, sent, axes=(2, 1))
    return K.concatenate((attention_context, adjl))

# %%
K.clear_session()
model = Sequential()
model.add(Embedding(VOCAB_SIZE, 
                    EMBEDDING_SIZE, 
                    weights=[embedding], 
                    mask_zero=True, 
                    input_length=MAX_SENT_LEN+MAX_ADJL_LEN, 
                    trainable=False, 
                    name='EMBEDDING'))
model.add(LSTM(RNN_SIZE, 
               return_sequences=True, 
               implementation=0, 
               dropout=RNN_DROPOUT_RATE, 
               recurrent_dropout=RNN_DROPOUT_RATE,
               name='LSTM_1'))
model.add(Dropout(DROPOUT_RATE, name='DROPOUT_1'))
model.add(LSTM(RNN_SIZE, 
               return_sequences=True, 
               implementation=0, 
               dropout=RNN_DROPOUT_RATE, 
               recurrent_dropout=RNN_DROPOUT_RATE,
               name='LSTM_2'))
model.add(Dropout(DROPOUT_RATE, name='DROPOUT_2'))
model.add(LSTM(RNN_SIZE, 
               return_sequences=True, 
               implementation=0, 
               dropout=RNN_DROPOUT_RATE, 
               recurrent_dropout=RNN_DROPOUT_RATE,
               name='LSTM_3'))
model.add(Dropout(DROPOUT_RATE, name='DROPOUT_3'))
model.add(Lambda(attention_context, 
                 mask=lambda inputs, mask: mask[:, MAX_SENT_LEN:],
                 output_shape=lambda input_shape: (input_shape[0], MAX_ADJL_LEN, 2*RNN_SIZE),
                 name='ATTENTION_CONTEXT'))
model.add(TimeDistributed(Dense(VOCAB_SIZE, activation='softmax'), name='OUTPUT'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# %%
def seq2seq_attention(encoder_vocab_size, encoder_maxlen,
                      decoder_vocab_size, decoder_maxlen,
                      hidden_size):

    encoder_input = Input(shape=(encoder_maxlen,), name='encoder_input')
    encoder_emb = Embedding(output_dim=hidden_size,
                            input_dim=encoder_vocab_size,
                            input_length=encoder_maxlen)(encoder_input)
    encoder_emb = SpatialDropout1D(0.2)(encoder_emb)  # 0.2 is dropping rate
    encoder = LSTM(hidden_size, return_sequences=True)(encoder_emb)  # save sequences for attention
    encoder_last_layer = Lambda(lambda x: x[:,-1,:])(encoder)
    encoder_out = RepeatVector(decoder_maxlen)(encoder_last_layer)

    decoder_input = Input(shape=(decoder_maxlen,), name='decoder_input')  
    decoder_emb = Embedding(decoder_vocab_size,
                            hidden_size,
                            input_length=decoder_maxlen)(decoder_input)
    decoder_emb = SpatialDropout1D(0.2)(decoder_emb)  # 0.2 is dropping rate

    enc_dec = concatenate([encoder_out, decoder_emb], axis=-1)
    enc_dec_hidden = LSTM(hidden_size)(enc_dec)

    attention_input = RepeatVector(encoder_maxlen)(enc_dec_hidden)
    attention = concatenate([encoder, attention_input], axis=-1)
    attention = TimeDistributed(Dense(1))(attention)
    attention = Lambda(lambda x: activations.softmax(x, axis=1))(attention)
    attention = multiply([encoder, attention])
    attention = Lambda(lambda x: K.sum(x, axis=1))(attention)

    main_output = concatenate([enc_dec_hidden, attention], axis=-1)
    main_output = Dense(hidden_size, activation='tanh')(main_output)
    main_output = Dense(decoder_vocab_size)(main_output)
    main_output = Activation('softmax', name='main_output')(main_output)

    model = Model(inputs=[encoder_input, decoder_input], outputs=[main_output])
    model.compile(loss='categorical_crossentropy', optimizer='adadelta')
    model.summary()
    
    return model

# %%
seq2seq_attention(EMBEDDING_SIZE,
                  MAX_SENT_LEN,
                  EMBEDDING_SIZE,
                  MAX_ADJL_LEN,
                  RNN_SIZE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-9bbbe5a65a37> in <module>()
#       3                   EMBEDDING_SIZE,
#       4                   MAX_ADJL_LEN,
# ----> 5                   RNN_SIZE)
#
# <ipython-input-65-ca3b14833506> in seq2seq_attention(encoder_vocab_size, encoder_maxlen, decoder_vocab_size, decoder_maxlen, hidden_size)
#       7                             input_dim=encoder_vocab_size,
#       8                             input_length=encoder_maxlen)(encoder_input)
# ----> 9     encoder_emb = SpatialDropout1D(0.2)(encoder_emb)  # 0.2 is dropping rate
#      10     encoder = LSTM(hidden_size, return_sequences=True)(encoder_emb)  # save sequences for attention
#      11     encoder_last_layer = Lambda(lambda x: x[:,-1,:])(encoder)
#
# NameError: name 'SpatialDropout1D' is not defined

# %%
data = np.ones((1, 72))

# %%
probs = model.predict(data, batch_size=1)
probs.shape
# Out:
# (1, 8, 65147)

# %% [markdown]
# ## Model Visualization

# %%
model.summary()
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING (Embedding)        (None, 72, 300)           19544100
# _________________________________________________________________
# LSTM_1 (LSTM)                (None, 72, 600)           2162400
# _________________________________________________________________
# DROPOUT_1 (Dropout)          (None, 72, 600)           0
# _________________________________________________________________
# LSTM_2 (LSTM)                (None, 72, 600)           2882400
# _________________________________________________________________
# DROPOUT_2 (Dropout)          (None, 72, 600)           0
# _________________________________________________________________
# LSTM_3 (LSTM)                (None, 72, 600)           2882400
# _________________________________________________________________
# DROPOUT_3 (Dropout)          (None, 72, 600)           0
# _________________________________________________________________
# ATTENTION_CONTEXT (Lambda)   (None, 8, 1200)           0
# _________________________________________________________________
# OUTPUT (TimeDistributed)     (None, 8, 65147)          78241547
# =================================================================
# Total params: 105,712,847
# Trainable params: 86,168,747
# Non-trainable params: 19,544,100
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
import numpy as np

# %%
def gen_label(s):
    """
    One-hot encoding
    """
    gen = to_categorical(s, num_classes=NUM_CLASSES)
    return gen

def data_generator_all(data, label, batch_size):
    """
    Yield batches of all data
    """
    count = 0
    while True:
        if count >= len(data[0]): 
            count = 0
        x_1 = np.zeros((batch_size, MAX_SENT_LEN))
        x_2 = np.zeros((batch_size, MAX_ADJL_LEN))
        y = np.zeros((batch_size, MAX_ADJL_LEN, NUM_CLASSES))
        for i in range(batch_size):
            n = i + count
            if n > len(data[0])-1:
                break
            x_1[i, :] = data[0][n]
            x_2[i, :] = data[1][n]
            x = np.concatenate((x_1, x_2), axis=-1)
            y[i, :, :] = gen_label(label[n])
        count += batch_size
        yield (x, y)
        
def data_generator(data, label, batch_size): 
    """
    Yield batches 
    """
    index = np.arange(len(data[0]))
    np.random.shuffle(index)    
    batches = [index[range(batch_size*i, min(len(data[0]), batch_size*(i+1)))] for i in range(len(data[0])//batch_size)]
    while True:
        for i in batches:
            x_1 = data[0][i]
            x_2 = data[1][i]
            x = np.concatenate((x_1, x_2), axis=-1)
            y = np.array(list(map(gen_label, label[i])))
            yield (x, y)

# %%
gen_train_all = data_generator([x_train_all, tf_train_all], y_train_all, BATCH_SIZE)
gen_test = data_generator_all([x_test, tf_test], y_test, BATCH_SIZE)
#gen_train = data_generator(x_train, y_train, BATCH_SIZE)
#gen_val = data_generator(x_val, y_val, BATCH_SIZE)

# %%
# Continue Trian
# filename = 'cp_logs/.hdf5'
# model.load_weights(filename)
# model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['acc'])

# %%
filepath = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/cp_logs/weights.{epoch:03d}-{val_loss:.6f}.hdf5'
log_string = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/tb_logs/1'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
tensorboard = TensorBoard(log_dir=log_string, 
                          histogram_freq=1, 
                          write_graph=False, 
                          write_grads=False, 
                          batch_size=BATCH_SIZE, 
                          write_images=True, 
                          embeddings_freq=1, 
                          embeddings_layer_names=None,
                          embeddings_metadata=None)

# %%
history = model.fit_generator(gen_train_all, 
                              steps_per_epoch=STEPS_PER_EPOCH, 
                              epochs=NUM_EPOCHS, 
                              verbose=1,
                              #callbacks=[checkpoint, tensorboard, lr],
                              validation_data=gen_test, 
                              validation_steps=TEST_STEPS)
# Out:
# Epoch 1/1024
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#
# /anaconda/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Incompatible shapes: [79,64,8] vs. [79,1,64]
# 	 [[Node: gradients/ATTENTION_CONTEXT/add_grad/BroadcastGradientArgs = BroadcastGradientArgs[T=DT_INT32, _class=["loc:@ATTENTION_CONTEXT/add"], _device="/job:localhost/replica:0/task:0/cpu:0"](gradients/ATTENTION_CONTEXT/add_grad/Shape, gradients/ATTENTION_CONTEXT/add_grad/Shape_1)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-40-fb7c46fa864b> in <module>()
#       5                               #callbacks=[checkpoint, tensorboard, lr],
#       6                               validation_data=gen_test,
# ----> 7                               validation_steps=TEST_STEPS)
#
# /anaconda/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /anaconda/lib/python3.6/site-packages/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, initial_epoch)
#    1115                                         workers=workers,
#    1116                                         use_multiprocessing=use_multiprocessing,
# -> 1117                                         initial_epoch=initial_epoch)
#    1118
#    1119     @interfaces.legacy_generator_methods_support
#
# /anaconda/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /anaconda/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, initial_epoch)
#    1838                     outs = self.train_on_batch(x, y,
#    1839                                                sample_weight=sample_weight,
# -> 1840                                                class_weight=class_weight)
#    1841
#    1842                     if not isinstance(outs, list):
#
# /anaconda/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1563             ins = x + y + sample_weights
#    1564         self._make_train_function()
# -> 1565         outputs = self.train_function(ins)
#    1566         if len(outputs) == 1:
#    1567             return outputs[0]
#
# /anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2266         updated = session.run(self.outputs + [self.updates_op],
#    2267                               feed_dict=feed_dict,
# -> 2268                               **self.session_kwargs)
#    2269         return updated[:len(self.outputs)]
#    2270
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1150         except KeyError:
#    1151           pass
# -> 1152       raise type(e)(node_def, op, message)
#    1153
#    1154   def _extend_graph(self):
#
# InvalidArgumentError: Incompatible shapes: [79,64,8] vs. [79,1,64]
# 	 [[Node: gradients/ATTENTION_CONTEXT/add_grad/BroadcastGradientArgs = BroadcastGradientArgs[T=DT_INT32, _class=["loc:@ATTENTION_CONTEXT/add"], _device="/job:localhost/replica:0/task:0/cpu:0"](gradients/ATTENTION_CONTEXT/add_grad/Shape, gradients/ATTENTION_CONTEXT/add_grad/Shape_1)]]
#
# Caused by op 'gradients/ATTENTION_CONTEXT/add_grad/BroadcastGradientArgs', defined at:
#   File "/anaconda/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/anaconda/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/anaconda/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/anaconda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/anaconda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-40-fb7c46fa864b>", line 7, in <module>
#     validation_steps=TEST_STEPS)
#   File "/anaconda/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 87, in wrapper
#     return func(*args, **kwargs)
#   File "/anaconda/lib/python3.6/site-packages/keras/models.py", line 1117, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/anaconda/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 87, in wrapper
#     return func(*args, **kwargs)
#   File "/anaconda/lib/python3.6/site-packages/keras/engine/training.py", line 1725, in fit_generator
#     self._make_train_function()
#   File "/anaconda/lib/python3.6/site-packages/keras/engine/training.py", line 937, in _make_train_function
#     self.total_loss)
#   File "/anaconda/lib/python3.6/site-packages/keras/optimizers.py", line 221, in get_updates
#     grads = self.get_gradients(loss, params)
#   File "/anaconda/lib/python3.6/site-packages/keras/optimizers.py", line 71, in get_gradients
#     grads = K.gradients(loss, params)
#   File "/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2305, in gradients
#     return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 540, in gradients
#     grad_scope, op, func_call, lambda: grad_fn(op, *out_grads))
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 346, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 540, in <lambda>
#     grad_scope, op, func_call, lambda: grad_fn(op, *out_grads))
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py", line 639, in _AddGrad
#     rx, ry = gen_array_ops._broadcast_gradient_args(sx, sy)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py", line 395, in _broadcast_gradient_args
#     name=name)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# ...which was originally created as op 'ATTENTION_CONTEXT/add', defined at:
#   File "/anaconda/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# [elided 18 identical lines from previous traceback]
#   File "/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-29-d9942879d98e>", line 29, in <module>
#     name='ATTENTION_CONTEXT'))
#   File "/anaconda/lib/python3.6/site-packages/keras/models.py", line 469, in add
#     output_tensor = layer(self.outputs[0])
#   File "/anaconda/lib/python3.6/site-packages/keras/engine/topology.py", line 596, in __call__
#     output = self.call(inputs, **kwargs)
#   File "/anaconda/lib/python3.6/site-packages/keras/layers/core.py", line 647, in call
#     return self.function(inputs, **arguments)
#   File "<ipython-input-12-56cbb5436bf3>", line 6, in attention_context
#     attention_energies = attention_energies + -1e20*K.expand_dims(1.-K.cast(mask[:, :MAX_SENT_LEN],'float32'),1)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py", line 838, in binary_op_wrapper
#     return func(x, y, name=name)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py", line 67, in add
#     result = _op_def_lib.apply_op("Add", x=x, y=y, name=name)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# InvalidArgumentError (see above for traceback): Incompatible shapes: [79,64,8] vs. [79,1,64]
# 	 [[Node: gradients/ATTENTION_CONTEXT/add_grad/BroadcastGradientArgs = BroadcastGradientArgs[T=DT_INT32, _class=["loc:@ATTENTION_CONTEXT/add"], _device="/job:localhost/replica:0/task:0/cpu:0"](gradients/ATTENTION_CONTEXT/add_grad/Shape, gradients/ATTENTION_CONTEXT/add_grad/Shape_1)]]

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Naive Evaluate

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/cp_logs/weights.376-1.372052.hdf5'
model.load_weights(filename)

result = np.argmax(model.predict([x_test, tf_test], batch_size=BATCH_SIZE, verbose=1), -1)
# Out:
# 395/395 [==============================] - 11s

# %%
preResult = [[index2word[i] for i in sent if i != 0] for sent in result]
actResult = [[index2word[i] for i in sent if i != 0] for sent in y_test]
e1Count = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0]]) + sum([1 for i in range(372, 373) if actResult[i][4] == preResult[i][4]])
e2Count = sum([1 for i in range(395) if actResult[i][1] == preResult[i][1]]) + sum([1 for i in range(372, 373) if actResult[i][5] == preResult[i][5]])
enCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1]]) + sum([1 for i in range(372, 373) if actResult[i][4] == preResult[i][4] and actResult[i][5] == preResult[i][5]])      
reCount = sum([1 for i in range(395) if actResult[i][2] == preResult[i][2]]) + sum([1 for i in range(372, 273) if actResult[i][6] == preResult[i][6]])
tripleCount = sum([1 for i in range(395) if actResult[i][0] == preResult[i][0] and actResult[i][1] == preResult[i][1] and actResult[i][2] == preResult[i][2]]) + sum([1 for i in range(372, 373) if actResult[i][4] == preResult[i][4] and actResult[i][5] == preResult[i][5] and actResult[i][6] == preResult[i][6]]) 
print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
print('En Accuracy: \t\t%.6f' % (enCount/396))
print('Re Accuracy: \t\t%.6f' % (reCount/396))
print('Triple Accuracy: \t%.6f' % (tripleCount/396))
# Out:
# E1 Accuracy: 		0.646465
# E2 Accuracy: 		0.608586
# En Accuracy: 		0.353535
# Re Accuracy: 		0.891414
# Triple Accuracy: 	0.290404

# %%
#' '.join(preResult[372])

# %%
#' '.join(actResult[372])

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(preResult[i]))
    print('Ground-Truth: \t%s' % ' '.join(actResult[i]))
    print('---')
# Out:
# Predict: 	spain italy /location/administrative_division/country /eos barcelona barcelona barcelona
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---
# Predict: 	westchester connecticut /location/neighborhood/neighborhood_of /eos fairfield fairfield fairfield
# Ground-Truth: 	westchester connecticut /location/administrative_division/country /eos
# ---
# Predict: 	ariel israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	dalia israel /people/person/nationality /eos
# ---
# Predict: 	waterloo chennai /location/location/contains /eos sri sri sri
# Ground-Truth: 	hyderabad potti /location/location/contains /eos
# ---
# Predict: 	elizabeth north /people/person/place_lived /eos lake lake lake
# Ground-Truth: 	kent north /people/person/place_lived /eos
# ---
# Predict: 	ontario waterloo /location/location/contains /eos vancouver vancouver vancouver
# Ground-Truth: 	ontario waterloo /location/location/contains /eos
# ---
# Predict: 	dreamworks stephen /business/company/founders /eos /eos /eos /eos
# Ground-Truth: 	blackstone stephen /business/company/founders /eos
# ---
# Predict: 	europe italy /location/administrative_division/country /eos barcelona barcelona barcelona
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	iran russia /location/administrative_division/country /eos serbia serbia serbia
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	france paris /location/location/contains /eos belgium belgium belgium
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	george abc /business/person/company /eos lake lake lake
# Ground-Truth: 	george abc /business/person/company /eos
# ---
# Predict: 	florida jacksonville /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida jacksonville /location/location/contains /eos
# ---
# Predict: 	nigeria abuja /location/location/contains /eos nigeria nigeria nigeria
# Ground-Truth: 	nigeria uyo /location/location/contains /eos
# ---
# Predict: 	sheldon rhode /people/person/place_lived /eos monmouth monmouth monmouth
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---
# Predict: 	brian franklin /people/person/place_lived /eos wayne wayne wayne
# Ground-Truth: 	patrick huntington /people/person/place_lived /eos
# ---
# Predict: 	angela germany /people/person/nationality /eos luxembourg luxembourg luxembourg
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	jeffrey lazard /business/person/company /eos wayne wayne wayne
# Ground-Truth: 	jeffrey lazard /business/person/company /eos
# ---
# Predict: 	middle israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	south south /location/administrative_division/country /eos roger roger roger
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---
# Predict: 	mark york /business/person/company /eos montclair montclair montclair
# Ground-Truth: 	mark york /business/person/company /eos
# ---
# Predict: 	peter australia /people/person/nationality /eos harry harry harry
# Ground-Truth: 	markus australia /people/person/nationality /eos
# ---
# Predict: 	alan princeton /business/person/company /eos montclair montclair montclair
# Ground-Truth: 	kwame princeton /business/person/company /eos
# ---
# Predict: 	jack john /business/company/founders /eos /eos /eos /eos
# Ground-Truth: 	endemol john /business/company/founders /eos
# ---
# Predict: 	jeff minnesota /people/person/place_lived /eos winnipeg winnipeg winnipeg
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---
# Predict: 	connecticut haven /location/location/contains /eos westport westport westport
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---
# Predict: 	iran russia /people/person/nationality /eos ali ali ali
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	manmohan india /location/administrative_division/country /eos /eos /eos /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---
# Predict: 	bill microsoft /people/person/place_lived /eos philippine philippine philippine
# Ground-Truth: 	bill dawsonville /people/person/place_lived /eos
# ---
# Predict: 	mark university /business/person/company /eos vancouver vancouver vancouver
# Ground-Truth: 	daniel university /business/person/company /eos
# ---
# Predict: 	soviet russia /location/administrative_division/country /eos /eop /eop /eop
# Ground-Truth: 	soviet russia /location/administrative_division/country /eos
# ---
# Predict: 	boston harvard /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	boston wbz-tv /location/location/contains /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos ehud ehud ehud
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	virginia united /business/person/company /eos jonathan jonathan jonathan
# Ground-Truth: 	virginia united /location/administrative_division/country /eos
# ---
# Predict: 	kenneth time /business/person/company /eos philippine philippine philippine
# Ground-Truth: 	ira system /business/person/company /eos
# ---
# Predict: 	cuba cuba /location/location/contains /eos caracas caracas caracas
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	anthony york /business/person/company /eos montclair montclair montclair
# Ground-Truth: 	anthony york /business/person/company /eos
# ---
# Predict: 	eric google /business/person/company /eos philippine philippine philippine
# Ground-Truth: 	chad google /business/person/company /eos
# ---
# Predict: 	washington seattle /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	washington bainbridge /location/location/contains /eos
# ---
# Predict: 	washington seattle /location/location/contains /eos trenton trenton trenton
# Ground-Truth: 	washington olympia /location/location/contains /eos
# ---
# Predict: 	south singapore /location/location/contains /eos sri sri sri
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---
# Predict: 	spain spain /location/administrative_division/country /eos /eos /eos /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos jon jon jon
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	europe italy /people/person/nationality /eos /location/administrative_division/country /location/administrative_division/country /location/administrative_division/country
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	iran syria /location/country/capital /eos jordan jordan jordan
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	colorado colorado /people/person/place_of_birth /eos edmonton edmonton edmonton
# Ground-Truth: 	kellen colorado /people/person/place_of_birth /eos
# ---
# Predict: 	donald france /people/person/nationality /eos costa costa costa
# Ground-Truth: 	tony france /people/person/nationality /eos
# ---
# Predict: 	carlos spain /people/person/nationality /eos bolivia bolivia bolivia
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---
# Predict: 	europe italy /people/person/nationality /eos /eos /eos /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos dick dick dick
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	york staten /location/location/contains /eos staten staten staten
# Ground-Truth: 	york staten /location/location/contains /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos halliburton halliburton halliburton
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	middle israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	jeff google /business/person/company /eos puerto puerto puerto
# Ground-Truth: 	ralph at&t /business/person/company /eos
# ---
# Predict: 	connecticut haven /location/location/contains /eos westport westport westport
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---
# Predict: 	somalia mogadishu /location/location/contains /eos sudan sudan sudan
# Ground-Truth: 	somalia puntland /location/location/contains /eos
# ---
# Predict: 	helsinki kazakhstan /people/person/nationality /eos larry larry larry
# Ground-Truth: 	riga latvia /location/administrative_division/country /eos
# ---
# Predict: 	switzerland davos /location/location/contains /eos davos davos davos
# Ground-Truth: 	switzerland davos /location/location/contains /eos
# ---
# Predict: 	colorado denver /location/location/contains /eos salt salt salt
# Ground-Truth: 	colorado vail /location/location/contains /eos
# ---
# Predict: 	paris france /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	hudson hudson /location/location/contains /eos rockaway rockaway rockaway
# Ground-Truth: 	lower hudson /location/location/contains /eos
# ---
# Predict: 	san north /location/location/contains /eos
# Ground-Truth: 	san north /location/location/contains /eos
# ---
# Predict: 	nassau suffolk /people/person/place_lived /eos nassau nassau nassau
# Ground-Truth: 	nassau suffolk /location/administrative_division/country /eos
# ---
# Predict: 	martin dell /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	chad youtube /business/person/company /eos
# ---
# Predict: 	westchester rochelle /location/location/contains /eos westchester westchester westchester
# Ground-Truth: 	westchester kensico /location/location/contains /eos
# ---
# Predict: 	ben nebraska /people/person/place_lived /eos halliburton halliburton halliburton
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---
# Predict: 	italy florence /location/location/contains /eos portugal portugal portugal
# Ground-Truth: 	italy orvieto /location/location/contains /eos
# ---
# Predict: 	nashville emory /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	greenville furman /location/location/contains /eos
# ---
# Predict: 	charles princeton /business/person/company /eos montclair montclair montclair
# Ground-Truth: 	charles princeton /business/person/company /eos
# ---
# Predict: 	canada canada /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---
# Predict: 	florida boca /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	middle israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	baltimore john /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	baltimore john /location/location/contains /eos
# ---
# Predict: 	manmohan india /people/person/place_lived /eos philippine philippine philippine
# Ground-Truth: 	samantha india /people/person/place_lived /eos
# ---
# Predict: 	david dell /business/person/company /eos philippine philippine philippine
# Ground-Truth: 	david digitas /business/person/company /eos
# ---
# Predict: 	jim iowa /people/person/place_lived /eos camden camden camden
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---
# Predict: 	rafik lebanon /people/person/nationality /eos rafik rafik rafik
# Ground-Truth: 	rafik lebanon /people/person/nationality /eos
# ---
# Predict: 	nigeria nigeria /people/person/nationality /eos liberia liberia liberia
# Ground-Truth: 	atiku nigeria /people/person/nationality /eos
# ---
# Predict: 	westchester scarsdale /location/location/contains /eos fairfield fairfield fairfield
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---
# Predict: 	florida florida /location/location/contains /eos tampa tampa tampa
# Ground-Truth: 	florida panama /location/location/contains /eos
# ---
# Predict: 	iran north /people/person/place_lived /eos vladimir vladimir vladimir
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---
# Predict: 	france paris /location/location/contains /eos belgium belgium belgium
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	europe spain /location/administrative_division/country /eos /location/administrative_division/country /location/administrative_division/country /location/administrative_division/country
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---
# Predict: 	bergen fort /location/location/contains /eos
# Ground-Truth: 	clarkstown city /location/location/contains /eos
# ---
# Predict: 	india mumbai /location/location/contains /eos lee lee lee
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---
# Predict: 	haley mississippi /people/person/place_lived /eos camden camden camden
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---
# Predict: 	florida boca /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	bruce national /business/person/company /eos philippine philippine philippine
# Ground-Truth: 	gordon continental /business/person/company /eos
# ---
# Predict: 	paris france /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	california long /location/location/contains /eos costa costa costa
# Ground-Truth: 	california long /location/location/contains /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos /eos /eos /eos
# Ground-Truth: 	france correze /location/location/contains /eos
# ---
# Predict: 	bergen newport /location/location/contains /eos monmouth monmouth monmouth
# Ground-Truth: 	fairfax westfield /location/location/contains /eos
# ---
# Predict: 	middle israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	spain madrid /location/location/contains /eos barcelona barcelona barcelona
# Ground-Truth: 	spain valencia /location/location/contains /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos dick dick dick
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	greenwich greenwich /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	greenwich jefferson /location/location/contains /eos
# ---
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos jordan jordan jordan
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	jacques france /people/person/nationality /eos jacques jacques jacques
# Ground-Truth: 	jacques france /people/person/nationality /eos
# ---
# Predict: 	bergen montclair /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	mahwah ramapo /location/location/contains /eos
# ---
# Predict: 	hudson valencia /location/location/contains /eos philippine philippine philippine
# Ground-Truth: 	guyana linden /location/location/contains /eos
# ---
# Predict: 	india delhi /location/location/contains /eos kim kim kim
# Ground-Truth: 	india punjab /location/location/contains /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos vancouver vancouver vancouver
# Ground-Truth: 	ontario tobermory /location/location/contains /eos
# ---
# Predict: 	middle iran /location/location/contains /eos middle middle middle
# Ground-Truth: 	middle iran /location/location/contains /eos
# ---
# Predict: 	cuba basra /location/location/contains /eos nelson nelson nelson
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	europe israel /location/administrative_division/country /eos jerusalem jerusalem jerusalem
# Ground-Truth: 	italy israel /location/administrative_division/country /eos
# ---
# Predict: 	europe spain /location/administrative_division/country /eos /location/administrative_division/country /location/administrative_division/country /location/administrative_division/country
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---
# Predict: 	eric google /business/person/company /eos philippine philippine philippine
# Ground-Truth: 	chad google /business/person/company /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos ariel ariel ariel
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	jeff minnesota /people/person/place_lived /eos winnipeg winnipeg winnipeg
# Ground-Truth: 	amy minnesota /people/person/place_lived /eos
# ---
# Predict: 	john australia /people/person/nationality /eos wayne wayne wayne
# Ground-Truth: 	john australia /people/person/nationality /eos
# ---
# Predict: 	jim kentucky /people/person/place_lived /eos wayne wayne wayne
# Ground-Truth: 	ernie kentucky /people/person/place_lived /eos
# ---
# Predict: 	iran north /people/person/place_lived /eos vladimir vladimir vladimir
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---
# Predict: 	india delhi /location/location/contains /eos delhi delhi delhi
# Ground-Truth: 	india bihar /location/country/administrative_divisions /eos
# ---
# Predict: 	ireland northern /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---
# Predict: 	fidel cuba /location/administrative_division/country /eos dominican dominican dominican
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---
# Predict: 	italy florence /location/location/contains /eos portugal portugal portugal
# Ground-Truth: 	italy umbria /location/location/contains /eos
# ---
# Predict: 	marcello italy /location/administrative_division/country /eos portugal portugal portugal
# Ground-Truth: 	campania italy /location/administrative_division/country /eos
# ---
# Predict: 	iran middle /location/neighborhood/neighborhood_of /eos ariel ariel ariel
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---
# Predict: 	florida boca /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	europe spain /location/administrative_division/country /eos /eos /eos /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---
# Predict: 	paris france /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	cleveland case /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	cleveland karamu /location/location/contains /eos
# ---
# Predict: 	ireland northern /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---
# Predict: 	california san /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	california san /location/location/contains /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos
# Ground-Truth: 	france albertville /location/location/contains /eos
# ---
# Predict: 	serbia belgrade /location/location/contains /eos ali ali ali
# Ground-Truth: 	bosnia srebrenica /location/location/contains /eos
# ---
# Predict: 	fort fort /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	upper fort /location/location/contains /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos philippine philippine philippine
# Ground-Truth: 	france valence /location/location/contains /eos
# ---
# Predict: 	james tampa /people/person/place_lived /eos tampa tampa tampa
# Ground-Truth: 	james tampa /people/person/place_lived /eos
# ---
# Predict: 	syria syria /location/location/contains /eos jordan jordan jordan
# Ground-Truth: 	syria damascus /location/country/administrative_divisions /eos
# ---
# Predict: 	mark florence /people/deceased_person/place_of_death /eos worcester worcester worcester
# Ground-Truth: 	marshall fremont /people/deceased_person/place_of_death /eos
# ---
# Predict: 	israel jerusalem /location/location/contains /eos jordan jordan jordan
# Ground-Truth: 	israel jerusalem /location/location/contains /eos
# ---
# Predict: 	iran syria /location/country/capital /eos ariel ariel ariel
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	cambridge clark /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	cambridge lesley /location/location/contains /eos
# ---
# Predict: 	mark australia /people/person/nationality /eos portugal portugal portugal
# Ground-Truth: 	chris australia /people/person/nationality /eos
# ---
# Predict: 	jeff nbc /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	dennis disney /business/person/company /eos
# ---
# Predict: 	colorado denver /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	colorado aspen /location/location/contains /eos
# ---
# Predict: 	south singapore /location/location/contains /eos sri sri sri
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---
# Predict: 	staten fort /location/location/contains /eos staten staten staten
# Ground-Truth: 	staten fort /location/location/contains /eos
# ---
# Predict: 	bashar syria /location/administrative_division/country /eos jordan jordan jordan
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---
# Predict: 	mexico mexico /location/administrative_division/country /eos costa costa costa
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---
# Predict: 	jacques france /people/person/nationality /eos harry harry harry
# Ground-Truth: 	jean-louis france /people/person/nationality /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos theo theo theo
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---
# Predict: 	jim kentucky /people/person/place_lived /eos wayne wayne wayne
# Ground-Truth: 	jim kentucky /people/person/place_lived /eos
# ---
# Predict: 	berlin germany /location/administrative_division/country /eos luxembourg luxembourg luxembourg
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	israel lebanon /people/person/nationality /eos ariel ariel ariel
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---
# Predict: 	martin dell /business/person/company /eos philippine philippine philippine
# Ground-Truth: 	brett priceline /business/person/company /eos
# ---
# Predict: 	newark jersey /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	newark jersey /location/location/contains /eos
# ---
# Predict: 	peter columbia /business/person/company /eos vancouver vancouver vancouver
# Ground-Truth: 	peter columbia /business/person/company /eos
# ---
# Predict: 	russia beslan /location/location/contains /eos philippine philippine philippine
# Ground-Truth: 	leningrad vaganova /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico jalisco /location/country/administrative_divisions /eos
# ---
# Predict: 	westchester westchester /location/location/contains /eos rockland rockland rockland
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---
# Predict: 	middle iran /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---
# Predict: 	terri fort /people/person/place_lived /eos philippine philippine philippine
# Ground-Truth: 	brittany seminole /people/person/place_lived /eos
# ---
# Predict: 	mexico mexico /location/administrative_division/country /eos puerto puerto puerto
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---
# Predict: 	germany munich /location/location/contains /eos karl karl karl
# Ground-Truth: 	germany munich /location/location/contains /eos
# ---
# Predict: 	angela davos /people/deceased_person/place_of_death /eos davos davos davos
# Ground-Truth: 	ernst davos /people/deceased_person/place_of_death /eos
# ---
# Predict: 	cuba basra /location/location/contains /eos bolivia bolivia bolivia
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	fidel cuba /location/administrative_division/country /eos montclair montclair montclair
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---
# Predict: 	germany leipzig /location/location/contains /eos hong hong hong
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---
# Predict: 	jeffrey general /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	jeffrey general /business/person/company /eos
# ---
# Predict: 	poland warsaw /location/location/contains /eos amsterdam amsterdam amsterdam
# Ground-Truth: 	poland cracow /location/location/contains /eos
# ---
# Predict: 	jeff minnesota /people/person/place_lived /eos winnipeg winnipeg winnipeg
# Ground-Truth: 	norm minnesota /people/person/place_lived /eos
# ---
# Predict: 	south iowa /people/person/place_lived /eos philippine philippine philippine
# Ground-Truth: 	south iowa /location/administrative_division/country /eos
# ---
# Predict: 	south south /location/administrative_division/country /eos /eos /eos /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---
# Predict: 	france paris /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	france paris /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	jordan amman /location/location/contains /eos ariel ariel ariel
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---
# Predict: 	jack robert /business/company/founders /eos /eos /eos /eos
# Ground-Truth: 	black robert /business/company/founders /eos
# ---
# Predict: 	arkansas pratt /location/location/contains /eos memphis memphis memphis
# Ground-Truth: 	arkansas arkadelphia /location/location/contains /eos
# ---
# Predict: 	barcelona spain /location/administrative_division/country /eos philippine philippine philippine
# Ground-Truth: 	navarre spain /location/administrative_division/country /eos
# ---
# Predict: 	toronto canada /location/administrative_division/country /eos edmonton edmonton edmonton
# Ground-Truth: 	toronto canada /location/administrative_division/country /eos
# ---
# Predict: 	coney york /location/location/contains /eos coney coney coney
# Ground-Truth: 	coney york /location/location/contains /eos
# ---
# Predict: 	port levittown /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	port harborside /location/location/contains /eos
# ---
# Predict: 	jim iowa /people/person/place_lived /eos camden camden camden
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---
# Predict: 	middle israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	california hudson /location/location/contains /eos westport westport westport
# Ground-Truth: 	california lawrence /location/location/contains /eos
# ---
# Predict: 	paris france /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---
# Predict: 	lower york /location/neighborhood/neighborhood_of /eos lower lower lower
# Ground-Truth: 	lower york /location/neighborhood/neighborhood_of /eos
# ---
# Predict: 	europe italy /location/administrative_division/country /eos portugal portugal portugal
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---
# Predict: 	berkeley santa /location/location/contains /eos santa santa santa
# Ground-Truth: 	sonoma occidental /location/location/contains /eos
# ---
# Predict: 	christopher bank /business/person/company /eos lee lee lee
# Ground-Truth: 	christopher security /business/person/company /eos
# ---
# Predict: 	india bangalore /location/location/contains /eos sri sri sri
# Ground-Truth: 	india hyderabad /location/location/contains /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos mitch mitch mitch
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	ben nebraska /people/person/place_lived /eos camden camden camden
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---
# Predict: 	susan nebraska /people/person/place_lived /eos camden camden camden
# Ground-Truth: 	tommy wisconsin /people/person/place_lived /eos
# ---
# Predict: 	taiwan thailand /location/administrative_division/country /eos /eop /eop /eop
# Ground-Truth: 	bangkok thailand /location/administrative_division/country /eos
# ---
# Predict: 	california santa /location/location/contains /eos santa santa santa
# Ground-Truth: 	california malibu /location/location/contains /eos
# ---
# Predict: 	berkeley berkeley /people/person/place_lived /eos costa costa costa
# Ground-Truth: 	ayelet berkeley /people/person/place_lived /eos
# ---
# Predict: 	cuba cuba /location/location/contains /eos bolivia bolivia bolivia
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	kansa kansa /people/person/place_lived /eos wayne wayne wayne
# Ground-Truth: 	kathleen kansa /people/person/place_lived /eos
# ---
# Predict: 	york greenwich /location/location/contains /eos lower lower lower
# Ground-Truth: 	york greenwich /location/location/contains /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos mitch mitch mitch
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos jordan jordan jordan
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	kenya kenya /people/person/place_lived /eos brisbane brisbane brisbane
# Ground-Truth: 	mount tanzania /location/administrative_division/country /eos
# ---
# Predict: 	israel lebanon /people/person/nationality /eos ariel ariel ariel
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---
# Predict: 	ireland dublin /location/location/contains /eos harry harry harry
# Ground-Truth: 	ireland athenry /location/location/contains /eos
# ---
# Predict: 	iran russia /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	berlin germany /location/administrative_division/country /eos luxembourg luxembourg luxembourg
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	israel lebanon /people/person/place_lived /eos jordan jordan jordan
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---
# Predict: 	iran iran /location/administrative_division/country /eos serbia serbia serbia
# Ground-Truth: 	russia iran /location/administrative_division/country /eos
# ---
# Predict: 	tucson university /location/location/contains /eos worcester worcester worcester
# Ground-Truth: 	eugene university /location/location/contains /eos
# ---
# Predict: 	barcelona spain /location/administrative_division/country /eos barcelona barcelona barcelona
# Ground-Truth: 	catalonia spain /location/administrative_division/country /eos
# ---
# Predict: 	australia port /location/location/contains /eos jamaica jamaica jamaica
# Ground-Truth: 	australia port /location/location/contains /eos
# ---
# Predict: 	evo bolivia /people/person/nationality /eos bolivia bolivia bolivia
# Ground-Truth: 	evo bolivia /people/person/nationality /eos
# ---
# Predict: 	berlin germany /location/administrative_division/country /eos berlin berlin berlin
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---
# Predict: 	south cape /location/location/contains /eos franklin franklin franklin
# Ground-Truth: 	south darlington /location/location/contains /eos
# ---
# Predict: 	nelson zimbabwe /people/person/nationality /eos athens athens athens
# Ground-Truth: 	nelson zimbabwe /people/person/nationality /eos
# ---
# Predict: 	israel tel /location/location/contains /eos
# Ground-Truth: 	israel ra'anana /location/location/contains /eos
# ---
# Predict: 	india delhi /location/location/contains /eos kim kim kim
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos ehud ehud ehud
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	manmohan india /location/administrative_division/country /eos /eos /eos /eos
# Ground-Truth: 	gujarat india /location/administrative_division/country /eos
# ---
# Predict: 	ohio cleveland /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	cuyahoga cleveland /location/location/contains /eos
# ---
# Predict: 	florida atlantic /location/location/contains /eos monmouth monmouth monmouth
# Ground-Truth: 	florida gulf /location/location/contains /eos
# ---
# Predict: 	india mumbai /location/location/contains /eos delhi delhi delhi
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---
# Predict: 	mexico mexico /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico mexico /location/location/contains /eos
# ---
# Predict: 	europe india /location/administrative_division/country /eos delhi delhi delhi
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos jordan jordan jordan
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	jerusalem haifa /location/location/contains /eos jordan jordan jordan
# Ground-Truth: 	jerusalem yad /location/location/contains /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos ehud ehud ehud
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	italy turin /location/location/contains /eos portugal portugal portugal
# Ground-Truth: 	italy maranello /location/location/contains /eos
# ---
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos jordan jordan jordan
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	ben nebraska /people/person/place_lived /eos camden camden camden
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---
# Predict: 	india delhi /location/location/contains /eos kim kim kim
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---
# Predict: 	bashar syria /people/person/nationality /eos ariel ariel ariel
# Ground-Truth: 	bashar syria /people/person/nationality /eos
# ---
# Predict: 	louisiana baton /location/location/contains /eos baton baton baton
# Ground-Truth: 	louisiana baton /location/location/contains /eos
# ---
# Predict: 	iran tehran /location/neighborhood/neighborhood_of /eos middle middle middle
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---
# Predict: 	sony sony /business/company/founders /eos ecuador ecuador ecuador
# Ground-Truth: 	sony akio /business/company/founders /eos
# ---
# Predict: 	ariel israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---
# Predict: 	europe india /location/administrative_division/country /eos delhi delhi delhi
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---
# Predict: 	portsmouth valencia /location/location/contains /eos portugal portugal portugal
# Ground-Truth: 	calabria crotone /location/location/contains /eos
# ---
# Predict: 	florida boca /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos costa costa costa
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---
# Predict: 	howard renault /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	derrick ford /business/person/company /eos
# ---
# Predict: 	chicago west /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	chicago west /location/location/contains /eos
# ---
# Predict: 	virginia valencia /location/location/contains /eos
# Ground-Truth: 	virginia middleburg /location/location/contains /eos
# ---
# Predict: 	tom oklahoma /people/person/place_lived /eos wayne wayne wayne
# Ground-Truth: 	brad oklahoma /people/person/place_lived /eos
# ---
# Predict: 	california berkeley /location/location/contains /eos westport westport westport
# Ground-Truth: 	california berkeley /location/location/contains /eos
# ---
# Predict: 	europe germany /people/person/nationality /eos alexander alexander alexander
# Ground-Truth: 	italy germany /location/administrative_division/country /eos
# ---
# Predict: 	illinois chicago /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	cook chicago /location/location/contains /eos
# ---
# Predict: 	nassau port /location/location/contains /eos monmouth monmouth monmouth
# Ground-Truth: 	fire ocean /location/location/contains /eos
# ---
# Predict: 	mexico mexico /location/administrative_division/country /eos puerto puerto puerto
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos mitch mitch mitch
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	dan google /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	shona google /business/person/company /eos
# ---
# Predict: 	paris france /location/administrative_division/country /eos belgium belgium belgium
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	vicente mexico /location/administrative_division/country /eos puerto puerto puerto
# Ground-Truth: 	juarez mexico /location/administrative_division/country /eos
# ---
# Predict: 	ehud israel /people/person/nationality /eos ehud ehud ehud
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---
# Predict: 	israel tel /location/location/contains /eos
# Ground-Truth: 	israel rehovot /location/location/contains /eos
# ---
# Predict: 	don york /business/person/company /eos portugal portugal portugal
# Ground-Truth: 	will york /business/person/company /eos
# ---
# Predict: 	boston boston /business/person/company /eos worcester worcester worcester
# Ground-Truth: 	juliet boston /business/person/company /eos
# ---
# Predict: 	europe france /location/administrative_division/country /eos portugal portugal portugal
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos mitch mitch mitch
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico puebla /location/location/contains /eos
# ---
# Predict: 	spain madrid /location/location/contains /eos ecuador ecuador ecuador
# Ground-Truth: 	spain cordoba /location/location/contains /eos
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos halliburton halliburton halliburton
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos jordan jordan jordan
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	toronto mount /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	toronto mount /location/location/contains /eos
# ---
# Predict: 	india india /location/administrative_division/country /eos serbia serbia serbia
# Ground-Truth: 	delhi india /location/administrative_division/country /eos
# ---
# Predict: 	canada calgary /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	canada calgary /location/location/contains /eos
# ---
# Predict: 	ontario canada /location/administrative_division/country /eos edmonton edmonton edmonton
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---
# Predict: 	vladimir russia /people/person/nationality /eos serbia serbia serbia
# Ground-Truth: 	nikolay russia /people/person/nationality /eos
# ---
# Predict: 	bensonhurst basra /business/person/company /eos grand grand grand
# Ground-Truth: 	vali naval /business/person/company /eos
# ---
# Predict: 	spain italy /location/administrative_division/country /eos barcelona barcelona barcelona
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---
# Predict: 	paris louvre /location/location/contains /eos theo theo theo
# Ground-Truth: 	paris ecole /location/location/contains /eos
# ---
# Predict: 	jordan amman /location/location/contains /eos jordan jordan jordan
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---
# Predict: 	nigeria khartoum /location/country/capital /eos ali ali ali
# Ground-Truth: 	algeria algiers /location/country/capital /eos
# ---
# Predict: 	india delhi /location/location/contains /eos delhi delhi delhi
# Ground-Truth: 	india dharamsala /location/location/contains /eos
# ---
# Predict: 	florida lake /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---
# Predict: 	donald washington /business/person/company /eos lake lake lake
# Ground-Truth: 	donald washington /business/person/company /eos
# ---
# Predict: 	ontario canada /location/administrative_division/country /eos wayne wayne wayne
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---
# Predict: 	arnold california /people/person/place_lived /eos liberia liberia liberia
# Ground-Truth: 	dana california /people/person/place_lived /eos
# ---
# Predict: 	germany leipzig /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	germany nuremberg /location/location/contains /eos
# ---
# Predict: 	jeffrey bank /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	stanley bank /business/person/company /eos
# ---
# Predict: 	lower lower /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	lower battery /location/location/contains /eos
# ---
# Predict: 	frank carroll /people/person/children /eos montclair montclair montclair
# Ground-Truth: 	frank lloyd /people/person/children /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---
# Predict: 	bashar syria /location/administrative_division/country /eos ariel ariel ariel
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---
# Predict: 	france paris /location/location/contains /eos belgium belgium belgium
# Ground-Truth: 	france paris /location/location/contains /eos
# ---
# Predict: 	york great /location/location/contains /eos /eos /eos /eos
# Ground-Truth: 	york peck /location/location/contains /eos
# ---
# Predict: 	iran russia /location/administrative_division/country /eos vladimir vladimir vladimir
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---
# Predict: 	taiwan taipei /location/location/contains /eos sri sri sri
# Ground-Truth: 	taiwan taipei /location/location/contains /eos
# ---
# Predict: 	bashar syria /location/administrative_division/country /eos jordan jordan jordan
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---
# Predict: 	europe spain /location/administrative_division/country /eos walter walter walter
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos hamilton hamilton hamilton
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---
# Predict: 	ariel israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico baja /location/location/contains /eos
# ---
# Predict: 	india delhi /location/location/contains /eos kim kim kim
# Ground-Truth: 	india chhattisgarh /location/location/contains /eos
# ---
# Predict: 	vicente mexico /location/administrative_division/country /eos el el el
# Ground-Truth: 	michoacan mexico /location/administrative_division/country /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico tulum /location/location/contains /eos
# ---
# Predict: 	atlanta georgia /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	atlanta georgia /location/location/contains /eos
# ---
# Predict: 	berkeley berkeley /location/location/contains /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---
# Predict: 	lleyton australia /people/person/nationality /eos philippine philippine philippine
# Ground-Truth: 	libby australia /people/person/nationality /eos
# ---
# Predict: 	carlos spain /people/person/nationality /eos ecuador ecuador ecuador
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---
# Predict: 	washington iran /people/person/nationality /eos serbia serbia serbia
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---
# Predict: 	mark hewlett-packard /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	mark hewlett-packard /business/person/company /eos
# ---
# Predict: 	paris louvre /location/location/contains /eos upper upper upper
# Ground-Truth: 	paris musee /location/location/contains /eos
# ---
# Predict: 	paris france /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---
# Predict: 	texas houston /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	harris houston /location/location/contains /eos
# ---
# Predict: 	fidel cuba /location/administrative_division/country /eos bolivia bolivia bolivia
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---
# Predict: 	martin great /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	will time /business/person/company /eos
# ---
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos jordan jordan jordan
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	chicago great /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	chicago winston /location/location/contains /eos
# ---
# Predict: 	martin national /business/person/company /eos philippine philippine philippine
# Ground-Truth: 	amory rocky /business/person/company /eos
# ---
# Predict: 	rochester george /location/location/contains /eos /eop /eop /eop
# Ground-Truth: 	rochester george /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico cancun /location/location/contains /eos
# ---
# Predict: 	idaho boise /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	idaho salmon /location/location/contains /eos
# ---
# Predict: 	west senegal /location/location/contains /eos nelson nelson nelson
# Ground-Truth: 	west senegal /location/location/contains /eos
# ---
# Predict: 	york staten /location/location/contains /eos staten staten staten
# Ground-Truth: 	york staten /location/location/contains /eos
# ---
# Predict: 	stephen qwest /business/person/company /eos edmonton edmonton edmonton
# Ground-Truth: 	stephen blackstone /business/person/company /eos
# ---
# Predict: 	ontario toronto /location/location/contains /eos vancouver vancouver vancouver
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---
# Predict: 	westport westport /location/location/contains /eos westport westport westport
# Ground-Truth: 	westport winslow /location/location/contains /eos
# ---
# Predict: 	baltimore tulane /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	baltimore m&t /location/location/contains /eos
# ---
# Predict: 	washington carroll /location/location/contains /eos
# Ground-Truth: 	washington walter /location/location/contains /eos
# ---
# Predict: 	vicente mexico /location/administrative_division/country /eos puerto puerto puerto
# Ground-Truth: 	guanajuato mexico /location/administrative_division/country /eos
# ---
# Predict: 	manmohan india /location/administrative_division/country /eos /eos /eos /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---
# Predict: 	europe france /location/administrative_division/country /eos portugal portugal portugal
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---
# Predict: 	frank york /business/person/company /eos montclair montclair montclair
# Ground-Truth: 	dennis york /business/person/company /eos
# ---
# Predict: 	kansa westport /location/location/contains /eos westport westport westport
# Ground-Truth: 	kansa atchison /location/location/contains /eos
# ---
# Predict: 	boston massachusetts /location/location/contains /eos denver denver denver
# Ground-Truth: 	boston massachusetts /location/location/contains /eos
# ---
# Predict: 	washington mount /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	washington mount /location/location/contains /eos
# ---
# Predict: 	cuba cuba /location/location/contains /eos bolivia bolivia bolivia
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	washington united /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	washington united /location/location/contains /eos
# ---
# Predict: 	florida boca /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---
# Predict: 	europe spain /location/administrative_division/country /eos barcelona barcelona barcelona
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---
# Predict: 	bob ford /business/person/company /eos /eos /eos /eos
# Ground-Truth: 	eddie reebok /business/person/company /eos
# ---
# Predict: 	ontario st /location/location/contains /eos vancouver vancouver vancouver
# Ground-Truth: 	ontario st /location/location/contains /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos dick dick dick
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	florida boca /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida ponte /location/location/contains /eos
# ---
# Predict: 	south south /location/administrative_division/country /eos kim kim kim
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---
# Predict: 	florida lake /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---
# Predict: 	chicago boca /location/location/contains /eos tampa tampa tampa
# Ground-Truth: 	chicago sears /location/location/contains /eos
# ---
# Predict: 	ontario windsor /location/location/contains /eos vancouver vancouver vancouver
# Ground-Truth: 	ontario woodbridge /location/location/contains /eos
# ---
# Predict: 	washington great /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	washington national /location/location/contains /eos
# ---
# Predict: 	zambia monrovia /location/country/capital /eos nelson nelson nelson
# Ground-Truth: 	guinea conakry /location/country/capital /eos
# ---
# Predict: 	iowa canton /location/location/contains /eos camden camden camden
# Ground-Truth: 	iowa waterloo /location/location/contains /eos
# ---
# Predict: 	italy florence /location/location/contains /eos portugal portugal portugal
# Ground-Truth: 	italy amalfi /location/location/contains /eos
# ---
# Predict: 	europe france /location/administrative_division/country /eos barcelona barcelona barcelona
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---
# Predict: 	westchester hudson /location/location/contains /eos rockland rockland rockland
# Ground-Truth: 	westchester hudson /location/location/contains /eos
# ---
# Predict: 	kenneth georgia /business/person/company /eos wayne wayne wayne
# Ground-Truth: 	g. georgia /business/person/company /eos
# ---
# Predict: 	cuba cuba /location/location/contains /eos caracas caracas caracas
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---
# Predict: 	berkeley berkeley /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---
# Predict: 	middle israel /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos dick dick dick
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	don york /business/person/company /eos arkansas arkansas arkansas
# Ground-Truth: 	tyler york /business/person/company /eos
# ---
# Predict: 	europe india /location/administrative_division/country /eos delhi delhi delhi
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---
# Predict: 	canada canada /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---
# Predict: 	michigan red /location/location/contains /eos wayne wayne wayne
# Ground-Truth: 	toledo ottawa /location/location/contains /eos
# ---
# Predict: 	zambia park /location/location/contains /eos nelson nelson nelson
# Ground-Truth: 	namibia windhoek /location/location/contains /eos
# ---
# Predict: 	kofi united /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	mamaroneck united /location/location/contains /eos
# ---
# Predict: 	vermont mount /location/location/contains /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---
# Predict: 	europe spain /location/administrative_division/country /eos portugal portugal portugal
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos amsterdam amsterdam amsterdam
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---
# Predict: 	washington iran /people/person/nationality /eos jordan jordan jordan
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---
# Predict: 	marcello france /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	corsica france /location/administrative_division/country /eos
# ---
# Predict: 	syria ramallah /location/location/contains /eos jordan jordan jordan
# Ground-Truth: 	syria damascus /location/location/contains /eos
# ---
# Predict: 	manmohan india /people/person/nationality /eos sri sri sri
# Ground-Truth: 	shilpa india /people/person/nationality /eos
# ---
# Predict: 	finland helsinki /location/location/contains /eos finland finland finland
# Ground-Truth: 	finland turku /location/location/contains /eos
# ---
# Predict: 	germany leipzig /location/location/contains /eos montclair montclair montclair
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---
# Predict: 	boston clark /location/location/contains /eos stanford stanford stanford
# Ground-Truth: 	boston beth /location/location/contains /eos
# ---
# Predict: 	tom maine /people/person/place_lived /eos wayne wayne wayne
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---
# Predict: 	rockland port /location/location/contains /eos rockland rockland rockland
# Ground-Truth: 	rockland city /location/location/contains /eos
# ---
# Predict: 	jared economic /business/person/company /eos montclair montclair montclair
# Ground-Truth: 	martin national /business/person/company /eos
# ---
# Predict: 	toronto /location/country/capital /location/location/contains /eos
# Ground-Truth: 	toronto barrick /location/location/contains /eos
# ---
# Predict: 	lake chicago /people/deceased_person/place_of_death /eos edmonton edmonton edmonton
# Ground-Truth: 	lake chicago /location/administrative_division/country /eos
# ---
# Predict: 	cambridge harvard /location/location/contains /eos stanford stanford stanford
# Ground-Truth: 	marlborough cytyc /location/location/contains /eos
# ---
# Predict: 	france strasbourg /location/location/contains /eos philippine philippine philippine
# Ground-Truth: 	france alzonne /location/location/contains /eos
# ---
# Predict: 	washington great /location/location/contains /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---
# Predict: 	mexico cancun /location/location/contains /eos puerto puerto puerto
# Ground-Truth: 	mexico ciudad /location/location/contains /eos
# ---
# Predict: 	iran syria /location/administrative_division/country /eos ali ali ali
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos jordan jordan jordan
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---
# Predict: 	vermont mount /location/location/contains /eos worcester worcester worcester
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---
# Predict: 	connecticut bridgeport /location/location/contains /eos westport westport westport
# Ground-Truth: 	connecticut hamden /location/location/contains /eos
# ---
# Predict: 	washington iran /location/administrative_division/country /eop russia russia /location/administrative_division/country /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eop russia iran /location/administrative_division/country /eos
# ---
# Predict: 	middle iran /location/administrative_division/country /eos jordan jordan jordan
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos dick dick dick
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos dick dick dick
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---
# Predict: 	iowa colombo /location/location/contains /eos memphis memphis memphis
# Ground-Truth: 	iowa waverly /location/location/contains /eos
# ---
# Predict: 	cuba caracas /location/location/contains /eos dominican dominican dominican
# Ground-Truth: 	cuba bayamo /location/location/contains /eos
# ---
# Predict: 	nelson south /people/person/nationality /eos ali ali ali
# Ground-Truth: 	aziz south /people/person/nationality /eos
# ---
# Predict: 	italy calgary /location/location/contains /eos edmonton edmonton edmonton
# Ground-Truth: 	italy reggio /location/location/contains /eos
# ---
# Predict: 	iran washington /people/person/place_lived /eos mohammad mohammad mohammad
# Ground-Truth: 	iran washington /location/administrative_division/country /eos
# ---
# Predict: 	hampshire pratt /location/location/contains /eos
# Ground-Truth: 	hampshire cannon /location/location/contains /eos
# ---
# Predict: 	evo bolivia /people/person/place_lived /eos philippine philippine philippine
# Ground-Truth: 	helen guatemala /people/person/place_lived /eos
# ---
# Predict: 	ukraine white /location/location/contains /eos /eos /eos /eos
# Ground-Truth: 	romania black /location/location/contains /eos
# ---
# Predict: 	iran syria /people/person/nationality /eos rafik rafik rafik
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---
# Predict: 	gainesville gainesville /location/location/contains /eos gainesville gainesville gainesville
# Ground-Truth: 	decatur agnes /location/location/contains /eos
# ---
# Predict: 	kim north /business/person/company /eos wayne wayne wayne
# Ground-Truth: 	robin north /business/person/company /eos
# ---
# Predict: 	pratt philippine /people/person/nationality /eos philippine philippine philippine
# Ground-Truth: 	imelda philippine /people/person/nationality /eos
# ---
# Predict: 	charles don /people/person/children /eos philippine philippine philippine
# Ground-Truth: 	charles woody /people/person/children /eos
# ---
# Predict: 	maryland baltimore /location/location/contains /eos franklin franklin franklin
# Ground-Truth: 	maryland annapolis /location/location/contains /eos
# ---
# Predict: 	paris louvre /location/location/contains /eos upper upper upper
# Ground-Truth: 	paris gare /location/location/contains /eos
# ---
# Predict: 	stephen case /business/person/company /eos montclair montclair montclair
# Ground-Truth: 	stephen case /business/person/company /eos
# ---
# Predict: 	boston great /location/location/contains /eos
# Ground-Truth: 	boston church /location/location/contains /eos
# ---
# Predict: 	haley mississippi /people/person/place_lived /eos mitch mitch mitch
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---
# Predict: 	susan maine /people/person/place_lived /eos camden camden camden
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---

# %% [markdown]
# ## Beam Search Evaluate

# %%
from keras.preprocessing.sequence import pad_sequences
from tqdm import tqdm

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/cp_logs/weights.376-1.372052.hdf5'
model.load_weights(filename)

# %%
def greedysearch():
    pred = []
    for i in tqdm(range(395)):
        pR = []
        tag = 0
        fb_words = np.array([word2index['/go']])
        x = np.array([x_test[i]])
    
        for j in range(MAX_ADJL_LEN):
            fb_input = pad_sequences([fb_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
            prob = model.predict([x, fb_input], batch_size=BATCH_SIZE)[0][j]
            if j in [0, 1, 4, 5]:
                for item in [i for i in x_test[i] if i != 0]:
                    prob[item] = float(prob[item]+1)
            if j in [2, 6]:
                prob[:65135] = -1
            if j == 3:
                prob[:65132] = -1
                prob[65134:] = -1
            if j == 8:
                prob[65133] = float(prob[65133]+1)
            prob[0] = -1
            prob[tag] = -1
            result = prob.argmax()
            tag = result
            pR.append(result)
            fb_words = np.append(fb_words, result)
            if index2word[result] == '/eos':
                break
        pred.append(pR)
        
    pred = [[index2word[i] for i in sent if i != 0] for sent in pred]
    actu = [[index2word[i] for i in sent if i != 0] for sent in y_test]
    e1Count = sum([1 for i in range(395) if actu[i][0] == pred[i][0]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][3] == pred[i][3]])
    e2Count = sum([1 for i in range(395) if actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])
    enCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])      
    reCount = sum([1 for i in range(395) if actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]])
    tripleCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1] and actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]]) 
    print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
    print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
    print('En Accuracy: \t\t%.6f' % (enCount/396))
    print('Re Accuracy: \t\t%.6f' % (reCount/396))
    print('Triple Accuracy: \t%.6f' % (tripleCount/396))
    
    for i in range(395):
        print('Predict: \t%s' % ' '.join(pred[i]))
        print('Ground-Truth: \t%s' % ' '.join(actu[i]))
        print('---------')

# %%
greedysearch()
# Out:
# 100%|██████████| 395/395 [03:29<00:00,  1.90it/s]
# E1 Accuracy: 		0.305556
# E2 Accuracy: 		0.239899
# En Accuracy: 		0.118687
# Re Accuracy: 		0.121212
# Triple Accuracy: 	0.027778
# Predict: 	italy spain /people/person/nationality /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---------
# Predict: 	westchester connecticut /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	westchester connecticut /location/administrative_division/country /eos
# ---------
# Predict: 	israel jordan /location/country/capital /eos
# Ground-Truth: 	dalia israel /people/person/nationality /eos
# ---------
# Predict: 	india university /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	hyderabad potti /location/location/contains /eos
# ---------
# Predict: 	north bush /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	kent north /people/person/place_lived /eos
# ---------
# Predict: 	ontario waterloo /people/deceased_person/place_of_death /eos
# Ground-Truth: 	ontario waterloo /location/location/contains /eos
# ---------
# Predict: 	stephen blackstone /people/deceased_person/place_of_death /eos
# Ground-Truth: 	blackstone stephen /business/company/founders /eos
# ---------
# Predict: 	italy spain /people/person/nationality /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	iran russia /people/person/nationality /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	american france /people/person/nationality /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	george american /people/deceased_person/place_of_death /eos
# Ground-Truth: 	george abc /business/person/company /eos
# ---------
# Predict: 	florida william /business/company/founders /eos
# Ground-Truth: 	florida jacksonville /location/location/contains /eos
# ---------
# Predict: 	nigeria resort /people/person/nationality /eos
# Ground-Truth: 	nigeria uyo /location/location/contains /eos
# ---------
# Predict: 	rhode vermont /people/person/place_lived /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---------
# Predict: 	kentucky patrick /people/person/children /eos
# Ground-Truth: 	patrick huntington /people/person/place_lived /eos
# ---------
# Predict: 	european germany /people/person/nationality /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	a weinberg /people/deceased_person/place_of_death /eos
# Ground-Truth: 	jeffrey lazard /business/person/company /eos
# ---------
# Predict: 	israel gaza /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	u.s. a /location/country/capital /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	mark york /people/deceased_person/place_of_death /eos
# Ground-Truth: 	mark york /business/person/company /eos
# ---------
# Predict: 	netherlands australia /people/person/nationality /eos
# Ground-Truth: 	markus australia /people/person/nationality /eos
# ---------
# Predict: 	princeton anthony /people/deceased_person/place_of_death /eos
# Ground-Truth: 	kwame princeton /business/person/company /eos
# ---------
# Predict: 	deal a /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	endemol john /business/company/founders /eos
# ---------
# Predict: 	state month /people/deceased_person/place_of_death /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---------
# Predict: 	haven connecticut /people/person/place_lived /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---------
# Predict: 	iran russia /people/person/nationality /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	india state /location/administrative_division/country /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---------
# Predict: 	bill understand /people/deceased_person/place_of_death /eos
# Ground-Truth: 	bill dawsonville /people/person/place_lived /eos
# ---------
# Predict: 	british columbia /people/deceased_person/place_of_death /eos
# Ground-Truth: 	daniel university /business/person/company /eos
# ---------
# Predict: 	soviet russia /people/person/nationality /eos
# Ground-Truth: 	soviet russia /location/administrative_division/country /eos
# ---------
# Predict: 	boston johnson /people/deceased_person/place_of_death /eos
# Ground-Truth: 	boston wbz-tv /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	a queen /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	virginia united /location/administrative_division/country /eos
# ---------
# Predict: 	ira security /people/deceased_person/place_of_death /eos
# Ground-Truth: 	ira system /business/person/company /eos
# ---------
# Predict: 	a legal /people/deceased_person/place_of_death /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a hoboken /people/deceased_person/place_of_death /eos
# Ground-Truth: 	anthony york /business/person/company /eos
# ---------
# Predict: 	a google /people/person/nationality /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---------
# Predict: 	evans a /people/deceased_person/place_of_death /eos
# Ground-Truth: 	washington bainbridge /location/location/contains /eos
# ---------
# Predict: 	cross lrb /people/deceased_person/place_of_death /eos
# Ground-Truth: 	washington olympia /location/location/contains /eos
# ---------
# Predict: 	south korea /location/administrative_division/country /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---------
# Predict: 	mexico spain /location/administrative_division/country /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	a germany /people/person/nationality /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	a syria /people/person/nationality /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	player thomas /people/person/children /eos
# Ground-Truth: 	kellen colorado /people/person/place_of_birth /eos
# ---------
# Predict: 	united argentina /people/person/nationality /eos
# Ground-Truth: 	tony france /people/person/nationality /eos
# ---------
# Predict: 	spain luis /location/administrative_division/country /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---------
# Predict: 	include italy /people/person/nationality /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	island staten /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---------
# Predict: 	alternative nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	at&t la /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	ralph at&t /business/person/company /eos
# ---------
# Predict: 	haven hartford /people/deceased_person/place_of_death /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---------
# Predict: 	somalia american /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	somalia puntland /location/location/contains /eos
# ---------
# Predict: 	latvia boris /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	riga latvia /location/administrative_division/country /eos
# ---------
# Predict: 	switzerland iran /people/person/nationality /eos
# Ground-Truth: 	switzerland davos /location/location/contains /eos
# ---------
# Predict: 	free resort /people/deceased_person/place_of_death /eos
# Ground-Truth: 	colorado vail /location/location/contains /eos
# ---------
# Predict: 	paris france /people/person/nationality /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	staten queen /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	lower hudson /location/location/contains /eos
# ---------
# Predict: 	a north /people/deceased_person/place_of_death /eos
# Ground-Truth: 	san north /location/location/contains /eos
# ---------
# Predict: 	york county /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	nassau suffolk /location/administrative_division/country /eos
# ---------
# Predict: 	chad youtube /people/person/nationality /eos
# Ground-Truth: 	chad youtube /business/person/company /eos
# ---------
# Predict: 	westchester city /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	westchester kensico /location/location/contains /eos
# ---------
# Predict: 	nebraska maine /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	italy house /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	italy orvieto /location/location/contains /eos
# ---------
# Predict: 	university local /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	greenville furman /location/location/contains /eos
# ---------
# Predict: 	a princeton /people/deceased_person/place_of_death /eos
# Ground-Truth: 	charles princeton /business/person/company /eos
# ---------
# Predict: 	ontario canada /people/person/nationality /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	egypt israel /people/person/nationality /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	baltimore john /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	baltimore john /location/location/contains /eos
# ---------
# Predict: 	a india /people/person/nationality /eos
# Ground-Truth: 	samantha india /people/person/place_lived /eos
# ---------
# Predict: 	david kenny /people/person/children /eos
# Ground-Truth: 	david digitas /business/person/company /eos
# ---------
# Predict: 	tom iowa /people/person/place_lived /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---------
# Predict: 	lebanon syria /people/person/nationality /eos
# Ground-Truth: 	rafik lebanon /people/person/nationality /eos
# ---------
# Predict: 	president party /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	atiku nigeria /people/person/nationality /eos
# ---------
# Predict: 	a watching /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---------
# Predict: 	a florida /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida panama /location/location/contains /eos
# ---------
# Predict: 	iraq west /people/deceased_person/place_of_death /eos
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /people/person/nationality /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	percent will /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---------
# Predict: 	town wall /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	clarkstown city /location/location/contains /eos
# ---------
# Predict: 	india delhi /people/deceased_person/place_of_death /eos
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---------
# Predict: 	mississippi state /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---------
# Predict: 	florida boca /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	chief jetblue /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	gordon continental /business/person/company /eos
# ---------
# Predict: 	henry france /people/person/nationality /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	san percent /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	california long /location/location/contains /eos
# ---------
# Predict: 	george france /people/person/nationality /eos
# Ground-Truth: 	france correze /location/location/contains /eos
# ---------
# Predict: 	school county /people/deceased_person/place_of_death /eos
# Ground-Truth: 	fairfax westfield /location/location/contains /eos
# ---------
# Predict: 	a palestinian /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	city spain /location/administrative_division/country /eos
# Ground-Truth: 	spain valencia /location/location/contains /eos
# ---------
# Predict: 	iraq a /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	greenwich jefferson /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	greenwich jefferson /location/location/contains /eos
# ---------
# Predict: 	a hamas /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	france jacques /people/person/nationality /eos
# Ground-Truth: 	jacques france /people/person/nationality /eos
# ---------
# Predict: 	ramapo mahwah /people/deceased_person/place_of_death /eos
# Ground-Truth: 	mahwah ramapo /location/location/contains /eos
# ---------
# Predict: 	guyana money /location/administrative_division/country /eos
# Ground-Truth: 	guyana linden /location/location/contains /eos
# ---------
# Predict: 	dr singh /people/person/nationality /eos
# Ground-Truth: 	india punjab /location/location/contains /eos
# ---------
# Predict: 	ontario marlene /people/person/children /eos
# Ground-Truth: 	ontario tobermory /location/location/contains /eos
# ---------
# Predict: 	a iran /people/person/nationality /eos
# Ground-Truth: 	middle iran /location/location/contains /eos
# ---------
# Predict: 	a africa /people/person/nationality /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a european /people/person/nationality /eos
# Ground-Truth: 	italy israel /location/administrative_division/country /eos
# ---------
# Predict: 	germany france /people/person/nationality /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---------
# Predict: 	a google /people/person/nationality /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---------
# Predict: 	israel palestinian /location/country/capital /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	minnesota amy /people/person/children /eos
# Ground-Truth: 	amy minnesota /people/person/place_lived /eos
# ---------
# Predict: 	australian john /business/company/founders /eos
# Ground-Truth: 	john australia /people/person/nationality /eos
# ---------
# Predict: 	kentucky ernie /people/person/children /eos
# Ground-Truth: 	ernie kentucky /people/person/place_lived /eos
# ---------
# Predict: 	north iran /people/person/nationality /eos
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---------
# Predict: 	northern india /people/person/nationality /eos
# Ground-Truth: 	india bihar /location/country/administrative_divisions /eos
# ---------
# Predict: 	a ireland /people/person/nationality /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---------
# Predict: 	1 cuba /people/person/nationality /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	italy house /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	italy umbria /location/location/contains /eos
# ---------
# Predict: 	italy spain /people/person/nationality /eos
# Ground-Truth: 	campania italy /location/administrative_division/country /eos
# ---------
# Predict: 	a iraq /people/person/nationality /eos
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---------
# Predict: 	city sahn /business/company/founders /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	canada spain /location/administrative_division/country /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---------
# Predict: 	british france /people/person/nationality /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	cleveland manhattan /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	cleveland karamu /location/location/contains /eos
# ---------
# Predict: 	airport ireland /people/person/nationality /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---------
# Predict: 	school paul /people/person/children /eos
# Ground-Truth: 	california san /location/location/contains /eos
# ---------
# Predict: 	france joyce /people/deceased_person/place_of_death /eos
# Ground-Truth: 	france albertville /location/location/contains /eos
# ---------
# Predict: 	eastern time /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	bosnia srebrenica /location/location/contains /eos
# ---------
# Predict: 	a john /people/person/children /eos
# Ground-Truth: 	upper fort /location/location/contains /eos
# ---------
# Predict: 	chef pic /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	france valence /location/location/contains /eos
# ---------
# Predict: 	james united /people/person/nationality /eos
# Ground-Truth: 	james tampa /people/person/place_lived /eos
# ---------
# Predict: 	president house /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	syria damascus /location/country/administrative_divisions /eos
# ---------
# Predict: 	a marshall /people/deceased_person/place_of_death /eos
# Ground-Truth: 	marshall fremont /people/deceased_person/place_of_death /eos
# ---------
# Predict: 	jerusalem israel /people/person/nationality /eos
# Ground-Truth: 	israel jerusalem /location/location/contains /eos
# ---------
# Predict: 	sunni syria /people/person/nationality /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	cambridge university /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	cambridge lesley /location/location/contains /eos
# ---------
# Predict: 	australia chris /location/administrative_division/country /eos
# Ground-Truth: 	chris australia /people/person/nationality /eos
# ---------
# Predict: 	dennis rice /people/person/nationality /eos
# Ground-Truth: 	dennis disney /business/person/company /eos
# ---------
# Predict: 	company 000 /people/deceased_person/place_of_death /eos
# Ground-Truth: 	colorado aspen /location/location/contains /eos
# ---------
# Predict: 	soviet south /people/person/nationality /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---------
# Predict: 	staten fort /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	staten fort /location/location/contains /eos
# ---------
# Predict: 	syria damascus /location/country/capital /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	mexico city /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	a france /people/person/nationality /eos
# Ground-Truth: 	jean-louis france /people/person/nationality /eos
# ---------
# Predict: 	france airbus /location/administrative_division/country /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---------
# Predict: 	jim kentucky /people/person/place_lived /eos
# Ground-Truth: 	jim kentucky /people/person/place_lived /eos
# ---------
# Predict: 	berlin germany /people/person/nationality /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	lebanon israel /people/person/nationality /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	james brett /people/person/children /eos
# Ground-Truth: 	brett priceline /business/person/company /eos
# ---------
# Predict: 	center jersey /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	newark jersey /location/location/contains /eos
# ---------
# Predict: 	peter columbia /people/deceased_person/place_of_death /eos
# Ground-Truth: 	peter columbia /business/person/company /eos
# ---------
# Predict: 	mikhail diana /people/deceased_person/place_of_death /eos
# Ground-Truth: 	leningrad vaganova /location/location/contains /eos
# ---------
# Predict: 	a mexico /people/person/nationality /eos
# Ground-Truth: 	mexico jalisco /location/country/administrative_divisions /eos
# ---------
# Predict: 	westchester york /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---------
# Predict: 	syria united /people/person/nationality /eos
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---------
# Predict: 	a brittany /people/person/children /eos
# Ground-Truth: 	brittany seminole /people/person/place_lived /eos
# ---------
# Predict: 	mexico city /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	munich germany /people/person/nationality /eos
# Ground-Truth: 	germany munich /location/location/contains /eos
# ---------
# Predict: 	a switzerland /people/person/nationality /eos
# Ground-Truth: 	ernst davos /people/deceased_person/place_of_death /eos
# ---------
# Predict: 	a review /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a baseball /people/deceased_person/place_of_death /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	germany news /location/administrative_division/country /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---------
# Predict: 	jeffrey general /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	jeffrey general /business/person/company /eos
# ---------
# Predict: 	a poland /people/person/nationality /eos
# Ground-Truth: 	poland cracow /location/location/contains /eos
# ---------
# Predict: 	senator minnesota /people/person/place_lived /eos
# Ground-Truth: 	norm minnesota /people/person/place_lived /eos
# ---------
# Predict: 	iowa hampshire /people/person/place_lived /eos
# Ground-Truth: 	south iowa /location/administrative_division/country /eos
# ---------
# Predict: 	south michigan /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	kofmehl charleston /people/deceased_person/place_of_death /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	kofmehl charleston /people/deceased_person/place_of_death /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	will meet /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---------
# Predict: 	black robert /people/person/children /eos
# Ground-Truth: 	black robert /business/company/founders /eos
# ---------
# Predict: 	a arkansas /people/person/place_lived /eos
# Ground-Truth: 	arkansas arkadelphia /location/location/contains /eos
# ---------
# Predict: 	a northern /people/person/nationality /eos
# Ground-Truth: 	navarre spain /location/administrative_division/country /eos
# ---------
# Predict: 	a grant /people/person/children /eos
# Ground-Truth: 	toronto canada /location/administrative_division/country /eos
# ---------
# Predict: 	coney brooklyn /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	coney york /location/location/contains /eos
# ---------
# Predict: 	washington amsterdam /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	port harborside /location/location/contains /eos
# ---------
# Predict: 	tom iowa /people/person/place_lived /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---------
# Predict: 	northern gaza /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	national california /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	california lawrence /location/location/contains /eos
# ---------
# Predict: 	american france /people/person/nationality /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	latin mexico /people/person/nationality /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	york city /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	lower york /location/neighborhood/neighborhood_of /eos
# ---------
# Predict: 	cruise lrb /people/deceased_person/place_of_death /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	county san /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	sonoma occidental /location/location/contains /eos
# ---------
# Predict: 	a christopher /people/person/children /eos
# Ground-Truth: 	christopher security /business/person/company /eos
# ---------
# Predict: 	a india /people/person/nationality /eos
# Ground-Truth: 	india hyderabad /location/location/contains /eos
# ---------
# Predict: 	subject kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	nebraska bill /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	gov rep /people/person/place_lived /eos
# Ground-Truth: 	tommy wisconsin /people/person/place_lived /eos
# ---------
# Predict: 	thailand state /location/administrative_division/country /eos
# Ground-Truth: 	bangkok thailand /location/administrative_division/country /eos
# ---------
# Predict: 	parent foundation /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	california malibu /location/location/contains /eos
# ---------
# Predict: 	berkeley school /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	ayelet berkeley /people/person/place_lived /eos
# ---------
# Predict: 	cuba american /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	kansa kathleen /people/deceased_person/place_of_death /eos
# Ground-Truth: 	kathleen kansa /people/person/place_lived /eos
# ---------
# Predict: 	greenwich york /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	york greenwich /location/location/contains /eos
# ---------
# Predict: 	senator kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	west bank /people/deceased_person/place_of_death /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	tanzania mount /location/country/capital /eos
# Ground-Truth: 	mount tanzania /location/administrative_division/country /eos
# ---------
# Predict: 	lebanon israel /people/person/nationality /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	ireland county /people/deceased_person/place_of_death /eos
# Ground-Truth: 	ireland athenry /location/location/contains /eos
# ---------
# Predict: 	iran tehran /location/country/capital /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	berlin germany /people/person/nationality /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	a lebanon /people/person/nationality /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	a russia /people/person/nationality /eos
# Ground-Truth: 	russia iran /location/administrative_division/country /eos
# ---------
# Predict: 	a oregon /people/deceased_person/place_of_death /eos
# Ground-Truth: 	eugene university /location/location/contains /eos
# ---------
# Predict: 	spain well /location/administrative_division/country /eos
# Ground-Truth: 	catalonia spain /location/administrative_division/country /eos
# ---------
# Predict: 	australia south /people/person/nationality /eos
# Ground-Truth: 	australia port /location/location/contains /eos
# ---------
# Predict: 	a indigenous /people/person/nationality /eos
# Ground-Truth: 	evo bolivia /people/person/nationality /eos
# ---------
# Predict: 	heart berlin /people/deceased_person/place_of_death /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	south carolina /people/person/nationality /eos
# Ground-Truth: 	south darlington /location/location/contains /eos
# ---------
# Predict: 	a official /people/person/nationality /eos
# Ground-Truth: 	nelson zimbabwe /people/person/nationality /eos
# ---------
# Predict: 	a israel /people/person/nationality /eos
# Ground-Truth: 	israel ra'anana /location/location/contains /eos
# ---------
# Predict: 	india state /location/administrative_division/country /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	india a /location/administrative_division/country /eos
# Ground-Truth: 	gujarat india /location/administrative_division/country /eos
# ---------
# Predict: 	cleveland county /people/deceased_person/place_of_death /eos
# Ground-Truth: 	cuyahoga cleveland /location/location/contains /eos
# ---------
# Predict: 	florida princeton /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida gulf /location/location/contains /eos
# ---------
# Predict: 	india delhi /location/country/capital /eos
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---------
# Predict: 	mexico 30 /location/administrative_division/country /eos
# Ground-Truth: 	mexico mexico /location/location/contains /eos
# ---------
# Predict: 	indonesia italy /people/person/nationality /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	a israel /people/person/nationality /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	jerusalem adolf /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	jerusalem yad /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	italy well /location/administrative_division/country /eos
# Ground-Truth: 	italy maranello /location/location/contains /eos
# ---------
# Predict: 	israel west /location/country/capital /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	nebraska ben /people/deceased_person/place_of_death /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	india africa /people/person/nationality /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---------
# Predict: 	syria israel /people/person/nationality /eos
# Ground-Truth: 	bashar syria /people/person/nationality /eos
# ---------
# Predict: 	louisiana baton /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	louisiana baton /location/location/contains /eos
# ---------
# Predict: 	nuclear iran /people/person/nationality /eos
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---------
# Predict: 	sony united /people/person/nationality /eos
# Ground-Truth: 	sony akio /business/company/founders /eos
# ---------
# Predict: 	israel brad /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---------
# Predict: 	indonesia italy /people/person/nationality /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	southern art /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	calabria crotone /location/location/contains /eos
# ---------
# Predict: 	florida jack /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	a claim /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	group congress /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	derrick ford /business/person/company /eos
# ---------
# Predict: 	west chicago /people/deceased_person/place_of_death /eos
# Ground-Truth: 	chicago west /location/location/contains /eos
# ---------
# Predict: 	carter virginia /people/person/place_lived /eos
# Ground-Truth: 	virginia middleburg /location/location/contains /eos
# ---------
# Predict: 	state oklahoma /people/person/place_lived /eos
# Ground-Truth: 	brad oklahoma /people/person/place_lived /eos
# ---------
# Predict: 	berkeley california /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	california berkeley /location/location/contains /eos
# ---------
# Predict: 	italy germany /people/person/nationality /eos
# Ground-Truth: 	italy germany /location/administrative_division/country /eos
# ---------
# Predict: 	chicago state /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	cook chicago /location/location/contains /eos
# ---------
# Predict: 	suffolk county /people/deceased_person/place_of_death /eos
# Ground-Truth: 	fire ocean /location/location/contains /eos
# ---------
# Predict: 	mexico central /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	republican kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	president chief /people/person/nationality /eos
# Ground-Truth: 	shona google /business/person/company /eos
# ---------
# Predict: 	george france /people/person/nationality /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	mexico north /people/person/nationality /eos
# Ground-Truth: 	juarez mexico /location/administrative_division/country /eos
# ---------
# Predict: 	minister work /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	pavony steven /people/person/children /eos
# Ground-Truth: 	israel rehovot /location/location/contains /eos
# ---------
# Predict: 	zeitlin bill /business/company/founders /eos
# Ground-Truth: 	will york /business/person/company /eos
# ---------
# Predict: 	boston college /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	juliet boston /business/person/company /eos
# ---------
# Predict: 	greece italy /people/person/nationality /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	leader kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	capuchinas mexico /people/person/nationality /eos
# Ground-Truth: 	mexico puebla /location/location/contains /eos
# ---------
# Predict: 	lrb rrb /people/deceased_person/place_of_death /eos
# Ground-Truth: 	spain cordoba /location/location/contains /eos
# ---------
# Predict: 	senator kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	israel gaza /location/country/capital /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	toronto university /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	toronto mount /location/location/contains /eos
# ---------
# Predict: 	india state /people/person/nationality /eos
# Ground-Truth: 	delhi india /location/administrative_division/country /eos
# ---------
# Predict: 	oregon canada /people/person/nationality /eos
# Ground-Truth: 	canada calgary /location/location/contains /eos
# ---------
# Predict: 	p.m. ontario /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---------
# Predict: 	woman player /people/person/place_lived /eos
# Ground-Truth: 	nikolay russia /people/person/nationality /eos
# ---------
# Predict: 	a sadr /people/deceased_person/place_of_death /eos
# Ground-Truth: 	vali naval /business/person/company /eos
# ---------
# Predict: 	italy spain /people/person/nationality /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---------
# Predict: 	paris de /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	paris ecole /location/location/contains /eos
# ---------
# Predict: 	a jordan /people/person/nationality /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---------
# Predict: 	europe a /location/country/capital /eos
# Ground-Truth: 	algeria algiers /location/country/capital /eos
# ---------
# Predict: 	a northern /people/deceased_person/place_of_death /eos
# Ground-Truth: 	india dharamsala /location/location/contains /eos
# ---------
# Predict: 	florida lake /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---------
# Predict: 	time washington /people/deceased_person/place_of_death /eos
# Ground-Truth: 	donald washington /business/person/company /eos
# ---------
# Predict: 	ontario canada /people/person/nationality /eos
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---------
# Predict: 	california republican /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	dana california /people/person/place_lived /eos
# ---------
# Predict: 	germany middle /location/administrative_division/country /eos
# Ground-Truth: 	germany nuremberg /location/location/contains /eos
# ---------
# Predict: 	paul israel /people/person/nationality /eos
# Ground-Truth: 	stanley bank /business/person/company /eos
# ---------
# Predict: 	park battery /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	lower battery /location/location/contains /eos
# ---------
# Predict: 	lloyd wright /people/deceased_person/place_of_death /eos
# Ground-Truth: 	frank lloyd /people/person/children /eos
# ---------
# Predict: 	mexico york /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	state syria /people/person/nationality /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	france paris /people/deceased_person/place_of_death /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	peck york /people/deceased_person/place_of_death /eos
# Ground-Truth: 	york peck /location/location/contains /eos
# ---------
# Predict: 	china russia /people/person/nationality /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	taiwan west /location/administrative_division/country /eos
# Ground-Truth: 	taiwan taipei /location/location/contains /eos
# ---------
# Predict: 	sex iraqi /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	a serbia /people/person/nationality /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	ontario mary /people/person/children /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---------
# Predict: 	israel shimon /location/country/capital /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---------
# Predict: 	baja a /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	mexico baja /location/location/contains /eos
# ---------
# Predict: 	police india /people/person/nationality /eos
# Ground-Truth: 	india chhattisgarh /location/location/contains /eos
# ---------
# Predict: 	michoacan mexico /people/person/nationality /eos
# Ground-Truth: 	michoacan mexico /location/administrative_division/country /eos
# ---------
# Predict: 	amansala mexico /people/person/nationality /eos
# Ground-Truth: 	mexico tulum /location/location/contains /eos
# ---------
# Predict: 	georgia atlanta /people/deceased_person/place_of_death /eos
# Ground-Truth: 	atlanta georgia /location/location/contains /eos
# ---------
# Predict: 	water year /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---------
# Predict: 	australia libby /business/company/founders /eos
# Ground-Truth: 	libby australia /people/person/nationality /eos
# ---------
# Predict: 	spain general /location/administrative_division/country /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---------
# Predict: 	a iran /people/person/nationality /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---------
# Predict: 	mark hewlett-packard /business/person/company /eos
# Ground-Truth: 	mark hewlett-packard /business/person/company /eos
# ---------
# Predict: 	paris national /people/person/nationality /eos
# Ground-Truth: 	paris musee /location/location/contains /eos
# ---------
# Predict: 	a 1938 /people/deceased_person/place_of_death /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	charles houston /people/deceased_person/place_of_death /eos
# Ground-Truth: 	harris houston /location/location/contains /eos
# ---------
# Predict: 	a cuba /people/person/nationality /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	puzzle time /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	will time /business/person/company /eos
# ---------
# Predict: 	israel west /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	chicago york /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	chicago winston /location/location/contains /eos
# ---------
# Predict: 	energy iraq /people/person/nationality /eos
# Ground-Truth: 	amory rocky /business/person/company /eos
# ---------
# Predict: 	george rochester /people/deceased_person/place_of_death /eos
# Ground-Truth: 	rochester george /location/location/contains /eos
# ---------
# Predict: 	mexico cancun /location/country/capital /eos
# Ground-Truth: 	mexico cancun /location/location/contains /eos
# ---------
# Predict: 	river a /people/deceased_person/place_of_death /eos
# Ground-Truth: 	idaho salmon /location/location/contains /eos
# ---------
# Predict: 	africa west /people/person/nationality /eos
# Ground-Truth: 	west senegal /location/location/contains /eos
# ---------
# Predict: 	a staten /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---------
# Predict: 	txu group /people/deceased_person/place_of_death /eos
# Ground-Truth: 	stephen blackstone /business/person/company /eos
# ---------
# Predict: 	ontario queen /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---------
# Predict: 	park a /people/deceased_person/place_of_death /eos
# Ground-Truth: 	westport winslow /location/location/contains /eos
# ---------
# Predict: 	baltimore cornell /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	baltimore m&t /location/location/contains /eos
# ---------
# Predict: 	washington walter /people/person/children /eos
# Ground-Truth: 	washington walter /location/location/contains /eos
# ---------
# Predict: 	mexico united /people/person/nationality /eos
# Ground-Truth: 	guanajuato mexico /location/administrative_division/country /eos
# ---------
# Predict: 	india central /location/administrative_division/country /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---------
# Predict: 	italy france /people/person/nationality /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	york university /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	dennis york /business/person/company /eos
# ---------
# Predict: 	5 kansa /people/deceased_person/place_of_death /eos
# Ground-Truth: 	kansa atchison /location/location/contains /eos
# ---------
# Predict: 	hospital massachusetts /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	boston massachusetts /location/location/contains /eos
# ---------
# Predict: 	mount a /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	washington mount /location/location/contains /eos
# ---------
# Predict: 	cuba american /location/administrative_division/country /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	department right /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	washington united /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	free spain /people/person/nationality /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	bill white /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	eddie reebok /business/person/company /eos
# ---------
# Predict: 	ontario caribbean /people/person/nationality /eos
# Ground-Truth: 	ontario st /location/location/contains /eos
# ---------
# Predict: 	iraq nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	florida john /business/company/founders /eos
# Ground-Truth: 	florida ponte /location/location/contains /eos
# ---------
# Predict: 	korea a /location/country/capital /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	florida lake /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---------
# Predict: 	miami chicago /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	chicago sears /location/location/contains /eos
# ---------
# Predict: 	webkinz ontario /people/deceased_person/place_of_death /eos
# Ground-Truth: 	ontario woodbridge /location/location/contains /eos
# ---------
# Predict: 	washington congress /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---------
# Predict: 	guinea people /location/country/capital /eos
# Ground-Truth: 	guinea conakry /location/country/capital /eos
# ---------
# Predict: 	iowa waterloo /people/deceased_person/place_of_death /eos
# Ground-Truth: 	iowa waterloo /location/location/contains /eos
# ---------
# Predict: 	italy sorrento /location/country/capital /eos
# Ground-Truth: 	italy amalfi /location/location/contains /eos
# ---------
# Predict: 	a lrb /people/deceased_person/place_of_death /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	westchester pennsylvania /people/person/place_lived /eos
# Ground-Truth: 	westchester hudson /location/location/contains /eos
# ---------
# Predict: 	a georgia /people/person/place_lived /eos
# Ground-Truth: 	g. georgia /business/person/company /eos
# ---------
# Predict: 	cuba bush /location/administrative_division/country /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	hill blue /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---------
# Predict: 	israel gaza /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	photographer time /people/deceased_person/place_of_death /eos
# Ground-Truth: 	tyler york /business/person/company /eos
# ---------
# Predict: 	indonesia italy /people/person/nationality /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	ontario canada /people/person/nationality /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---------
# Predict: 	government federal /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	toledo ottawa /location/location/contains /eos
# ---------
# Predict: 	namibia alexander /people/person/children /eos
# Ground-Truth: 	namibia windhoek /location/location/contains /eos
# ---------
# Predict: 	united mamaroneck /people/deceased_person/place_of_death /eos
# Ground-Truth: 	mamaroneck united /location/location/contains /eos
# ---------
# Predict: 	vermont long /people/deceased_person/place_of_death /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---------
# Predict: 	work netherlands /people/person/nationality /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	france hamburg /people/deceased_person/place_of_death /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---------
# Predict: 	iraq syria /people/person/nationality /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---------
# Predict: 	france black /location/administrative_division/country /eos
# Ground-Truth: 	corsica france /location/administrative_division/country /eos
# ---------
# Predict: 	syria damascus /location/country/capital /eos
# Ground-Truth: 	syria damascus /location/location/contains /eos
# ---------
# Predict: 	india british /location/administrative_division/country /eos
# Ground-Truth: 	shilpa india /people/person/nationality /eos
# ---------
# Predict: 	finland a /location/country/capital /eos
# Ground-Truth: 	finland turku /location/location/contains /eos
# ---------
# Predict: 	director germany /people/person/nationality /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---------
# Predict: 	boston israel /people/person/nationality /eos
# Ground-Truth: 	boston beth /location/location/contains /eos
# ---------
# Predict: 	chairman gov /people/person/place_lived /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---------
# Predict: 	drexler rockland /people/deceased_person/place_of_death /eos
# Ground-Truth: 	rockland city /location/location/contains /eos
# ---------
# Predict: 	a harvard /people/deceased_person/place_of_death /eos
# Ground-Truth: 	martin national /business/person/company /eos
# ---------
# Predict: 	peter toronto /people/deceased_person/place_of_death /eos
# Ground-Truth: 	toronto barrick /location/location/contains /eos
# ---------
# Predict: 	lake michigan /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	lake chicago /location/administrative_division/country /eos
# ---------
# Predict: 	mass bedford /people/deceased_person/place_of_death /eos
# Ground-Truth: 	marlborough cytyc /location/location/contains /eos
# ---------
# Predict: 	france southern /people/person/nationality /eos
# Ground-Truth: 	france alzonne /location/location/contains /eos
# ---------
# Predict: 	african art /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---------
# Predict: 	mexico gregory /people/person/children /eos
# Ground-Truth: 	mexico ciudad /location/location/contains /eos
# ---------
# Predict: 	american administration /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	west bank /people/deceased_person/place_of_death /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	audubon vermont /people/deceased_person/place_of_death /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---------
# Predict: 	a north /people/deceased_person/place_of_death /eos
# Ground-Truth: 	connecticut hamden /location/location/contains /eos
# ---------
# Predict: 	russia system /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eop russia iran /location/administrative_division/country /eos
# ---------
# Predict: 	syria jordan /location/country/capital /eos
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---------
# Predict: 	a nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	iowa university /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	iowa waverly /location/location/contains /eos
# ---------
# Predict: 	cuba boston /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	cuba bayamo /location/location/contains /eos
# ---------
# Predict: 	africa south /people/person/nationality /eos
# Ground-Truth: 	aziz south /people/person/nationality /eos
# ---------
# Predict: 	university canada /people/person/nationality /eos
# Ground-Truth: 	italy reggio /location/location/contains /eos
# ---------
# Predict: 	iran washington /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	iran washington /location/administrative_division/country /eos
# ---------
# Predict: 	park mountain /people/deceased_person/place_of_death /eos
# Ground-Truth: 	hampshire cannon /location/location/contains /eos
# ---------
# Predict: 	guatemala helen /location/administrative_division/country /eos
# Ground-Truth: 	helen guatemala /people/person/place_lived /eos
# ---------
# Predict: 	afghanistan iraq /people/person/nationality /eos
# Ground-Truth: 	romania black /location/location/contains /eos
# ---------
# Predict: 	syria iran /people/person/nationality /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	college florida /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	decatur agnes /location/location/contains /eos
# ---------
# Predict: 	natural north /people/deceased_person/place_of_death /eos
# Ground-Truth: 	robin north /business/person/company /eos
# ---------
# Predict: 	love philippine /people/person/nationality /eos
# Ground-Truth: 	imelda philippine /people/person/nationality /eos
# ---------
# Predict: 	harrelson federal /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	charles woody /people/person/children /eos
# ---------
# Predict: 	a maryland /people/person/place_lived /eos
# Ground-Truth: 	maryland annapolis /location/location/contains /eos
# ---------
# Predict: 	paris security /people/deceased_person/place_of_death /eos
# Ground-Truth: 	paris gare /location/location/contains /eos
# ---------
# Predict: 	good stephen /people/deceased_person/place_of_death /eos
# Ground-Truth: 	stephen case /business/person/company /eos
# ---------
# Predict: 	boston bay /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	boston church /location/location/contains /eos
# ---------
# Predict: 	mississippi clinton /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---------
# Predict: 	democrat missouri /people/person/place_lived /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---------

# %%
def beamsearch(NUM_BEAMS):
    pred = []
    for i in tqdm(range(395)):
        fb_words = np.array([word2index['/go']])
        x = np.array([x_test[i]])
    
        st_words = np.array([word2index['/go']])
        st_input = pad_sequences([st_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
        prob = model.predict([x, st_input], batch_size=BATCH_SIZE)[0][0]
        prob[0] = -1
        for item in [i for i in x_test[i] if i != 0]:
            prob[item] = float(prob[item]+1)
        beam = {}
        for _ in range(NUM_BEAMS):
            b = prob.argmax()
            beam[b] = float(prob[b])
            prob[b] = -1
        
        allResult = []
        for b, s in beam.items():
            pR = [b]
            fb_words = np.append(fb_words, b)
            tag = b
            for j in range(1, MAX_ADJL_LEN):
                fb_input = pad_sequences([fb_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
                prob = model.predict([x, fb_input], batch_size=BATCH_SIZE)[0][j]
                if j in [1, 4, 5]:
                    for item in [i for i in x_test[i] if i != 0]:
                        prob[item] = float(prob[item]+1)
                if j in [2, 6]:
                    prob[:65135] = -1
                if j == 3:
                    prob[:65132] = -1
                    prob[65134:] = -1
                if j == 8:
                    prob[65133] = float(prob[65133]+1)                
                prob[0] = -1
                prob[tag] = -1
                result = prob.argmax()
                beam[b] += float(prob[result])
                tag = result
                pR.append(result)
                fb_words = np.append(fb_words, result)
                if index2word[result] == '/eos':
                    break
            allResult.append(pR)
        pR = sum([i for i in allResult if i[0] == max(beam, key=lambda x: beam[x])], [])
        pred.append(pR)

    pred = [[index2word[i] for i in sent if i != 0] for sent in pred]
    actu = [[index2word[i] for i in sent if i != 0] for sent in y_test]
    e1Count = sum([1 for i in range(395) if actu[i][0] == pred[i][0]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][3] == pred[i][3]])
    e2Count = sum([1 for i in range(395) if actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])
    enCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])      
    reCount = sum([1 for i in range(395) if actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]])
    tripleCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1] and actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]]) 
    print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
    print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
    print('En Accuracy: \t\t%.6f' % (enCount/396))
    print('Re Accuracy: \t\t%.6f' % (reCount/396))
    print('Triple Accuracy: \t%.6f' % (tripleCount/396))

# %%
for NUM_BEAMS in range(1, 10):
    beamsearch(NUM_BEAMS)
# Out:
#   0%|          | 0/395 [00:00<?, ?it/s]
#   0%|          | 1/395 [00:00<03:46,  1.74it/s]
#   1%|          | 2/395 [00:01<03:47,  1.73it/s]
#   1%|          | 3/395 [00:01<03:50,  1.70it/s]
#   1%|          | 4/395 [00:02<03:51,  1.69it/s]
#   1%|▏         | 5/395 [00:02<03:51,  1.68it/s]
#   2%|▏         | 6/395 [00:03<03:44,  1.73it/s]
#   2%|▏         | 7/395 [00:04<03:40,  1.76it/s]
# 100%|██████████| 395/395 [03:22<00:00,  2.01it/s]
#   0%|          | 0/395 [00:00<?, ?it/s]
# E1 Accuracy: 		0.305556
# E2 Accuracy: 		0.239899
# En Accuracy: 		0.118687
# Re Accuracy: 		0.121212
# Triple Accuracy: 	0.027778
# 100%|██████████| 395/395 [08:32<00:00,  1.34s/it]
#   0%|          | 0/395 [00:00<?, ?it/s]
# E1 Accuracy: 		0.217172
# E2 Accuracy: 		0.217172
# En Accuracy: 		0.080808
# Re Accuracy: 		0.121212
# Triple Accuracy: 	0.005051
#  30%|██▉       | 118/395 [04:23<10:49,  2.35s/it]

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(preResult[i]))
    print('Ground-Truth: \t%s' % ' '.join(actResult[i]))
    print('---')
