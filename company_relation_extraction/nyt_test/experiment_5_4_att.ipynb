# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preprocessing</a></div><div class="lev2 toc-item"><a href="#Load-Data" data-toc-modified-id="Load-Data-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load Data</a></div><div class="lev3 toc-item"><a href="#Load-Train-Data" data-toc-modified-id="Load-Train-Data-111"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Load Train Data</a></div><div class="lev3 toc-item"><a href="#Load-Test-Data" data-toc-modified-id="Load-Test-Data-112"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Load Test Data</a></div><div class="lev3 toc-item"><a href="#Relation-Types" data-toc-modified-id="Relation-Types-113"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Relation Types</a></div><div class="lev2 toc-item"><a href="#Participle" data-toc-modified-id="Participle-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Participle</a></div><div class="lev2 toc-item"><a href="#Make-Adjacency-List" data-toc-modified-id="Make-Adjacency-List-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Make Adjacency List</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Train-Data" data-toc-modified-id="Make-Adjacency-List-of-Train-Data-131"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Make Adjacency List of Train Data</a></div><div class="lev3 toc-item"><a href="#Make-Adjacency-List-of-Test-Data" data-toc-modified-id="Make-Adjacency-List-of-Test-Data-132"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Make Adjacency List of Test Data</a></div><div class="lev1 toc-item"><a href="#Word-to-Vector" data-toc-modified-id="Word-to-Vector-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Word to Vector</a></div><div class="lev2 toc-item"><a href="#Tokenize-Text" data-toc-modified-id="Tokenize-Text-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Tokenize Text</a></div><div class="lev2 toc-item"><a href="#Create-Word-Embeddings-with-GloVe" data-toc-modified-id="Create-Word-Embeddings-with-GloVe-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Create Word Embeddings with GloVe</a></div><div class="lev3 toc-item"><a href="#Read-GloVe" data-toc-modified-id="Read-GloVe-221"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Read GloVe</a></div><div class="lev3 toc-item"><a href="#Use-Glove-to-Initialize-Embedding-Matrix" data-toc-modified-id="Use-Glove-to-Initialize-Embedding-Matrix-222"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Use Glove to Initialize Embedding Matrix</a></div><div class="lev1 toc-item"><a href="#Build-Dateset" data-toc-modified-id="Build-Dateset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Build Dateset</a></div><div class="lev1 toc-item"><a href="#Save-Dataset" data-toc-modified-id="Save-Dataset-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Save Dataset</a></div><div class="lev1 toc-item"><a href="#Checkpoint" data-toc-modified-id="Checkpoint-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Checkpoint</a></div><div class="lev1 toc-item"><a href="#Build-Model" data-toc-modified-id="Build-Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Build Model</a></div><div class="lev2 toc-item"><a href="#Set-Hyperparameters" data-toc-modified-id="Set-Hyperparameters-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Set Hyperparameters</a></div><div class="lev2 toc-item"><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Import Libraries</a></div><div class="lev2 toc-item"><a href="#Build-Graph" data-toc-modified-id="Build-Graph-63"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Build Graph</a></div><div class="lev2 toc-item"><a href="#Model-Visualization" data-toc-modified-id="Model-Visualization-64"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Model Visualization</a></div><div class="lev2 toc-item"><a href="#Train" data-toc-modified-id="Train-65"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Train</a></div><div class="lev1 toc-item"><a href="#Evaluate" data-toc-modified-id="Evaluate-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Evaluate</a></div><div class="lev2 toc-item"><a href="#Naive-Evaluate" data-toc-modified-id="Naive-Evaluate-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Naive Evaluate</a></div><div class="lev2 toc-item"><a href="#Beam-Search-Evaluate" data-toc-modified-id="Beam-Search-Evaluate-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Beam Search Evaluate</a></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Load Train Data

# %%
import json

# %%
sentText = []
relationMentions = []
relationLabels = []
entityMentions = []
entityLabels = []
em1Text = []
em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/train.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    # Exclude "None" label
    if not all(i['label'] == 'None' for i in item['relationMentions']):
        sentText.append(item['sentText'])
        relationMentions.append(item['relationMentions'])
        entityMentions.append(item['entityMentions'])
    
relationLabels = [[i['label'] for i in rM] for rM in relationMentions]
entityLabels = [[i['text'] for i in eM] for eM in entityMentions]
em1Text = [[i['em1Text'] for i in rM] for rM in relationMentions]
em2Text = [[i['em2Text'] for i in rM] for rM in relationMentions]

# %%
# Clean words
replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
em1Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em1Text]
em2Text = [[''.join([replaceDict.get(i, i) for i in e]) for e in eT] for eT in em2Text]

# %% [markdown]
# ### Load Test Data

# %%
t_sentText = []
t_relationMentions = []
t_relationLabels = []
t_entityMentions = []
t_entityLabels = []
t_em1Text = []
t_em2Text = []

with open("/Users/lizhn7/Downloads/DATA/nyt/test.json") as f:
    lines = f.readlines()

for line in lines:
    item = json.loads(line)
    t_sentText.append(item['sentText'])
    t_relationMentions.append(item['relationMentions'])
    t_entityMentions.append(item['entityMentions'])
    
t_relationLabels = [[i['label'] for i in rM] for rM in t_relationMentions]
t_entityLabels = [[i['text'] for i in eM] for eM in t_entityMentions]
t_em1Text = [[i['em1Text'] for i in rM] for rM in t_relationMentions]
t_em2Text = [[i['em2Text'] for i in rM] for rM in t_relationMentions]

# %%
# Clean words
t_replaceDict = {
               'ā': 'a', 'á': 'a', 'ǎ': 'a', 'à': 'a',
               'ō': 'o', 'ó': 'o', 'ǒ': 'o', 'ò': 'o', 'ô': 'o', 'ö': 'o',
               'ē': 'e', 'é': 'e', 'ě': 'e', 'è': 'e', 
               'ī': 'i', 'í': 'i', 'ǐ': 'i', 'ì': 'i',
               'ū': 'u', 'ú': 'u', 'ǔ': 'u', 'ù': 'u', 'ü': 'u',
               'ñ': 'n',
               'É': 'E'
              }
t_em1Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em1Text]
t_em2Text = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_em2Text]
t_entityLabels = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_entityLabels]

# %% [markdown]
# ###  Relation Types

# %%
relationTypes = list(set([r for rl in relationLabels for r in rl]))
relationTypes
# Out:
# ['/people/person/nationality',
#  '/people/person/place_lived',
#  '/people/person/ethnicity',
#  '/sports/sports_team/location',
#  '/location/neighborhood/neighborhood_of',
#  '/location/country/capital',
#  '/location/administrative_division/country',
#  '/business/person/company',
#  '/people/person/children',
#  '/location/location/contains',
#  '/business/company/place_founded',
#  '/people/ethnicity/people',
#  '/people/deceased_person/place_of_death',
#  '/people/person/profession',
#  '/location/country/administrative_divisions',
#  '/people/ethnicity/geographic_distribution',
#  '/business/company/founders',
#  '/business/company/industry',
#  '/people/person/place_of_birth',
#  '/business/company_shareholder/major_shareholder_of',
#  '/business/company/major_shareholders',
#  '/business/company/advisors',
#  '/sports/sports_team_location/teams',
#  '/people/person/religion']

# %%
t_relationTypes = list(set([r for rl in t_relationLabels for r in rl if r != 'None']))
t_relationTypes
# Out:
# ['/people/person/nationality',
#  '/people/person/place_of_birth',
#  '/people/deceased_person/place_of_death',
#  '/business/person/company',
#  '/people/person/children',
#  '/location/location/contains',
#  '/people/person/place_lived',
#  '/location/country/administrative_divisions',
#  '/business/company/founders',
#  '/location/neighborhood/neighborhood_of',
#  '/location/country/capital',
#  '/location/administrative_division/country']

# %% [markdown]
# ## Participle

# %%
from nltk import regexp_tokenize

# %%
def cut(s):
    """
    Participle
    """
    pattern = r'''
              (?x)                   # set flag to allow verbose regexps 
              (?:[A-Z]\.)+           # abbreviations, e.g. U.S.A. 
              |\d+(?:\.\d+)?%?       # numbers, incl. currency and percentages 
              |\w+(?:[-&']\w+)*       # words w/ optional internal hyphens/apostrophe  
           '''  
    return regexp_tokenize(s, pattern=pattern)

# %%
filename = "stopwords_666.txt"
stopWords = {w: None for w in open(filename).read().split()}

# %%
sentWords = [cut(s) for s in sentText]
entlabWords = [[cut(s) for s in eL] for eL in entityLabels]
em1Words = [[cut(s) for s in eL] for eL in em1Text]
em2Words = [[cut(s) for s in eL] for eL in em2Text]
t_sentWords = [cut(s) for s in t_sentText]
t_entlabWords = [[cut(s) for s in eL] for eL in t_entityLabels]
t_em1Words = [[cut(s) for s in eL] for eL in t_em1Text]
t_em2Words = [[cut(s) for s in eL] for eL in t_em2Text]
# Clean words
t_sentWords = [[''.join([t_replaceDict.get(i, i) for i in e]) for e in eT] for eT in t_sentWords]

# %%
# Delete stopwords
for n in range(len(sentWords)):
    sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in sentWords[n]] if i != None]
    entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in entlabWords[n]]
    entlabWords[n] = [[i for i in item if i != None] for item in entlabWords[n]]
    em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em1Words[n]]
    em1Words[n] = [[i for i in item if i != None] for item in em1Words[n]]
    em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in em2Words[n]]
    em2Words[n] = [[i for i in item if i != None] for item in em2Words[n]] 

for n in range(len(t_sentWords)):
    t_sentWords[n] = [i for i in [stopWords.get(i.lower(), i) for i in t_sentWords[n]] if i != None]
    t_entlabWords[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_entlabWords[n]]
    t_entlabWords[n] = [[i for i in item if i != None] for item in t_entlabWords[n]]
    t_em1Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em1Words[n]]
    t_em1Words[n] = [[i for i in item if i != None] for item in t_em1Words[n]]
    t_em2Words[n] = [[stopWords.get(i.lower(), i) for i in item] for item in t_em2Words[n]]
    t_em2Words[n] = [[i for i in item if i != None] for item in t_em2Words[n]]

# %%
#max([len(i) for i in t_sentWords])

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8

# %% [markdown]
# ## Make Adjacency List

# %% [markdown]
# ### Make Adjacency List of Train Data

# %%
from collections import Counter

# %%
i_entityLabels = []
for i in range(len(sentWords)):
    eL = []
    sDict = list(enumerate(sentWords[i]))
    j = 0
    for item in entlabWords[i]:
        el = []
        for e in item:
            while j < len(sDict):
                if e == sDict[j][1]:
                    el.append(sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    i_entityLabels.append(eL)

# %%
rmSet = []
for item in range(len(relationMentions)):
    rms = [(em1Words[item][i][0], em2Words[item][i][0], relationLabels[item][i]) for i in range(len(relationLabels[item]))]
    rms = [' '.join(list(i)) for i in rms]
    rmSet.append(rms)
rmSet = [set(i) for i in rmSet]

# %%
i_adjacencyList = []
new_sentWords = []
pad = ['/eop', '/eos']
for n in range(len(sentWords)):
    aL = []
    for l in range(len(relationLabels[n])):
        e1 = []
        e2 = []
        for item in i_entityLabels[n]:
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([sentWords[n][i] for i in item]) == ' '.join(em2Words[n][l]):
                e2.append(item[0])
        c1 = [(a, b) for a in e1 for b in e2 if ' '.join([sentWords[n][a], sentWords[n][b], relationLabels[n][l]]) in rmSet[n]]
        c2 = [(a, b) for a in e2 for b in e1 if ' '.join([sentWords[n][b], sentWords[n][a], relationLabels[n][l]]) in rmSet[n]]
        c = c1 + c2
        m = min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[-1]
        r = [i[0] for i in [(i, abs(j[0]-j[1])) for i, j in enumerate(c)] if i[-1] == m]
        for i in r:
            if ' '.join([sentWords[n][c[i][0]], sentWords[n][c[i][1]], relationLabels[n][l]]) in rmSet[n]:
                al = (c[i][0], c[i][1], relationLabels[n][l], pad[0])
                if al[2] in t_relationTypes and al[0] < MAX_SENT_LEN and al[1] < MAX_SENT_LEN: 
                    aL.append(al)
    aL = sorted([list(i) for i in set(aL)])
    if len(aL) == 1 or len(aL) == 2:
        i_adjacencyList.append(aL)
        new_sentWords.append(sentWords[n])
i_adjacencyList = [sum(i, []) for i in i_adjacencyList]
for i in i_adjacencyList:
    i[-1] = pad[-1]

# %% [markdown]
# ### Make Adjacency List of Test Data

# %%
ti_entityLabels = []
for i in range(len(t_sentWords)):
    eL = []
    t_sDict = list(enumerate(t_sentWords[i]))
    j = 0
    for item in t_entlabWords[i]:
        el = []
        for e in item:
            while j < len(t_sDict):
                if e == t_sDict[j][1]:
                    el.append(t_sDict[j][0])
                    j += 1
                    break
                j += 1
        eL.append(el)
    ti_entityLabels.append(eL)

# %%
ti_trueLables = [[i for i, j in enumerate(rl) if j != 'None'] for rl in t_relationLabels]
t_trueMentions = [[j for i, j in enumerate(rl) if j['label'] != 'None'] for rl in t_relationMentions]
pad = ['/eop', '/eos']
ti_adjacencyList = []
for n in range(len(t_sentWords)): 
    e1 = []
    e2 = []
    aL = []
    for l in ti_trueLables[n]:
        for item in ti_entityLabels[n]:
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em1Words[n][l]):
                e1.append(item[0])
            if ' '.join([t_sentWords[n][i] for i in item]) == ' '.join(t_em2Words[n][l]):
                e2.append(item[0])
    c = [(a, b) for a in e1 for b in e2]
    r = c[min([(i, abs(j[0]-j[1])) for i, j in enumerate(c)], key=lambda x: x[-1])[0]]
    aL = aL + [r[0], r[1], t_relationLabels[n][l], pad[-1]]
    ti_adjacencyList.append(aL)

# Modify 
#ti_adjacencyList[26] = [18, 20, '/business/company/founders', pad[-1]]
ti_adjacencyList[191] = [13, 19, '/location/administrative_division/country', pad[0], 18, 19, '/location/administrative_division/country', pad[-1]]

# %%
#max([max(sum(i, [])) for i in ti_entityLabels])

# %% [markdown]
# # Word to Vector

# %% [markdown]
# ## Tokenize Text

# %%
from keras.preprocessing.text import Tokenizer
from nltk import WordNetLemmatizer
# Out:
# Using TensorFlow backend.

# %%
wnl = WordNetLemmatizer()
sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in new_sentWords]
t_sentWords = [[wnl.lemmatize(t.lower()) for t in toks] for toks in t_sentWords]
tok_sentWords = sentWords.copy()
tok_sentWords.extend(t_sentWords)
tokTexts = [' '.join(i) for i in tok_sentWords]

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts(tokTexts)
word2index = tokenizer.word_index
for i in [i for i in zip(list(range(65132, 65147)), pad+['/go']+t_relationTypes)]:
    word2index[i[-1]] = i[0]
index2word = {i: w for w, i in word2index.items()}
print('Found %s unique tokens.' % len(word2index))
# Out:
# Found 65146 unique tokens.

# %% [markdown]
# ## Create Word Embeddings with GloVe

# %%
VOCAB_SIZE = 65147
EMBEDDING_SIZE = 300
SEED = 42

# %% [markdown]
# ### Read GloVe

# %%
import numpy as np

# %%
#glove_n_symbols = !wc -l /Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt
#glove_n_symbols = int(glove_n_symbols[0].split()[0])
glove_n_symbols = 1917495

# %%
glove_index_dict = {}
glove_embedding_weights = np.empty((glove_n_symbols, EMBEDDING_SIZE))
globale_scale = 0.1
with open('/Users/lizhn7/Downloads/DATA/Glove/glove.42B.300d.txt', 'r') as fp:
    index = 0
    for l in fp:
        l = l.strip().split()
        word = l[0]
        glove_index_dict[word] = index
        glove_embedding_weights[index, :] = [float(n) for n in l[1:]]
        index += 1
glove_embedding_weights *= globale_scale

# %% [markdown]
# ### Use Glove to Initialize Embedding Matrix

# %%
from nltk import PorterStemmer, LancasterStemmer

# %%
# Generate random embedding with same scale as glove
np.random.seed(SEED)
shape = (VOCAB_SIZE, EMBEDDING_SIZE)
scale = glove_embedding_weights.std() * np.sqrt(12) / 2 
embedding = np.random.uniform(low=-scale, high=scale, size=shape)

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()

# %%
# Copy from glove weights of words that appear in index2word
count = 0 
for i in range(1, 65132):
    w = index2word[i]
    g = glove_index_dict.get(w)
    if g is None:
        w = porter.stem(w)
        g = glove_index_dict.get(w)
    if g is None:
        w = lancaster.stem(w)
        g = glove_index_dict.get(w)
    if g is not None:
        embedding[i, :] = glove_embedding_weights[g, :]
        count += 1
print('{num_tokens}-{per:.2f}% tokens in vocab found in glove and copied to embedding.'.format(num_tokens=count, per=count/float(VOCAB_SIZE)*100))
# Out:
# 60641-93.08% tokens in vocab found in glove and copied to embedding.

# %%
for i in range(65132, 65147):
    item = np.random.uniform(low=-scale, high=scale, size=(EMBEDDING_SIZE,))
    item[i-65132] = 1
    embedding[i, :] = item

# %% [markdown]
# # Build Dateset

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
new_sentText = [' '.join(i) for i in sentWords]
sentSeq = tokenizer.texts_to_sequences(new_sentText)
sentData = pad_sequences(sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

t_new_sentText = [' '.join(i) for i in t_sentWords]
t_sentSeq = tokenizer.texts_to_sequences(t_new_sentText)
t_sentData = pad_sequences(t_sentSeq, maxlen=MAX_SENT_LEN, padding='post', truncating='post')

new_adjacencyList = [[sentWords[c][j] if i < 2 or i == 4 or i == 5 else j for i, j in enumerate(item)] for c, item in enumerate(i_adjacencyList)]
adjlText = [' '.join(i) for i in new_adjacencyList]
adjlSeq = tokenizer.texts_to_sequences(adjlText)
adjlData = pad_sequences(adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

newt_adjacencyList = [[t_sentWords[c][j] if i < 2 or i == 4 or i == 5 else j for i, j in enumerate(item)] for c, item in enumerate(ti_adjacencyList)]
t_adjlText = [' '.join(i) for i in newt_adjacencyList]
t_adjlSeq = tokenizer.texts_to_sequences(t_adjlText)
t_adjlData = pad_sequences(t_adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

[i.insert(0, '/go') for i in new_adjacencyList];
adjlText = [' '.join(i) for i in new_adjacencyList]
adjlSeq = tokenizer.texts_to_sequences(adjlText)
tfData = pad_sequences(adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

[i.insert(0, '/go') for i in newt_adjacencyList];
t_adjlText = [' '.join(i) for i in newt_adjacencyList]
t_adjlSeq = tokenizer.texts_to_sequences(t_adjlText)
t_tfData = pad_sequences(t_adjlSeq, maxlen=MAX_ADJL_LEN, padding='post', truncating='post')

# %%
# Split the data into a training set, a validation set and a test set
x_train_all = sentData
tf_train_all = tfData
y_train_all = adjlData

x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, test_size=0.15, random_state=SEED)
tf_train, tf_val, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0.15, random_state=SEED)

x_train_all, _, y_train_all, _  = train_test_split(x_train_all, y_train_all, test_size=0., random_state=SEED)
tf_train_all, _, _, _ = train_test_split(tf_train_all, tf_train_all, test_size=0., random_state=SEED)
 
x_test = t_sentData
tf_test = t_tfData
y_test = t_adjlData

x_test, _, y_test, _ = train_test_split(x_test, y_test, test_size=0., random_state=SEED)
tf_test, _, _, _ = train_test_split(tf_test, tf_test, test_size=0., random_state=SEED)

# %% [markdown]
# # Save Dataset

# %%
import h5py
import pickle

# %%
fh = h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/allData.h5', 'w')
fh['x_train'] = x_train
fh['tf_train'] = tf_train
fh['y_train'] = y_train
fh['x_val'] = x_val
fh['tf_val'] = tf_val
fh['y_val'] = y_val
fh['x_train_all'] = x_train_all
fh['tf_train_all'] = tf_train_all
fh['y_train_all'] = y_train_all
fh['x_test'] = x_test
fh['tf_test'] = tf_test
fh['y_test'] = y_test
fh['embedding'] = embedding
fh.close()

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/index.pkl', 'wb') as fp:
    pickle.dump((word2index, index2word), fp, -1)

# %% [markdown]
# # Checkpoint

# %%
import h5py
import pickle

# %%
with h5py.File('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/allData.h5', 'r') as fh:
    x_train = fh['x_train'][:]
    tf_train = fh['tf_train'][:]
    y_train = fh['y_train'][:]
    x_val = fh['x_val'][:]
    tf_val = fh['tf_val'][:]
    y_val = fh['y_val'][:]
    x_train_all = fh['x_train_all'][:]
    tf_train_all = fh['tf_train_all'][:]
    y_train_all = fh['y_train_all'][:]
    x_test = fh['x_test'][:]
    tf_test = fh['tf_test'][:]
    y_test = fh['y_test'][:]
    embedding = fh['embedding'][:]

# %%
with open('/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/index.pkl', 'rb') as fp:
    word2index, index2word = pickle.load(fp)

# %% [markdown]
# # Build Model

# %% [markdown]
# ##  Set Hyperparameters

# %%
MAX_SENT_LEN = 64
MAX_ADJL_LEN = 8
VOCAB_SIZE = len(word2index)+1
#NUM_CLASSES = VOCAB_SIZE
EMBEDDING_SIZE = 300
TF_EMBEDDING_SIZE = 300

RNN_SIZE = 600
DROPOUT_RATE = 0.5
RNN_DROPOUT_RATE = 0.2
NUM_EPOCHS = 1024
BATCH_SIZE = 79
STEPS_PER_EPOCH = 20
TEST_STEPS = len(x_test)//BATCH_SIZE

VALIDATION_STEPS = 3

# %%
print('NUM_EPOCHS: \t\t%d' % NUM_EPOCHS)
print('STEPS_PER_EPOCH: \t%d' % STEPS_PER_EPOCH)
print('TEST_STEPS: \t\t%d' % TEST_STEPS)
print('VALIDATION_STEPS: \t%d' % VALIDATION_STEPS)
print('TRAIN_BATCHES: \t\t%d' % (NUM_EPOCHS * STEPS_PER_EPOCH))
print('NUM_BATCHES \t\t%d' % (len(x_train)//BATCH_SIZE+1))
# Out:
# NUM_EPOCHS: 		1024
# STEPS_PER_EPOCH: 	20
# TEST_STEPS: 		5
# VALIDATION_STEPS: 	3
# TRAIN_BATCHES: 		20480
# NUM_BATCHES 		612

# %% [markdown]
# ## Import Libraries

# %%
from keras.layers import Lambda, Input, Embedding, Dropout, Bidirectional, LSTM, RepeatVector, concatenate, TimeDistributed, Dense
from keras.models import Model
from keras.models import Sequential
import keras.backend as K
from keras.callbacks import*
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Build Graph

# %%
def attention_context(x):
    """
    Compute context with attention weight
    """
    sent, adjl = x[:, :MAX_SENT_LEN, :], x[:, :MAX_ADJL_LEN, :]
    attention_energies = K.batch_dot(sent, adjl, axes=(2, 2))
    attention_energies = K.reshape(attention_energies, (-1, MAX_SENT_LEN))
    attention_weights = K.softmax(attention_energies)
    attention_weights = K.reshape(attention_weights, (-1, MAX_ADJL_LEN, MAX_SENT_LEN))
    attention_context = K.batch_dot(attention_weights, sent, axes=(2, 1))
    return K.concatenate((attention_context, adjl))

# %%
K.clear_session()
model = Sequential()
model.add(Embedding(VOCAB_SIZE, 
                    EMBEDDING_SIZE, 
                    weights=[embedding], 
                    mask_zero=True, 
                    input_length=MAX_SENT_LEN+MAX_ADJL_LEN, 
                    trainable=False, 
                    name='EMBEDDING'))
model.add(LSTM(RNN_SIZE, 
               return_sequences=True, 
               implementation=0, 
               dropout=RNN_DROPOUT_RATE, 
               recurrent_dropout=RNN_DROPOUT_RATE,
               name='LSTM_1'))
model.add(Dropout(DROPOUT_RATE, name='DROPOUT_1'))
model.add(LSTM(RNN_SIZE, 
               return_sequences=True, 
               implementation=0, 
               dropout=RNN_DROPOUT_RATE, 
               recurrent_dropout=RNN_DROPOUT_RATE,
               name='LSTM_2'))
model.add(Dropout(DROPOUT_RATE, name='DROPOUT_2'))
model.add(LSTM(RNN_SIZE, 
               return_sequences=True, 
               implementation=0, 
               dropout=RNN_DROPOUT_RATE, 
               recurrent_dropout=RNN_DROPOUT_RATE,
               name='LSTM_3'))
model.add(Dropout(DROPOUT_RATE, name='DROPOUT_3'))
model.add(Lambda(attention_context, 
                 output_shape=lambda input_shape: (input_shape[0], MAX_ADJL_LEN, 2*RNN_SIZE),
                 name='ATTENTION_CONTEXT'))
model.add(TimeDistributed(Dense(VOCAB_SIZE, activation='softmax'), name='OUTPUT'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# %% [markdown]
# ## Model Visualization

# %%
model.summary()
SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# EMBEDDING (Embedding)        (None, 72, 300)           19544100
# _________________________________________________________________
# LSTM_1 (LSTM)                (None, 72, 600)           2162400
# _________________________________________________________________
# DROPOUT_1 (Dropout)          (None, 72, 600)           0
# _________________________________________________________________
# LSTM_2 (LSTM)                (None, 72, 600)           2882400
# _________________________________________________________________
# DROPOUT_2 (Dropout)          (None, 72, 600)           0
# _________________________________________________________________
# LSTM_3 (LSTM)                (None, 72, 600)           2882400
# _________________________________________________________________
# DROPOUT_3 (Dropout)          (None, 72, 600)           0
# _________________________________________________________________
# ATTENTION_CONTEXT (Lambda)   (None, 8, 1200)           0
# _________________________________________________________________
# OUTPUT (TimeDistributed)     (None, 8, 65147)          78241547
# =================================================================
# Total params: 105,712,847
# Trainable params: 86,168,747
# Non-trainable params: 19,544,100
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
import numpy as np

# %%
def gen_label(s):
    """
    One-hot encoding
    """
    gen = to_categorical(s, num_classes=NUM_CLASSES)
    return gen

def data_generator_all(data, label, batch_size):
    """
    Yield batches of all data
    """
    count = 0
    while True:
        if count >= len(data[0]): 
            count = 0
        x_1 = np.zeros((batch_size, MAX_SENT_LEN))
        x_2 = np.zeros((batch_size, MAX_ADJL_LEN))
        y = np.zeros((batch_size, MAX_ADJL_LEN, NUM_CLASSES))
        for i in range(batch_size):
            n = i + count
            if n > len(data[0])-1:
                break
            x_1[i, :] = data[0][n]
            x_2[i, :] = data[1][n]
            x = np.concatenate((x_1, x_2), axis=-1)
            y[i, :, :] = gen_label(label[n])
        count += batch_size
        yield (x, y)
        
def data_generator(data, label, batch_size): 
    """
    Yield batches 
    """
    index = np.arange(len(data[0]))
    np.random.shuffle(index)    
    batches = [index[range(batch_size*i, min(len(data[0]), batch_size*(i+1)))] for i in range(len(data[0])//batch_size)]
    while True:
        for i in batches:
            x_1 = data[0][i]
            x_2 = data[1][i]
            x = np.concatenate((x_1, x_2), axis=-1)
            y = np.array(list(map(gen_label, label[i])))
            yield (x, y)

# %%
gen_train_all = data_generator([x_train_all, tf_train_all], y_train_all, BATCH_SIZE)
gen_test = data_generator_all([x_test, tf_test], y_test, BATCH_SIZE)
#gen_train = data_generator(x_train, y_train, BATCH_SIZE)
#gen_val = data_generator(x_val, y_val, BATCH_SIZE)

# %%
# Continue Trian
# filename = 'cp_logs/.hdf5'
# model.load_weights(filename)
# model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['acc'])

# %%
filepath = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/cp_logs/weights.{epoch:03d}-{val_loss:.6f}.hdf5'
log_string = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4/tb_logs/1'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
tensorboard = TensorBoard(log_dir=log_string, 
                          histogram_freq=1, 
                          write_graph=False, 
                          write_grads=False, 
                          batch_size=BATCH_SIZE, 
                          write_images=True, 
                          embeddings_freq=1, 
                          embeddings_layer_names=None,
                          embeddings_metadata=None)

# %%
history = model.fit_generator(gen_train_all, 
                              steps_per_epoch=STEPS_PER_EPOCH, 
                              epochs=NUM_EPOCHS, 
                              verbose=1,
                              #callbacks=[checkpoint, tensorboard, lr],
                              validation_data=gen_test, 
                              validation_steps=TEST_STEPS)

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Naive Evaluate

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4_pro/cp_logs/att_false/weights.356-1.742565.hdf5'
model.load_weights(filename)

result = np.argmax(model.predict(np.concatenate((x_test, tf_test), axis=-1), batch_size=BATCH_SIZE, verbose=1), -1)
# Out:
# 395/395 [==============================] - 30s

# %%
index2word[0] = '<PAD>'

# %%
pred = [[index2word[i] for i in sent] for sent in result]
actu = [[index2word[i] for i in sent] for sent in y_test]
e1Count = sum([1 for i in range(395) if actu[i][0] == pred[i][0]]) + sum([1 for i in range(372, 373) if actu[i][4] == pred[i][4]])
e2Count = sum([1 for i in range(395) if actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][5] == pred[i][5]])
enCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][4] == pred[i][4] and actu[i][5] == pred[i][5]])      
reCount = sum([1 for i in range(395) if actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][6] == pred[i][6]])
tripleCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1] and actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][4] == pred[i][4] and actu[i][5] == pred[i][5] and actu[i][6] == pred[i][6]]) 
print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
print('En Accuracy: \t\t%.6f' % (enCount/396))
print('Re Accuracy: \t\t%.6f' % (reCount/396))
print('Triple Accuracy: \t%.6f' % (tripleCount/396))
# Out:
# E1 Accuracy: 		0.340909
# E2 Accuracy: 		0.265152
# En Accuracy: 		0.095960
# Re Accuracy: 		0.608586
# Triple Accuracy: 	0.058081

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(pred[i]))
    print('Ground-Truth: \t%s' % ' '.join(actu[i]))
    print('---')
# Out:
# Predict: 	europe spain /location/location/contains /eos <PAD> <PAD> <PAD> /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	connecticut stamford /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	westchester connecticut /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jordan amman /location/country/capital /eop jordan amman /location/location/contains /eos
# Ground-Truth: 	dalia israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india bangalore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	hyderabad potti /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	north north /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	kent north /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ontario ontario /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ontario waterloo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	peter google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	blackstone stephen /business/company/founders /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /location/location/contains /eos <PAD> <PAD> <PAD> /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iran russia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran russia /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	john albany /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	george abc /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida palm /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida jacksonville /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa nigeria /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	nigeria uyo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	rhode maine /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	tennessee missouri /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	patrick huntington /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe germany /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert morgan /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	jeffrey lazard /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	gaza gaza /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india sydney /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	seoul south /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mark york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	australia australia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	markus australia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert yale /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	kwame princeton /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert morgan /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	endemol john /business/company/founders /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	tom kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ned connecticut /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	connecticut haven /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe russia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran russia /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india lahore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	bihar india /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york brooklyn /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	bill dawsonville /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	columbia columbia /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	daniel university /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe russia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	soviet russia /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	boston chicago /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	boston wbz-tv /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	virginia virginia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	virginia united /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert cbs /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ira system /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	puerto la /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york staten /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	anthony york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	leslie google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chad google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	massachusetts danbury /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington bainbridge /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington olympia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india bangalore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	south seoul /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /location/location/contains /eop <PAD> <PAD> <PAD> /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	belgium luxembourg /location/country/administrative_divisions /eop luxembourg luxembourg <PAD> /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iran iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran syria /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	north north /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	kellen colorado /people/person/place_of_birth /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy spain /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	tony france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	jose spain /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe luxembourg /location/location/contains /eop europe <PAD> /location/location/contains /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york staten /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	york staten /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	san san /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ralph at&t /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	connecticut connecticut /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	connecticut haven /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	somalia kandahar /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	somalia puntland /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	slovakia bratislava /location/country/capital /eop slovakia bratislava /location/location/contains /eos
# Ground-Truth: 	riga latvia /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	switzerland tehran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	switzerland davos /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	utah park /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	colorado vail /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	paris france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	south queen /location/neighborhood/neighborhood_of /eop queen <PAD> /location/location/contains /eos
# Ground-Truth: 	lower hudson /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	san san /location/neighborhood/neighborhood_of /eop <PAD> san /location/location/contains /eos
# Ground-Truth: 	san north /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york westchester /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	nassau suffolk /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	eric google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chad youtube /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	westchester westchester /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	westchester kensico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	susan nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy italy /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy orvieto /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iowa university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	greenville furman /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert yale /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	charles princeton /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ontario calgary /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	canada ontario /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida florida /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida boca /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel haifa /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	john baltimore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	baltimore john /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india lahore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	samantha india /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	david digitas /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ohio ohio /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	tom iowa /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	lebanon lebanon /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	rafik lebanon /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa uganda /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	atiku nigeria /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jersey jersey /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida florida /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida panama /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iran iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran north /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains /eop europe <PAD> /location/location/contains /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york mount /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	clarkstown city /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india bangalore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india delhi /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mississippi mississippi /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida palm /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida boca /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	gordon continental /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris paris /people/deceased_person/place_of_death /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	paris france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	california san /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	california long /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jacques france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france correze /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jersey hempstead /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	fairfax westfield /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	gaza gaza /location/country/capital /eos gaza gaza <PAD> /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	spain valencia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	greenwich greenwich /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	greenwich jefferson /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel west /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jacques france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	jacques france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	westchester ramapo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mahwah ramapo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	sri bogota /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	guyana linden /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india punjab /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ontario brampton /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ontario tobermory /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	middle iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	middle iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa sudan /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy israel /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains /eop europe <PAD> /location/location/contains /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	eric google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chad google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jim kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	amy minnesota /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	australia australia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	john australia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ohio oklahoma /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ernie kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe china /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran north /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india bihar /location/country/administrative_divisions /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy verona /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ireland county /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	dominican bolivia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy italy /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy umbria /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy italy /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	campania italy /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	middle iraq /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran middle /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida florida /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida boca /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe germany /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	germany spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	paris france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	manhattan manhattan /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cleveland karamu /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	south mount /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ireland county /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	alberta university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	california san /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy turin /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france albertville /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa lahore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	bosnia srebrenica /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	manhattan manhattan /location/neighborhood/neighborhood_of /eop manhattan manhattan /location/location/contains /eos
# Ground-Truth: 	upper fort /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	france france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france valence /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida spain /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	james tampa /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	bashar syria /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	syria damascus /location/country/administrative_divisions /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	colorado portland /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	marshall fremont /people/deceased_person/place_of_death /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jerusalem jerusalem /location/country/capital /eop israel jerusalem /location/location/contains /eos
# Ground-Truth: 	israel jerusalem /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	middle iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran syria /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cambridge lesley /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	australia australia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chris australia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	eric google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	dennis disney /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	utah colorado /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	colorado aspen /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india hong /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	south seoul /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	fort brooklyn /location/neighborhood/neighborhood_of /eop brooklyn fort /location/location/contains /eos
# Ground-Truth: 	staten fort /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel haifa /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	france france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	jean-louis france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains <PAD> <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france toulouse /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	trent mississippi /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	jim kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe germany /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel israel /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	john morgan /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	brett priceline /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jersey newark /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	newark jersey /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	british columbia /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	peter columbia /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	/people/person/children isaac /people/person/children /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	leningrad vaganova /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico jalisco /location/country/administrative_divisions /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york westchester /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe russia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	syria iran /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida boynton /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	brittany seminole /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	germany germany /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	germany munich /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	switzerland switzerland /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ernst davos /people/deceased_person/place_of_death /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	puerto la /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	eric university /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	germany germany /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	germany stuttgart /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	leslie cbs /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	jeffrey general /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	poland denmark /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	poland cracow /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	roy arizona /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	norm minnesota /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	maine maine /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	south iowa /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	seoul south /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jordan amman /location/country/capital /eop jordan amman /location/location/contains /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert cbs /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	black robert /business/company/founders /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	oklahoma austin /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	arkansas arkadelphia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	navarre spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	australia canada /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	toronto canada /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	staten staten /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	coney york /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	washington university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	port harborside /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	tom iowa /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	gaza gaza /location/country/capital /eos gaza gaza <PAD> <PAD>
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	california california /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	california lawrence /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	paris france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york manhattan /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	lower york /location/neighborhood/neighborhood_of /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe italy /location/location/contains /eop europe <PAD> /location/location/contains /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	california san /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	sonoma occidental /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	leslie nbc /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	christopher security /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india hyderabad /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	sam kansa /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	tommy wisconsin /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	bangkok thailand /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	california california /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	california malibu /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	silicon berkeley /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ayelet berkeley /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa puerto /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	tennessee wichita /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	kathleen kansa /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	york greenwich /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	sam oklahoma /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel west /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	nigeria ghana /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mount tanzania /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	hawaii hangzhou /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ireland athenry /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iran tehran /location/country/capital /eop iran tehran /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	germany frankfurt /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	russia russia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	russia iran /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	university university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	eugene university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	catalonia spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	australia sydney /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	australia port /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chile bolivia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	evo bolivia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	germany berlin /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida north /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	south darlington /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	somalia nairobi /location/country/capital /eop <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	nelson zimbabwe /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel tel /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel ra'anana /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india lahore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india bihar /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	gujarat india /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ohio dayton /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuyahoga cleveland /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jersey trenton /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida gulf /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india mumbai /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india delhi /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy india /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel west /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel tel /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	jerusalem yad /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy italy /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy maranello /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel west /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ohio nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india bihar /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	bashar syria /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	bashar syria /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	louisiana orleans /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	louisiana baton /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	middle iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran middle /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	kai-fu google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	sony akio /business/company/founders /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	shimon israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy india /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy verona /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	calabria crotone /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida florida /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida boca /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	leslie google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	derrick ford /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	boston boston /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chicago west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	virginia virginia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	virginia middleburg /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	oklahoma oklahoma /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	brad oklahoma /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	california california /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	california berkeley /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe germany /location/location/contains <PAD> <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy germany /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chicago chicago /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cook chicago /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	nassau nassau /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	fire ocean /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert cbs /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	shona google /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	france france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	paris france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	juarez mexico /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ehud israel /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel tel /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel rehovot /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	will york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	boston boston /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	juliet boston /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe italy /location/location/contains /eop italy italy /location/location/contains /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jim missouri /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico puebla /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	spain cordoba /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel west /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	toronto university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	toronto mount /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india delhi /location/location/contains /eos india delhi <PAD> <PAD>
# Ground-Truth: 	delhi india /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	alberta calgary /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	canada calgary /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	alberta st /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	russia russia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	nikolay russia /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iraq sadr /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	vali naval /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /location/location/contains /eos <PAD> <PAD> <PAD> /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris paris /people/deceased_person/place_of_death /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	paris ecole /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jordan amman /location/country/capital /eop jordan amman /location/location/contains /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe turkey /location/location/contains /eos <PAD> <PAD> /location/location/contains /eos
# Ground-Truth: 	algeria algiers /location/country/capital /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india lahore /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	india dharamsala /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida florida /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida lake /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	george economic /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	donald washington /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy luxembourg /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	california california /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	dana california /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	germany germany /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	germany nuremberg /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# ...
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico cancun /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	idaho boise /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	idaho salmon /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa ghana /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	west senegal /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york manhattan /location/location/contains /eop <PAD> york <PAD> /eos
# Ground-Truth: 	york staten /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	texas texas /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	stephen blackstone /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ontario vancouver /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ontario kingston /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	vermont mount /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	westport winslow /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	philadelphia philadelphia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	baltimore m&t /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	texas austin /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington walter /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	guanajuato mexico /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	bihar india /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	france france /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	dennis york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	fairfield westport /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	kansa atchison /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	boston massachusetts /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	boston massachusetts /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	california sonoma /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington mount /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	hawaii la /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	washington washington /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington united /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida palm /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida boca /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	spain spain /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	eric philadelphia /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	eddie reebok /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ontario ontario /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ontario st /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida florida /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida ponte /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	seoul south /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida florida /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	florida lake /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	seattle chicago /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chicago sears /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ontario ontario /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	ontario woodbridge /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	washington capitol /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington national /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	somalia lagos /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	guinea conakry /location/country/capital /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ohio canton <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iowa waterloo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy italy /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy amalfi /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy netherlands /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jersey hudson /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	westchester hudson /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	illinois university /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	g. georgia /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	latin cuba /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	berkeley chez /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel gaza /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york missouri /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	tyler york /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy india /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy luxembourg /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	canada ontario /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	detroit st /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	toledo ottawa /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	nigeria lagos /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	namibia windhoek /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york mount /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mamaroneck united /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	vermont vermont /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	vermont stowe /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy france /people/person/nationality /eop <PAD> <PAD> <PAD> /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	belgium moscow /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france toulouse /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iran iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington iran /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	corsica france /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel haifa /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	syria damascus /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	india india /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	shilpa india /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	finland denmark /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	finland turku /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	germany germany /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	germany stuttgart /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	boston beth /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	boston beth /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jim kentucky /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	rockland city /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	robert yale /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	martin national /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	peter virgin /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	toronto barrick /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ohio portland /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	lake chicago /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ontario yale /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	marlborough cytyc /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	france france /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	france alzonne /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	york york /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington national /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	mexico mexico /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	mexico ciudad /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iran iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran syria /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	israel west /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	israel west /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	vermont vermont /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	vermont stowe /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	connecticut connecticut /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	connecticut hamden /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe russia /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	washington iran /location/administrative_division/country /eop russia iran /location/administrative_division/country /eos
# ---
# Predict: 	saudi syria /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	syria iran /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iowa akron /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iowa waverly /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	washington cuba /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	cuba bayamo /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa south /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	aziz south /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	italy turin /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	italy reggio /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	iran iran /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	iran washington /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	ohio boynton /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	hampshire cannon /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	africa santiago /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	helen guatemala /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	afghanistan kandahar /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	romania black /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	europe west /location/location/contains /location/location/contains /location/location/contains /location/location/contains /location/location/contains /location/location/contains
# Ground-Truth: 	iran syria /location/administrative_division/country /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	florida miami /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	decatur agnes /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	north north /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	robin north /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	fidel la /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	imelda philippine /people/person/nationality /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	henry st /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	charles woody /people/person/children /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	virginia university /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	maryland annapolis /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	paris paris /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	paris gare /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	jared economic /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	stephen case /business/person/company /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	boston boston /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	boston church /location/location/contains /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	trent mississippi /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---
# Predict: 	roy missouri /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos <PAD> <PAD> <PAD> <PAD>
# ---

# %% [markdown]
# ## Beam Search Evaluate

# %%
from keras.preprocessing.sequence import pad_sequences
from tqdm import tqdm

# %%
filename = '/Users/lizhn7/Downloads/DATA/nyt/experiment_5_4_pro/cp_logs/att_false/weights.356-1.742565.hdf5'
model.load_weights(filename)

# %%
def greedysearch():
    pred = []
    for i in tqdm(range(395)):
        pR = []
        tag = 0
        fb_words = np.array([word2index['/go']])
        x = np.array([x_test[i]])
    
        for j in range(MAX_ADJL_LEN):
            fb_input = pad_sequences([fb_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
            prob = model.predict(np.concatenate((x, fb_input), axis=-1), batch_size=BATCH_SIZE)[0][j]
            if j in [0, 1, 4, 5]:
                for item in [i for i in x_test[i] if i != 0]:
                    prob[item] = float(prob[item]+1)
            if j in [2, 6]:
                prob[:65135] = -1
            if j == 3:
                prob[:65132] = -1
                prob[65134:] = -1
            if j == 8:
                prob[65133] = float(prob[65133]+1)
            prob[0] = -1
            prob[tag] = -1
            result = prob.argmax()
            tag = result
            pR.append(result)
            fb_words = np.append(fb_words, result)
            if index2word[result] == '/eos':
                break
        pred.append(pR)
        
    pred = [[index2word[i] for i in sent if i != 0] for sent in pred]
    actu = [[index2word[i] for i in sent if i != 0] for sent in y_test]
    e1Count = sum([1 for i in range(395) if actu[i][0] == pred[i][0]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][3] == pred[i][3]])
    e2Count = sum([1 for i in range(395) if actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])
    enCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])      
    reCount = sum([1 for i in range(395) if actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]])
    tripleCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1] and actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]]) 
    print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
    print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
    print('En Accuracy: \t\t%.6f' % (enCount/396))
    print('Re Accuracy: \t\t%.6f' % (reCount/396))
    print('Triple Accuracy: \t%.6f' % (tripleCount/396))        
    for i in range(395):
        print('Predict: \t%s' % ' '.join(pred[i]))
        print('Ground-Truth: \t%s' % ' '.join(actu[i]))
        print('---------')

# %%
greedysearch()
# Out:
# 100%|██████████| 395/395 [08:21<00:00,  1.20s/it]
# E1 Accuracy: 		0.320707
# E2 Accuracy: 		0.292929
# En Accuracy: 		0.164141
# Re Accuracy: 		0.611111
# Triple Accuracy: 	0.101010
# Predict: 	spain france /location/location/contains /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---------
# Predict: 	connecticut westchester /location/location/contains /eos
# Ground-Truth: 	westchester connecticut /location/administrative_division/country /eos
# ---------
# Predict: 	israel amman /location/country/capital /eop israel amman /location/location/contains /eos
# Ground-Truth: 	dalia israel /people/person/nationality /eos
# ---------
# Predict: 	india hyderabad /location/location/contains /eos
# Ground-Truth: 	hyderabad potti /location/location/contains /eos
# ---------
# Predict: 	north bush /people/person/place_lived /eos
# Ground-Truth: 	kent north /people/person/place_lived /eos
# ---------
# Predict: 	ontario waterloo /location/location/contains /eos
# Ground-Truth: 	ontario waterloo /location/location/contains /eos
# ---------
# Predict: 	stephen blackstone /business/person/company /eos
# Ground-Truth: 	blackstone stephen /business/company/founders /eos
# ---------
# Predict: 	spain france /location/location/contains /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	iran russia /people/person/nationality /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	george news /people/person/place_lived /eos
# Ground-Truth: 	george abc /business/person/company /eos
# ---------
# Predict: 	florida jacksonville /location/location/contains /eos
# Ground-Truth: 	florida jacksonville /location/location/contains /eos
# ---------
# Predict: 	nigeria resort /location/location/contains /eos
# Ground-Truth: 	nigeria uyo /location/location/contains /eos
# ---------
# Predict: 	rhode vermont /people/person/place_lived /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---------
# Predict: 	kentucky patrick /location/location/contains /eos
# Ground-Truth: 	patrick huntington /people/person/place_lived /eos
# ---------
# Predict: 	germany berlin /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	a weinberg /business/person/company /eos
# Ground-Truth: 	jeffrey lazard /business/person/company /eos
# ---------
# Predict: 	gaza israel /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	u.s. a /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	york mark /business/person/company /eos
# Ground-Truth: 	mark york /business/person/company /eos
# ---------
# Predict: 	australia netherlands /people/person/nationality /eos
# Ground-Truth: 	markus australia /people/person/nationality /eos
# ---------
# Predict: 	princeton university /business/person/company /eos
# Ground-Truth: 	kwame princeton /business/person/company /eos
# ---------
# Predict: 	deal a /business/person/company /eos
# Ground-Truth: 	endemol john /business/company/founders /eos
# ---------
# Predict: 	state month /people/person/place_lived /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---------
# Predict: 	connecticut haven /people/person/place_lived /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---------
# Predict: 	russia iran /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	india state /location/location/contains /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---------
# Predict: 	bill elliott /location/location/contains /eos
# Ground-Truth: 	bill dawsonville /people/person/place_lived /eos
# ---------
# Predict: 	columbia university /business/person/company /eos
# Ground-Truth: 	daniel university /business/person/company /eos
# ---------
# Predict: 	russia vladimir /location/location/contains /eos
# Ground-Truth: 	soviet russia /location/administrative_division/country /eos
# ---------
# Predict: 	boston johnson /location/location/contains /eos
# Ground-Truth: 	boston wbz-tv /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	a virginia /location/location/contains /eos
# Ground-Truth: 	virginia united /location/administrative_division/country /eos
# ---------
# Predict: 	security ira /business/person/company /eos
# Ground-Truth: 	ira system /business/person/company /eos
# ---------
# Predict: 	a legal /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a hoboken /location/location/contains /eos
# Ground-Truth: 	anthony york /business/person/company /eos
# ---------
# Predict: 	a google /business/person/company /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---------
# Predict: 	evans a /location/location/contains /eos
# Ground-Truth: 	washington bainbridge /location/location/contains /eos
# ---------
# Predict: 	cross lrb /location/location/contains /eos
# Ground-Truth: 	washington olympia /location/location/contains /eos
# ---------
# Predict: 	south seoul /location/location/contains /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---------
# Predict: 	spain mexico /location/location/contains /eop spain mexico /location/location/contains /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	a france /location/country/administrative_divisions /eop a france /location/administrative_division/country /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	a iran /location/location/contains /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	player north /people/person/place_lived /eos
# Ground-Truth: 	kellen colorado /people/person/place_of_birth /eos
# ---------
# Predict: 	united france /people/person/nationality /eos
# Ground-Truth: 	tony france /people/person/nationality /eos
# ---------
# Predict: 	spain luis /people/person/nationality /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---------
# Predict: 	include france /location/location/contains /eop include france /location/location/contains /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	island staten /location/location/contains /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---------
# Predict: 	alternative nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	at&t san /business/person/company /eos
# Ground-Truth: 	ralph at&t /business/person/company /eos
# ---------
# Predict: 	connecticut england /location/location/contains /eos
# Ground-Truth: 	connecticut haven /location/location/contains /eos
# ---------
# Predict: 	somalia hassan /location/location/contains /eos
# Ground-Truth: 	somalia puntland /location/location/contains /eos
# ---------
# Predict: 	riga boris /location/country/capital /eop boris riga /location/location/contains /eos
# Ground-Truth: 	riga latvia /location/administrative_division/country /eos
# ---------
# Predict: 	switzerland tehran /location/location/contains /eos
# Ground-Truth: 	switzerland davos /location/location/contains /eos
# ---------
# Predict: 	free ski /location/location/contains /eos
# Ground-Truth: 	colorado vail /location/location/contains /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	south queen /location/neighborhood/neighborhood_of /eop queen south /location/location/contains /eos
# Ground-Truth: 	lower hudson /location/location/contains /eos
# ---------
# Predict: 	a san /location/neighborhood/neighborhood_of /eop a san /location/location/contains /eos
# Ground-Truth: 	san north /location/location/contains /eos
# ---------
# Predict: 	york county /location/location/contains /eos
# Ground-Truth: 	nassau suffolk /location/administrative_division/country /eos
# ---------
# Predict: 	youtube chad /business/person/company /eos
# Ground-Truth: 	chad youtube /business/person/company /eos
# ---------
# Predict: 	westchester city /location/location/contains /eos
# Ground-Truth: 	westchester kensico /location/location/contains /eos
# ---------
# Predict: 	susan nebraska /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	italy house /location/location/contains /eos
# Ground-Truth: 	italy orvieto /location/location/contains /eos
# ---------
# Predict: 	university greenville /location/location/contains /eos
# Ground-Truth: 	greenville furman /location/location/contains /eos
# ---------
# Predict: 	a princeton /business/person/company /eos
# Ground-Truth: 	charles princeton /business/person/company /eos
# ---------
# Predict: 	ontario canada /location/location/contains /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	israel gaza /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	john baltimore /location/location/contains /eos
# Ground-Truth: 	baltimore john /location/location/contains /eos
# ---------
# Predict: 	a india /location/location/contains /eos
# Ground-Truth: 	samantha india /people/person/place_lived /eos
# ---------
# Predict: 	david kenny /business/person/company /eos
# Ground-Truth: 	david digitas /business/person/company /eos
# ---------
# Predict: 	ohio iowa /people/person/place_lived /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---------
# Predict: 	lebanon syria /people/person/nationality /eos
# Ground-Truth: 	rafik lebanon /people/person/nationality /eos
# ---------
# Predict: 	president abubakar /people/person/nationality /eos
# Ground-Truth: 	atiku nigeria /people/person/nationality /eos
# ---------
# Predict: 	a watching /location/location/contains /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---------
# Predict: 	a florida /location/location/contains /eos
# Ground-Truth: 	florida panama /location/location/contains /eos
# ---------
# Predict: 	iran iraq /location/location/contains /eos
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	percent will /location/location/contains /eop percent will /location/location/contains /eos
# Ground-Truth: 	france spain /location/administrative_division/country /eos
# ---------
# Predict: 	town wall /location/location/contains /eos
# Ground-Truth: 	clarkstown city /location/location/contains /eos
# ---------
# Predict: 	india bangalore /location/location/contains /eos
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---------
# Predict: 	mississippi haley /people/person/place_lived /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	chief jetblue /business/person/company /eos
# Ground-Truth: 	gordon continental /business/person/company /eos
# ---------
# Predict: 	paris france /people/deceased_person/place_of_death /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	san percent /location/location/contains /eos
# Ground-Truth: 	california long /location/location/contains /eos
# ---------
# Predict: 	france george /people/person/nationality /eos
# Ground-Truth: 	france correze /location/location/contains /eos
# ---------
# Predict: 	school county /location/location/contains /eos
# Ground-Truth: 	fairfax westfield /location/location/contains /eos
# ---------
# Predict: 	a palestinian /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	city spain /location/location/contains /eos
# Ground-Truth: 	spain valencia /location/location/contains /eos
# ---------
# Predict: 	iraq a /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	greenwich jefferson /location/location/contains /eos
# Ground-Truth: 	greenwich jefferson /location/location/contains /eos
# ---------
# Predict: 	a hamas /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	france jacques /people/person/nationality /eos
# Ground-Truth: 	jacques france /people/person/nationality /eos
# ---------
# Predict: 	ramapo mahwah /location/location/contains /eos
# Ground-Truth: 	mahwah ramapo /location/location/contains /eos
# ---------
# Predict: 	guyana money /location/location/contains /eos
# Ground-Truth: 	guyana linden /location/location/contains /eos
# ---------
# Predict: 	dr singh /location/location/contains /eos
# Ground-Truth: 	india punjab /location/location/contains /eos
# ---------
# Predict: 	ontario marlene /location/location/contains /eos
# Ground-Truth: 	ontario tobermory /location/location/contains /eos
# ---------
# Predict: 	a iran /location/location/contains /eos
# Ground-Truth: 	middle iran /location/location/contains /eos
# ---------
# Predict: 	a africa /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a france /location/location/contains /eos
# Ground-Truth: 	italy israel /location/administrative_division/country /eos
# ---------
# Predict: 	germany france /location/location/contains /eop france germany /location/location/contains /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---------
# Predict: 	a google /business/person/company /eos
# Ground-Truth: 	chad google /business/person/company /eos
# ---------
# Predict: 	israel palestinian /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	minnesota amy /people/person/place_lived /eos
# Ground-Truth: 	amy minnesota /people/person/place_lived /eos
# ---------
# Predict: 	australian australia /people/person/nationality /eos
# Ground-Truth: 	john australia /people/person/nationality /eos
# ---------
# Predict: 	kentucky ernie /people/person/place_lived /eos
# Ground-Truth: 	ernie kentucky /people/person/place_lived /eos
# ---------
# Predict: 	iran north /location/location/contains /eos
# Ground-Truth: 	iran north /location/administrative_division/country /eos
# ---------
# Predict: 	india economic /location/location/contains /eos
# Ground-Truth: 	india bihar /location/country/administrative_divisions /eos
# ---------
# Predict: 	a ireland /location/location/contains /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---------
# Predict: 	1 cuba /location/location/contains /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	italy house /location/location/contains /eos
# Ground-Truth: 	italy umbria /location/location/contains /eos
# ---------
# Predict: 	italy spain /location/location/contains /eos
# Ground-Truth: 	campania italy /location/administrative_division/country /eos
# ---------
# Predict: 	a iraq /location/location/contains /eos
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---------
# Predict: 	city sahn /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	germany spain /location/location/contains /eos
# Ground-Truth: 	germany spain /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	manhattan cleveland /location/location/contains /eos
# Ground-Truth: 	cleveland karamu /location/location/contains /eos
# ---------
# Predict: 	airport west /location/location/contains /eos
# Ground-Truth: 	ireland county /location/location/contains /eos
# ---------
# Predict: 	school seattle /location/location/contains /eos
# Ground-Truth: 	california san /location/location/contains /eos
# ---------
# Predict: 	france joyce /location/location/contains /eos
# Ground-Truth: 	france albertville /location/location/contains /eos
# ---------
# Predict: 	eastern time /location/location/contains /eos
# Ground-Truth: 	bosnia srebrenica /location/location/contains /eos
# ---------
# Predict: 	a manhattan /location/neighborhood/neighborhood_of /eop a manhattan /location/location/contains /eos
# Ground-Truth: 	upper fort /location/location/contains /eos
# ---------
# Predict: 	chef pic /people/person/nationality /eos
# Ground-Truth: 	france valence /location/location/contains /eos
# ---------
# Predict: 	spain tampa /people/person/nationality /eos
# Ground-Truth: 	james tampa /people/person/place_lived /eos
# ---------
# Predict: 	president house /people/person/nationality /eos
# Ground-Truth: 	syria damascus /location/country/administrative_divisions /eos
# ---------
# Predict: 	a marshall /location/location/contains /eos
# Ground-Truth: 	marshall fremont /people/deceased_person/place_of_death /eos
# ---------
# Predict: 	jerusalem israel /location/country/capital /eop jerusalem israel /location/location/contains /eos
# Ground-Truth: 	israel jerusalem /location/location/contains /eos
# ---------
# Predict: 	sunni syria /location/location/contains /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	cambridge university /location/location/contains /eos
# Ground-Truth: 	cambridge lesley /location/location/contains /eos
# ---------
# Predict: 	australia chris /people/person/nationality /eos
# Ground-Truth: 	chris australia /people/person/nationality /eos
# ---------
# Predict: 	dennis rice /business/person/company /eos
# Ground-Truth: 	dennis disney /business/person/company /eos
# ---------
# Predict: 	aspen company /location/location/contains /eos
# Ground-Truth: 	colorado aspen /location/location/contains /eos
# ---------
# Predict: 	korea seoul /location/location/contains /eos
# Ground-Truth: 	south seoul /location/location/contains /eos
# ---------
# Predict: 	fort staten /location/neighborhood/neighborhood_of /eop staten fort /location/location/contains /eos
# Ground-Truth: 	staten fort /location/location/contains /eos
# ---------
# Predict: 	syria damascus /location/location/contains /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	mexico city /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	a france /people/person/nationality /eos
# Ground-Truth: 	jean-louis france /people/person/nationality /eos
# ---------
# Predict: 	france airbus /location/location/contains /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---------
# Predict: 	jim kentucky /people/person/place_lived /eos
# Ground-Truth: 	jim kentucky /people/person/place_lived /eos
# ---------
# Predict: 	berlin germany /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	israel lebanon /location/location/contains /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	james brett /business/person/company /eos
# Ground-Truth: 	brett priceline /business/person/company /eos
# ---------
# Predict: 	center newark /location/location/contains /eos
# Ground-Truth: 	newark jersey /location/location/contains /eos
# ---------
# Predict: 	peter columbia /business/person/company /eos
# Ground-Truth: 	peter columbia /business/person/company /eos
# ---------
# Predict: 	mikhail academy /people/person/children /eos
# Ground-Truth: 	leningrad vaganova /location/location/contains /eos
# ---------
# Predict: 	a mexico /people/person/nationality /eos
# Ground-Truth: 	mexico jalisco /location/country/administrative_divisions /eos
# ---------
# Predict: 	york westchester /location/location/contains /eos
# Ground-Truth: 	westchester mamaroneck /location/location/contains /eos
# ---------
# Predict: 	europe iran /location/location/contains /eos
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---------
# Predict: 	seminole brittany /location/location/contains /eos
# Ground-Truth: 	brittany seminole /people/person/place_lived /eos
# ---------
# Predict: 	mexico city /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	germany munich /location/location/contains /eos
# Ground-Truth: 	germany munich /location/location/contains /eos
# ---------
# Predict: 	a switzerland /location/location/contains /eos
# Ground-Truth: 	ernst davos /people/deceased_person/place_of_death /eos
# ---------
# Predict: 	a review /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	a baseball /business/person/company /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	germany stuttgart /location/location/contains /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---------
# Predict: 	jeffrey general /business/person/company /eos
# Ground-Truth: 	jeffrey general /business/person/company /eos
# ---------
# Predict: 	a poland /location/location/contains /eos
# Ground-Truth: 	poland cracow /location/location/contains /eos
# ---------
# Predict: 	senator minnesota /people/person/place_lived /eos
# Ground-Truth: 	norm minnesota /people/person/place_lived /eos
# ---------
# Predict: 	iowa hampshire /location/location/contains /eos
# Ground-Truth: 	south iowa /location/administrative_division/country /eos
# ---------
# Predict: 	south seoul /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	kofmehl charleston /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	kofmehl charleston /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	will meet /location/country/capital /eop will meet /location/location/contains /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---------
# Predict: 	black robert /business/person/company /eos
# Ground-Truth: 	black robert /business/company/founders /eos
# ---------
# Predict: 	a arkansas /location/location/contains /eos
# Ground-Truth: 	arkansas arkadelphia /location/location/contains /eos
# ---------
# Predict: 	a spain /location/location/contains /eos
# Ground-Truth: 	navarre spain /location/administrative_division/country /eos
# ---------
# Predict: 	a grant /people/person/nationality /eos
# Ground-Truth: 	toronto canada /location/administrative_division/country /eos
# ---------
# Predict: 	coney brooklyn /location/location/contains /eos
# Ground-Truth: 	coney york /location/location/contains /eos
# ---------
# Predict: 	washington port /location/location/contains /eos
# Ground-Truth: 	port harborside /location/location/contains /eos
# ---------
# Predict: 	iowa tom /people/person/place_lived /eos
# Ground-Truth: 	tom iowa /people/person/place_lived /eos
# ---------
# Predict: 	gaza israel /location/country/capital /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	national california /location/location/contains /eos
# Ground-Truth: 	california lawrence /location/location/contains /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	mexico latin /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	york city /location/location/contains /eos
# Ground-Truth: 	lower york /location/neighborhood/neighborhood_of /eos
# ---------
# Predict: 	cruise lrb /location/location/contains /eop cruise lrb /location/location/contains /eos
# Ground-Truth: 	france italy /location/administrative_division/country /eos
# ---------
# Predict: 	san sonoma /location/location/contains /eos
# Ground-Truth: 	sonoma occidental /location/location/contains /eos
# ---------
# Predict: 	a republican /business/person/company /eos
# Ground-Truth: 	christopher security /business/person/company /eos
# ---------
# Predict: 	a india /location/location/contains /eos
# Ground-Truth: 	india hyderabad /location/location/contains /eos
# ---------
# Predict: 	subject kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	ben nebraska /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	gov rep /people/person/place_lived /eos
# Ground-Truth: 	tommy wisconsin /people/person/place_lived /eos
# ---------
# Predict: 	thailand bangkok /location/location/contains /eos
# Ground-Truth: 	bangkok thailand /location/administrative_division/country /eos
# ---------
# Predict: 	parent foundation /location/location/contains /eos
# Ground-Truth: 	california malibu /location/location/contains /eos
# ---------
# Predict: 	berkeley boy /location/location/contains /eos
# Ground-Truth: 	ayelet berkeley /people/person/place_lived /eos
# ---------
# Predict: 	bay cuba /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	kansa kathleen /location/location/contains /eos
# Ground-Truth: 	kathleen kansa /people/person/place_lived /eos
# ---------
# Predict: 	york greenwich /location/location/contains /eos
# Ground-Truth: 	york greenwich /location/location/contains /eos
# ---------
# Predict: 	senator kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	west bank /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	tanzania mount /location/location/contains /eos
# Ground-Truth: 	mount tanzania /location/administrative_division/country /eos
# ---------
# Predict: 	israel lebanon /location/location/contains /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	ireland county /location/location/contains /eos
# Ground-Truth: 	ireland athenry /location/location/contains /eos
# ---------
# Predict: 	iran tehran /location/country/capital /eop iran tehran /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	germany frankfurt /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	a israel /people/person/nationality /eos
# Ground-Truth: 	israel lebanon /location/administrative_division/country /eos
# ---------
# Predict: 	a russia /location/location/contains /eos
# Ground-Truth: 	russia iran /location/administrative_division/country /eos
# ---------
# Predict: 	a university /location/location/contains /eos
# Ground-Truth: 	eugene university /location/location/contains /eos
# ---------
# Predict: 	spain well /location/location/contains /eos
# Ground-Truth: 	catalonia spain /location/administrative_division/country /eos
# ---------
# Predict: 	australia south /location/location/contains /eos
# Ground-Truth: 	australia port /location/location/contains /eos
# ---------
# Predict: 	a indigenous /people/person/nationality /eos
# Ground-Truth: 	evo bolivia /people/person/nationality /eos
# ---------
# Predict: 	heart berlin /location/location/contains /eos
# Ground-Truth: 	berlin germany /location/administrative_division/country /eos
# ---------
# Predict: 	south carolina /location/location/contains /eos
# Ground-Truth: 	south darlington /location/location/contains /eos
# ---------
# Predict: 	a official /location/country/capital /eop a official /location/location/contains /eos
# Ground-Truth: 	nelson zimbabwe /people/person/nationality /eos
# ---------
# Predict: 	a israel /location/location/contains /eos
# Ground-Truth: 	israel ra'anana /location/location/contains /eos
# ---------
# Predict: 	india state /location/location/contains /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	india a /location/location/contains /eos
# Ground-Truth: 	gujarat india /location/administrative_division/country /eos
# ---------
# Predict: 	cleveland cuyahoga /location/location/contains /eos
# Ground-Truth: 	cuyahoga cleveland /location/location/contains /eos
# ---------
# Predict: 	florida princeton /location/location/contains /eos
# Ground-Truth: 	florida gulf /location/location/contains /eos
# ---------
# Predict: 	india delhi /location/location/contains /eos
# Ground-Truth: 	india delhi /location/location/contains /eos
# ---------
# Predict: 	mexico 30 /location/location/contains /eos
# Ground-Truth: 	mexico mexico /location/location/contains /eos
# ---------
# Predict: 	italy indonesia /location/location/contains /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	a west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	jerusalem museum /location/location/contains /eos
# Ground-Truth: 	jerusalem yad /location/location/contains /eos
# ---------
# Predict: 	ehud israel /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	italy well /location/location/contains /eos
# Ground-Truth: 	italy maranello /location/location/contains /eos
# ---------
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	nebraska ben /people/person/place_lived /eos
# Ground-Truth: 	ben nebraska /people/person/place_lived /eos
# ---------
# Predict: 	africa india /location/location/contains /eos
# Ground-Truth: 	india bihar /location/location/contains /eos
# ---------
# Predict: 	bashar syria /people/person/nationality /eos
# Ground-Truth: 	bashar syria /people/person/nationality /eos
# ---------
# Predict: 	louisiana baton /location/location/contains /eos
# Ground-Truth: 	louisiana baton /location/location/contains /eos
# ---------
# Predict: 	nuclear iran /location/location/contains /eos
# Ground-Truth: 	iran middle /location/administrative_division/country /eos
# ---------
# Predict: 	sony akio /business/person/company /eos
# Ground-Truth: 	sony akio /business/company/founders /eos
# ---------
# Predict: 	israel shimon /people/person/nationality /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---------
# Predict: 	italy indonesia /location/location/contains /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	southern crotone /location/location/contains /eos
# Ground-Truth: 	calabria crotone /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	a claim /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	group m. /business/person/company /eos
# Ground-Truth: 	derrick ford /business/person/company /eos
# ---------
# Predict: 	chicago west /location/location/contains /eos
# Ground-Truth: 	chicago west /location/location/contains /eos
# ---------
# Predict: 	carter virginia /location/location/contains /eos
# Ground-Truth: 	virginia middleburg /location/location/contains /eos
# ---------
# Predict: 	state oklahoma /people/person/place_lived /eos
# Ground-Truth: 	brad oklahoma /people/person/place_lived /eos
# ---------
# Predict: 	california berkeley /location/location/contains /eos
# Ground-Truth: 	california berkeley /location/location/contains /eos
# ---------
# Predict: 	italy germany /location/location/contains /eos
# Ground-Truth: 	italy germany /location/administrative_division/country /eos
# ---------
# Predict: 	chicago state /location/location/contains /eos
# Ground-Truth: 	cook chicago /location/location/contains /eos
# ---------
# Predict: 	suffolk ocean /location/location/contains /eos
# Ground-Truth: 	fire ocean /location/location/contains /eos
# ---------
# Predict: 	mexico mission /people/person/nationality /eos
# Ground-Truth: 	mexico mexico /location/administrative_division/country /eos
# ---------
# Predict: 	republican kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	president chief /business/person/company /eos
# Ground-Truth: 	shona google /business/person/company /eos
# ---------
# Predict: 	france paris /location/location/contains /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	mexico juarez /location/location/contains /eos
# Ground-Truth: 	juarez mexico /location/administrative_division/country /eos
# ---------
# Predict: 	minister work /people/person/nationality /eos
# Ground-Truth: 	ehud israel /people/person/nationality /eos
# ---------
# Predict: 	pavony israel /location/location/contains /eos
# Ground-Truth: 	israel rehovot /location/location/contains /eos
# ---------
# Predict: 	zeitlin york /business/person/company /eos
# Ground-Truth: 	will york /business/person/company /eos
# ---------
# Predict: 	boston college /location/location/contains /eos
# Ground-Truth: 	juliet boston /business/person/company /eos
# ---------
# Predict: 	europe italy /location/location/contains /eop italy france /location/location/contains /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	leader kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	capuchinas mexico /location/location/contains /eos
# Ground-Truth: 	mexico puebla /location/location/contains /eos
# ---------
# Predict: 	lrb rrb /people/person/nationality /eos
# Ground-Truth: 	spain cordoba /location/location/contains /eos
# ---------
# Predict: 	senator kentucky /people/person/place_lived /eos
# Ground-Truth: 	mitch kentucky /people/person/place_lived /eos
# ---------
# Predict: 	israel gaza /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	toronto university /location/location/contains /eos
# Ground-Truth: 	toronto mount /location/location/contains /eos
# ---------
# Predict: 	india delhi /location/location/contains /eos
# Ground-Truth: 	delhi india /location/administrative_division/country /eos
# ---------
# Predict: 	canada calgary /location/location/contains /eos
# Ground-Truth: 	canada calgary /location/location/contains /eos
# ---------
# Predict: 	p.m. canada /location/location/contains /eos
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---------
# Predict: 	woman player /people/person/nationality /eos
# Ground-Truth: 	nikolay russia /people/person/nationality /eos
# ---------
# Predict: 	a sadr /location/location/contains /eos
# Ground-Truth: 	vali naval /business/person/company /eos
# ---------
# Predict: 	spain france /location/location/contains /eos
# Ground-Truth: 	spain italy /location/administrative_division/country /eos
# ---------
# Predict: 	paris de /people/deceased_person/place_of_death /eos
# Ground-Truth: 	paris ecole /location/location/contains /eos
# ---------
# Predict: 	a amman /location/country/capital /eop a amman /location/location/contains /eos
# Ground-Truth: 	jordan amman /location/location/contains /eos
# ---------
# Predict: 	europe a /location/location/contains /eos
# Ground-Truth: 	algeria algiers /location/country/capital /eos
# ---------
# Predict: 	a lhasa /location/location/contains /eos
# Ground-Truth: 	india dharamsala /location/location/contains /eos
# ---------
# Predict: 	florida lake /location/location/contains /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---------
# Predict: 	time washington /business/person/company /eos
# Ground-Truth: 	donald washington /business/person/company /eos
# ---------
# Predict: 	italy spain /location/location/contains /eos
# Ground-Truth: 	ontario canada /location/administrative_division/country /eos
# ---------
# Predict: 	california republican /people/person/place_lived /eos
# Ground-Truth: 	dana california /people/person/place_lived /eos
# ---------
# Predict: 	germany middle /location/location/contains /eos
# Ground-Truth: 	germany nuremberg /location/location/contains /eos
# ---------
# Predict: 	paul israel /business/person/company /eos
# Ground-Truth: 	stanley bank /business/person/company /eos
# ---------
# Predict: 	park battery /location/neighborhood/neighborhood_of /eos
# Ground-Truth: 	lower battery /location/location/contains /eos
# ---------
# Predict: 	lloyd museum /business/person/company /eos
# Ground-Truth: 	frank lloyd /people/person/children /eos
# ---------
# Predict: 	state university /location/location/contains /eos
# Ground-Truth: 	mexico guadalajara /location/location/contains /eos
# ---------
# Predict: 	state lebanon /location/country/capital /eop state lebanon /location/location/contains /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	paris france /location/location/contains /eos
# Ground-Truth: 	france paris /location/location/contains /eos
# ---------
# Predict: 	peck york /location/location/contains /eos
# Ground-Truth: 	york peck /location/location/contains /eos
# ---------
# Predict: 	iran russia /location/location/contains /eos
# Ground-Truth: 	iran russia /location/administrative_division/country /eos
# ---------
# Predict: 	taiwan taipei /location/location/contains /eos
# Ground-Truth: 	taiwan taipei /location/location/contains /eos
# ---------
# Predict: 	sex iraqi /location/location/contains /eos
# Ground-Truth: 	damascus syria /location/administrative_division/country /eos
# ---------
# Predict: 	a spain /location/location/contains /eop a spain /location/location/contains /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	ontario st /location/location/contains /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---------
# Predict: 	israel shimon /people/person/nationality /eos
# Ground-Truth: 	shimon israel /people/person/nationality /eos
# ---------
# Predict: 	a baja /location/location/contains /eos
# Ground-Truth: 	mexico baja /location/location/contains /eos
# ---------
# Predict: 	police india /location/location/contains /eos
# Ground-Truth: 	india chhattisgarh /location/location/contains /eos
# ---------
# Predict: 	michoacan mexico /location/location/contains /eos
# Ground-Truth: 	michoacan mexico /location/administrative_division/country /eos
# ---------
# Predict: 	amansala mexico /location/location/contains /eos
# Ground-Truth: 	mexico tulum /location/location/contains /eos
# ---------
# Predict: 	atlanta university /location/location/contains /eos
# Ground-Truth: 	atlanta georgia /location/location/contains /eos
# ---------
# Predict: 	water year /location/location/contains /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---------
# Predict: 	australia butterfly /people/person/nationality /eos
# Ground-Truth: 	libby australia /people/person/nationality /eos
# ---------
# Predict: 	spain general /people/person/nationality /eos
# Ground-Truth: 	jose spain /people/person/nationality /eos
# ---------
# Predict: 	a iran /location/location/contains /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---------
# Predict: 	mark hewlett-packard /business/person/company /eos
# Ground-Truth: 	mark hewlett-packard /business/person/company /eos
# ---------
# Predict: 	paris national /people/person/place_lived /eos
# Ground-Truth: 	paris musee /location/location/contains /eos
# ---------
# Predict: 	a 1938 /people/person/nationality /eos
# Ground-Truth: 	paris france /location/administrative_division/country /eos
# ---------
# Predict: 	houston harris /location/location/contains /eos
# Ground-Truth: 	harris houston /location/location/contains /eos
# ---------
# Predict: 	a cuba /people/person/nationality /eos
# Ground-Truth: 	havana cuba /location/administrative_division/country /eos
# ---------
# Predict: 	puzzle time /business/person/company /eos
# Ground-Truth: 	will time /business/person/company /eos
# ---------
# Predict: 	israel west /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	york chicago /business/person/company /eos
# Ground-Truth: 	chicago winston /location/location/contains /eos
# ---------
# Predict: 	energy iraq /location/location/contains /eos
# Ground-Truth: 	amory rocky /business/person/company /eos
# ---------
# Predict: 	george rochester /location/location/contains /eos
# Ground-Truth: 	rochester george /location/location/contains /eos
# ---------
# Predict: 	mexico cancun /location/location/contains /eos
# Ground-Truth: 	mexico cancun /location/location/contains /eos
# ---------
# Predict: 	a river /location/location/contains /eos
# Ground-Truth: 	idaho salmon /location/location/contains /eos
# ---------
# Predict: 	africa ghana /location/location/contains /eos
# Ground-Truth: 	west senegal /location/location/contains /eos
# ---------
# Predict: 	a manhattan /location/location/contains /eop a york /location/location/contains /eos
# Ground-Truth: 	york staten /location/location/contains /eos
# ---------
# Predict: 	txu group /business/person/company /eos
# Ground-Truth: 	stephen blackstone /business/person/company /eos
# ---------
# Predict: 	ontario queen /location/location/contains /eos
# Ground-Truth: 	ontario kingston /location/location/contains /eos
# ---------
# Predict: 	park a /location/location/contains /eos
# Ground-Truth: 	westport winslow /location/location/contains /eos
# ---------
# Predict: 	baltimore cornell /location/location/contains /eos
# Ground-Truth: 	baltimore m&t /location/location/contains /eos
# ---------
# Predict: 	washington walter /location/location/contains /eos
# Ground-Truth: 	washington walter /location/location/contains /eos
# ---------
# Predict: 	mexico united /location/location/contains /eos
# Ground-Truth: 	guanajuato mexico /location/administrative_division/country /eos
# ---------
# Predict: 	india northeastern /location/location/contains /eos
# Ground-Truth: 	bihar india /location/administrative_division/country /eos
# ---------
# Predict: 	france italy /people/person/nationality /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	york university /business/person/company /eos
# Ground-Truth: 	dennis york /business/person/company /eos
# ---------
# Predict: 	5 norwalk /location/location/contains /eos
# Ground-Truth: 	kansa atchison /location/location/contains /eos
# ---------
# Predict: 	hospital massachusetts /location/location/contains /eos
# Ground-Truth: 	boston massachusetts /location/location/contains /eos
# ---------
# Predict: 	mount a /location/location/contains /eos
# Ground-Truth: 	washington mount /location/location/contains /eos
# ---------
# Predict: 	bay cuba /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	department right /location/location/contains /eos
# Ground-Truth: 	washington united /location/location/contains /eos
# ---------
# Predict: 	florida boca /location/location/contains /eos
# Ground-Truth: 	florida boca /location/location/contains /eos
# ---------
# Predict: 	free spain /location/location/contains /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	bill white /people/person/place_lived /eos
# Ground-Truth: 	eddie reebok /business/person/company /eos
# ---------
# Predict: 	ontario st /location/location/contains /eos
# Ground-Truth: 	ontario st /location/location/contains /eos
# ---------
# Predict: 	iraq nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	florida john /location/location/contains /eos
# Ground-Truth: 	florida ponte /location/location/contains /eos
# ---------
# Predict: 	korea a /location/location/contains /eos
# Ground-Truth: 	seoul south /location/administrative_division/country /eos
# ---------
# Predict: 	florida lake /location/location/contains /eos
# Ground-Truth: 	florida lake /location/location/contains /eos
# ---------
# Predict: 	miami chicago /location/location/contains /eos
# Ground-Truth: 	chicago sears /location/location/contains /eos
# ---------
# Predict: 	webkinz ontario /location/location/contains /eos
# Ground-Truth: 	ontario woodbridge /location/location/contains /eos
# ---------
# Predict: 	washington national /business/person/company /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---------
# Predict: 	guinea people /location/location/contains /eos
# Ground-Truth: 	guinea conakry /location/country/capital /eos
# ---------
# Predict: 	iowa waterloo /location/location/contains /eos
# Ground-Truth: 	iowa waterloo /location/location/contains /eos
# ---------
# Predict: 	italy sorrento /location/location/contains /eos
# Ground-Truth: 	italy amalfi /location/location/contains /eos
# ---------
# Predict: 	a lrb /people/person/nationality /eos
# Ground-Truth: 	italy france /location/administrative_division/country /eos
# ---------
# Predict: 	jersey hudson /location/location/contains /eos
# Ground-Truth: 	westchester hudson /location/location/contains /eos
# ---------
# Predict: 	a wayne /business/person/company /eos
# Ground-Truth: 	g. georgia /business/person/company /eos
# ---------
# Predict: 	cuba bush /location/location/contains /eos
# Ground-Truth: 	cuba guantanamo /location/location/contains /eos
# ---------
# Predict: 	hill blue /location/location/contains /eos
# Ground-Truth: 	berkeley chez /location/location/contains /eos
# ---------
# Predict: 	israel gaza /location/location/contains /eos
# Ground-Truth: 	gaza israel /location/administrative_division/country /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	photographer time /location/location/contains /eos
# Ground-Truth: 	tyler york /business/person/company /eos
# ---------
# Predict: 	italy indonesia /location/location/contains /eos
# Ground-Truth: 	italy india /location/administrative_division/country /eos
# ---------
# Predict: 	italy spain /location/location/contains /eos
# Ground-Truth: 	canada ontario /location/location/contains /eos
# ---------
# Predict: 	government toledo /location/location/contains /eos
# Ground-Truth: 	toledo ottawa /location/location/contains /eos
# ---------
# Predict: 	namibia windhoek /location/location/contains /eos
# Ground-Truth: 	namibia windhoek /location/location/contains /eos
# ---------
# Predict: 	united mamaroneck /location/location/contains /eos
# Ground-Truth: 	mamaroneck united /location/location/contains /eos
# ---------
# Predict: 	vermont green /location/location/contains /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---------
# Predict: 	work france /people/person/nationality /eop work france /location/location/contains /eos
# Ground-Truth: 	italy spain /location/administrative_division/country /eos
# ---------
# Predict: 	france airbus /location/location/contains /eos
# Ground-Truth: 	france toulouse /location/location/contains /eos
# ---------
# Predict: 	iraq iran /location/location/contains /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eos
# ---------
# Predict: 	france black /location/location/contains /eos
# Ground-Truth: 	corsica france /location/administrative_division/country /eos
# ---------
# Predict: 	syria damascus /location/location/contains /eos
# Ground-Truth: 	syria damascus /location/location/contains /eos
# ---------
# Predict: 	india center /people/person/nationality /eos
# Ground-Truth: 	shilpa india /people/person/nationality /eos
# ---------
# Predict: 	finland a /location/location/contains /eos
# Ground-Truth: 	finland turku /location/location/contains /eos
# ---------
# Predict: 	director germany /location/location/contains /eos
# Ground-Truth: 	germany stuttgart /location/location/contains /eos
# ---------
# Predict: 	boston beth /location/location/contains /eos
# Ground-Truth: 	boston beth /location/location/contains /eos
# ---------
# Predict: 	chairman gov /people/person/place_lived /eos
# Ground-Truth: 	tim minnesota /people/person/place_lived /eos
# ---------
# Predict: 	drexler york /location/location/contains /eos
# Ground-Truth: 	rockland city /location/location/contains /eos
# ---------
# Predict: 	a harvard /business/person/company /eos
# Ground-Truth: 	martin national /business/person/company /eos
# ---------
# Predict: 	peter toronto /business/person/company /eos
# Ground-Truth: 	toronto barrick /location/location/contains /eos
# ---------
# Predict: 	lake chicago /location/location/contains /eos
# Ground-Truth: 	lake chicago /location/administrative_division/country /eos
# ---------
# Predict: 	mass marlborough /location/location/contains /eos
# Ground-Truth: 	marlborough cytyc /location/location/contains /eos
# ---------
# Predict: 	france southern /location/location/contains /eos
# Ground-Truth: 	france alzonne /location/location/contains /eos
# ---------
# Predict: 	african art /location/location/contains /eos
# Ground-Truth: 	washington national /location/location/contains /eos
# ---------
# Predict: 	mexico juarez /location/location/contains /eos
# Ground-Truth: 	mexico ciudad /location/location/contains /eos
# ---------
# Predict: 	american administration /location/location/contains /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	west bank /location/location/contains /eos
# Ground-Truth: 	israel west /location/administrative_division/country /eos
# ---------
# Predict: 	audubon vermont /location/location/contains /eos
# Ground-Truth: 	vermont stowe /location/location/contains /eos
# ---------
# Predict: 	a connecticut /location/location/contains /eos
# Ground-Truth: 	connecticut hamden /location/location/contains /eos
# ---------
# Predict: 	russia system /location/location/contains /eos
# Ground-Truth: 	washington iran /location/administrative_division/country /eop russia iran /location/administrative_division/country /eos
# ---------
# Predict: 	syria iran /location/location/contains /eos
# Ground-Truth: 	syria iran /location/administrative_division/country /eos
# ---------
# Predict: 	a nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	chuck nebraska /people/person/place_lived /eos
# Ground-Truth: 	chuck nebraska /people/person/place_lived /eos
# ---------
# Predict: 	iowa university /location/location/contains /eos
# Ground-Truth: 	iowa waverly /location/location/contains /eos
# ---------
# Predict: 	boston cuba /location/location/contains /eos
# Ground-Truth: 	cuba bayamo /location/location/contains /eos
# ---------
# Predict: 	africa south /people/person/nationality /eos
# Ground-Truth: 	aziz south /people/person/nationality /eos
# ---------
# Predict: 	university italy /location/location/contains /eos
# Ground-Truth: 	italy reggio /location/location/contains /eos
# ---------
# Predict: 	iran washington /location/location/contains /eos
# Ground-Truth: 	iran washington /location/administrative_division/country /eos
# ---------
# Predict: 	park mountain /location/location/contains /eos
# Ground-Truth: 	hampshire cannon /location/location/contains /eos
# ---------
# Predict: 	guatemala helen /people/person/nationality /eos
# Ground-Truth: 	helen guatemala /people/person/place_lived /eos
# ---------
# Predict: 	afghanistan iraq /location/location/contains /eos
# Ground-Truth: 	romania black /location/location/contains /eos
# ---------
# Predict: 	iran syria /location/location/contains /eos
# Ground-Truth: 	iran syria /location/administrative_division/country /eos
# ---------
# Predict: 	college florida /location/location/contains /eos
# Ground-Truth: 	decatur agnes /location/location/contains /eos
# ---------
# Predict: 	natural north /location/location/contains /eos
# Ground-Truth: 	robin north /business/person/company /eos
# ---------
# Predict: 	love philippine /business/person/company /eos
# Ground-Truth: 	imelda philippine /people/person/nationality /eos
# ---------
# Predict: 	harrelson woody /people/person/place_lived /eos
# Ground-Truth: 	charles woody /people/person/children /eos
# ---------
# Predict: 	a maryland /location/location/contains /eos
# Ground-Truth: 	maryland annapolis /location/location/contains /eos
# ---------
# Predict: 	paris gare /location/location/contains /eos
# Ground-Truth: 	paris gare /location/location/contains /eos
# ---------
# Predict: 	good case /business/person/company /eos
# Ground-Truth: 	stephen case /business/person/company /eos
# ---------
# Predict: 	boston bay /location/location/contains /eos
# Ground-Truth: 	boston church /location/location/contains /eos
# ---------
# Predict: 	mississippi haley /people/person/place_lived /eos
# Ground-Truth: 	haley mississippi /people/person/place_lived /eos
# ---------
# Predict: 	democrat missouri /people/person/place_lived /eos
# Ground-Truth: 	sheldon rhode /people/person/place_lived /eos
# ---------

# %%
def beamsearch(NUM_BEAMS):
    pred = []
    for i in tqdm(range(395)):
        fb_words = np.array([word2index['/go']])
        x = np.array([x_test[i]])
    
        st_words = np.array([word2index['/go']])
        st_input = pad_sequences([st_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
        prob = model.predict(np.concatenate((x, st_input), axis=-1), batch_size=BATCH_SIZE)[0][0]
        prob[0] = -1
        for item in [i for i in x_test[i] if i != 0]:
            prob[item] = float(prob[item]+1)
        beam = {}
        for _ in range(NUM_BEAMS):
            b = prob.argmax()
            beam[b] = float(prob[b])
            prob[b] = -1
        
        allResult = []
        for b, s in beam.items():
            pR = [b]
            fb_words = np.append(fb_words, b)
            tag = b
            for j in range(1, MAX_ADJL_LEN):
                fb_input = pad_sequences([fb_words], maxlen=MAX_ADJL_LEN, padding='post', truncating='post')
                prob = model.predict(np.concatenate((x, fb_input), axis=-1), batch_size=BATCH_SIZE)[0][j]
                if j in [1, 4, 5]:
                    for item in [i for i in x_test[i] if i != 0]:
                        prob[item] = float(prob[item]+1)
                if j in [2, 6]:
                    prob[:65135] = -1
                if j == 3:
                    prob[:65132] = -1
                    prob[65134:] = -1
                if j == 8:
                    prob[65133] = float(prob[65133]+1)                
                prob[0] = -1
                prob[tag] = -1
                result = prob.argmax()
                beam[b] += float(prob[result])
                tag = result
                pR.append(result)
                fb_words = np.append(fb_words, result)
                if index2word[result] == '/eos':
                    break
            allResult.append(pR)
        pR = sum([i for i in allResult if i[0] == max(beam, key=lambda x: beam[x])], [])
        pred.append(pR)

    pred = [[index2word[i] for i in sent if i != 0] for sent in pred]
    actu = [[index2word[i] for i in sent if i != 0] for sent in y_test]
    e1Count = sum([1 for i in range(395) if actu[i][0] == pred[i][0]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][3] == pred[i][3]])
    e2Count = sum([1 for i in range(395) if actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])
    enCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][3] == pred[i][3]])      
    reCount = sum([1 for i in range(395) if actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]])
    tripleCount = sum([1 for i in range(395) if actu[i][0] == pred[i][0] and actu[i][1] == pred[i][1] and actu[i][2] == pred[i][2]]) + sum([1 for i in range(372, 373) if actu[i][-4] == pred[i][-4] and actu[i][-3] == pred[i][-3] and actu[i][-2] == pred[i][-2] and actu[i][3] == pred[i][3]]) 
    print('E1 Accuracy: \t\t%.6f' % (e1Count/396))
    print('E2 Accuracy: \t\t%.6f' % (e2Count/396))
    print('En Accuracy: \t\t%.6f' % (enCount/396))
    print('Re Accuracy: \t\t%.6f' % (reCount/396))
    print('Triple Accuracy: \t%.6f' % (tripleCount/396))

# %%
for NUM_BEAMS in range(1, 6):
    beamsearch(NUM_BEAMS)
# Out:
# 100%|██████████| 395/395 [08:13<00:00,  1.13s/it]
#   0%|          | 0/395 [00:00<?, ?it/s]
# E1 Accuracy: 		0.320707
# E2 Accuracy: 		0.292929
# En Accuracy: 		0.164141
# Re Accuracy: 		0.611111
# Triple Accuracy: 	0.101010
# 100%|██████████| 395/395 [13:58<00:00,  1.95s/it]
#   0%|          | 0/395 [00:00<?, ?it/s]
# E1 Accuracy: 		0.401515
# E2 Accuracy: 		0.295455
# En Accuracy: 		0.181818
# Re Accuracy: 		0.611111
# Triple Accuracy: 	0.126263
#  20%|██        | 80/395 [04:18<16:28,  3.14s/it]

# %%
for i in range(395):
    print('Predict: \t%s' % ' '.join(preResult[i]))
    print('Ground-Truth: \t%s' % ' '.join(actResult[i]))
    print('---')
